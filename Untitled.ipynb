# %%
"""
- Rollouts
- Define networks
- GAE
- Utils : Normal distributions and log probability of an action
- train
- logging utilities

Experiment with shared network for both policy and value function
"""

using Flux, CuArrays
using OpenAIGym
import Reinforce.action
import Reinforce:run_episode
import Flux.params
using Flux.Tracker: grad, update!
using Flux: onehot
using Statistics
using Distributed
using Distributions
using LinearAlgebra
using Base.Iterators
using BSON:@save,@load
using JLD

"""
A few intricacies : 
The policy is a Normal distribution and the `policy_net` outputs the `μ` and `logσ`.
Each action is assumed to be independent of the others.
Thus our covariance matrix is a diagonal matrix with each element representing the variance of
taking a particular action.
"""

"""
Utilities
"""
# weight initialization
function _random_normal(shape...)
    return map(Float32,rand(Normal(0,0.1),shape...))
end

function constant_init(shape...)
    return map(Float32,ones(shape...) * 0.1)
end

function normal_log_prob(μ,log_std,a)
    """
    Returns the log probability of an action under a policy Gaussian policy π
    """
    σ = exp.(log_std)
    σ² = σ.^2
    -(((a .- μ).^2)./(2.0 * σ²)) .- log.(sqrt(2 * π)) .- log.(σ)
end

function normal_entropy(log_std)
    0.5 + 0.5 * log(2 * π) .+ log_std
end

function normalise(arr)
    (arr .- mean(arr))./(sqrt(var(arr) + 1e-10))
end

# Logging #
"""
Create logging utility
"""
mutable struct Logger
    hist_dict
end

Logger() = Logger(Dict())

function register(l::Logger,name::String)
     l.hist_dict[name] = []
end

function add(l::Logger,name,value)
    """
    Add a variable for it's history to be logged
    """
    if !(name in l.hist_dict.keys)
        err("Error...")
    else
        push!(l.hist_dict[name],value)
    end
end

"""
HYPERPARAMETERS
"""
# Policy parameters #
η = 3e-4 # Learning rate
STD = 0.0 # Standard deviation
HIDDEN_SIZE = 256
# Environment Variables #
STATE_SIZE = 3
ACTION_SIZE = 1
EPISODE_LENGTH = 20
TEST_STEPS = 10000
# GAE parameters
γ = 0.99
λ = 0.95
# Optimization parameters
PPO_EPOCHS = 4
NUM_EPISODES = 15000
BATCH_SIZE = 5
c₀ = 1.0
c₁ = 0.5
c₂ = 0.001
# PPO parameters
ϵ = 0.2
# FREQUENCIES
SAVE_FREQUENCY = 50

reward_hist = []

mutable struct PendulumPolicy <: Reinforce.AbstractPolicy
  train::Bool

  function PendulumPolicy(train = true)
    new(train)
  end
end

"""
Define the networks
"""
policy_μ = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu;initW = _random_normal,initb=constant_init),
                 Dense(HIDDEN_SIZE,ACTION_SIZE;initW = _random_normal,initb=constant_init)) 
policy_Σ = param(ones(ACTION_SIZE) * STD)

value = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu),
              Dense(HIDDEN_SIZE,1))

# Optimizer
opt = ADAM(η)

function action(state)
    # Acccounting for the element type
    state = reshape(Array(state),length(state),1)

    # Our policy outputs the parameters of a Normal distribution
    μ = policy_μ(state)
    μ = reshape(μ,ACTION_SIZE)
    log_std = policy_Σ
    
    σ² = (exp.(log_std)).^2
    Σ = diagm(0=>σ².data)
    
    dis = MvNormal(μ.data,Σ)
    
    a = rand(dis,ACTION_SIZE)
    a
end

function run_episode(env)
    experience = []
    
    s = reset!(env)
    for i in 1:EPISODE_LENGTH
        a = action(s)
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        
        r,s_ = step!(env,a)
        push!(experience,(s,a,r,s_))
        s = s_
        if env.done
           break 
        end
    end
    experience
end


function test_run(env)
    ep_r = 0.0
    
    s = reset!(env)
    for i in 1:TEST_STEPS
        OpenAIGym.render(env)
        a = action(s)
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        println("Action : $a")
        
        r,s_ = step!(env,a)
        ep_r += r
        
        s = s_
        if env.done
           break 
        end
    end
    ep_r
end
# Out:
# ┌ Info: Recompiling stale cache file /home/shreyas/.julia/compiled/v1.1/Flux/QdkVy.ji for Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1184
# ┌ Info: Recompiling stale cache file /home/shreyas/.julia/compiled/v1.1/CuArrays/7YFE0.ji for CuArrays [3a865a2d-5b23-5a0f-bc46-62713ec82fae]
# └ @ Base loading.jl:1184
# ┌ Warning: Flux is only supported with CuArrays v0.9.
# │ Try running `] pin CuArrays@0.9`.
# └ @ Flux.CUDA /home/shreyas/.julia/packages/Flux/WSB7k/src/cuda/cuda.jl:12
# ┌ Info: Recompiling stale cache file /home/shreyas/.julia/compiled/v1.1/OpenAIGym/V0oOr.ji for OpenAIGym [41d6fcb8-dd24-11e8-2536-c3dc023218b5]
# └ @ Base loading.jl:1184
# WARNING: using Distributions.params in module Main conflicts with an existing identifier.
# ┌ Info: Recompiling stale cache file /home/shreyas/.julia/compiled/v1.1/JLD/l8ijy.ji for JLD [4138dd39-2aa7-5051-a626-17a0bb65d9c8]
# └ @ Base loading.jl:1184
# WARNING: using JLD.@save in module Main conflicts with an existing identifier.
# WARNING: using JLD.@load in module Main conflicts with an existing identifier.
# test_run (generic function with 1 method)

# %%
"""
Rollout collection
"""
num_processes = 16
addprocs(num_processes) 

@everywhere function collect(env)
    run_episode(env)
end

@everywhere function rollout()
  env = GymEnv(:Pendulum,:v0)
  return collect(env)
end

function get_rollouts()
    g = []
    for  w in workers()
      push!(g, rollout())
    end

    rollouts = fetch.(g)
end
# Out:
# get_rollouts (generic function with 1 method)

# %%
function gae(states,actions,rewards,next_states)
    """
    Returns a Generalized Advantage Estimate for an episode
    """
    Â = []
    A = 0.0
    for i in reverse(1:length(states))
        δ = rewards[i] + γ*value(next_states[i]).data[1] - value(states[i]).data[1]
        A = δ + (γ*λ*A)
        push!(Â,A)
    end
    
    Â = reverse(Â)
    return Â
end

function disconunted_returns(rewards)
    r = 0.0
    returns = []
    for i in reverse(1:length(rewards))
        r = rewards[i] + γ*r
        push!(returns,r)
    end
    returns = reverse(returns)
    returns
end

function log_prob_from_actions(states,actions)
    """
    Returns log probabilities of the actions taken
    
    states,actions : episode vairbles in the form of a list
    """
    log_probs = []
    
    for i in 1:length(states)
        μ = reshape(policy_μ(states[i]),ACTION_SIZE).data
        logΣ = policy_Σ.data
        push!(log_probs,normal_log_prob(μ,logΣ,actions[i]))
    end
    
    log_probs
end

function process_rollouts(rollouts)
    """
    rollouts : variable returned by calling `get_rollouts`
    
    Returns : 
    states, actions, rewards for minibatch processing
    """
    # Process the variables
    states = []
    actions = []
    rewards = []
    next_states = []
    advantages = []
    returns = []
    log_probs = []
    
    # Logging statistics
    episode_mean_returns = []
    
    for ro in rollouts
        episode_states = []
        episode_actions = []
        episode_rewards = []
        episode_next_states = []
        
        for i in 1:length(ro)
             push!(episode_states,Array(ro[i][1]))
             push!(episode_actions,ro[i][2])
             push!(episode_rewards,ro[i][3])
             push!(episode_next_states,ro[i][4])
        end
        
#         println("Ep Max A : $(maximum(episode_actions))")
        
        episode_advantages = gae(episode_states,episode_actions,episode_rewards,episode_next_states)
        episode_returns = disconunted_returns(episode_rewards)
        
        push!(episode_mean_returns,mean(episode_returns))
        
        episode_advantages = normalise(episode_advantages)
        
        push!(states,episode_states)
        push!(actions,episode_actions)
        push!(rewards,episode_rewards)
        push!(advantages,episode_advantages)
        push!(returns,episode_returns)
        push!(log_probs,log_prob_from_actions(episode_states,episode_actions))
    end
    
    states = cat(states...,dims=1)
    actions = cat(actions...,dims=1)
    rewards = cat(rewards...,dims=1)
    advantages = cat(advantages...,dims=1)
    returns = cat(returns...,dims=1)
    log_probs = cat(log_probs...,dims=1)
    
    push!(reward_hist,mean(episode_mean_returns))
    println("RETURNS : $(mean(episode_mean_returns))")
    
    return hcat(states...),hcat(actions...),hcat(rewards...),hcat(advantages...),hcat(returns...),hcat(log_probs...)
end
# Out:
# process_rollouts (generic function with 1 method)

# %%
function print_losses(pl,vl,el) 
   println("------")
   println("Policy Loss : $pl")
   println("Value Loss : $vl")
   println("Entropy Loss : $el") 
   println("------")
end

function loss(states,actions,advantages,returns,old_log_probs)
#     println("---")
#     println(size(states))
#     println("States : $states")
#     println("---")
#     println("Actions : $actions")
#     println("---")
    
    μ = policy_μ(states)
    logΣ = policy_Σ
    
#     println("μ : $μ")
#     println("---")
#     println("logΣ : $logΣ")
#     println("---")
    
    new_log_probs = normal_log_prob(μ,logΣ,actions)
#     println("New Log Probs : $new_log_probs")
#     println("Old Log Probs : $old_log_probs")
    
    # Surrogate loss computation
    ratio = exp.(new_log_probs .- old_log_probs)
    surr1 = ratio .* advantages
    surr2 = clamp.(ratio,1.0 - ϵ,1.0 + ϵ)
    policy_loss = mean(min.(surr1,surr2))
    
#     println("Surr1 : $surr1")
#     println("Surr2 : $surr2")
#     println("Policy Loss : $policy_loss")
    
    value_predicted = value(states)
    value_loss = mean((value_predicted .- returns).^2)
#     println("Value Loss : $value_loss")
    
    entropy_loss = mean(normal_entropy(logΣ))
    
#     print_losses(policy_loss.data,value_loss.data,entropy_loss.data)
    
    -c₀*policy_loss + c₁*value_loss - c₂*entropy_loss
end

function ppo_update(states,actions,advantages,returns,old_log_probs)
    # Define model parameters
    model_params = params(params(policy_μ)...,params(policy_Σ)...,params(value)...)

    # Calculate gradients
    gs = Tracker.gradient(() -> loss(states,actions,advantages,returns,old_log_probs),model_params)
#     println("Gradient Done")
    
    # Take a step of optimisation
    update!(opt,model_params,gs)
#     println("Update Done")
end

function train_step()
    routs = get_rollouts()
    states,actions,rewards,advantages,returns,log_probs = process_rollouts(routs)
    
    idxs = partition(1:size(states)[end],BATCH_SIZE)
    
    for epoch in 1:PPO_EPOCHS
#         println("Epoch : $epoch")
        for i in idxs
#             println(i)
            mb_states = states[:,i] 
            mb_actions = actions[:,i] 
            mb_advantages = advantages[:,i] 
            mb_returns = returns[:,i] 
            mb_log_probs = log_probs[:,i]
            
            ppo_update(mb_states,mb_actions,mb_advantages,mb_returns,mb_log_probs)
        end
    end
end

function train()
    for i in 1:NUM_EPISODES
        println("EP : $i")
        train_step()
        println("Ep done")
        
        if i%SAVE_FREQUENCY == 0
            @save "weights/policy_mu.bson" policy_μ
            @save "weights/policy_sigma.bson" policy_Σ
            @save "weights/value.bson" value
            
            save("stats.jld","rewards",reward_hist)
            println("\n\n\n----MAX REWRD SO FAR : $(maximum(reward_hist))---\n\n\n")
        end
    end
end
# Out:
# train (generic function with 1 method)

# %%
train()
# Out:
# EP : 1
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = #GymEnv#1(::Type, ::Type, ::Symbol, ::Symbol) at OpenAIGym.jl:49
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:49
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv(::Symbol, ::Symbol, ::PyCall.PyObject, ::Type) at OpenAIGym.jl:56
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:56
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actions(::GymEnv{PyCall.PyArray{Float64,1}}, ::Nothing) at OpenAIGym.jl:117
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:117
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:88
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:88
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:91
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:91
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:95
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:95
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# RETURNS : -66.2363732956386
# Ep done
# EP : 2
# RETURNS : -68.8290401192988
# Ep done
# EP : 3
# RETURNS : -62.31276541974704
# Ep done
# EP : 4
# RETURNS : -70.77031451788554
# Ep done
# EP : 5
# RETURNS : -61.22629990200464
# Ep done
# EP : 6
# RETURNS : -69.14104832554696
# Ep done
# EP : 7
# RETURNS : -68.84303862454836
# Ep done
# EP : 8
# RETURNS : -57.33112094375506
# Ep done
# EP : 9
# RETURNS : -66.13855118609658
# Ep done
# EP : 10
# RETURNS : -69.66846934017788
# Ep done
# EP : 11
# RETURNS : -52.26338972875693
# Ep done
# EP : 12
# RETURNS : -64.22434899000196
# Ep done
# EP : 13
# RETURNS : -67.85589332178489
# Ep done
# EP : 14
# RETURNS : -65.95817708157342
# Ep done
# EP : 15
# RETURNS : -69.87722569809492
# Ep done
# EP : 16
# RETURNS : -56.75866390996785
# Ep done
# EP : 17
# RETURNS : -62.2884932123113
# Ep done
# EP : 18
# RETURNS : -66.10793914391044
# Ep done
# EP : 19
# RETURNS : -63.67268537552447
# Ep done
# EP : 20
# RETURNS : -59.053902351275696
# Ep done
# EP : 21
# RETURNS : -70.49650798438424
# Ep done
# EP : 22
# RETURNS : -70.00550800408872
# Ep done
# EP : 23
# RETURNS : -67.324887165359
# Ep done
# EP : 24
# RETURNS : -65.47385198623448
# Ep done
# EP : 25
# RETURNS : -60.91414173019521
# Ep done
# EP : 26
# RETURNS : -66.95307162850006
# Ep done
# EP : 27
# RETURNS : -61.685824203064385
# Ep done
# EP : 28
# RETURNS : -69.67193048355527
# Ep done
# EP : 29
# RETURNS : -55.81272410992614
# Ep done
# EP : 30
# RETURNS : -66.86233907858276
# Ep done
# EP : 31
# RETURNS : -67.98831448383753
# Ep done
# EP : 32
# RETURNS : -64.24844923369842
# Ep done
# EP : 33
# RETURNS : -68.16664518757972
# Ep done
# EP : 34
# RETURNS : -66.84922260420416
# Ep done
# EP : 35
# RETURNS : -68.6775732011074
# Ep done
# EP : 36
# RETURNS : -58.5672934085649
# Ep done
# EP : 37
# RETURNS : -70.82070397764136
# Ep done
# EP : 38
# RETURNS : -66.22900290229953
# Ep done
# EP : 39
# RETURNS : -66.34396217525284
# Ep done
# EP : 40
# RETURNS : -69.47653757532888
# Ep done
# EP : 41
# RETURNS : -69.73976112611525
# Ep done
# EP : 42
# RETURNS : -68.70252615991578
# Ep done
# EP : 43
# RETURNS : -68.0508218544467
# Ep done
# EP : 44
# RETURNS : -66.88456681917503
# Ep done
# EP : 45
# RETURNS : -65.38733499411819
# Ep done
# EP : 46
# RETURNS : -53.67535451796261
# Ep done
# EP : 47
# RETURNS : -57.85402771431711
# Ep done
# EP : 48
# RETURNS : -67.69717175991232
# Ep done
# EP : 49
# RETURNS : -57.48921168441339
# Ep done
# EP : 50
# RETURNS : -66.54750218454124
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -52.26338972875693---
#
#
#
# EP : 51
# RETURNS : -62.63108419304449
# Ep done
# EP : 52
# RETURNS : -69.15848512966103
# Ep done
# EP : 53
# RETURNS : -55.1187281179306
# Ep done
# EP : 54
# RETURNS : -69.82062333652732
# Ep done
# EP : 55
# RETURNS : -73.12250548818989
# Ep done
# EP : 56
# RETURNS : -66.54692994681994
# Ep done
# EP : 57
# RETURNS : -62.04357171197145
# Ep done
# EP : 58
# RETURNS : -71.81434260381401
# Ep done
# EP : 59
# RETURNS : -68.45117433006648
# Ep done
# EP : 60
# RETURNS : -64.02699932496404
# Ep done
# EP : 61
# RETURNS : -65.75442628591213
# Ep done
# EP : 62
# RETURNS : -59.51755080942724
# Ep done
# EP : 63
# RETURNS : -57.48618687636321
# Ep done
# EP : 64
# RETURNS : -61.77691215768313
# Ep done
# EP : 65
# RETURNS : -62.499178266854045
# Ep done
# EP : 66
# RETURNS : -66.47426629427443
# Ep done
# EP : 67
# RETURNS : -66.38725432650443
# Ep done
# EP : 68
# RETURNS : -56.84027744473384
# Ep done
# EP : 69
# RETURNS : -47.070601811165254
# Ep done
# EP : 70
# RETURNS : -68.02566133718206
# Ep done
# EP : 71
# RETURNS : -57.57151966699923
# Ep done
# EP : 72
# RETURNS : -58.74890432087497
# Ep done
# EP : 73
# RETURNS : -55.84337400376186
# Ep done
# EP : 74
# RETURNS : -70.83933521655689
# Ep done
# EP : 75
# RETURNS : -60.937965993581265
# Ep done
# EP : 76
# RETURNS : -65.67405843017688
# Ep done
# EP : 77
# RETURNS : -66.19423931502817
# Ep done
# EP : 78
# RETURNS : -65.49546893096773
# Ep done
# EP : 79
# RETURNS : -57.55312057802075
# Ep done
# EP : 80
# RETURNS : -62.88062183783761
# Ep done
# EP : 81
# RETURNS : -62.77881991859546
# Ep done
# EP : 82
# RETURNS : -63.86171251844171
# Ep done
# EP : 83
# RETURNS : -58.25682983571865
# Ep done
# EP : 84
# RETURNS : -66.13753345517843
# Ep done
# EP : 85
# RETURNS : -73.99195005678561
# Ep done
# EP : 86
# RETURNS : -60.400181716994304
# Ep done
# EP : 87
# RETURNS : -72.31911342301983
# Ep done
# EP : 88
# RETURNS : -70.03318638307107
# Ep done
# EP : 89
# RETURNS : -70.51092148078408
# Ep done
# EP : 90
# RETURNS : -72.0517729513918
# Ep done
# EP : 91
# RETURNS : -62.35481237527394
# Ep done
# EP : 92
# RETURNS : -75.70546670574429
# Ep done
# EP : 93
# RETURNS : -66.60268463133366
# Ep done
# EP : 94
# RETURNS : -53.87181613944741
# Ep done
# EP : 95
# RETURNS : -65.53814401307129
# Ep done
# EP : 96
# RETURNS : -66.3996697635577
# Ep done
# EP : 97
# RETURNS : -70.21026307655616
# Ep done
# EP : 98
# RETURNS : -66.28347713071868
# Ep done
# EP : 99
# RETURNS : -60.18765321676803
# Ep done
# EP : 100
# RETURNS : -65.47863106746628
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -47.070601811165254---
#
#
#
# EP : 101
# RETURNS : -68.26504578850056
# Ep done
# EP : 102
# RETURNS : -70.89067885159827
# Ep done
# EP : 103
# RETURNS : -68.44520647265507
# Ep done
# EP : 104
# RETURNS : -66.99521058183456
# Ep done
# EP : 105
# RETURNS : -70.56889160892811
# Ep done
# EP : 106
# RETURNS : -57.515605197046796
# Ep done
# EP : 107
# RETURNS : -60.18479105303195
# Ep done
# EP : 108
# RETURNS : -63.43587748659416
# Ep done
# EP : 109
# RETURNS : -59.60899419768777
# Ep done
# EP : 110
# RETURNS : -62.3617746774631
# Ep done
# EP : 111
# RETURNS : -57.17012714681941
# Ep done
# EP : 112
# RETURNS : -53.47143528529217
# Ep done
# EP : 113
# RETURNS : -72.0379492857192
# Ep done
# EP : 114
# RETURNS : -60.995713546565526
# Ep done
# EP : 115
# RETURNS : -58.60016444768125
# Ep done
# EP : 116
# RETURNS : -58.16458101949343
# Ep done
# EP : 117
# RETURNS : -69.51501235828825
# Ep done
# EP : 118
# RETURNS : -54.29619420377294
# Ep done
# EP : 119
# RETURNS : -72.9194570575424
# Ep done
# EP : 120
# RETURNS : -58.32671304148263
# Ep done
# EP : 121
# RETURNS : -72.31654978223386
# Ep done
# EP : 122
# RETURNS : -64.7778138058941
# Ep done
# EP : 123
# RETURNS : -67.46972093397191
# Ep done
# EP : 124
# RETURNS : -53.78169338575516
# Ep done
# EP : 125
# RETURNS : -57.30700299334062
# Ep done
# EP : 126
# RETURNS : -67.94194342420091
# Ep done
# EP : 127
# RETURNS : -69.17811749400057
# Ep done
# EP : 128
# RETURNS : -57.19167733078741
# Ep done
# EP : 129
# RETURNS : -68.98227475056028
# Ep done
# EP : 130
# RETURNS : -60.52996059367552
# Ep done
# EP : 131
# RETURNS : -55.640543874348076
# Ep done
# EP : 132
# RETURNS : -64.26262540122235
# Ep done
# EP : 133
# RETURNS : -59.783958117824724
# Ep done
# EP : 134
# RETURNS : -63.02671191163249
# Ep done
# EP : 135
# RETURNS : -65.21827805989834
# Ep done
# EP : 136
# RETURNS : -63.28611042374999
# Ep done
# EP : 137
# RETURNS : -67.32882421290736
# Ep done
# EP : 138
# RETURNS : -42.95396921032899
# Ep done
# EP : 139
# RETURNS : -56.074030720639875
# Ep done
# EP : 140
# RETURNS : -63.99926256359444
# Ep done
# EP : 141
# RETURNS : -56.177407166861556
# Ep done
# EP : 142
# RETURNS : -46.40059371543772
# Ep done
# EP : 143
# RETURNS : -53.335548587123455
# Ep done
# EP : 144
# RETURNS : -70.80848124986105
# Ep done
# EP : 145
# RETURNS : -66.40061348431992
# Ep done
# EP : 146
# RETURNS : -62.69248623496428
# Ep done
# EP : 147
# RETURNS : -68.45999394708544
# Ep done
# EP : 148
# RETURNS : -72.49726880933414
# Ep done
# EP : 149
# RETURNS : -61.7034770970555
# Ep done
# EP : 150
# RETURNS : -63.99609130547482
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -42.95396921032899---
#
#
#
# EP : 151
# RETURNS : -72.82886538412639
# Ep done
# EP : 152
# RETURNS : -58.89431956876545
# Ep done
# EP : 153
# RETURNS : -59.32249873184634
# Ep done
# EP : 154
# RETURNS : -55.568393042216435
# Ep done
# EP : 155
# RETURNS : -65.71709765388957
# Ep done
# EP : 156
# RETURNS : -67.12734909697062
# Ep done
# EP : 157
# RETURNS : -59.88380218991605
# Ep done
# EP : 158
# RETURNS : -52.99473720666835
# Ep done
# EP : 159
# RETURNS : -63.57949711462236
# Ep done
# EP : 160
# RETURNS : -62.84114674504579
# Ep done
# EP : 161
# RETURNS : -52.896902844001765
# Ep done
# EP : 162
# RETURNS : -50.78983090026231
# Ep done
# EP : 163
# RETURNS : -69.43906649612522
# Ep done
# EP : 164
# RETURNS : -53.41769285144252
# Ep done
# EP : 165
# RETURNS : -67.08949222438183
# Ep done
# EP : 166
# RETURNS : -58.25120406129528
# Ep done
# EP : 167
# RETURNS : -72.59913348942271
# Ep done
# EP : 168
# RETURNS : -57.662698888426654
# Ep done
# EP : 169
# RETURNS : -60.32513186283195
# Ep done
# EP : 170
# RETURNS : -58.63299401818712
# Ep done
# EP : 171
# RETURNS : -55.4136568743505
# Ep done
# EP : 172
# RETURNS : -62.66505614482547
# Ep done
# EP : 173
# RETURNS : -47.02001617026483
# Ep done
# EP : 174
# RETURNS : -69.50607163417202
# Ep done
# EP : 175
# RETURNS : -66.2499743645573
# Ep done
# EP : 176
# RETURNS : -63.563497011068335
# Ep done
# EP : 177
# RETURNS : -60.64615934025289
# Ep done
# EP : 178
# RETURNS : -64.88289923763138
# Ep done
# EP : 179
# RETURNS : -58.05073575790025
# Ep done
# EP : 180
# RETURNS : -65.9415421751496
# Ep done
# EP : 181
# RETURNS : -67.78057605345298
# Ep done
# EP : 182
# RETURNS : -70.0754950442735
# Ep done
# EP : 183
# RETURNS : -44.70796597398794
# Ep done
# EP : 184
# RETURNS : -62.60684562669485
# Ep done
# EP : 185
# RETURNS : -49.258279198844164
# Ep done
# EP : 186
# RETURNS : -58.78086226343798
# Ep done
# EP : 187
# RETURNS : -67.63507375856261
# Ep done
# EP : 188
# RETURNS : -73.64123763015893
# Ep done
# EP : 189
# RETURNS : -56.98866703683653
# Ep done
# EP : 190
# RETURNS : -63.784281271923106
# Ep done
# EP : 191
# RETURNS : -60.78188573262128
# Ep done
# EP : 192
# RETURNS : -58.913926534579616
# Ep done
# EP : 193
# RETURNS : -59.346316031375146
# Ep done
# EP : 194
# RETURNS : -67.65423016663992
# Ep done
# EP : 195
# RETURNS : -58.52889625486512
# Ep done
# EP : 196
# RETURNS : -51.67320546171081
# Ep done
# EP : 197
# RETURNS : -60.270034601998276
# Ep done
# EP : 198
# RETURNS : -68.22736243479133
# Ep done
# EP : 199
# RETURNS : -62.392420470848364
# Ep done
# EP : 200
# RETURNS : -63.10893737375436
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -42.95396921032899---
#
#
#
# EP : 201
# RETURNS : -68.77127714966593
# Ep done
# EP : 202
# RETURNS : -60.14557326367495
# Ep done
# EP : 203
# RETURNS : -46.824806787787345
# Ep done
# EP : 204
# RETURNS : -52.24964254439499
# Ep done
# EP : 205
# RETURNS : -62.51105138648599
# Ep done
# EP : 206
# RETURNS : -59.83906776830646
# Ep done
# EP : 207
# RETURNS : -66.29193436306602
# Ep done
# EP : 208
# RETURNS : -64.3481823312416
# Ep done
# EP : 209
# RETURNS : -57.30544886503265
# Ep done
# EP : 210
# RETURNS : -66.79466331552246
# Ep done
# EP : 211
# RETURNS : -62.183096771253666
# Ep done
# EP : 212
# RETURNS : -64.45566855768871
# Ep done
# EP : 213
# RETURNS : -64.32721638647239
# Ep done
# EP : 214
# RETURNS : -67.0710103232824
# Ep done
# EP : 215
# RETURNS : -53.72297982043758
# Ep done
# EP : 216
# RETURNS : -67.44891624533551
# Ep done
# EP : 217
# RETURNS : -57.38268281940341
# Ep done
# EP : 218
# RETURNS : -58.67569135582315
# Ep done
# EP : 219
# RETURNS : -44.39690436868934
# Ep done
# EP : 220
# RETURNS : -60.53653457690273
# Ep done
# EP : 221
# RETURNS : -62.24288893989271
# Ep done
# EP : 222
# RETURNS : -54.323747981843866
# Ep done
# EP : 223
# RETURNS : -59.569569374687546
# Ep done
# EP : 224
# RETURNS : -52.34486007872251
# Ep done
# EP : 225
# RETURNS : -65.52394951595454
# Ep done
# EP : 226
# RETURNS : -69.8685181686331
# Ep done
# EP : 227
# RETURNS : -67.41736105603312
# Ep done
# EP : 228
# RETURNS : -50.80627037331485
# Ep done
# EP : 229
# RETURNS : -53.15289626267379
# Ep done
# EP : 230
# RETURNS : -58.46780170364145
# Ep done
# EP : 231
# RETURNS : -59.21729226927152
# Ep done
# EP : 232
# RETURNS : -58.53219700147328
# Ep done
# EP : 233
# RETURNS : -72.93680448476773
# Ep done
# EP : 234
# RETURNS : -63.919487774479386
# Ep done
# EP : 235
# RETURNS : -73.60162944900809
# Ep done
# EP : 236
# RETURNS : -56.39099535773686
# Ep done
# EP : 237
# RETURNS : -71.04608264662657
# Ep done
# EP : 238
# RETURNS : -57.91415126149553
# Ep done
# EP : 239
# RETURNS : -69.60640602903923
# Ep done
# EP : 240
# RETURNS : -60.40049561592472
# Ep done
# EP : 241
# RETURNS : -67.92564782089514
# Ep done
# EP : 242
# RETURNS : -53.07387070105124
# Ep done
# EP : 243
# RETURNS : -56.37742763826713
# Ep done
# EP : 244
# RETURNS : -61.77649822482799
# Ep done
# EP : 245
# RETURNS : -58.00360556547416
# Ep done
# EP : 246
# RETURNS : -56.97277932115836
# Ep done
# EP : 247
# RETURNS : -70.17637999199435
# Ep done
# EP : 248
# RETURNS : -66.37215925556737
# Ep done
# EP : 249
# RETURNS : -65.03085636671199
# Ep done
# EP : 250
# RETURNS : -68.08600008007356
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -42.95396921032899---
#
#
#
# EP : 251
# RETURNS : -63.028148912509124
# Ep done
# EP : 252
# RETURNS : -75.23340217227556
# Ep done
# EP : 253
# RETURNS : -73.19124104434542
# Ep done
# EP : 254
# RETURNS : -65.89188364689348
# Ep done
# EP : 255
# RETURNS : -72.05619677720304
# Ep done
# EP : 256
# RETURNS : -42.998371757535736
# Ep done
# EP : 257
# RETURNS : -57.666730854731775
# Ep done
# EP : 258
# RETURNS : -58.134938672196945
# Ep done
# EP : 259
# RETURNS : -53.5734665582384
# Ep done
# EP : 260
# RETURNS : -69.98413461649837
# Ep done
# EP : 261
# RETURNS : -72.33434612963595
# Ep done
# EP : 262
# RETURNS : -54.18519306791162
# Ep done
# EP : 263
# RETURNS : -61.549084809375074
# Ep done
# EP : 264
# RETURNS : -62.76408680725606
# Ep done
# EP : 265
# RETURNS : -58.244834213500624
# Ep done
# EP : 266
# RETURNS : -57.276475246685486
# Ep done
# EP : 267
# RETURNS : -64.25653551321844
# Ep done
# EP : 268
# RETURNS : -65.99207648599938
# Ep done
# EP : 269
# RETURNS : -59.419988396599486
# Ep done
# EP : 270
# RETURNS : -62.830299535299815
# Ep done
# EP : 271
# RETURNS : -54.99145925270843
# Ep done
# EP : 272
# RETURNS : -53.555701922895544
# Ep done
# EP : 273
# RETURNS : -52.66879585987381
# Ep done
# EP : 274
# RETURNS : -68.0676014052718
# Ep done
# EP : 275
# RETURNS : -69.4831303202863
# Ep done
# EP : 276
# RETURNS : -62.64849002720157
# Ep done
# EP : 277
# RETURNS : -67.66177647545017
# Ep done
# EP : 278
# RETURNS : -61.28076766310511
# Ep done
# EP : 279
# RETURNS : -64.28413785902613
# Ep done
# EP : 280
# RETURNS : -69.21544363724112
# Ep done
# EP : 281
# RETURNS : -70.1045481320999
# Ep done
# EP : 282
# RETURNS : -63.352316908581265
# Ep done
# EP : 283
# RETURNS : -66.75760458410724
# Ep done
# EP : 284
# RETURNS : -66.07251485666372
# Ep done
# EP : 285
# RETURNS : -59.690124134345815
# Ep done
# EP : 286
# RETURNS : -65.66724910609108
# Ep done
# EP : 287
# RETURNS : -63.85351556957732
# Ep done
# EP : 288
# RETURNS : -53.281813061012926
# Ep done
# EP : 289
# RETURNS : -61.162784518458345
# Ep done
# EP : 290
# RETURNS : -69.27277936145974
# Ep done
# EP : 291
# RETURNS : -57.15082459618488
# Ep done
# EP : 292
# RETURNS : -49.997151038516144
# Ep done
# EP : 293
# RETURNS : -70.56147580946147
# Ep done
# EP : 294
# RETURNS : -66.80560462003218
# Ep done
# EP : 295
# RETURNS : -67.9181519848637
# Ep done
# EP : 296
# RETURNS : -58.506125390365085
# Ep done
# EP : 297
# RETURNS : -71.27878868895448
# Ep done
# EP : 298
# RETURNS : -64.90568060983065
# Ep done
# EP : 299
# RETURNS : -55.5023619879839
# Ep done
# EP : 300
# RETURNS : -60.29775384398201
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -42.95396921032899---
#
#
#
# EP : 301
# RETURNS : -56.714461826277734
# Ep done
# EP : 302
# RETURNS : -65.13683519422324
# Ep done
# EP : 303
# RETURNS : -66.71674219971972
# Ep done
# EP : 304
# RETURNS : -70.58940560932469
# Ep done
# EP : 305
# RETURNS : -60.21818842004175
# Ep done
# EP : 306
# RETURNS : -63.052835739216924
# Ep done
# EP : 307
# RETURNS : -61.89391595640932
# Ep done
# EP : 308
# RETURNS : -55.75645189571929
# Ep done
# EP : 309
# RETURNS : -58.91922836842517
# Ep done
# EP : 310
# RETURNS : -66.15341133926643
# Ep done
# EP : 311
# RETURNS : -62.73407119403771
# Ep done
# EP : 312
# RETURNS : -61.641621872287665
# Ep done
# EP : 313
# RETURNS : -61.72698468156997
# Ep done
# EP : 314
# RETURNS : -62.26450435121078
# Ep done
# EP : 315
# RETURNS : -57.049775846339
# Ep done
# EP : 316
# RETURNS : -64.27007906203987
# Ep done
# EP : 317
# RETURNS : -56.698988077830435
# Ep done
# EP : 318
# RETURNS : -65.61251866889143
# Ep done
# EP : 319
# RETURNS : -69.93231569523442
# Ep done
# EP : 320
# RETURNS : -61.28505572035497
# Ep done
# EP : 321
# RETURNS : -68.03286208002999
# Ep done
# EP : 322
# RETURNS : -61.243820161317984
# Ep done
# EP : 323
# RETURNS : -65.66260893302703
# Ep done
# EP : 324
# RETURNS : -65.09007714883312
# Ep done
# EP : 325
# RETURNS : -65.16830449193394
# Ep done
# EP : 326
# RETURNS : -71.14048252856928
# Ep done
# EP : 327
# RETURNS : -58.80328437502934
# Ep done
# EP : 328
# RETURNS : -56.287647166955395
# Ep done
# EP : 329
# RETURNS : -54.004551362095825
# Ep done
# EP : 330
# RETURNS : -53.63107668725589
# Ep done
# EP : 331
# RETURNS : -46.104633711949546
# Ep done
# EP : 332
# RETURNS : -45.73757679964169
# Ep done
# EP : 333
# RETURNS : -60.42973062982499
# Ep done
# EP : 334
# RETURNS : -53.71101904674357
# Ep done
# EP : 335
# RETURNS : -41.775129549361644
# Ep done
# EP : 336
# RETURNS : -63.89437193700708
# Ep done
# EP : 337
# RETURNS : -52.79903363644137
# Ep done
# EP : 338
# RETURNS : -60.533776283784114
# Ep done
# EP : 339
# RETURNS : -66.06753580703273
# Ep done
# EP : 340
# RETURNS : -55.60079576136275
# Ep done
# EP : 341
# RETURNS : -49.397089810971764
# Ep done
# EP : 342
# RETURNS : -63.578143396920126
# Ep done
# EP : 343
# RETURNS : -61.935149146334034
# Ep done
# EP : 344
# RETURNS : -62.55849088529685
# Ep done
# EP : 345
# RETURNS : -66.6859238961707
# Ep done
# EP : 346
# RETURNS : -54.486276409653634
# Ep done
# EP : 347
# RETURNS : -53.500595735618404
# Ep done
# EP : 348
# RETURNS : -63.362413386023945
# Ep done
# EP : 349
# RETURNS : -61.40462384347582
# Ep done
# EP : 350
# RETURNS : -58.65951020379921
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 351
# RETURNS : -70.72611601873797
# Ep done
# EP : 352
# RETURNS : -61.20661869507831
# Ep done
# EP : 353
# RETURNS : -45.042503105618344
# Ep done
# EP : 354
# RETURNS : -65.96841216509762
# Ep done
# EP : 355
# RETURNS : -64.66292311068045
# Ep done
# EP : 356
# RETURNS : -57.709054690371964
# Ep done
# EP : 357
# RETURNS : -64.27466433778436
# Ep done
# EP : 358
# RETURNS : -59.01092307094123
# Ep done
# EP : 359
# RETURNS : -61.12704281004267
# Ep done
# EP : 360
# RETURNS : -60.89030947969475
# Ep done
# EP : 361
# RETURNS : -70.02893261311087
# Ep done
# EP : 362
# RETURNS : -74.62158435551231
# Ep done
# EP : 363
# RETURNS : -57.9098063696535
# Ep done
# EP : 364
# RETURNS : -62.91863202975471
# Ep done
# EP : 365
# RETURNS : -47.51999622124156
# Ep done
# EP : 366
# RETURNS : -61.71247611324324
# Ep done
# EP : 367
# RETURNS : -45.31362970418209
# Ep done
# EP : 368
# RETURNS : -63.59279234374275
# Ep done
# EP : 369
# RETURNS : -67.45245552219043
# Ep done
# EP : 370
# RETURNS : -61.40341835377428
# Ep done
# EP : 371
# RETURNS : -60.82034007107792
# Ep done
# EP : 372
# RETURNS : -65.12314454443442
# Ep done
# EP : 373
# RETURNS : -72.51657980418092
# Ep done
# EP : 374
# RETURNS : -58.2520674242157
# Ep done
# EP : 375
# RETURNS : -61.49183291135557
# Ep done
# EP : 376
# RETURNS : -73.48319123618728
# Ep done
# EP : 377
# RETURNS : -65.5447300762688
# Ep done
# EP : 378
# RETURNS : -65.04174712437495
# Ep done
# EP : 379
# RETURNS : -63.528633081752815
# Ep done
# EP : 380
# RETURNS : -62.56422376821456
# Ep done
# EP : 381
# RETURNS : -64.13995367259015
# Ep done
# EP : 382
# RETURNS : -63.214396979370626
# Ep done
# EP : 383
# RETURNS : -58.81973733784464
# Ep done
# EP : 384
# RETURNS : -52.22117494847961
# Ep done
# EP : 385
# RETURNS : -68.18995596509345
# Ep done
# EP : 386
# RETURNS : -53.989960497578494
# Ep done
# EP : 387
# RETURNS : -61.656950831476536
# Ep done
# EP : 388
# RETURNS : -63.010596255267714
# Ep done
# EP : 389
# RETURNS : -64.35466120641871
# Ep done
# EP : 390
# RETURNS : -61.23599157746745
# Ep done
# EP : 391
# RETURNS : -54.768934389821524
# Ep done
# EP : 392
# RETURNS : -64.47699321471586
# Ep done
# EP : 393
# RETURNS : -66.77408981356103
# Ep done
# EP : 394
# RETURNS : -60.59235903476104
# Ep done
# EP : 395
# RETURNS : -62.632572900128025
# Ep done
# EP : 396
# RETURNS : -63.58609472161458
# Ep done
# EP : 397
# RETURNS : -62.283452834767154
# Ep done
# EP : 398
# RETURNS : -60.88532893223125
# Ep done
# EP : 399
# RETURNS : -57.02748333598472
# Ep done
# EP : 400
# RETURNS : -65.07156171983227
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 401
# RETURNS : -62.6070397954576
# Ep done
# EP : 402
# RETURNS : -74.8800294677169
# Ep done
# EP : 403
# RETURNS : -67.31516248093243
# Ep done
# EP : 404
# RETURNS : -62.318375393955876
# Ep done
# EP : 405
# RETURNS : -64.79360641532685
# Ep done
# EP : 406
# RETURNS : -58.486249266909255
# Ep done
# EP : 407
# RETURNS : -55.47289667121209
# Ep done
# EP : 408
# RETURNS : -63.396111031006946
# Ep done
# EP : 409
# RETURNS : -70.7099113717044
# Ep done
# EP : 410
# RETURNS : -63.751206946579906
# Ep done
# EP : 411
# RETURNS : -54.30136045609753
# Ep done
# EP : 412
# RETURNS : -59.98953122242603
# Ep done
# EP : 413
# RETURNS : -60.381602894131554
# Ep done
# EP : 414
# RETURNS : -53.971746139174655
# Ep done
# EP : 415
# RETURNS : -70.69243642717315
# Ep done
# EP : 416
# RETURNS : -63.539212528605304
# Ep done
# EP : 417
# RETURNS : -55.01288921865235
# Ep done
# EP : 418
# RETURNS : -57.76824536123877
# Ep done
# EP : 419
# RETURNS : -47.313733080060416
# Ep done
# EP : 420
# RETURNS : -56.67105406374617
# Ep done
# EP : 421
# RETURNS : -64.65661341130719
# Ep done
# EP : 422
# RETURNS : -67.5230366987137
# Ep done
# EP : 423
# RETURNS : -53.747935232530956
# Ep done
# EP : 424
# RETURNS : -67.82255213201323
# Ep done
# EP : 425
# RETURNS : -54.743699646608476
# Ep done
# EP : 426
# RETURNS : -62.370049078279166
# Ep done
# EP : 427
# RETURNS : -63.776880324002605
# Ep done
# EP : 428
# RETURNS : -49.810895619575696
# Ep done
# EP : 429
# RETURNS : -58.577004809975236
# Ep done
# EP : 430
# RETURNS : -53.501962873417284
# Ep done
# EP : 431
# RETURNS : -71.92550856205767
# Ep done
# EP : 432
# RETURNS : -58.79156015294845
# Ep done
# EP : 433
# RETURNS : -66.76648164997522
# Ep done
# EP : 434
# RETURNS : -66.71655633666695
# Ep done
# EP : 435
# RETURNS : -73.50585949011801
# Ep done
# EP : 436
# RETURNS : -62.291985631804096
# Ep done
# EP : 437
# RETURNS : -60.73141059980714
# Ep done
# EP : 438
# RETURNS : -62.40542788103115
# Ep done
# EP : 439
# RETURNS : -71.24168463316109
# Ep done
# EP : 440
# RETURNS : -68.9175660623798
# Ep done
# EP : 441
# RETURNS : -64.44302000560003
# Ep done
# EP : 442
# RETURNS : -53.813661338699134
# Ep done
# EP : 443
# RETURNS : -56.19406572940019
# Ep done
# EP : 444
# RETURNS : -67.17930579797739
# Ep done
# EP : 445
# RETURNS : -62.391192793382785
# Ep done
# EP : 446
# RETURNS : -54.960278837220976
# Ep done
# EP : 447
# RETURNS : -56.669388163466245
# Ep done
# EP : 448
# RETURNS : -60.066672601888634
# Ep done
# EP : 449
# RETURNS : -57.72146503022264
# Ep done
# EP : 450
# RETURNS : -54.88154881254718
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 451
# RETURNS : -73.84845599652274
# Ep done
# EP : 452
# RETURNS : -57.34564087535737
# Ep done
# EP : 453
# RETURNS : -67.82312841043301
# Ep done
# EP : 454
# RETURNS : -64.28090654856011
# Ep done
# EP : 455
# RETURNS : -52.51891820817269
# Ep done
# EP : 456
# RETURNS : -62.56232300407257
# Ep done
# EP : 457
# RETURNS : -62.11345027388813
# Ep done
# EP : 458
# RETURNS : -63.24504297840497
# Ep done
# EP : 459
# RETURNS : -74.90629860683914
# Ep done
# EP : 460
# RETURNS : -53.38681266678904
# Ep done
# EP : 461
# RETURNS : -65.97678701438431
# Ep done
# EP : 462
# RETURNS : -57.67686646337114
# Ep done
# EP : 463
# RETURNS : -61.921874625708696
# Ep done
# EP : 464
# RETURNS : -70.09139316864491
# Ep done
# EP : 465
# RETURNS : -63.66805686533071
# Ep done
# EP : 466
# RETURNS : -66.66335173392065
# Ep done
# EP : 467
# RETURNS : -57.70378268680004
# Ep done
# EP : 468
# RETURNS : -61.76799819579804
# Ep done
# EP : 469
# RETURNS : -58.269253621688804
# Ep done
# EP : 470
# RETURNS : -56.17333583946518
# Ep done
# EP : 471
# RETURNS : -64.76846269400286
# Ep done
# EP : 472
# RETURNS : -52.267284299442665
# Ep done
# EP : 473
# RETURNS : -63.307407926974854
# Ep done
# EP : 474
# RETURNS : -65.93776011852088
# Ep done
# EP : 475
# RETURNS : -70.21821415448959
# Ep done
# EP : 476
# RETURNS : -68.7779335169078
# Ep done
# EP : 477
# RETURNS : -70.56846265382592
# Ep done
# EP : 478
# RETURNS : -68.02630372157121
# Ep done
# EP : 479
# RETURNS : -62.2844669879445
# Ep done
# EP : 480
# RETURNS : -72.83049851861297
# Ep done
# EP : 481
# RETURNS : -67.79712917194843
# Ep done
# EP : 482
# RETURNS : -61.70585029969687
# Ep done
# EP : 483
# RETURNS : -70.57030634643985
# Ep done
# EP : 484
# RETURNS : -66.03851678495317
# Ep done
# EP : 485
# RETURNS : -63.01702860587775
# Ep done
# EP : 486
# RETURNS : -69.70077002934165
# Ep done
# EP : 487
# RETURNS : -66.96449883534112
# Ep done
# EP : 488
# RETURNS : -65.31168772407607
# Ep done
# EP : 489
# RETURNS : -69.27638919172671
# Ep done
# EP : 490
# RETURNS : -67.56371502342947
# Ep done
# EP : 491
# RETURNS : -67.39435443988421
# Ep done
# EP : 492
# RETURNS : -70.98063716720807
# Ep done
# EP : 493
# RETURNS : -63.60171979135238
# Ep done
# EP : 494
# RETURNS : -63.79161820623328
# Ep done
# EP : 495
# RETURNS : -70.49597486515637
# Ep done
# EP : 496
# RETURNS : -65.61967873766717
# Ep done
# EP : 497
# RETURNS : -66.58324248886214
# Ep done
# EP : 498
# RETURNS : -71.30069908199852
# Ep done
# EP : 499
# RETURNS : -66.2201776434567
# Ep done
# EP : 500
# RETURNS : -70.4194615518499
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 501
# RETURNS : -61.459907926191846
# Ep done
# EP : 502
# RETURNS : -63.301589506389085
# Ep done
# EP : 503
# RETURNS : -67.63998758999998
# Ep done
# EP : 504
# RETURNS : -74.54158442293401
# Ep done
# EP : 505
# RETURNS : -62.936299815501364
# Ep done
# EP : 506
# RETURNS : -66.30360932161692
# Ep done
# EP : 507
# RETURNS : -64.4326195130625
# Ep done
# EP : 508
# RETURNS : -68.84610091909212
# Ep done
# EP : 509
# RETURNS : -72.91390422840894
# Ep done
# EP : 510
# RETURNS : -75.88842493466103
# Ep done
# EP : 511
# RETURNS : -58.99615271193511
# Ep done
# EP : 512
# RETURNS : -64.22187984108494
# Ep done
# EP : 513
# RETURNS : -61.52541095179154
# Ep done
# EP : 514
# RETURNS : -62.73681213441026
# Ep done
# EP : 515
# RETURNS : -71.91636479942149
# Ep done
# EP : 516
# RETURNS : -63.28987665430787
# Ep done
# EP : 517
# RETURNS : -69.96851874583844
# Ep done
# EP : 518
# RETURNS : -65.25773963393135
# Ep done
# EP : 519
# RETURNS : -60.286373343683955
# Ep done
# EP : 520
# RETURNS : -63.39824160391757
# Ep done
# EP : 521
# RETURNS : -61.24113290702832
# Ep done
# EP : 522
# RETURNS : -60.371728245606555
# Ep done
# EP : 523
# RETURNS : -63.71773256999189
# Ep done
# EP : 524
# RETURNS : -63.88188465324285
# Ep done
# EP : 525
# RETURNS : -59.485385980472245
# Ep done
# EP : 526
# RETURNS : -56.39917106190152
# Ep done
# EP : 527
# RETURNS : -58.860534226997544
# Ep done
# EP : 528
# RETURNS : -65.70219951609332
# Ep done
# EP : 529
# RETURNS : -63.02100786897868
# Ep done
# EP : 530
# RETURNS : -49.92532428758173
# Ep done
# EP : 531
# RETURNS : -69.66370599972286
# Ep done
# EP : 532
# RETURNS : -56.72829306074124
# Ep done
# EP : 533
# RETURNS : -67.18744621951146
# Ep done
# EP : 534
# RETURNS : -69.81441994696966
# Ep done
# EP : 535
# RETURNS : -70.26171593315426
# Ep done
# EP : 536
# RETURNS : -66.51574514034948
# Ep done
# EP : 537
# RETURNS : -46.78637409920843
# Ep done
# EP : 538
# RETURNS : -63.55704026352813
# Ep done
# EP : 539
# RETURNS : -61.465425478340535
# Ep done
# EP : 540
# RETURNS : -65.8934266028168
# Ep done
# EP : 541
# RETURNS : -56.249963373378776
# Ep done
# EP : 542
# RETURNS : -57.54744564867669
# Ep done
# EP : 543
# RETURNS : -43.52761949185583
# Ep done
# EP : 544
# RETURNS : -59.41175924003247
# Ep done
# EP : 545
# RETURNS : -72.03177475273898
# Ep done
# EP : 546
# RETURNS : -56.67289748795333
# Ep done
# EP : 547
# RETURNS : -66.77807974000179
# Ep done
# EP : 548
# RETURNS : -61.3044981381413
# Ep done
# EP : 549
# RETURNS : -55.23511035695404
# Ep done
# EP : 550
# RETURNS : -63.34471773381664
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 551
# RETURNS : -56.321720306776896
# Ep done
# EP : 552
# RETURNS : -63.865710503150034
# Ep done
# EP : 553
# RETURNS : -60.210380019598254
# Ep done
# EP : 554
# RETURNS : -60.6936479453648
# Ep done
# EP : 555
# RETURNS : -71.19476041164285
# Ep done
# EP : 556
# RETURNS : -51.77996517400092
# Ep done
# EP : 557
# RETURNS : -63.71882064908144
# Ep done
# EP : 558
# RETURNS : -58.65158101472794
# Ep done
# EP : 559
# RETURNS : -65.9887533399062
# Ep done
# EP : 560
# RETURNS : -59.54915216721645
# Ep done
# EP : 561
# RETURNS : -58.506925018918
# Ep done
# EP : 562
# RETURNS : -68.22726268937731
# Ep done
# EP : 563
# RETURNS : -69.87391153105297
# Ep done
# EP : 564
# RETURNS : -56.59059484698979
# Ep done
# EP : 565
# RETURNS : -68.12935978226686
# Ep done
# EP : 566
# RETURNS : -63.96198644624314
# Ep done
# EP : 567
# RETURNS : -74.23832025962886
# Ep done
# EP : 568
# RETURNS : -64.85299010895085
# Ep done
# EP : 569
# RETURNS : -63.67630728486763
# Ep done
# EP : 570
# RETURNS : -72.62182979765943
# Ep done
# EP : 571
# RETURNS : -70.43185749247596
# Ep done
# EP : 572
# RETURNS : -60.205192578548505
# Ep done
# EP : 573
# RETURNS : -63.528428859992026
# Ep done
# EP : 574
# RETURNS : -68.58588667223432
# Ep done
# EP : 575
# RETURNS : -59.78903523680274
# Ep done
# EP : 576
# RETURNS : -62.57309444631791
# Ep done
# EP : 577
# RETURNS : -70.44218044592796
# Ep done
# EP : 578
# RETURNS : -64.16225678939661
# Ep done
# EP : 579
# RETURNS : -71.21412898303124
# Ep done
# EP : 580
# RETURNS : -69.11917751228201
# Ep done
# EP : 581
# RETURNS : -68.40371718929939
# Ep done
# EP : 582
# RETURNS : -61.39047481882099
# Ep done
# EP : 583
# RETURNS : -69.01867439155443
# Ep done
# EP : 584
# RETURNS : -75.63295689447966
# Ep done
# EP : 585
# RETURNS : -73.71794143402796
# Ep done
# EP : 586
# RETURNS : -70.76021458310689
# Ep done
# EP : 587
# RETURNS : -65.95014015700579
# Ep done
# EP : 588
# RETURNS : -66.1368934957657
# Ep done
# EP : 589
# RETURNS : -67.43939388309613
# Ep done
# EP : 590
# RETURNS : -67.00662890125334
# Ep done
# EP : 591
# RETURNS : -64.07714314757186
# Ep done
# EP : 592
# RETURNS : -57.93687211783886
# Ep done
# EP : 593
# RETURNS : -68.98144642903799
# Ep done
# EP : 594
# RETURNS : -74.90768383025011
# Ep done
# EP : 595
# RETURNS : -68.0762635526853
# Ep done
# EP : 596
# RETURNS : -71.70299135017083
# Ep done
# EP : 597
# RETURNS : -64.1765461219114
# Ep done
# EP : 598
# RETURNS : -64.20030424134116
# Ep done
# EP : 599
# RETURNS : -73.77971221303613
# Ep done
# EP : 600
# RETURNS : -69.80354200279523
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 601
# RETURNS : -65.94665370755217
# Ep done
# EP : 602
# RETURNS : -69.38576524691418
# Ep done
# EP : 603
# RETURNS : -68.87379504774556
# Ep done
# EP : 604
# RETURNS : -68.0697757523816
# Ep done
# EP : 605
# RETURNS : -70.996456966974
# Ep done
# EP : 606
# RETURNS : -68.2032182410426
# Ep done
# EP : 607
# RETURNS : -65.54921493405519
# Ep done
# EP : 608
# RETURNS : -68.23136079094498
# Ep done
# EP : 609
# RETURNS : -65.212576411023
# Ep done
# EP : 610
# RETURNS : -69.27485027942042
# Ep done
# EP : 611
# RETURNS : -58.62571340485406
# Ep done
# EP : 612
# RETURNS : -71.8037947783599
# Ep done
# EP : 613
# RETURNS : -65.10460206091254
# Ep done
# EP : 614
# RETURNS : -70.22958081398374
# Ep done
# EP : 615
# RETURNS : -73.73834423252119
# Ep done
# EP : 616
# RETURNS : -74.31882926025867
# Ep done
# EP : 617
# RETURNS : -68.71015760009999
# Ep done
# EP : 618
# RETURNS : -76.40718619794517
# Ep done
# EP : 619
# RETURNS : -64.98070119447615
# Ep done
# EP : 620
# RETURNS : -65.3653089227117
# Ep done
# EP : 621
# RETURNS : -62.31488406507261
# Ep done
# EP : 622
# RETURNS : -64.84346217602021
# Ep done
# EP : 623
# RETURNS : -71.85900623030318
# Ep done
# EP : 624
# RETURNS : -71.15204215089244
# Ep done
# EP : 625
# RETURNS : -72.80931797829815
# Ep done
# EP : 626
# RETURNS : -61.6556447521469
# Ep done
# EP : 627
# RETURNS : -57.71289089530763
# Ep done
# EP : 628
# RETURNS : -72.15460276402932
# Ep done
# EP : 629
# RETURNS : -68.07005960081445
# Ep done
# EP : 630
# RETURNS : -57.36773844669606
# Ep done
# EP : 631
# RETURNS : -62.57496546766348
# Ep done
# EP : 632
# RETURNS : -66.63463584862578
# Ep done
# EP : 633
# RETURNS : -67.10567201412921
# Ep done
# EP : 634
# RETURNS : -70.63429160886272
# Ep done
# EP : 635
# RETURNS : -69.5761786772383
# Ep done
# EP : 636
# RETURNS : -76.07009538296548
# Ep done
# EP : 637
# RETURNS : -64.92948089187165
# Ep done
# EP : 638
# RETURNS : -62.98378864872596
# Ep done
# EP : 639
# RETURNS : -69.31455586049078
# Ep done
# EP : 640
# RETURNS : -63.49592124063643
# Ep done
# EP : 641
# RETURNS : -57.45316698787375
# Ep done
# EP : 642
# RETURNS : -67.02568112837214
# Ep done
# EP : 643
# RETURNS : -64.70245327439943
# Ep done
# EP : 644
# RETURNS : -67.87812954342078
# Ep done
# EP : 645
# RETURNS : -65.7228123322765
# Ep done
# EP : 646
# RETURNS : -67.9017396414696
# Ep done
# EP : 647
# RETURNS : -62.065795928412875
# Ep done
# EP : 648
# RETURNS : -63.88915245169912
# Ep done
# EP : 649
# RETURNS : -61.352521491899225
# Ep done
# EP : 650
# RETURNS : -59.95282406557358
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 651
# RETURNS : -60.06396602923926
# Ep done
# EP : 652
# RETURNS : -70.5483990553628
# Ep done
# EP : 653
# RETURNS : -66.85813561795351
# Ep done
# EP : 654
# RETURNS : -67.36283730387956
# Ep done
# EP : 655
# RETURNS : -59.20462688772146
# Ep done
# EP : 656
# RETURNS : -48.96866248618303
# Ep done
# EP : 657
# RETURNS : -64.48727092041193
# Ep done
# EP : 658
# RETURNS : -66.058126060649
# Ep done
# EP : 659
# RETURNS : -69.69533116202032
# Ep done
# EP : 660
# RETURNS : -74.20610161824223
# Ep done
# EP : 661
# RETURNS : -64.00113990518533
# Ep done
# EP : 662
# RETURNS : -66.88764479134832
# Ep done
# EP : 663
# RETURNS : -64.85043140117072
# Ep done
# EP : 664
# RETURNS : -57.90705074632361
# Ep done
# EP : 665
# RETURNS : -55.19110806133356
# Ep done
# EP : 666
# RETURNS : -64.59359873058338
# Ep done
# EP : 667
# RETURNS : -66.28341698408087
# Ep done
# EP : 668
# RETURNS : -66.32252349581434
# Ep done
# EP : 669
# RETURNS : -60.74429419411524
# Ep done
# EP : 670
# RETURNS : -71.76635929994254
# Ep done
# EP : 671
# RETURNS : -66.44792787660113
# Ep done
# EP : 672
# RETURNS : -70.07467429934404
# Ep done
# EP : 673
# RETURNS : -66.92480365133903
# Ep done
# EP : 674
# RETURNS : -68.93160557704624
# Ep done
# EP : 675
# RETURNS : -65.09398125297558
# Ep done
# EP : 676
# RETURNS : -75.09142214059547
# Ep done
# EP : 677
# RETURNS : -73.54989074078959
# Ep done
# EP : 678
# RETURNS : -71.9973116759063
# Ep done
# EP : 679
# RETURNS : -63.30557536814349
# Ep done
# EP : 680
# RETURNS : -73.6415905451906
# Ep done
# EP : 681
# RETURNS : -69.52496157442997
# Ep done
# EP : 682
# RETURNS : -66.07697205853319
# Ep done
# EP : 683
# RETURNS : -65.80697384054538
# Ep done
# EP : 684
# RETURNS : -64.86131653051078
# Ep done
# EP : 685
# RETURNS : -73.04994813782929
# Ep done
# EP : 686
# RETURNS : -66.44290439909503
# Ep done
# EP : 687
# RETURNS : -75.02751515100552
# Ep done
# EP : 688
# RETURNS : -69.13641144315868
# Ep done
# EP : 689
# RETURNS : -72.56791191265627
# Ep done
# EP : 690
# RETURNS : -68.66773203055573
# Ep done
# EP : 691
# RETURNS : -70.28326691170233
# Ep done
# EP : 692
# RETURNS : -67.98942939338632
# Ep done
# EP : 693
# RETURNS : -73.80169605255446
# Ep done
# EP : 694
# RETURNS : -61.889375203999855
# Ep done
# EP : 695
# RETURNS : -65.74285519411845
# Ep done
# EP : 696
# RETURNS : -67.52944592494052
# Ep done
# EP : 697
# RETURNS : -68.47504637960833
# Ep done
# EP : 698
# RETURNS : -65.56095961986111
# Ep done
# EP : 699
# RETURNS : -73.12304995908377
# Ep done
# EP : 700
# RETURNS : -72.33606347659538
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 701
# RETURNS : -60.69093773056392
# Ep done
# EP : 702
# RETURNS : -68.25154606855037
# Ep done
# EP : 703
# RETURNS : -62.90883214599145
# Ep done
# EP : 704
# RETURNS : -70.62949073949812
# Ep done
# EP : 705
# RETURNS : -58.48789393637016
# Ep done
# EP : 706
# RETURNS : -68.12061304952695
# Ep done
# EP : 707
# RETURNS : -66.42157340700544
# Ep done
# EP : 708
# RETURNS : -69.0721039477632
# Ep done
# EP : 709
# RETURNS : -67.97652776866309
# Ep done
# EP : 710
# RETURNS : -75.32082107997316
# Ep done
# EP : 711
# RETURNS : -67.83887701332158
# Ep done
# EP : 712
# RETURNS : -69.71733263235015
# Ep done
# EP : 713
# RETURNS : -60.738578280787465
# Ep done
# EP : 714
# RETURNS : -66.35344953135798
# Ep done
# EP : 715
# RETURNS : -67.07747740211633
# Ep done
# EP : 716
# RETURNS : -72.85088854250385
# Ep done
# EP : 717
# RETURNS : -68.50447863402964
# Ep done
# EP : 718
# RETURNS : -63.364273667751135
# Ep done
# EP : 719
# RETURNS : -71.56324733540137
# Ep done
# EP : 720
# RETURNS : -70.98837932119598
# Ep done
# EP : 721
# RETURNS : -70.48891634122064
# Ep done
# EP : 722
# RETURNS : -67.95383456343312
# Ep done
# EP : 723
# RETURNS : -70.59203194721167
# Ep done
# EP : 724
# RETURNS : -70.80350092676123
# Ep done
# EP : 725
# RETURNS : -61.916020920162
# Ep done
# EP : 726
# RETURNS : -74.48161336857768
# Ep done
# EP : 727
# RETURNS : -69.73851300615208
# Ep done
# EP : 728
# RETURNS : -76.23407237445302
# Ep done
# EP : 729
# RETURNS : -60.34656496801431
# Ep done
# EP : 730
# RETURNS : -75.0499244991734
# Ep done
# EP : 731
# RETURNS : -72.97133608066346
# Ep done
# EP : 732
# RETURNS : -66.94617072114886
# Ep done
# EP : 733
# RETURNS : -64.71970462983892
# Ep done
# EP : 734
# RETURNS : -68.412698752754
# Ep done
# EP : 735
# RETURNS : -69.23189916731893
# Ep done
# EP : 736
# RETURNS : -71.59831879806245
# Ep done
# EP : 737
# RETURNS : -62.10452298898702
# Ep done
# EP : 738
# RETURNS : -73.9804685580055
# Ep done
# EP : 739
# RETURNS : -72.15051919572385
# Ep done
# EP : 740
# RETURNS : -72.20238976128927
# Ep done
# EP : 741
# RETURNS : -72.92301578919675
# Ep done
# EP : 742
# RETURNS : -65.22581909722514
# Ep done
# EP : 743
# RETURNS : -76.41171434174797
# Ep done
# EP : 744
# RETURNS : -75.38958478268451
# Ep done
# EP : 745
# RETURNS : -75.70571454214542
# Ep done
# EP : 746
# RETURNS : -68.09607970026313
# Ep done
# EP : 747
# RETURNS : -66.92055760393573
# Ep done
# EP : 748
# RETURNS : -68.8334533080943
# Ep done
# EP : 749
# RETURNS : -75.76899443136887
# Ep done
# EP : 750
# RETURNS : -61.92632585398513
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 751
# RETURNS : -72.81678831643944
# Ep done
# EP : 752
# RETURNS : -57.93815970107753
# Ep done
# EP : 753
# RETURNS : -68.4181256761448
# Ep done
# EP : 754
# RETURNS : -59.88268089669091
# Ep done
# EP : 755
# RETURNS : -71.83892252042213
# Ep done
# EP : 756
# RETURNS : -69.8420416519229
# Ep done
# EP : 757
# RETURNS : -66.80696821354795
# Ep done
# EP : 758
# RETURNS : -63.618280461451924
# Ep done
# EP : 759
# RETURNS : -74.40437005631799
# Ep done
# EP : 760
# RETURNS : -75.54165203650243
# Ep done
# EP : 761
# RETURNS : -72.03508602474624
# Ep done
# EP : 762
# RETURNS : -57.81519465940778
# Ep done
# EP : 763
# RETURNS : -64.0924882457988
# Ep done
# EP : 764
# RETURNS : -75.32021598936723
# Ep done
# EP : 765
# RETURNS : -68.27857275740946
# Ep done
# EP : 766
# RETURNS : -59.66791423459327
# Ep done
# EP : 767
# RETURNS : -67.87868276656955
# Ep done
# EP : 768
# RETURNS : -72.47235374487204
# Ep done
# EP : 769
# RETURNS : -68.57167534735972
# Ep done
# EP : 770
# RETURNS : -63.54050006585425
# Ep done
# EP : 771
# RETURNS : -55.71315890289207
# Ep done
# EP : 772
# RETURNS : -74.61667517460045
# Ep done
# EP : 773
# RETURNS : -71.136825519901
# Ep done
# EP : 774
# RETURNS : -60.61288644049185
# Ep done
# EP : 775
# RETURNS : -74.55258695652195
# Ep done
# EP : 776
# RETURNS : -66.27884216423776
# Ep done
# EP : 777
# RETURNS : -70.97424832081529
# Ep done
# EP : 778
# RETURNS : -64.75199136692312
# Ep done
# EP : 779
# RETURNS : -76.7375157558109
# Ep done
# EP : 780
# RETURNS : -68.95551107340299
# Ep done
# EP : 781
# RETURNS : -70.00279754715352
# Ep done
# EP : 782
# RETURNS : -70.0853144139588
# Ep done
# EP : 783
# RETURNS : -65.75322843038522
# Ep done
# EP : 784
# RETURNS : -59.17470559739239
# Ep done
# EP : 785
# RETURNS : -69.16624236856212
# Ep done
# EP : 786
# RETURNS : -73.55210302715658
# Ep done
# EP : 787
# RETURNS : -72.30450391641044
# Ep done
# EP : 788
# RETURNS : -72.84921562345647
# Ep done
# EP : 789
# RETURNS : -66.53897377221301
# Ep done
# EP : 790
# RETURNS : -72.71952124737338
# Ep done
# EP : 791
# RETURNS : -64.54724464909215
# Ep done
# EP : 792
# RETURNS : -74.28088365044235
# Ep done
# EP : 793
# RETURNS : -71.99985626671584
# Ep done
# EP : 794
# RETURNS : -65.01548085926537
# Ep done
# EP : 795
# RETURNS : -69.3713854111247
# Ep done
# EP : 796
# RETURNS : -62.80781646672553
# Ep done
# EP : 797
# RETURNS : -60.11129550207054
# Ep done
# EP : 798
# RETURNS : -77.15263494188828
# Ep done
# EP : 799
# RETURNS : -60.14984204337954
# Ep done
# EP : 800
# RETURNS : -64.92577666710734
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 801
# RETURNS : -60.27084513859177
# Ep done
# EP : 802
# RETURNS : -68.02253269911999
# Ep done
# EP : 803
# RETURNS : -70.70600123876838
# Ep done
# EP : 804
# RETURNS : -65.9850530063294
# Ep done
# EP : 805
# RETURNS : -73.9982094028663
# Ep done
# EP : 806
# RETURNS : -60.15636013849048
# Ep done
# EP : 807
# RETURNS : -60.91619298235918
# Ep done
# EP : 808
# RETURNS : -66.87702993169312
# Ep done
# EP : 809
# RETURNS : -61.07940180237099
# Ep done
# EP : 810
# RETURNS : -70.17312837263312
# Ep done
# EP : 811
# RETURNS : -68.32043201951535
# Ep done
# EP : 812
# RETURNS : -67.33919367999864
# Ep done
# EP : 813
# RETURNS : -60.65732505557248
# Ep done
# EP : 814
# RETURNS : -66.64679652008753
# Ep done
# EP : 815
# RETURNS : -57.73926602148825
# Ep done
# EP : 816
# RETURNS : -69.2232543697595
# Ep done
# EP : 817
# RETURNS : -62.29351379618753
# Ep done
# EP : 818
# RETURNS : -64.7912600339162
# Ep done
# EP : 819
# RETURNS : -70.79195072884944
# Ep done
# EP : 820
# RETURNS : -63.18092568153354
# Ep done
# EP : 821
# RETURNS : -72.1928046748718
# Ep done
# EP : 822
# RETURNS : -66.05486100523329
# Ep done
# EP : 823
# RETURNS : -60.7390291311776
# Ep done
# EP : 824
# RETURNS : -67.90507964354128
# Ep done
# EP : 825
# RETURNS : -67.61505025655929
# Ep done
# EP : 826
# RETURNS : -70.9603811603892
# Ep done
# EP : 827
# RETURNS : -65.76265132892706
# Ep done
# EP : 828
# RETURNS : -66.82407632454127
# Ep done
# EP : 829
# RETURNS : -62.26146500005841
# Ep done
# EP : 830
# RETURNS : -67.78962155248351
# Ep done
# EP : 831
# RETURNS : -68.2886610454723
# Ep done
# EP : 832
# RETURNS : -61.53785279816032
# Ep done
# EP : 833
# RETURNS : -73.05371537773256
# Ep done
# EP : 834
# RETURNS : -71.60000196349195
# Ep done
# EP : 835
# RETURNS : -73.77568349295345
# Ep done
# EP : 836
# RETURNS : -49.9100042197846
# Ep done
# EP : 837
# RETURNS : -51.98484900729699
# Ep done
# EP : 838
# RETURNS : -68.17829716670866
# Ep done
# EP : 839
# RETURNS : -66.84584126644391
# Ep done
# EP : 840
# RETURNS : -60.016239604937184
# Ep done
# EP : 841
# RETURNS : -53.46190143011963
# Ep done
# EP : 842
# RETURNS : -65.89630676498207
# Ep done
# EP : 843
# RETURNS : -74.08805767340796
# Ep done
# EP : 844
# RETURNS : -68.7341280535372
# Ep done
# EP : 845
# RETURNS : -56.108017636449404
# Ep done
# EP : 846
# RETURNS : -66.18666828699507
# Ep done
# EP : 847
# RETURNS : -69.54688460693238
# Ep done
# EP : 848
# RETURNS : -67.29702630346067
# Ep done
# EP : 849
# RETURNS : -65.12715389848759
# Ep done
# EP : 850
# RETURNS : -66.1775776672792
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 851
# RETURNS : -68.26987850782399
# Ep done
# EP : 852
# RETURNS : -66.45068422763185
# Ep done
# EP : 853
# RETURNS : -68.3604025686149
# Ep done
# EP : 854
# RETURNS : -65.74968637347673
# Ep done
# EP : 855
# RETURNS : -68.26837860564125
# Ep done
# EP : 856
# RETURNS : -69.9863704956612
# Ep done
# EP : 857
# RETURNS : -68.73839373503301
# Ep done
# EP : 858
# RETURNS : -68.14581894762149
# Ep done
# EP : 859
# RETURNS : -68.22226818422206
# Ep done
# EP : 860
# RETURNS : -64.6121999924813
# Ep done
# EP : 861
# RETURNS : -67.87357469278476
# Ep done
# EP : 862
# RETURNS : -69.03354238454158
# Ep done
# EP : 863
# RETURNS : -56.56338822925037
# Ep done
# EP : 864
# RETURNS : -74.9502258597922
# Ep done
# EP : 865
# RETURNS : -75.61301886336445
# Ep done
# EP : 866
# RETURNS : -66.63339386759792
# Ep done
# EP : 867
# RETURNS : -73.76924780022537
# Ep done
# EP : 868
# RETURNS : -71.46025004958173
# Ep done
# EP : 869
# RETURNS : -74.22674245366508
# Ep done
# EP : 870
# RETURNS : -71.88123283058738
# Ep done
# EP : 871
# RETURNS : -61.61332380916591
# Ep done
# EP : 872
# RETURNS : -72.72325223703854
# Ep done
# EP : 873
# RETURNS : -61.57828126989256
# Ep done
# EP : 874
# RETURNS : -62.58155809494386
# Ep done
# EP : 875
# RETURNS : -76.37234845402011
# Ep done
# EP : 876
# RETURNS : -66.71783695479778
# Ep done
# EP : 877
# RETURNS : -66.01780427820405
# Ep done
# EP : 878
# RETURNS : -58.063851189987744
# Ep done
# EP : 879
# RETURNS : -75.59927221050295
# Ep done
# EP : 880
# RETURNS : -70.41671133098447
# Ep done
# EP : 881
# RETURNS : -69.35351439163624
# Ep done
# EP : 882
# RETURNS : -65.38760578389835
# Ep done
# EP : 883
# RETURNS : -69.0502397077824
# Ep done
# EP : 884
# RETURNS : -65.03478206290644
# Ep done
# EP : 885
# RETURNS : -68.5424373769824
# Ep done
# EP : 886
# RETURNS : -66.46455406449911
# Ep done
# EP : 887
# RETURNS : -69.88672822812836
# Ep done
# EP : 888
# RETURNS : -69.6845063871731
# Ep done
# EP : 889
# RETURNS : -70.8475595437039
# Ep done
# EP : 890
# RETURNS : -76.01619505205682
# Ep done
# EP : 891
# RETURNS : -66.27212957141761
# Ep done
# EP : 892
# RETURNS : -64.26758545391966
# Ep done
# EP : 893
# RETURNS : -71.20089860287904
# Ep done
# EP : 894
# RETURNS : -66.61990794500346
# Ep done
# EP : 895
# RETURNS : -71.42415099354376
# Ep done
# EP : 896
# RETURNS : -67.33590688977756
# Ep done
# EP : 897
# RETURNS : -67.36521692651793
# Ep done
# EP : 898
# RETURNS : -66.60542140861253
# Ep done
# EP : 899
# RETURNS : -67.48968198893351
# Ep done
# EP : 900
# RETURNS : -69.27497146083955
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 901
# RETURNS : -64.732915381466
# Ep done
# EP : 902
# RETURNS : -64.80433632405476
# Ep done
# EP : 903
# RETURNS : -76.39945256314174
# Ep done
# EP : 904
# RETURNS : -73.26002127621258
# Ep done
# EP : 905
# RETURNS : -71.33347983052754
# Ep done
# EP : 906
# RETURNS : -69.90891395648401
# Ep done
# EP : 907
# RETURNS : -70.79800787308265
# Ep done
# EP : 908
# RETURNS : -68.1607171441543
# Ep done
# EP : 909
# RETURNS : -63.1820428247956
# Ep done
# EP : 910
# RETURNS : -65.95832539943935
# Ep done
# EP : 911
# RETURNS : -69.31746356436447
# Ep done
# EP : 912
# RETURNS : -68.0130440286949
# Ep done
# EP : 913
# RETURNS : -59.89240949829457
# Ep done
# EP : 914
# RETURNS : -71.71197146106103
# Ep done
# EP : 915
# RETURNS : -71.64682357412345
# Ep done
# EP : 916
# RETURNS : -63.204880751741264
# Ep done
# EP : 917
# RETURNS : -72.29614623469914
# Ep done
# EP : 918
# RETURNS : -67.50898290421645
# Ep done
# EP : 919
# RETURNS : -64.0341839620078
# Ep done
# EP : 920
# RETURNS : -69.6957744207678
# Ep done
# EP : 921
# RETURNS : -64.69229854089227
# Ep done
# EP : 922
# RETURNS : -67.76980624156735
# Ep done
# EP : 923
# RETURNS : -70.62466238715939
# Ep done
# EP : 924
# RETURNS : -63.73799300131243
# Ep done
# EP : 925
# RETURNS : -66.34473284038546
# Ep done
# EP : 926
# RETURNS : -69.71315371111523
# Ep done
# EP : 927
# RETURNS : -68.38532930636336
# Ep done
# EP : 928
# RETURNS : -70.09280369096693
# Ep done
# EP : 929
# RETURNS : -72.21589486543488
# Ep done
# EP : 930
# RETURNS : -67.12448506782502
# Ep done
# EP : 931
# RETURNS : -57.662928287667114
# Ep done
# EP : 932
# RETURNS : -70.15297856353202
# Ep done
# EP : 933
# RETURNS : -69.70506024781561
# Ep done
# EP : 934
# RETURNS : -69.11094649729961
# Ep done
# EP : 935
# RETURNS : -72.72936524138085
# Ep done
# EP : 936
# RETURNS : -60.21277981884897
# Ep done
# EP : 937
# RETURNS : -72.13277973134774
# Ep done
# EP : 938
# RETURNS : -66.32150243659873
# Ep done
# EP : 939
# RETURNS : -70.87599673363631
# Ep done
# EP : 940
# RETURNS : -60.28416169559241
# Ep done
# EP : 941
# RETURNS : -66.70621160634406
# Ep done
# EP : 942
# RETURNS : -68.04242866773312
# Ep done
# EP : 943
# RETURNS : -67.65993541797012
# Ep done
# EP : 944
# RETURNS : -68.43152238858647
# Ep done
# EP : 945
# RETURNS : -67.62263050368696
# Ep done
# EP : 946
# RETURNS : -67.06479777397858
# Ep done
# EP : 947
# RETURNS : -67.4367054857544
# Ep done
# EP : 948
# RETURNS : -62.94102014409173
# Ep done
# EP : 949
# RETURNS : -68.27010475819729
# Ep done
# EP : 950
# RETURNS : -58.626440008243684
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -41.775129549361644---
#
#
#
# EP : 951
# RETURNS : -66.54186873244365
# Ep done
# EP : 952
# RETURNS : -72.066375245436
# Ep done
# EP : 953
# RETURNS : -65.12939075024914
# Ep done
# EP : 954
# ...
# EP : 10525
# RETURNS : -69.61484578857656
# Ep done
# EP : 10526
# RETURNS : -61.79892740063697
# Ep done
# EP : 10527
# RETURNS : -64.93344088273328
# Ep done
# EP : 10528
# RETURNS : -67.38060067843944
# Ep done
# EP : 10529
# RETURNS : -67.50125366547734
# Ep done
# EP : 10530
# RETURNS : -58.2088535717787
# Ep done
# EP : 10531
# RETURNS : -62.34685090101504
# Ep done
# EP : 10532
# RETURNS : -71.00420106510695
# Ep done
# EP : 10533
# RETURNS : -65.37536734622384
# Ep done
# EP : 10534
# RETURNS : -69.37472259418476
# Ep done
# EP : 10535
# RETURNS : -60.25477696566334
# Ep done
# EP : 10536
# RETURNS : -68.88272597733204
# Ep done
# EP : 10537
# RETURNS : -64.18262977681131
# Ep done
# EP : 10538
# RETURNS : -60.203260966869514
# Ep done
# EP : 10539
# RETURNS : -66.90033131025216
# Ep done
# EP : 10540
# RETURNS : -69.15983554976283
# Ep done
# EP : 10541
# RETURNS : -62.98327253895929
# Ep done
# EP : 10542
# RETURNS : -63.48394708992784
# Ep done
# EP : 10543
# RETURNS : -53.234188478744294
# Ep done
# EP : 10544
# RETURNS : -65.09828516539575
# Ep done
# EP : 10545
# RETURNS : -71.67724792855594
# Ep done
# EP : 10546
# RETURNS : -65.67201892457601
# Ep done
# EP : 10547
# RETURNS : -66.6294338893525
# Ep done
# EP : 10548
# RETURNS : -63.869603390488635
# Ep done
# EP : 10549
# RETURNS : -63.226326531753145
# Ep done
# EP : 10550
# RETURNS : -72.94954113746327
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10551
# RETURNS : -66.38538272856191
# Ep done
# EP : 10552
# RETURNS : -67.36394106189488
# Ep done
# EP : 10553
# RETURNS : -72.66768756091047
# Ep done
# EP : 10554
# RETURNS : -61.66265527838902
# Ep done
# EP : 10555
# RETURNS : -69.77930421449229
# Ep done
# EP : 10556
# RETURNS : -65.2921429069652
# Ep done
# EP : 10557
# RETURNS : -68.12445406501828
# Ep done
# EP : 10558
# RETURNS : -56.8420720971404
# Ep done
# EP : 10559
# RETURNS : -62.725658110526325
# Ep done
# EP : 10560
# RETURNS : -63.17608611922893
# Ep done
# EP : 10561
# RETURNS : -65.3182742010978
# Ep done
# EP : 10562
# RETURNS : -59.55493033700888
# Ep done
# EP : 10563
# RETURNS : -60.530549301640725
# Ep done
# EP : 10564
# RETURNS : -66.91708111492612
# Ep done
# EP : 10565
# RETURNS : -65.53477328625546
# Ep done
# EP : 10566
# RETURNS : -67.79956226946315
# Ep done
# EP : 10567
# RETURNS : -59.57051527049067
# Ep done
# EP : 10568
# RETURNS : -64.67156660368708
# Ep done
# EP : 10569
# RETURNS : -68.1897717240895
# Ep done
# EP : 10570
# RETURNS : -64.20923044959417
# Ep done
# EP : 10571
# RETURNS : -62.90386504830399
# Ep done
# EP : 10572
# RETURNS : -60.51362769263482
# Ep done
# EP : 10573
# RETURNS : -65.91305953630064
# Ep done
# EP : 10574
# RETURNS : -61.59426047762928
# Ep done
# EP : 10575
# RETURNS : -67.45742905822557
# Ep done
# EP : 10576
# RETURNS : -59.536126655174535
# Ep done
# EP : 10577
# RETURNS : -63.4391608949152
# Ep done
# EP : 10578
# RETURNS : -64.11735628015711
# Ep done
# EP : 10579
# RETURNS : -69.06997663559022
# Ep done
# EP : 10580
# RETURNS : -63.18378059802504
# Ep done
# EP : 10581
# RETURNS : -70.14104505616766
# Ep done
# EP : 10582
# RETURNS : -68.62304830293847
# Ep done
# EP : 10583
# RETURNS : -57.14568790894029
# Ep done
# EP : 10584
# RETURNS : -61.88461927776227
# Ep done
# EP : 10585
# RETURNS : -64.20145287305864
# Ep done
# EP : 10586
# RETURNS : -61.42541135934306
# Ep done
# EP : 10587
# RETURNS : -67.38362800659188
# Ep done
# EP : 10588
# RETURNS : -67.97632502564382
# Ep done
# EP : 10589
# RETURNS : -63.39215072695667
# Ep done
# EP : 10590
# RETURNS : -64.35548932439762
# Ep done
# EP : 10591
# RETURNS : -66.0996724107566
# Ep done
# EP : 10592
# RETURNS : -66.56621887803098
# Ep done
# EP : 10593
# RETURNS : -69.64515840522506
# Ep done
# EP : 10594
# RETURNS : -64.57615924794723
# Ep done
# EP : 10595
# RETURNS : -65.8733823579861
# Ep done
# EP : 10596
# RETURNS : -66.39161207789185
# Ep done
# EP : 10597
# RETURNS : -61.934864312078524
# Ep done
# EP : 10598
# RETURNS : -66.1238631640891
# Ep done
# EP : 10599
# RETURNS : -65.39139535367676
# Ep done
# EP : 10600
# RETURNS : -64.76968133226045
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10601
# RETURNS : -67.07265768106517
# Ep done
# EP : 10602
# RETURNS : -66.82200818962002
# Ep done
# EP : 10603
# RETURNS : -67.29396894116594
# Ep done
# EP : 10604
# RETURNS : -65.43902250604978
# Ep done
# EP : 10605
# RETURNS : -67.32032494180957
# Ep done
# EP : 10606
# RETURNS : -67.90134844792696
# Ep done
# EP : 10607
# RETURNS : -66.8129271977384
# Ep done
# EP : 10608
# RETURNS : -60.85087135918409
# Ep done
# EP : 10609
# RETURNS : -67.22955050596701
# Ep done
# EP : 10610
# RETURNS : -65.89529650363639
# Ep done
# EP : 10611
# RETURNS : -65.38146755302158
# Ep done
# EP : 10612
# RETURNS : -66.49878255992185
# Ep done
# EP : 10613
# RETURNS : -65.26842566646685
# Ep done
# EP : 10614
# RETURNS : -68.28655041603369
# Ep done
# EP : 10615
# RETURNS : -57.14994545366157
# Ep done
# EP : 10616
# RETURNS : -70.99763799628244
# Ep done
# EP : 10617
# RETURNS : -65.93560852536476
# Ep done
# EP : 10618
# RETURNS : -63.593340387353145
# Ep done
# EP : 10619
# RETURNS : -64.9739776971762
# Ep done
# EP : 10620
# RETURNS : -64.28258975097992
# Ep done
# EP : 10621
# RETURNS : -62.884759756406176
# Ep done
# EP : 10622
# RETURNS : -67.00973846634236
# Ep done
# EP : 10623
# RETURNS : -66.3078909396458
# Ep done
# EP : 10624
# RETURNS : -60.80426513544166
# Ep done
# EP : 10625
# RETURNS : -61.61715538933199
# Ep done
# EP : 10626
# RETURNS : -66.16039724004115
# Ep done
# EP : 10627
# RETURNS : -64.48246324694459
# Ep done
# EP : 10628
# RETURNS : -67.52666097617154
# Ep done
# EP : 10629
# RETURNS : -64.61934529346566
# Ep done
# EP : 10630
# RETURNS : -65.5739910575898
# Ep done
# EP : 10631
# RETURNS : -63.15009995248376
# Ep done
# EP : 10632
# RETURNS : -63.182955575965465
# Ep done
# EP : 10633
# RETURNS : -61.45233065246542
# Ep done
# EP : 10634
# RETURNS : -65.66338030487765
# Ep done
# EP : 10635
# RETURNS : -58.500278001579154
# Ep done
# EP : 10636
# RETURNS : -59.881748195546834
# Ep done
# EP : 10637
# RETURNS : -60.72998533689915
# Ep done
# EP : 10638
# RETURNS : -60.21704728474265
# Ep done
# EP : 10639
# RETURNS : -68.34732821300636
# Ep done
# EP : 10640
# RETURNS : -57.66456806691751
# Ep done
# EP : 10641
# RETURNS : -60.8981153823201
# Ep done
# EP : 10642
# RETURNS : -69.7274675552119
# Ep done
# EP : 10643
# RETURNS : -58.09672510427222
# Ep done
# EP : 10644
# RETURNS : -63.72496566579499
# Ep done
# EP : 10645
# RETURNS : -62.54850288719667
# Ep done
# EP : 10646
# RETURNS : -66.83660163769362
# Ep done
# EP : 10647
# RETURNS : -64.17134493089702
# Ep done
# EP : 10648
# RETURNS : -70.38771356443426
# Ep done
# EP : 10649
# RETURNS : -59.97765101780131
# Ep done
# EP : 10650
# RETURNS : -62.10880167632562
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10651
# RETURNS : -58.54703582998299
# Ep done
# EP : 10652
# RETURNS : -65.45785188858896
# Ep done
# EP : 10653
# RETURNS : -67.12166803565007
# Ep done
# EP : 10654
# RETURNS : -66.79522318998481
# Ep done
# EP : 10655
# RETURNS : -67.41564500594515
# Ep done
# EP : 10656
# RETURNS : -55.307932807043656
# Ep done
# EP : 10657
# RETURNS : -66.43347037996051
# Ep done
# EP : 10658
# RETURNS : -65.77373434291043
# Ep done
# EP : 10659
# RETURNS : -61.35686651721463
# Ep done
# EP : 10660
# RETURNS : -65.56790964653011
# Ep done
# EP : 10661
# RETURNS : -64.1287311987002
# Ep done
# EP : 10662
# RETURNS : -62.59578932448902
# Ep done
# EP : 10663
# RETURNS : -66.11056100863652
# Ep done
# EP : 10664
# RETURNS : -63.864400335237775
# Ep done
# EP : 10665
# RETURNS : -60.943154531473745
# Ep done
# EP : 10666
# RETURNS : -64.448469711359
# Ep done
# EP : 10667
# RETURNS : -69.03200467064904
# Ep done
# EP : 10668
# RETURNS : -67.51264658708445
# Ep done
# EP : 10669
# RETURNS : -65.00905635297583
# Ep done
# EP : 10670
# RETURNS : -64.29262412025713
# Ep done
# EP : 10671
# RETURNS : -57.605376770389086
# Ep done
# EP : 10672
# RETURNS : -67.0358655488634
# Ep done
# EP : 10673
# RETURNS : -66.51530383216286
# Ep done
# EP : 10674
# RETURNS : -60.877470153090634
# Ep done
# EP : 10675
# RETURNS : -64.67102328872896
# Ep done
# EP : 10676
# RETURNS : -61.484086605480194
# Ep done
# EP : 10677
# RETURNS : -64.54319576116714
# Ep done
# EP : 10678
# RETURNS : -61.85139526977007
# Ep done
# EP : 10679
# RETURNS : -63.13978159792671
# Ep done
# EP : 10680
# RETURNS : -64.98662194259776
# Ep done
# EP : 10681
# RETURNS : -65.53749820171741
# Ep done
# EP : 10682
# RETURNS : -65.2984123008978
# Ep done
# EP : 10683
# RETURNS : -66.3442873547092
# Ep done
# EP : 10684
# RETURNS : -68.9556211902553
# Ep done
# EP : 10685
# RETURNS : -66.70965151629245
# Ep done
# EP : 10686
# RETURNS : -68.33185308419195
# Ep done
# EP : 10687
# RETURNS : -67.23372194390008
# Ep done
# EP : 10688
# RETURNS : -64.50014290604777
# Ep done
# EP : 10689
# RETURNS : -64.75940644169073
# Ep done
# EP : 10690
# RETURNS : -61.76807148099591
# Ep done
# EP : 10691
# RETURNS : -68.36742038251556
# Ep done
# EP : 10692
# RETURNS : -63.7860677064152
# Ep done
# EP : 10693
# RETURNS : -64.87911280436505
# Ep done
# EP : 10694
# RETURNS : -64.35422534654538
# Ep done
# EP : 10695
# RETURNS : -63.73174660576019
# Ep done
# EP : 10696
# RETURNS : -68.22902407643531
# Ep done
# EP : 10697
# RETURNS : -65.51605085312329
# Ep done
# EP : 10698
# RETURNS : -61.8026283569275
# Ep done
# EP : 10699
# RETURNS : -57.830209830455615
# Ep done
# EP : 10700
# RETURNS : -66.06454465107862
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10701
# RETURNS : -69.24233243274689
# Ep done
# EP : 10702
# RETURNS : -65.17890444033947
# Ep done
# EP : 10703
# RETURNS : -63.446319994385576
# Ep done
# EP : 10704
# RETURNS : -64.7206895437264
# Ep done
# EP : 10705
# RETURNS : -68.65541746704405
# Ep done
# EP : 10706
# RETURNS : -57.98887453450388
# Ep done
# EP : 10707
# RETURNS : -62.13926204263424
# Ep done
# EP : 10708
# RETURNS : -62.92164645403879
# Ep done
# EP : 10709
# RETURNS : -58.83197415464134
# Ep done
# EP : 10710
# RETURNS : -64.50499169703424
# Ep done
# EP : 10711
# RETURNS : -64.20398345169926
# Ep done
# EP : 10712
# RETURNS : -65.37023567021
# Ep done
# EP : 10713
# RETURNS : -63.70484487100594
# Ep done
# EP : 10714
# RETURNS : -56.43485456633091
# Ep done
# EP : 10715
# RETURNS : -64.24895548699627
# Ep done
# EP : 10716
# RETURNS : -60.18146281631966
# Ep done
# EP : 10717
# RETURNS : -58.74474062128204
# Ep done
# EP : 10718
# RETURNS : -55.09632024906994
# Ep done
# EP : 10719
# RETURNS : -55.05449614040403
# Ep done
# EP : 10720
# RETURNS : -68.58046585242144
# Ep done
# EP : 10721
# RETURNS : -67.75302426271097
# Ep done
# EP : 10722
# RETURNS : -64.90803357567464
# Ep done
# EP : 10723
# RETURNS : -69.08659655760444
# Ep done
# EP : 10724
# RETURNS : -62.57786367639642
# Ep done
# EP : 10725
# RETURNS : -64.14662584274619
# Ep done
# EP : 10726
# RETURNS : -60.809723096363
# Ep done
# EP : 10727
# RETURNS : -66.85382664157137
# Ep done
# EP : 10728
# RETURNS : -64.58398903857473
# Ep done
# EP : 10729
# RETURNS : -62.49050512412827
# Ep done
# EP : 10730
# RETURNS : -62.68212377666092
# Ep done
# EP : 10731
# RETURNS : -59.67518443036466
# Ep done
# EP : 10732
# RETURNS : -59.98563932254861
# Ep done
# EP : 10733
# RETURNS : -64.94408602411829
# Ep done
# EP : 10734
# RETURNS : -65.91523843604938
# Ep done
# EP : 10735
# RETURNS : -63.03726999228643
# Ep done
# EP : 10736
# RETURNS : -62.53052933490431
# Ep done
# EP : 10737
# RETURNS : -68.15525806053256
# Ep done
# EP : 10738
# RETURNS : -67.33473005135309
# Ep done
# EP : 10739
# RETURNS : -62.67431066950474
# Ep done
# EP : 10740
# RETURNS : -69.43092702602569
# Ep done
# EP : 10741
# RETURNS : -67.56225803270556
# Ep done
# EP : 10742
# RETURNS : -66.50282094696219
# Ep done
# EP : 10743
# RETURNS : -58.6548641792362
# Ep done
# EP : 10744
# RETURNS : -64.19050495503384
# Ep done
# EP : 10745
# RETURNS : -66.98095904144266
# Ep done
# EP : 10746
# RETURNS : -66.49586867674518
# Ep done
# EP : 10747
# RETURNS : -69.60967784586754
# Ep done
# EP : 10748
# RETURNS : -70.84741189503187
# Ep done
# EP : 10749
# RETURNS : -64.44853084159006
# Ep done
# EP : 10750
# RETURNS : -62.83956284791328
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10751
# RETURNS : -66.91791495151672
# Ep done
# EP : 10752
# RETURNS : -55.23447170098517
# Ep done
# EP : 10753
# RETURNS : -62.344012080466634
# Ep done
# EP : 10754
# RETURNS : -64.8117663736773
# Ep done
# EP : 10755
# RETURNS : -66.13129099946629
# Ep done
# EP : 10756
# RETURNS : -72.07335230158277
# Ep done
# EP : 10757
# RETURNS : -61.001453582232735
# Ep done
# EP : 10758
# RETURNS : -66.54650519879041
# Ep done
# EP : 10759
# RETURNS : -65.71773690450621
# Ep done
# EP : 10760
# RETURNS : -64.10632960397666
# Ep done
# EP : 10761
# RETURNS : -65.23934462736912
# Ep done
# EP : 10762
# RETURNS : -65.89037568357583
# Ep done
# EP : 10763
# RETURNS : -65.56544022627122
# Ep done
# EP : 10764
# RETURNS : -57.05577594046923
# Ep done
# EP : 10765
# RETURNS : -57.25215447302527
# Ep done
# EP : 10766
# RETURNS : -68.78806133591493
# Ep done
# EP : 10767
# RETURNS : -70.04505569284714
# Ep done
# EP : 10768
# RETURNS : -65.57685633186166
# Ep done
# EP : 10769
# RETURNS : -63.74255679273584
# Ep done
# EP : 10770
# RETURNS : -67.08199819055646
# Ep done
# EP : 10771
# RETURNS : -60.34651216682667
# Ep done
# EP : 10772
# RETURNS : -60.571724549305
# Ep done
# EP : 10773
# RETURNS : -60.46837116084369
# Ep done
# EP : 10774
# RETURNS : -60.319474273078605
# Ep done
# EP : 10775
# RETURNS : -64.89296067266737
# Ep done
# EP : 10776
# RETURNS : -65.45151080624215
# Ep done
# EP : 10777
# RETURNS : -68.56057255135113
# Ep done
# EP : 10778
# RETURNS : -66.53520363651258
# Ep done
# EP : 10779
# RETURNS : -66.15351044962982
# Ep done
# EP : 10780
# RETURNS : -63.61791955541645
# Ep done
# EP : 10781
# RETURNS : -63.733787916946085
# Ep done
# EP : 10782
# RETURNS : -68.02191489548048
# Ep done
# EP : 10783
# RETURNS : -66.75678223002191
# Ep done
# EP : 10784
# RETURNS : -62.98150152517319
# Ep done
# EP : 10785
# RETURNS : -62.68875385663874
# Ep done
# EP : 10786
# RETURNS : -65.66181549262703
# Ep done
# EP : 10787
# RETURNS : -65.54262110911571
# Ep done
# EP : 10788
# RETURNS : -65.01983456790273
# Ep done
# EP : 10789
# RETURNS : -63.79258582548726
# Ep done
# EP : 10790
# RETURNS : -59.17582396070554
# Ep done
# EP : 10791
# RETURNS : -64.252324686346
# Ep done
# EP : 10792
# RETURNS : -64.19869960835923
# Ep done
# EP : 10793
# RETURNS : -68.13875784178535
# Ep done
# EP : 10794
# RETURNS : -60.933296986842805
# Ep done
# EP : 10795
# RETURNS : -63.03118025180566
# Ep done
# EP : 10796
# RETURNS : -66.37883009582217
# Ep done
# EP : 10797
# RETURNS : -67.72291134601745
# Ep done
# EP : 10798
# RETURNS : -67.20436062476011
# Ep done
# EP : 10799
# RETURNS : -62.44338600766639
# Ep done
# EP : 10800
# RETURNS : -66.09054257623475
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -29.676545772955638---
#
#
#
# EP : 10801
# RETURNS : -68.45420320268654
# Ep done
# EP : 10802
# RETURNS : -58.916812913647234
# Ep done
# EP : 10803
# RETURNS : -56.27657398580713
# Ep done
# EP : 10804
# RETURNS : -63.94845449138735
# Ep done
# EP : 10805
# RETURNS : -58.49091018768468
# Ep done
# EP : 10806
# RETURNS : -58.492134199366916
# Ep done
# EP : 10807
# RETURNS : -63.31145196289654
# Ep done
# EP : 10808
# RETURNS : -63.39195648896143
# Ep done
# EP : 10809
# RETURNS : -68.23676787936861
# Ep done
# EP : 10810
# RETURNS : -66.83361969803687
# Ep done
# EP : 10811
# RETURNS : -68.32811426105029
# Ep done
# EP : 10812
# RETURNS : -62.14241855451097
# Ep done
# EP : 10813
# RETURNS : -65.76856658460358
# Ep done
# EP : 10814
# RETURNS : -68.17712937432508
# Ep done
# EP : 10815
# RETURNS : -62.143489237195794
# Ep done
# EP : 10816
# RETURNS : -62.95147862906846
# Ep done
# EP : 10817
# RETURNS : -65.69099568716906
# Ep done
# EP : 10818
# RETURNS : -66.18652781327381
# Ep done
# EP : 10819
# RETURNS : -63.40123604285606
# Ep done
# EP : 10820
# RETURNS : -66.87028066076304
# Ep done
# EP : 10821
# RETURNS : -62.83045652177553
# Ep done
# EP : 10822
# RETURNS : -66.69309768868656
# Ep done
# EP : 10823
# RETURNS : -62.849419501252164
# Ep done
# EP : 10824
# RETURNS : -67.77198139708524
# Ep done
# EP : 10825
# RETURNS : -67.43538100688947
# Ep done
# EP : 10826
# RETURNS : -61.37360951493386
# Ep done
# EP : 10827
# RETURNS : -66.6613864366035
# Ep done
# EP : 10828
# RETURNS : -64.09670371419497
# Ep done
# EP : 10829
# RETURNS : -61.075603173228366
# Ep done
# EP : 10830
# RETURNS : -66.34656116584748
# Ep done
# EP : 10831
# RETURNS : -68.04525999646965
# Ep done
# EP : 10832
# RETURNS : -59.69296137743489
# Ep done
# EP : 10833
# RETURNS : -58.407932011253486
# Ep done
# EP : 10834
# RETURNS : -59.86283136006213
# Ep done
# EP : 10835
# RETURNS : -63.89180628490372
# Ep done
# EP : 10836
# RETURNS : -64.44296073055685
# Ep done
# EP : 10837
# RETURNS : -69.03623024762216
# Ep done
# EP : 10838
# RETURNS : -67.88097365387124
# Ep done
# EP : 10839
# RETURNS : -65.54608395209847
# Ep done
# EP : 10840
# RETURNS : -67.77633929176487
# Ep done
# EP : 10841
# RETURNS : -58.85110861011563
# Ep done
# EP : 10842
# RETURNS : -62.44581247283631
# Ep done
# EP : 10843
# RETURNS : -66.88902649843729
# Ep done
# EP : 10844
# RETURNS : -64.5823037263992
# Ep done
# EP : 10845
# RETURNS : -65.13775237368985
# Ep done
# EP : 10846
# RETURNS : -66.3656671244578
# Ep done
# EP : 10847
# RETURNS : -66.04064845517922
# Ep done
# EP : 10848
# RETURNS : -60.57616343562773
# Ep done
# EP : 10849
# RETURNS : -66.36390501477685
# Ep done
# EP : 10850
# RETURNS : -63.88115357304683
# Ep done
# Excessive output truncated after 524305 bytes.

# %%
# Test the policy #
env = GymEnv("Pendulum-v0")
env.pyenv._max_episode_steps = 10000
TEST_STEPS = 10000

r = test_run(env)
# Out:
# Action : [36.4835]
# Action : [42.2082]
# Action : [46.7772]
# Action : [50.6818]
# Action : [53.0478]
# Action : [54.0718]
# Action : [52.409]
# Action : [48.5782]
# Action : [43.7334]
# Action : [37.5431]
# Action : [30.1382]
# Action : [21.5755]
# Action : [12.4511]
# Action : [1.2422]
# Action : [-10.5666]
# Action : [-21.7242]
# Action : [-26.4691]
# Action : [-20.7219]
# Action : [-7.35382]
# Action : [8.03739]
# Action : [18.2925]
# Action : [29.5834]
# Action : [40.6675]
# Action : [50.8255]
# Action : [57.0252]
# Action : [58.708]
# Action : [57.0881]
# Action : [53.4172]
# Action : [47.0651]
# Action : [39.7697]
# Action : [34.1712]
# Action : [29.9508]
# Action : [32.0114]
# Action : [37.6825]
# Action : [43.1227]
# Action : [48.3394]
# Action : [51.3434]
# Action : [53.7514]
# Action : [54.4399]
# Action : [52.4036]
# Action : [47.9123]
# Action : [42.9738]
# Action : [36.5431]
# Action : [29.5377]
# Action : [20.282]
# Action : [10.5188]
# Action : [-1.02953]
# Action : [-14.5847]
# Action : [-23.7515]
# Action : [-24.7118]
# Action : [-15.977]
# Action : [-1.77475]
# Action : [14.4975]
# Action : [25.5355]
# Action : [36.3614]
# Action : [47.7539]
# Action : [56.3816]
# Action : [59.8935]
# Action : [59.1609]
# Action : [55.7048]
# Action : [50.4887]
# Action : [43.0652]
# Action : [36.343]
# Action : [31.1065]
# Action : [30.5321]
# Action : [35.3949]
# Action : [41.41]
# Action : [46.2784]
# Action : [50.5851]
# Action : [54.5593]
# Action : [55.3993]
# Action : [53.74]
# Action : [50.774]
# Action : [46.145]
# Action : [39.4959]
# Action : [32.9191]
# Action : [25.3885]
# Action : [14.1513]
# Action : [3.7557]
# Action : [-8.22203]
# Action : [-20.8694]
# Action : [-26.9052]
# Action : [-25.6555]
# Action : [-13.6724]
# Action : [1.12434]
# Action : [12.5199]
# Action : [23.3488]
# Action : [34.1147]
# Action : [45.5076]
# Action : [55.2066]
# Action : [58.8247]
# Action : [58.8348]
# Action : [56.4458]
# Action : [51.1112]
# Action : [44.068]
# Action : [37.5992]
# Action : [32.0518]
# Action : [30.1339]
# Action : [34.2694]
# Action : [40.3954]
# Action : [45.7437]
# Action : [50.2633]
# Action : [53.651]
# Action : [55.306]
# Action : [54.3303]
# Action : [51.2228]
# Action : [46.9032]
# Action : [41.138]
# Action : [33.804]
# Action : [26.7616]
# Action : [16.3035]
# Action : [5.87129]
# Action : [-6.28094]
# Action : [-18.9923]
# Action : [-26.2938]
# Action : [-25.4046]
# Action : [-13.1153]
# Action : [1.60529]
# Action : [11.7334]
# Action : [22.1361]
# Action : [33.027]
# Action : [44.1837]
# Action : [53.5631]
# Action : [57.7486]
# Action : [57.6819]
# Action : [55.4319]
# Action : [51.1986]
# Action : [43.6845]
# Action : [37.1673]
# Action : [32.413]
# Action : [29.6894]
# Action : [33.6572]
# Action : [39.5978]
# Action : [44.3341]
# Action : [49.0746]
# Action : [52.3364]
# Action : [53.5453]
# Action : [53.2505]
# Action : [50.2032]
# Action : [45.8368]
# Action : [40.1118]
# Action : [33.5615]
# Action : [26.3978]
# Action : [16.2656]
# Action : [6.90458]
# Action : [-5.47152]
# Action : [-17.9869]
# Action : [-24.4179]
# Action : [-23.333]
# Action : [-10.9024]
# Action : [3.62352]
# Action : [13.9249]
# Action : [24.2735]
# Action : [34.6805]
# Action : [45.3846]
# Action : [54.0131]
# Action : [57.1142]
# Action : [56.4298]
# Action : [53.6307]
# Action : [48.9278]
# Action : [41.7521]
# Action : [35.6074]
# Action : [30.7778]
# Action : [30.2152]
# Action : [35.1916]
# Action : [40.3588]
# Action : [44.9634]
# Action : [49.3115]
# Action : [52.2534]
# Action : [52.57]
# Action : [51.703]
# Action : [48.6726]
# Action : [43.8207]
# Action : [38.3565]
# Action : [31.9866]
# Action : [24.4841]
# Action : [14.0626]
# Action : [4.87611]
# Action : [-6.48821]
# Action : [-18.1428]
# Action : [-24.1778]
# Action : [-21.1829]
# Action : [-7.98415]
# Action : [7.22171]
# Action : [17.7272]
# Action : [27.9464]
# Action : [39.0435]
# Action : [49.045]
# Action : [55.7522]
# Action : [57.6801]
# Action : [55.9323]
# Action : [52.4448]
# Action : [46.0125]
# Action : [39.3223]
# Action : [34.065]
# Action : [29.6125]
# Action : [31.2999]
# Action : [36.7295]
# Action : [42.1889]
# Action : [46.6286]
# Action : [50.7949]
# Action : [52.6098]
# Action : [52.4962]
# Action : [51.1162]
# Action : [47.0264]
# Action : [42.0679]
# Action : [36.323]
# Action : [29.7584]
# Action : [20.5293]
# Action : [10.9424]
# Action : [0.151076]
# Action : [-12.1001]
# Action : [-21.5019]
# Action : [-24.5588]
# Action : [-16.7501]
# Action : [-2.26406]
# Action : [13.8585]
# Action : [24.8219]
# Action : [36.5942]
# Action : [46.7611]
# Action : [55.6839]
# Action : [59.0566]
# Action : [58.2787]
# Action : [55.5562]
# Action : [50.019]
# Action : [42.3148]
# Action : [36.0941]
# Action : [31.1046]
# Action : [30.0533]
# Action : [34.9187]
# Action : [41.1927]
# Action : [46.3551]
# Action : [50.2716]
# Action : [53.6397]
# Action : [54.5817]
# Action : [53.3582]
# Action : [49.8359]
# Action : [45.1578]
# Action : [39.2913]
# Action : [32.6409]
# Action : [24.6028]
# Action : [14.2905]
# Action : [3.43431]
# Action : [-7.74354]
# Action : [-20.0879]
# Action : [-25.8801]
# Action : [-23.4992]
# Action : [-12.0405]
# Action : [2.67293]
# Action : [12.667]
# Action : [23.8625]
# Action : [34.83]
# Action : [45.2927]
# Action : [54.2475]
# Action : [58.1447]
# Action : [58.2112]
# Action : [55.1738]
# Action : [50.3242]
# Action : [42.9814]
# Action : [36.8083]
# Action : [31.5446]
# Action : [29.7151]
# Action : [34.6025]
# Action : [40.4256]
# Action : [45.4018]
# Action : [49.4613]
# Action : [52.583]
# Action : [53.6433]
# Action : [52.6617]
# Action : [50.0805]
# Action : [45.2216]
# Action : [39.4272]
# Action : [33.2032]
# Action : [25.6708]
# Action : [15.5191]
# Action : [5.17734]
# Action : [-6.45998]
# Action : [-18.6784]
# Action : [-24.9288]
# Action : [-22.5374]
# Action : [-10.1063]
# Action : [4.15388]
# Action : [14.2345]
# Action : [24.8783]
# Action : [35.6621]
# Action : [46.7903]
# Action : [54.6336]
# Action : [57.1277]
# Action : [56.778]
# Action : [54.0939]
# Action : [48.6178]
# Action : [41.086]
# Action : [35.4787]
# Action : [30.9008]
# Action : [30.0443]
# Action : [35.0484]
# Action : [40.5488]
# Action : [45.6156]
# Action : [49.2814]
# Action : [52.2579]
# Action : [53.7101]
# Action : [51.5937]
# Action : [48.4133]
# Action : [43.9148]
# Action : [38.5214]
# Action : [31.7396]
# Action : [23.6528]
# Action : [14.1192]
# Action : [3.67184]
# Action : [-7.2404]
# Action : [-19.6531]
# Action : [-24.6905]
# Action : [-21.7864]
# Action : [-8.82698]
# Action : [6.73139]
# Action : [16.5375]
# Action : [27.6435]
# Action : [38.35]
# Action : [48.6717]
# Action : [55.7822]
# Action : [58.0208]
# Action : [56.2349]
# Action : [53.2169]
# Action : [47.0828]
# Action : [39.8236]
# Action : [34.7314]
# Action : [29.8775]
# Action : [31.1634]
# Action : [37.0026]
# Action : [42.0869]
# Action : [46.4146]
# Action : [50.6143]
# Action : [52.9894]
# Action : [53.446]
# Action : [51.6687]
# Action : [48.1896]
# Action : [43.0095]
# Action : [37.0665]
# Action : [30.2476]
# Action : [21.7806]
# Action : [11.6063]
# Action : [0.951212]
# Action : [-10.6983]
# Action : [-21.384]
# Action : [-25.1819]
# Action : [-19.1931]
# Action : [-5.2871]
# Action : [9.95104]
# Action : [20.748]
# Action : [31.7569]
# Action : [43.3445]
# Action : [53.2185]
# Action : [57.5939]
# Action : [58.8965]
# Action : [56.5849]
# Action : [52.2997]
# Action : [45.1331]
# Action : [38.1141]
# Action : [32.8607]
# Action : [29.7677]
# Action : [33.4084]
# Action : [38.9578]
# Action : [44.4333]
# Action : [48.7556]
# Action : [52.8017]
# Action : [53.6703]
# Action : [53.6371]
# Action : [51.2323]
# Action : [47.0634]
# Action : [41.6652]
# Action : [35.0319]
# Action : [27.7587]
# Action : [17.7539]
# Action : [8.60117]
# Action : [-4.1138]
# Action : [-17.293]
# Action : [-24.3023]
# Action : [-23.7889]
# Action : [-12.3069]
# Action : [1.98903]
# Action : [11.9145]
# Action : [22.2909]
# Action : [32.9967]
# Action : [43.3946]
# Action : [52.6484]
# Action : [56.1068]
# Action : [56.3299]
# Action : [54.5984]
# Action : [49.8429]
# Action : [42.7502]
# Action : [36.2843]
# Action : [31.6286]
# Action : [29.3181]
# Action : [33.6409]
# Action : [39.3558]
# Action : [43.9739]
# Action : [48.6329]
# Action : [51.5077]
# Action : [52.4714]
# Action : [51.6874]
# Action : [48.8055]
# Action : [44.6434]
# Action : [39.2309]
# Action : [32.8737]
# Action : [26.3326]
# Action : [16.2562]
# Action : [6.53828]
# Action : [-4.79016]
# Action : [-17.6661]
# Action : [-23.3334]
# Action : [-20.8299]
# Action : [-8.4148]
# Action : [7.20419]
# Action : [17.2754]
# Action : [27.4485]
# Action : [38.2525]
# Action : [48.3739]
# Action : [54.9787]
# Action : [56.8112]
# Action : [55.3287]
# Action : [52.0347]
# Action : [46.3615]
# Action : [39.1005]
# Action : [33.7519]
# Action : [29.4251]
# Action : [31.4605]
# Action : [36.3245]
# Action : [42.0723]
# Action : [46.4126]
# Action : [50.2378]
# Action : [52.0858]
# Action : [52.4644]
# Action : [50.4794]
# Action : [46.9856]
# Action : [41.8283]
# Action : [35.9378]
# Action : [29.4365]
# Action : [20.7278]
# Action : [10.9696]
# Action : [0.929698]
# Action : [-10.5753]
# Action : [-20.7585]
# Action : [-23.652]
# Action : [-16.3583]
# Action : [-2.35427]
# Action : [12.7586]
# Action : [24.0695]
# Action : [34.9576]
# Action : [45.8457]
# Action : [54.7695]
# Action : [58.214]
# Action : [58.0709]
# Action : [55.977]
# Action : [50.1545]
# Action : [42.8307]
# Action : [36.413]
# Action : [31.335]
# Action : [30.2476]
# Action : [34.9192]
# Action : [40.0096]
# Action : [45.4769]
# Action : [49.9874]
# Action : [52.7834]
# Action : [54.0465]
# Action : [52.9927]
# Action : [50.2742]
# Action : [45.36]
# Action : [39.4227]
# Action : [32.8042]
# Action : [25.1899]
# Action : [15.1695]
# Action : [4.94614]
# Action : [-6.84281]
# Action : [-19.2062]
# Action : [-25.5395]
# Action : [-23.2806]
# Action : [-10.8616]
# Action : [3.45319]
# Action : [13.779]
# Action : [24.2269]
# Action : [35.5669]
# Action : [45.869]
# Action : [54.586]
# Action : [58.1268]
# Action : [56.9884]
# Action : [54.2397]
# Action : [49.564]
# Action : [41.8373]
# Action : [35.4168]
# Action : [30.563]
# Action : [30.4796]
# Action : [34.9342]
# Action : [40.5808]
# Action : [45.5951]
# Action : [49.3248]
# Action : [53.0564]
# Action : [53.4331]
# Action : [51.7231]
# Action : [49.1362]
# Action : [44.5733]
# Action : [38.7293]
# Action : [32.0284]
# Action : [24.4666]
# Action : [13.5829]
# Action : [4.25724]
# Action : [-6.89838]
# Action : [-19.2297]
# Action : [-24.844]
# Action : [-21.6281]
# Action : [-9.33545]
# Action : [5.7563]
# Action : [16.1003]
# Action : [26.9929]
# Action : [37.5181]
# Action : [47.8813]
# Action : [55.5514]
# Action : [57.8813]
# Action : [56.3407]
# Action : [53.6149]
# Action : [47.2558]
# Action : [40.5644]
# Action : [34.4666]
# Action : [29.9407]
# Action : [30.8179]
# Action : [35.9456]
# Action : [42.0348]
# Action : [46.636]
# Action : [50.2341]
# Action : [52.7845]
# Action : [53.4153]
# Action : [51.2891]
# Action : [48.2577]
# Action : [43.2446]
# Action : [37.6083]
# Action : [30.8544]
# Action : [21.787]
# Action : [12.3629]
# Action : [1.39634]
# Action : [-9.72512]
# Action : [-20.7905]
# Action : [-25.4169]
# Action : [-19.615]
# Action : [-6.60785]
# Action : [8.89405]
# Action : [19.3639]
# Action : [30.3295]
# Action : [41.2938]
# Action : [51.2213]
# Action : [57.1036]
# Action : [58.024]
# Action : [56.301]
# Action : [52.183]
# Action : [46.0135]
# Action : [38.987]
# Action : [33.4955]
# Action : [29.7489]
# Action : [32.4236]
# Action : [38.0662]
# Action : [43.6832]
# Action : [47.9543]
# Action : [51.9669]
# Action : [53.6519]
# Action : [53.965]
# Action : [51.2428]
# Action : [47.0993]
# Action : [42.2485]
# Action : [36.0356]
# Action : [29.081]
# Action : [19.1778]
# Action : [9.63643]
# Action : [-2.12806]
# Action : [-16.1879]
# Action : [-23.0298]
# Action : [-23.1471]
# Action : [-12.2041]
# Action : [2.53325]
# Action : [12.5808]
# Action : [22.3773]
# Action : [33.4494]
# Action : [43.2133]
# Action : [52.2404]
# Action : [56.174]
# Action : [55.7009]
# Action : [53.5584]
# Action : [48.4981]
# Action : [41.8403]
# Action : [35.9802]
# Action : [31.0397]
# Action : [29.8761]
# Action : [33.3914]
# Action : [39.6078]
# Action : [44.2668]
# Action : [48.035]
# Action : [50.6759]
# Action : [52.1578]
# Action : [51.5458]
# Action : [48.6057]
# Action : [44.057]
# Action : [38.6693]
# Action : [32.5012]
# Action : [25.4122]
# Action : [15.8477]
# Action : [6.7934]
# Action : [-4.95634]
# Action : [-17.1367]
# Action : [-22.8813]
# Action : [-18.501]
# Action : [-6.73016]
# Action : [8.67373]
# Action : [19.2593]
# Action : [29.6319]
# Action : [39.8727]
# Action : [49.8482]
# Action : [55.3335]
# Action : [56.5076]
# Action : [54.4272]
# Action : [50.3384]
# Action : [44.7652]
# Action : [37.6631]
# Action : [33.2174]
# Action : [29.5709]
# Action : [32.1667]
# Action : [37.1771]
# Action : [42.5111]
# Action : [47.137]
# Action : [50.2538]
# Action : [52.2736]
# Action : [51.2959]
# Action : [49.9963]
# Action : [45.4728]
# Action : [40.5401]
# Action : [35.5693]
# Action : [28.2034]
# Action : [19.5959]
# Action : [10.1019]
# Action : [-1.00355]
# Action : [-13.4724]
# Action : [-21.3173]
# Action : [-21.549]
# Action : [-10.7524]
# Action : [4.14878]
# Action : [13.373]
# Action : [23.2681]
# Action : [33.9293]
# Action : [44.5536]
# Action : [52.1342]
# Action : [54.7452]
# Action : [54.7658]
# Action : [52.2948]
# Action : [47.2776]
# Action : [40.4698]
# Action : [34.8239]
# Action : [30.3973]
# Action : [29.823]
# Action : [33.9492]
# Action : [39.4669]
# Action : [44.3636]
# Action : [47.4288]
# Action : [50.1015]
# Action : [51.0059]
# Action : [50.273]
# Action : [46.6288]
# Action : [42.4512]
# Action : [36.706]
# Action : [31.3297]
# Action : [23.8254]
# Action : [14.6277]
# Action : [5.41125]
# Action : [-4.89519]
# Action : [-16.984]
# Action : [-21.7933]
# Action : [-17.2323]
# Action : [-3.57857]
# Action : [11.6638]
# Action : [22.0382]
# Action : [33.2256]
# Action : [43.33]
# Action : [51.9613]
# Action : [56.1014]
# Action : [55.9438]
# Action : [53.9088]
# Action : [49.1718]
# Action : [42.2747]
# Action : [36.5654]
# Action : [31.3285]
# Action : [29.2049]
# Action : [33.6964]
# Action : [39.1416]
# Action : [43.8427]
# Action : [48.2164]
# Action : [50.9838]
# Action : [52.635]
# Action : [50.9659]
# Action : [48.7368]
# Action : [44.3999]
# Action : [39.1299]
# Action : [32.944]
# Action : [26.1078]
# Action : [16.3211]
# Action : [7.05428]
# Action : [-4.38629]
# Action : [-16.2896]
# Action : [-22.2448]
# Action : [-19.7969]
# Action : [-7.08682]
# Action : [8.60639]
# Action : [18.101]
# Action : [28.5306]
# Action : [39.5032]
# Action : [48.8086]
# Action : [54.6171]
# Action : [56.5171]
# Action : [54.8843]
# Action : [51.2361]
# Action : [45.0248]
# Action : [38.1404]
# Action : [33.047]
# Action : [29.4315]
# Action : [31.6719]
# Action : [37.3858]
# Action : [42.4652]
# Action : [47.0757]
# Action : [49.6865]
# Action : [52.1482]
# Action : [52.1688]
# Action : [49.765]
# Action : [46.1326]
# Action : [40.9827]
# Action : [34.8645]
# Action : [28.0394]
# Action : [19.9262]
# Action : [10.4479]
# Action : [-0.299669]
# Action : [-12.5901]
# Action : [-20.7988]
# Action : [-22.1497]
# Action : [-12.5617]
# Action : [1.61657]
# Action : [12.043]
# Action : [22.3078]
# Action : [32.4771]
# Action : [42.2974]
# Action : [50.868]
# Action : [54.4875]
# Action : [54.6887]
# Action : [52.7317]
# Action : [48.1793]
# Action : [41.7709]
# Action : [35.6873]
# Action : [30.913]
# Action : [29.2699]
# Action : [33.4808]
# Action : [38.7814]
# Action : [43.6698]
# Action : [47.2549]
# Action : [49.8847]
# Action : [50.9691]
# Action : [50.3716]
# Action : [47.7448]
# Action : [43.4617]
# Action : [38.3112]
# Action : [32.3019]
# Action : [25.4049]
# Action : [16.0796]
# Action : [7.18679]
# Action : [-3.89392]
# Action : [-15.8693]
# Action : [-20.9805]
# Action : [-17.2161]
# Action : [-4.17824]
# Action : [10.6499]
# Action : [21.1867]
# Action : [31.438]
# Action : [41.4895]
# Action : [50.7706]
# Action : [55.1278]
# Action : [55.6194]
# Action : [53.7785]
# Action : [49.4183]
# Action : [42.8752]
# Action : [36.776]
# Action : [31.6985]
# Action : [29.302]
# Action : [32.8821]
# Action : [38.1332]
# Action : [43.7673]
# Action : [47.4031]
# Action : [50.1496]
# Action : [51.5946]
# Action : [51.1552]
# Action : [48.4878]
# Action : [43.9975]
# Action : [39.0748]
# Action : [32.5113]
# Action : [27.1076]
# Action : [17.4944]
# Action : [7.89488]
# Action : [-3.82124]
# Action : [-15.7965]
# Action : [-21.6997]
# Action : [-18.6826]
# Action : [-6.24495]
# Action : [9.06128]
# Action : [19.2221]
# Action : [29.7223]
# Action : [39.8332]
# Action : [49.5607]
# Action : [54.2714]
# Action : [55.9483]
# Action : [54.0989]
# Action : [50.7894]
# Action : [44.047]
# Action : [37.766]
# Action : [32.5281]
# Action : [29.1949]
# Action : [32.2833]
# Action : [37.6051]
# Action : [42.8233]
# Action : [47.0175]
# Action : [49.9947]
# Action : [51.5033]
# Action : [51.2565]
# Action : [49.1551]
# Action : [45.317]
# Action : [40.1689]
# Action : [34.0191]
# Action : [27.9463]
# Action : [18.7579]
# Action : [9.77101]
# Action : [-0.923213]
# Action : [-13.3542]
# Action : [-20.917]
# Action : [-20.9593]
# Action : [-9.62342]
# Action : [5.31933]
# Action : [14.497]
# Action : [24.9297]
# Action : [35.3594]
# Action : [44.8425]
# Action : [52.7253]
# Action : [54.577]
# Action : [53.6897]
# Action : [51.0215]
# Action : [46.3323]
# Action : [39.4692]
# Action : [34.0882]
# Action : [30.0124]
# Action : [30.3161]
# Action : [34.7584]
# Action : [40.2144]
# Action : [44.7475]
# Action : [48.4221]
# Action : [49.8649]
# Action : [50.8149]
# Action : [49.3375]
# Action : [46.3269]
# Action : [41.6213]
# Action : [36.3091]
# Action : [29.7783]
# Action : [22.3279]
# Action : [13.7403]
# Action : [4.02496]
# Action : [-6.63344]
# Action : [-17.5684]
# Action : [-21.8777]
# Action : [-16.0631]
# Action : [-2.84125]
# Action : [12.8345]
# Action : [23.6695]
# Action : [34.1347]
# Action : [44.4292]
# Action : [53.159]
# Action : [56.7606]
# Action : [56.0407]
# Action : [54.3881]
# Action : [49.1406]
# Action : [42.0634]
# Action : [35.8868]
# Action : [31.2582]
# Action : [29.7607]
# Action : [33.8062]
# Action : [40.0405]
# Action : [44.3877]
# Action : [49.0625]
# Action : [51.3506]
# Action : [52.5878]
# Action : [51.5359]
# Action : [48.7906]
# Action : [44.411]
# Action : [38.534]
# Action : [32.0873]
# Action : [25.4627]
# Action : [15.3618]
# Action : [5.85783]
# Action : [-5.11938]
# Action : [-17.5102]
# Action : [-23.5395]
# Action : [-20.2494]
# Action : [-7.49596]
# Action : [7.63133]
# Action : [17.922]
# Action : [28.4169]
# Action : [39.2374]
# Action : [48.8215]
# Action : [55.4087]
# Action : [57.07]
# Action : [55.4897]
# Action : [51.7513]
# Action : [46.0384]
# Action : [38.5204]
# Action : [33.6334]
# Action : [29.151]
# Action : [31.59]
# Action : [36.8603]
# Action : [41.8045]
# Action : [46.5797]
# Action : [50.3775]
# Action : [52.3264]
# Action : [52.6341]
# Action : [50.6047]
# Action : [46.7007]
# Action : [41.505]
# Action : [35.8409]
# Action : [29.1078]
# Action : [20.1283]
# Action : [10.4643]
# Action : [-0.442818]
# Action : [-12.345]
# Action : [-21.1879]
# Action : [-23.1786]
# Action : [-13.6581]
# Action : [0.951752]
# Action : [12.2475]
# Action : [22.7894]
# Action : [33.1787]
# Action : [42.6081]
# Action : [51.8679]
# Action : [55.4086]
# Action : [55.2268]
# Action : [53.2232]
# Action : [48.714]
# Action : [42.6003]
# Action : [36.2037]
# Action : [30.8235]
# Action : [29.4574]
# Action : [33.8464]
# Action : [39.1457]
# Action : [44.1043]
# Action : [47.9273]
# Action : [50.5072]
# Action : [51.8885]
# Action : [51.5623]
# Action : [47.7666]
# Action : [43.6652]
# Action : [38.4847]
# Action : [32.1283]
# Action : [25.776]
# Action : [16.018]
# Action : [7.4915]
# Action : [-4.65151]
# Action : [-16.4748]
# Action : [-22.4362]
# Action : [-18.7559]
# Action : [-5.98518]
# Action : [9.52803]
# Action : [19.6206]
# Action : [29.7191]
# Action : [40.6797]
# Action : [50.4283]
# Action : [55.2318]
# Action : [56.2737]
# Action : [53.9788]
# Action : [50.3771]
# Action : [44.1924]
# Action : [37.8057]
# Action : [32.1786]
# Action : [29.7599]
# Action : [32.0722]
# Action : [37.5024]
# Action : [42.7519]
# Action : [46.8588]
# Action : [49.9947]
# Action : [51.9785]
# Action : [51.3474]
# Action : [49.1852]
# Action : [45.6446]
# Action : [40.3677]
# Action : [34.2237]
# Action : [27.9966]
# Action : [18.6719]
# Action : [9.32403]
# Action : [-1.42926]
# Action : [-14.0712]
# Action : [-21.6424]
# Action : [-21.0222]
# Action : [-8.87739]
# Action : [5.82723]
# Action : [15.5948]
# Action : [25.6431]
# Action : [36.2647]
# Action : [45.9458]
# Action : [53.2142]
# Action : [55.0765]
# Action : [54.6398]
# Action : [51.4706]
# Action : [46.0226]
# Action : [39.477]
# Action : [33.951]
# Action : [29.7476]
# Action : [30.5839]
# Action : [35.3309]
# Action : [40.8134]
# Action : [45.0683]
# Action : [48.5633]
# Action : [50.6229]
# Action : [51.5154]
# Action : [49.4068]
# Action : [46.3751]
# Action : [41.9959]
# Action : [35.8049]
# Action : [29.7653]
# Action : [21.893]
# Action : [12.9636]
# Action : [2.65749]
# Action : [-7.41581]
# Action : [-18.5064]
# Action : [-22.5958]
# Action : [-16.8278]
# Action : [-3.3187]
# Action : [12.4526]
# Action : [22.5789]
# Action : [33.2462]
# Action : [43.9532]
# Action : [52.8034]
# Action : [57.1251]
# Action : [56.9731]
# Action : [54.0323]
# Action : [49.8175]
# Action : [42.5695]
# Action : [36.7133]
# Action : [31.6385]
# Action : [29.3693]
# Action : [33.9374]
# Action : [39.6261]
# Action : [44.6466]
# Action : [48.885]
# Action : [51.7596]
# Action : [52.801]
# Action : [52.0201]
# Action : [49.1027]
# Action : [45.0107]
# Action : [39.6352]
# Action : [32.9779]
# Action : [25.8947]
# Action : [15.992]
# Action : [6.20908]
# Action : [-5.59885]
# Action : [-17.6231]
# Action : [-24.4583]
# Action : [-21.6664]
# Action : [-8.45006]
# Action : [6.34578]
# Action : [16.6036]
# Action : [27.0034]
# Action : [38.0462]
# Action : [48.2011]
# Action : [54.7909]
# Action : [56.9436]
# Action : [55.805]
# Action : [52.6775]
# Action : [46.5127]
# Action : [39.7657]
# Action : [33.9397]
# Action : [29.7848]
# Action : [31.4823]
# Action : [36.2754]
# Action : [41.9082]
# Action : [46.5373]
# Action : [49.8592]
# Action : [52.2317]
# Action : [52.7208]
# Action : [50.6721]
# Action : [47.0284]
# Action : [42.3781]
# Action : [36.4096]
# Action : [29.461]
# Action : [21.6811]
# Action : [11.7454]
# Action : [1.3772]
# Action : [-9.57447]
# Action : [-20.4629]
# Action : [-24.0147]
# Action : [-18.5435]
# Action : [-4.67762]
# Action : [11.1377]
# Action : [21.7675]
# Action : [32.6408]
# Action : [43.2239]
# Action : [52.813]
# Action : [57.6139]
# Action : [58.6843]
# Action : [55.5995]
# Action : [51.5249]
# Action : [44.149]
# Action : [37.4638]
# Action : [32.3949]
# Action : [29.955]
# Action : [32.9658]
# Action : [39.004]
# Action : [44.3579]
# Action : [48.807]
# Action : [52.4551]
# Action : [53.6269]
# Action : [53.0264]
# Action : [50.7529]
# Action : [46.1006]
# Action : [40.5731]
# Action : [34.5149]
# Action : [27.1514]
# Action : [17.2678]
# Action : [7.3457]
# Action : [-4.0849]
# Action : [-17.3902]
# Action : [-24.1173]
# Action : [-23.229]
# Action : [-11.252]
# Action : [3.25492]
# Action : [13.2497]
# Action : [24.1333]
# Action : [34.3957]
# Action : [44.8955]
# Action : [53.2338]
# Action : [56.454]
# Action : [56.1831]
# Action : [53.6236]
# Action : [48.5046]
# Action : [41.4876]
# Action : [35.232]
# Action : [31.3316]
# Action : [29.7844]
# Action : [34.4613]
# Action : [39.7998]
# Action : [45.2458]
# Action : [48.9844]
# Action : [52.0127]
# Action : [52.6231]
# Action : [51.3012]
# Action : [48.4902]
# Action : [44.2537]
# Action : [38.4462]
# Action : [32.1296]
# Action : [24.5242]
# Action : [15.2234]
# Action : [5.18476]
# Action : [-6.2009]
# Action : [-18.2824]
# Action : [-24.0511]
# Action : [-20.6338]
# Action : [-7.43234]
# Action : [7.63984]
# Action : [17.9833]
# Action : [28.5731]
# Action : [39.6917]
# Action : [49.5762]
# Action : [55.4821]
# Action : [57.0716]
# Action : [55.2556]
# Action : [52.1045]
# Action : [45.8194]
# Action : [38.7023]
# Action : [34.2755]
# Action : [29.7788]
# Action : [31.4788]
# Action : [36.6561]
# Action : [42.3018]
# Action : [46.9738]
# Action : [50.6559]
# Action : [52.4806]
# Action : [52.6059]
# Action : [51.1532]
# Action : [46.7933]
# Action : [42.07]
# Action : [36.178]
# Action : [29.4471]
# Action : [20.6622]
# Action : [10.9484]
# Action : [-0.249337]
# Action : [-12.1897]
# Action : [-22.0727]
# Action : [-23.1789]
# Action : [-14.2325]
# Action : [-0.0506783]
# Action : [12.7308]
# Action : [23.0154]
# Action : [33.9315]
# Action : [44.8225]
# Action : [53.1887]
# Action : [57.1949]
# Action : [56.3794]
# Action : [54.1335]
# Action : [49.3279]
# Action : [41.9396]
# Action : [36.3834]
# Action : [31.3511]
# Action : [29.8501]
# Action : [34.0193]
# Action : [39.9875]
# Action : [44.8351]
# Action : [49.3038]
# Action : [51.5704]
# Action : [52.8215]
# Action : [51.9479]
# Action : [49.4102]
# Action : [44.7913]
# Action : [38.7204]
# Action : [32.583]
# Action : [25.3893]
# Action : [15.4859]
# Action : [6.20725]
# Action : [-5.73234]
# Action : [-17.7289]
# Action : [-23.7946]
# Action : [-20.5984]
# Action : [-8.39525]
# Action : [6.75655]
# Action : [17.1315]
# Action : [27.7136]
# Action : [38.0809]
# Action : [48.8349]
# Action : [55.1691]
# Action : [56.799]
# Action : [55.4813]
# Action : [52.1383]
# Action : [46.1659]
# Action : [39.2111]
# Action : [34.1531]
# Action : [30.0487]
# Action : [31.5703]
# Action : [36.9188]
# Action : [42.0719]
# Action : [46.3076]
# Action : [50.2456]
# Action : [52.2776]
# Action : [52.0933]
# Action : [50.8749]
# Action : [46.8091]
# Action : [42.6171]
# Action : [35.9554]
# Action : [29.7947]
# Action : [21.2509]
# Action : [11.8504]
# Action : [0.678826]
# Action : [-10.7415]
# Action : [-20.9803]
# Action : [-23.8172]
# Action : [-16.9004]
# Action : [-2.93518]
# Action : [13.2428]
# Action : [24.25]
# Action : [34.8337]
# Action : [45.6496]
# Action : [54.8736]
# Action : [58.4088]
# Action : [58.1748]
# Action : [55.1407]
# Action : [49.9426]
# Action : [42.7188]
# Action : [36.302]
# Action : [31.9917]
# Action : [30.1225]
# Action : [34.2622]
# Action : [40.2479]
# Action : [45.6848]
# Action : [49.7622]
# Action : [52.9535]
# Action : [54.1591]
# Action : [53.1782]
# Action : [49.9524]
# Action : [45.3939]
# Action : [39.6026]
# Action : [32.9037]
# Action : [24.9736]
# Action : [15.2219]
# Action : [4.83938]
# Action : [-6.74044]
# Action : [-19.202]
# Action : [-25.5957]
# Action : [-23.8149]
# Action : [-11.4396]
# Action : [2.88014]
# Action : [13.2978]
# Action : [24.3338]
# Action : [35.0478]
# Action : [45.885]
# Action : [54.8681]
# Action : [57.5714]
# Action : [57.1547]
# Action : [54.6783]
# Action : [49.2373]
# Action : [41.9495]
# Action : [36.0651]
# Action : [31.6196]
# Action : [29.7728]
# Action : [34.4684]
# Action : [40.4521]
# Action : [45.3098]
# Action : [49.2015]
# Action : [52.4385]
# Action : [53.5324]
# Action : [52.2695]
# Action : [49.3922]
# Action : [44.7346]
# Action : [38.6824]
# Action : [32.146]
# Action : [24.4641]
# Action : [14.6743]
# Action : [4.9271]
# Action : [-6.52934]
# Action : [-18.6116]
# Action : [-25.0004]
# Action : [-22.0624]
# Action : [-9.4074]
# Action : [5.65952]
# Action : [15.7119]
# Action : [26.9167]
# Action : [37.6683]
# Action : [47.5991]
# Action : [55.2773]
# Action : [57.4685]
# Action : [56.8029]
# Action : [53.4753]
# Action : [47.7673]
# Action : [40.5044]
# Action : [34.9279]
# Action : [31.0343]
# Action : [30.1936]
# Action : [36.341]
# Action : [41.599]
# Action : [46.4537]
# Action : [50.435]
# Action : [52.1714]
# Action : [53.3753]
# Action : [51.8179]
# Action : [48.7601]
# Action : [43.3138]
# Action : [36.949]
# Action : [30.694]
# Action : [22.3219]
# Action : [12.5763]
# Action : [2.20346]
# Action : [-8.86137]
# Action : [-20.4997]
# Action : [-25.5418]
# Action : [-21.3338]
# Action : [-7.75762]
# Action : [7.03769]
# Action : [17.9301]
# Action : [28.5017]
# Action : [39.103]
# Action : [49.8215]
# Action : [56.5309]
# Action : [58.4667]
# Action : [57.1402]
# Action : [53.1888]
# Action : [46.9051]
# Action : [39.8258]
# Action : [33.8325]
# Action : [30.1886]
# Action : [31.2494]
# Action : [37.072]
# Action : [42.782]
# Action : [47.4093]
# Action : [51.0269]
# Action : [53.6087]
# Action : [54.0875]
# Action : [51.9115]
# Action : [48.2829]
# Action : [42.6162]
# Action : [36.9372]
# Action : [29.9292]
# Action : [21.0883]
# Action : [10.9555]
# Action : [-0.0401578]
# Action : [-12.457]
# Action : [-22.5096]
# Action : [-25.7308]
# Action : [-17.1553]
# Action : [-3.82479]
# Action : [12.5182]
# Action : [23.7306]
# Action : [34.4528]
# Action : [45.5694]
# Action : [55.7191]
# Action : [58.622]
# Action : [58.6697]
# Action : [56.533]
# Action : [51.4903]
# Action : [43.7483]
# Action : [37.0369]
# Action : [31.6624]
# Action : [30.0279]
# Action : [34.5943]
# Action : [40.3173]
# Action : [45.6857]
# Action : [50.7174]
# Action : [53.7989]
# Action : [54.8311]
# Action : [53.9671]
# Action : [50.9175]
# Action : [46.4109]
# Action : [40.6907]
# Action : [33.5174]
# Action : [26.2956]
# Action : [16.2831]
# Action : [5.88811]
# Action : [-6.45171]
# Action : [-19.0395]
# Action : [-25.8107]
# Action : [-24.7278]
# Action : [-12.8618]
# Action : [2.24272]
# Action : [11.4475]
# Action : [22.4297]
# Action : [33.0364]
# Action : [43.7826]
# Action : [52.931]
# Action : [57.2808]
# Action : [57.4378]
# Action : [54.9994]
# Action : [50.8293]
# Action : [43.4646]
# Action : [36.6693]
# Action : [32.4562]
# Action : [29.6564]
# Action : [33.4854]
# Action : [39.6619]
# Action : [45.0317]
# Action : [48.6009]
# Action : [51.8431]
# Action : [52.9253]
# Action : [52.5781]
# Action : [50.0501]
# Action : [46.0578]
# Action : [39.9043]
# Action : [34.0869]
# Action : [26.8047]
# Action : [16.7369]
# Action : [7.33491]
# Action : [-4.46562]
# Action : [-17.5132]
# Action : [-23.6801]
# Action : [-22.0791]
# Action : [-9.79523]
# Action : [5.37727]
# Action : [14.7673]
# Action : [25.2963]
# Action : [36.243]
# Action : [46.1434]
# Action : [54.3963]
# Action : [56.6892]
# Action : [56.0205]
# Action : [52.9626]
# Action : [47.4924]
# Action : [41.0046]
# Action : [35.1354]
# Action : [30.5344]
# Action : [30.3968]
# Action : [35.3059]
# Action : [40.8961]
# Action : [45.4637]
# Action : [49.3286]
# Action : [52.0017]
# Action : [52.8604]
# Action : [51.5454]
# Action : [47.8903]
# Action : [43.3143]
# Action : [37.1342]
# Action : [31.341]
# Action : [23.0556]
# Action : [13.6063]
# Action : [3.70656]
# Action : [-7.60373]
# Action : [-19.2127]
# Action : [-24.9199]
# Action : [-19.9156]
# Action : [-7.27536]
# Action : [8.20329]
# Action : [18.5941]
# Action : [29.6066]
# Action : [39.6653]
# Action : [50.3771]
# Action : [56.0143]
# Action : [58.0562]
# Action : [56.2698]
# Action : [51.9865]
# Action : [45.5728]
# Action : [38.6775]
# Action : [33.8276]
# Action : [29.4609]
# Action : [31.4748]
# Action : [37.5022]
# Action : [42.9157]
# Action : [47.3954]
# Action : [50.6233]
# Action : [52.8923]
# Action : [53.0345]
# Action : [50.6614]
# Action : [47.5114]
# Action : [41.514]
# Action : [35.7883]
# Action : [29.0433]
# Action : [19.762]
# Action : [9.78012]
# Action : [-1.11065]
# Action : [-14.2313]
# Action : [-22.4438]
# Action : [-23.4134]
# Action : [-12.952]
# Action : [1.05432]
# Action : [12.3269]
# Action : [23.3286]
# Action : [33.8186]
# Action : [44.033]
# Action : [52.9116]
# Action : [56.0406]
# Action : [55.4313]
# Action : [53.6227]
# Action : [48.7479]
# Action : [41.8162]
# Action : [36.0043]
# Action : [31.0145]
# Action : [29.3321]
# Action : [33.9176]
# Action : [39.8636]
# Action : [44.1114]
# Action : [48.5369]
# Action : [51.2204]
# Action : [52.0036]
# Action : [51.0395]
# Action : [48.1666]
# Action : [44.2879]
# Action : [38.1588]
# Action : [32.0945]
# Action : [25.069]
# Action : [15.033]
# Action : [6.03644]
# Action : [-5.23039]
# Action : [-17.5886]
# Action : [-22.6573]
# Action : [-19.2025]
# Action : [-6.57261]
# Action : [8.54288]
# Action : [18.9942]
# Action : [29.1331]
# Action : [39.7306]
# Action : [49.6474]
# Action : [55.3465]
# Action : [56.9159]
# Action : [54.7023]
# Action : [51.7214]
# Action : [45.3594]
# Action : [38.4397]
# Action : [33.2894]
# Action : [29.348]
# Action : [31.4654]
# Action : [37.5854]
# Action : [42.6173]
# Action : [46.7335]
# Action : [50.5446]
# Action : [52.0697]
# Action : [52.1276]
# Action : [49.9361]
# Action : [46.2616]
# Action : [40.757]
# Action : [35.1303]
# Action : [28.2306]
# Action : [19.5164]
# Action : [10.592]
# Action : [-0.825403]
# Action : [-12.8773]
# Action : [-21.4058]
# Action : [-22.246]
# Action : [-11.6576]
# Action : [2.76025]
# Action : [11.9364]
# Action : [22.4581]
# Action : [32.5164]
# Action : [42.8902]
# Action : [51.2766]
# Action : [55.0364]
# Action : [54.9722]
# Action : [52.065]
# Action : [47.8274]
# Action : [41.4687]
# Action : [35.3105]
# Action : [31.2115]
# Action : [29.615]
# Action : [33.6763]
# Action : [38.7043]
# Action : [43.905]
# Action : [47.2288]
# Action : [49.6654]
# Action : [51.0176]
# Action : [50.0171]
# Action : [47.5261]
# Action : [43.118]
# Action : [37.3066]
# Action : [31.8334]
# Action : [25.2542]
# Action : [15.1416]
# Action : [6.93193]
# Action : [-4.35202]
# Action : [-15.6669]
# Action : [-21.1864]
# Action : [-17.3239]
# Action : [-4.3817]
# Action : [11.0819]
# Action : [21.3565]
# Action : [32.4659]
# Action : [42.1061]
# Action : [51.3127]
# Action : [55.489]
# Action : [55.7662]
# Action : [53.5252]
# Action : [49.0946]
# Action : [42.5487]
# Action : [36.4956]
# Action : [31.4952]
# Action : [29.3539]
# Action : [33.3345]
# Action : [38.5366]
# Action : [43.4429]
# Action : [47.3211]
# Action : [50.6845]
# Action : [51.6064]
# Action : [51.4808]
# Action : [48.7427]
# Action : [44.7355]
# Action : [38.787]
# Action : [33.3704]
# Action : [26.3363]
# Action : [16.7557]
# Action : [7.77201]
# Action : [-3.81322]
# Action : [-16.4482]
# Action : [-22.0815]
# Action : [-18.5977]
# Action : [-6.32577]
# Action : [8.42488]
# Action : [19.142]
# Action : [29.0785]
# Action : [39.9162]
# Action : [49.038]
# Action : [54.8472]
# Action : [55.9409]
# Action : [54.3293]
# Action : [50.3226]
# Action : [44.3388]
# Action : [38.068]
# Action : [32.934]
# Action : [28.8417]
# Action : [31.8203]
# Action : [37.454]
# Action : [42.8733]
# Action : [47.0619]
# Action : [49.8679]
# Action : [51.8692]
# Action : [51.3012]
# Action : [49.4158]
# Action : [45.4455]
# Action : [40.4702]
# Action : [34.3627]
# Action : [28.165]
# Action : [19.1511]
# Action : [10.0818]
# Action : [-0.844469]
# Action : [-12.3988]
# Action : [-20.9621]
# Action : [-21.5803]
# Action : [-9.75305]
# Action : [4.52196]
# Action : [14.481]
# Action : [24.4581]
# Action : [34.5624]
# Action : [44.3907]
# Action : [52.299]
# Action : [54.6992]
# Action : [54.1076]
# Action : [51.3426]
# Action : [46.4844]
# Action : [39.8193]
# Action : [34.4147]
# Action : [30.2783]
# Action : [29.7119]
# Action : [34.3166]
# Action : [39.8104]
# Action : [44.3987]
# Action : [47.7]
# Action : [50.2767]
# Action : [51.4915]
# Action : [49.307]
# Action : [46.2821]
# Action : [42.3417]
# Action : [36.5788]
# Action : [30.5292]
# Action : [23.3567]
# Action : [14.1224]
# Action : [4.60663]
# Action : [-5.85904]
# Action : [-17.0488]
# Action : [-21.9658]
# Action : [-16.451]
# Action : [-3.10227]
# Action : [12.3008]
# Action : [22.6669]
# Action : [33.5482]
# Action : [43.8233]
# Action : [52.7486]
# Action : [56.2766]
# Action : [56.0498]
# Action : [53.7635]
# Action : [48.55]
# Action : [42.3416]
# Action : [35.997]
# Action : [31.7014]
# Action : [29.5617]
# Action : [34.0803]
# Action : [39.6826]
# Action : [44.7502]
# Action : [48.7655]
# Action : [51.1959]
# Action : [52.4898]
# Action : [51.0013]
# Action : [48.5836]
# Action : [44.3773]
# Action : [39.0099]
# Action : [32.2723]
# Action : [25.1368]
# Action : [15.8752]
# Action : [6.08545]
# Action : [-5.01186]
# Action : [-17.6662]
# Action : [-23.2207]
# Action : [-19.7732]
# Action : [-6.90592]
# Action : [7.85357]
# Action : [18.371]
# Action : [29.2157]
# Action : [39.4344]
# Action : [49.3321]
# Action : [55.3033]
# Action : [56.6868]
# Action : [55.6546]
# Action : [51.6787]
# Action : [44.9183]
# Action : [38.5894]
# Action : [33.1908]
# Action : [30.0375]
# Action : [31.6892]
# Action : [36.9615]
# Action : [42.5439]
# Action : [46.98]
# Action : [49.9603]
# Action : [52.3892]
# Action : [52.078]
# Action : [49.8753]
# Action : [46.2596]
# Action : [41.5138]
# Action : [35.1064]
# Action : [28.889]
# Action : [19.7656]
# Action : [10.4494]
# Action : [-0.297957]
# Action : [-12.6195]
# Action : [-21.0831]
# Action : [-22.911]
# Action : [-12.9131]
# Action : [1.07257]
# Action : [12.2906]
# Action : [22.4388]
# Action : [32.4891]
# Action : [42.9809]
# Action : [51.3953]
# Action : [55.3493]
# Action : [55.6641]
# Action : [53.2012]
# Action : [48.5572]
# Action : [42.1385]
# Action : [36.0386]
# Action : [31.2848]
# Action : [29.3871]
# Action : [33.749]
# Action : [39.341]
# Action : [44.1126]
# Action : [47.4723]
# Action : [50.8505]
# Action : [51.9507]
# Action : [50.5948]
# Action : [48.3296]
# Action : [43.1255]
# Action : [38.6442]
# Action : [32.2372]
# Action : [25.789]
# Action : [16.4679]
# Action : [6.99639]
# Action : [-3.99352]
# Action : [-16.6366]
# Action : [-22.3805]
# Action : [-18.5417]
# Action : [-6.03987]
# Action : [9.37072]
# Action : [19.6411]
# Action : [30.2951]
# Action : [40.2491]
# Action : [49.9975]
# Action : [55.2166]
# Action : [56.6273]
# Action : [54.1626]
# Action : [50.7591]
# Action : [44.2791]
# Action : [38.067]
# Action : [32.6637]
# Action : [29.3196]
# Action : [32.4955]
# Action : [37.935]
# Action : [42.7072]
# Action : [46.8069]
# Action : [50.463]
# Action : [51.7023]
# Action : [51.842]
# Action : [49.0306]
# Action : [45.5075]
# Action : [40.0812]
# Action : [34.3922]
# Action : [27.9683]
# Action : [18.3821]
# Action : [9.35796]
# Action : [-1.67353]
# Action : [-14.2128]
# Action : [-21.6506]
# Action : [-20.3455]
# Action : [-8.85461]
# Action : [6.76196]
# Action : [16.6626]
# Action : [26.6743]
# Action : [36.9569]
# Action : [46.9635]
# Action : [53.1245]
# Action : [55.2047]
# Action : [54.3875]
# Action : [51.1705]
# Action : [45.3292]
# Action : [38.9882]
# Action : [33.5828]
# Action : [28.9157]
# Action : [30.9102]
# Action : [36.0043]
# Action : [41.2266]
# Action : [45.7922]
# Action : [48.9024]
# Action : [50.9283]
# Action : [50.8371]
# Action : [49.3268]
# Action : [46.1738]
# Action : [41.0725]
# Action : [35.5177]
# Action : [29.1668]
# Action : [20.845]
# Action : [12.0235]
# Action : [2.0097]
# Action : [-8.34701]
# Action : [-19.8629]
# Action : [-23.0689]
# Action : [-16.8567]
# Action : [-3.16261]
# Action : [12.0788]
# Action : [22.7261]
# Action : [34.0696]
# Action : [44.6065]
# Action : [53.3378]
# Action : [57.3386]
# Action : [56.7635]
# Action : [54.887]
# Action : [49.8438]
# Action : [42.3839]
# Action : [36.3614]
# Action : [31.5871]
# Action : [30.0032]
# Action : [34.1435]
# Action : [40.2553]
# Action : [44.9815]
# Action : [49.3016]
# Action : [52.1489]
# Action : [53.3388]
# Action : [52.5694]
# Action : [49.2545]
# Action : [45.1606]
# Action : [39.3687]
# Action : [33.0695]
# Action : [25.4729]
# Action : [15.6411]
# Action : [6.0461]
# Action : [-5.29006]
# Action : [-18.0201]
# Action : [-24.3323]
# Action : [-21.7439]
# Action : [-9.56059]
# Action : [5.82212]
# Action : [15.6231]
# Action : [26.4221]
# Action : [37.3061]
# Action : [47.2199]
# Action : [54.6646]
# Action : [56.8495]
# Action : [55.9519]
# Action : [53.2722]
# Action : [46.9534]
# Action : [39.9687]
# Action : [34.6183]
# Action : [29.994]
# Action : [30.6984]
# Action : [35.8586]
# Action : [41.6061]
# Action : [45.8735]
# Action : [50.0702]
# Action : [52.7515]
# Action : [52.4793]
# Action : [51.495]
# Action : [48.079]
# Action : [42.8903]
# Action : [36.9265]
# Action : [30.5143]
# Action : [22.0038]
# Action : [12.4768]
# Action : [2.4332]
# Action : [-8.54533]
# Action : [-20.0985]
# Action : [-24.8622]
# Action : [-20.4057]
# Action : [-7.84023]
# Action : [8.37148]
# Action : [18.4953]
# Action : [29.237]
# Action : [40.6212]
# Action : [50.4295]
# Action : [56.592]
# Action : [58.2832]
# Action : [55.7607]
# Action : [53.0993]
# Action : [46.2831]
# Action : [38.9765]
# Action : [33.9693]
# Action : [29.6234]
# Action : [31.3505]
# Action : [37.2037]
# Action : [43.4837]
# Action : [47.7679]
# Action : [51.3458]
# Action : [53.5213]
# Action : [53.5181]
# Action : [51.2448]
# Action : [47.6972]
# Action : [42.0266]
# Action : [36.247]
# Action : [28.7005]
# Action : [19.9325]
# Action : [10.5274]
# Action : [-1.71166]
# Action : [-14.7699]
# Action : [-22.4915]
# Action : [-23.3065]
# Action : [-12.496]
# Action : [1.70668]
# Action : [12.1381]
# Action : [23.0626]
# Action : [33.0019]
# Action : [43.1772]
# Action : [52.3117]
# Action : [55.6862]
# Action : [55.7089]
# Action : [53.561]
# Action : [48.9284]
# Action : [41.7099]
# Action : [35.6894]
# Action : [31.1123]
# Action : [29.1864]
# Action : [33.5677]
# Action : [39.6086]
# Action : [44.2432]
# Action : [48.0526]
# Action : [50.7219]
# Action : [52.4019]
# Action : [50.9611]
# Action : [48.063]
# Action : [44.0194]
# Action : [38.3659]
# Action : [32.204]
# Action : [25.2725]
# Action : [15.2947]
# Action : [6.3976]
# Action : [-4.32716]
# Action : [-16.8888]
# Action : [-22.6693]
# Action : [-19.0099]
# Action : [-6.09841]
# Action : [9.26112]
# Action : [19.5201]
# Action : [30.4956]
# Action : [40.2904]
# Action : [50.0126]
# Action : [55.0365]
# Action : [56.9044]
# Action : [54.7001]
# Action : [50.2164]
# Action : [44.1032]
# Action : [37.9384]
# Action : [32.9082]
# Action : [28.9098]
# Action : [32.3715]
# Action : [37.4452]
# Action : [42.9977]
# Action : [47.1418]
# Action : [50.5969]
# Action : [52.1158]
# Action : [51.5746]
# Action : [49.3062]
# Action : [45.5371]
# Action : [40.4349]
# Action : [34.6909]
# Action : [28.1942]
# Action : [18.5338]
# Action : [9.46163]
# Action : [-1.45672]
# Action : [-14.3641]
# Action : [-22.0353]
# Action : [-21.3576]
# Action : [-9.58239]
# Action : [5.19498]
# Action : [15.2462]
# Action : [25.4928]
# Action : [35.6153]
# Action : [45.9611]
# Action : [53.3649]
# Action : [55.6776]
# Action : [54.0489]
# Action : [51.4254]
# Action : [46.6384]
# Action : [39.3486]
# Action : [34.1612]
# Action : [29.5076]
# Action : [30.1624]
# Action : [34.7758]
# Action : [40.4333]
# Action : [44.8752]
# Action : [48.0185]
# Action : [50.4229]
# Action : [51.0718]
# Action : [49.5295]
# Action : [46.6667]
# Action : [41.9927]
# Action : [36.0887]
# Action : [29.4178]
# Action : [22.4024]
# Action : [13.1329]
# Action : [3.2674]
# Action : [-6.95389]
# Action : [-18.5004]
# Action : [-22.9569]
# Action : [-16.9515]
# Action : [-3.25298]
# Action : [11.7328]
# Action : [22.6923]
# Action : [33.3692]
# Action : [43.8658]
# Action : [52.8744]
# Action : [56.8014]
# Action : [56.9228]
# Action : [54.7908]
# Action : [49.884]
# Action : [42.7669]
# Action : [36.5243]
# Action : [31.7118]
# Action : [29.5804]
# Action : [33.9322]
# Action : [39.9006]
# Action : [44.4522]
# Action : [48.7976]
# Action : [51.8959]
# Action : [53.3299]
# Action : [51.8529]
# Action : [49.2492]
# Action : [44.5652]
# Action : [38.7349]
# Action : [33.331]
# Action : [26.2403]
# Action : [15.308]
# Action : [6.92011]
# Action : [-4.68949]
# Action : [-17.6326]
# Action : [-23.2859]
# Action : [-20.5554]
# Action : [-8.94825]
# Action : [6.74167]
# Action : [16.5717]
# Action : [27.7033]
# Action : [37.7849]
# Action : [47.4844]
# Action : [54.4331]
# Action : [56.472]
# Action : [55.3964]
# Action : [52.0376]
# Action : [46.2738]
# Action : [39.4874]
# Action : [34.0048]
# Action : [29.3878]
# Action : [30.6197]
# Action : [36.7349]
# Action : [41.6636]
# Action : [46.0022]
# Action : [50.0405]
# Action : [52.3563]
# Action : [52.036]
# Action : [50.8553]
# Action : [47.2575]
# Action : [42.5845]
# Action : [36.5995]
# Action : [29.9964]
# Action : [21.2223]
# Action : [12.1187]
# Action : [1.24892]
# Action : [-9.76615]
# Action : [-20.2433]
# Action : [-24.4667]
# Action : [-17.7377]
# Action : [-4.01618]
# Action : [12.1454]
# Action : [22.5106]
# Action : [34.0783]
# Action : [43.8337]
# Action : [53.7957]
# Action : [58.093]
# Action : [57.8184]
# Action : [55.6429]
# Action : [50.5458]
# Action : [43.6999]
# Action : [37.4097]
# Action : [31.5397]
# Action : [29.795]
# Action : [33.5281]
# Action : [39.9126]
# Action : [44.8095]
# Action : [48.9036]
# Action : [52.5264]
# Action : [53.8624]
# Action : [53.4377]
# Action : [50.7175]
# Action : [46.0576]
# Action : [40.0044]
# Action : [33.7275]
# Action : [26.6739]
# Action : [16.4551]
# Action : [6.61077]
# Action : [-5.27883]
# Action : [-17.985]
# Action : [-24.6376]
# Action : [-23.4154]
# Action : [-11.173]
# Action : [3.55328]
# Action : [13.495]
# Action : [24.4012]
# Action : [34.9629]
# Action : [45.4247]
# Action : [53.5751]
# Action : [57.4036]
# Action : [56.6212]
# Action : [53.8988]
# Action : [48.5433]
# Action : [41.2983]
# Action : [35.3612]
# Action : [31.2055]
# Action : [30.0134]
# Action : [34.9306]
# Action : [40.6842]
# Action : [45.1436]
# Action : [48.9926]
# Action : [51.714]
# Action : [52.8064]
# Action : [51.7336]
# Action : [48.6077]
# Action : [44.1139]
# Action : [38.194]
# Action : [32.2197]
# Action : [23.9951]
# Action : [14.6927]
# Action : [5.05845]
# Action : [-6.51727]
# Action : [-18.2009]
# Action : [-24.0715]
# Action : [-21.1254]
# Action : [-7.82131]
# Action : [7.10279]
# Action : [17.1165]
# Action : [28.2326]
# Action : [38.6804]
# Action : [48.9697]
# Action : [55.1018]
# Action : [57.5209]
# Action : [56.1896]
# Action : [52.7606]
# Action : [46.151]
# Action : [39.1388]
# Action : [33.2755]
# Action : [30.1295]
# Action : [30.8525]
# Action : [36.6229]
# Action : [42.1541]
# Action : [47.0747]
# Action : [50.2254]
# Action : [52.7232]
# Action : [53.0363]
# Action : [50.6398]
# Action : [47.2385]
# Action : [42.3477]
# Action : [36.0885]
# Action : [29.5311]
# Action : [21.1556]
# Action : [11.2333]
# Action : [0.312435]
# Action : [-11.4039]
# Action : [-21.4173]
# Action : [-24.4063]
# Action : [-16.3913]
# Action : [-2.36359]
# Action : [13.6902]
# Action : [23.9968]
# Action : [35.5021]
# Action : [46.5505]
# Action : [55.4346]
# Action : [58.6996]
# Action : [58.5404]
# Action : [55.3124]
# Action : [50.3033]
# Action : [43.0709]
# Action : [36.8922]
# Action : [31.2064]
# Action : [29.8816]
# Action : [34.7064]
# Action : [40.7613]
# Action : [45.857]
# Action : [50.3598]
# Action : [53.4331]
# Action : [54.4965]
# Action : [53.072]
# Action : [50.2827]
# Action : [45.7182]
# Action : [39.1935]
# Action : [32.9496]
# Action : [24.6058]
# Action : [14.8291]
# Action : [4.76966]
# Action : [-6.78773]
# Action : [-19.5723]
# Action : [-26.3507]
# Action : [-24.3916]
# Action : [-12.2181]
# Action : [3.21833]
# Action : [12.1741]
# Action : [23.9584]
# Action : [34.4282]
# Action : [45.2144]
# Action : [54.5775]
# Action : [57.4438]
# Action : [57.553]
# Action : [54.8218]
# Action : [49.6656]
# Action : [42.6234]
# Action : [36.4725]
# Action : [31.714]
# Action : [29.8202]
# Action : [34.661]
# Action : [39.948]
# Action : [44.7646]
# Action : [49.1324]
# Action : [52.1233]
# Action : [53.7482]
# Action : [52.3136]
# Action : [49.4546]
# Action : [45.0955]
# Action : [39.1365]
# Action : [32.7778]
# Action : [25.4392]
# Action : [15.2765]
# Action : [5.31418]
# Action : [-6.2537]
# Action : [-18.5164]
# Action : [-25.1836]
# Action : [-22.6908]
# Action : [-9.97774]
# Action : [4.67219]
# Action : [14.562]
# Action : [25.4551]
# Action : [35.8766]
# Action : [46.9157]
# Action : [54.5192]
# Action : [57.9214]
# Action : [56.5982]
# Action : [53.6942]
# Action : [47.9187]
# Action : [41.2017]
# Action : [34.9812]
# Action : [30.9331]
# Action : [30.6404]
# Action : [35.3958]
# Action : [41.4393]
# Action : [46.0019]
# Action : [50.0391]
# Action : [52.755]
# Action : [52.9981]
# Action : [51.8835]
# Action : [48.481]
# Action : [43.7454]
# Action : [37.8499]
# Action : [31.0593]
# Action : [23.0561]
# Action : [13.509]
# Action : [2.63047]
# Action : [-7.94555]
# Action : [-19.55]
# Action : [-24.7365]
# Action : [-21.4582]
# Action : [-8.37395]
# Action : [7.30136]
# Action : [16.9759]
# Action : [27.8441]
# Action : [39.159]
# Action : [48.7582]
# Action : [56.2094]
# Action : [58.2842]
# Action : [56.2932]
# Action : [53.1595]
# Action : [46.8324]
# Action : [39.6559]
# Action : [34.4013]
# Action : [30.1267]
# Action : [31.6552]
# Action : [36.7478]
# Action : [42.2283]
# Action : [46.7026]
# Action : [50.9765]
# Action : [52.9468]
# Action : [53.7182]
# Action : [51.4213]
# Action : [47.852]
# Action : [42.9836]
# Action : [36.4822]
# Action : [30.1476]
# Action : [21.2095]
# Action : [11.164]
# Action : [0.172895]
# Action : [-12.5073]
# Action : [-22.1156]
# Action : [-24.2785]
# Action : [-17.0487]
# Action : [-3.08404]
# Action : [12.7127]
# Action : [23.0465]
# Action : [34.9253]
# Action : [45.7765]
# Action : [55.0515]
# Action : [58.6885]
# Action : [58.7118]
# Action : [56.1226]
# Action : [51.0799]
# Action : [43.2363]
# Action : [36.6964]
# Action : [32.1013]
# Action : [29.8513]
# Action : [34.1315]
# Action : [40.209]
# Action : [45.2014]
# Action : [49.9883]
# Action : [53.2091]
# Action : [54.4832]
# Action : [53.3847]
# Action : [50.5686]
# Action : [45.8226]
# Action : [40.5864]
# Action : [33.9842]
# Action : [26.0774]
# Action : [15.7495]
# Action : [5.83092]
# Action : [-6.35271]
# Action : [-19.4293]
# Action : [-25.4253]
# Action : [-24.1363]
# Action : [-12.61]
# Action : [2.25763]
# Action : [12.339]
# Action : [22.7067]
# Action : [33.6131]
# Action : [43.8199]
# Action : [53.7931]
# Action : [57.4974]
# Action : [57.5884]
# Action : [55.2748]
# Action : [50.4844]
# Action : [42.9682]
# Action : [36.6931]
# Action : [31.4506]
# Action : [29.4988]
# Action : [33.9379]
# Action : [39.6528]
# Action : [44.6678]
# Action : [49.1976]
# Action : [52.0351]
# Action : [53.4568]
# Action : [52.6559]
# Action : [49.9005]
# Action : [45.6403]
# Action : [39.7145]
# Action : [32.947]
# Action : [25.728]
# Action : [15.8735]
# Action : [6.28176]
# Action : [-5.34107]
# Action : [-17.8383]
# Action : [-24.4357]
# Action : [-22.2689]
# Action : [-9.68019]
# Action : [5.23721]
# Action : [14.7898]
# Action : [25.6776]
# Action : [36.5294]
# Action : [47.0036]
# Action : [54.3944]
# Action : [57.0662]
# Action : [56.4146]
# Action : [53.3282]
# Action : [48.0377]
# Action : [40.8389]
# Action : [35.0956]
# Action : [30.0347]
# Action : [30.5411]
# Action : [34.9497]
# Action : [41.427]
# Action : [45.8479]
# Action : [49.3416]
# Action : [52.099]
# Action : [52.477]
# Action : [51.0767]
# Action : [48.0157]
# Action : [43.4695]
# Action : [37.2168]
# Action : [31.0037]
# Action : [22.5667]
# Action : [12.8815]
# Action : [3.13202]
# Action : [-7.53158]
# Action : [-19.2046]
# Action : [-24.6934]
# Action : [-20.4225]
# Action : [-7.78127]
# Action : [7.92881]
# Action : [17.8939]
# Action : [29.0836]
# Action : [39.9289]
# Action : [50.1528]
# Action : [56.2547]
# Action : [57.6828]
# Action : [56.5528]
# Action : [52.6283]
# Action : [45.804]
# Action : [39.1354]
# Action : [33.447]
# Action : [29.5395]
# Action : [31.9961]
# Action : [37.3667]
# Action : [42.678]
# Action : [48.1597]
# Action : [50.8181]
# Action : [52.9667]
# Action : [52.9479]
# Action : [51.0694]
# Action : [47.2891]
# Action : [41.6548]
# Action : [36.0453]
# Action : [29.3769]
# Action : [20.1661]
# Action : [10.0757]
# Action : [-1.24915]
# Action : [-13.965]
# Action : [-21.8992]
# Action : [-23.7077]
# Action : [-13.0444]
# Action : [1.55054]
# Action : [11.855]
# Action : [22.0292]
# Action : [32.1701]
# Action : [42.5584]
# Action : [51.7342]
# Action : [55.7244]
# Action : [55.5728]
# Action : [53.4666]
# Action : [49.3291]
# Action : [41.619]
# Action : [36.1359]
# Action : [31.7352]
# Action : [29.5847]
# Action : [33.322]
# Action : [38.7487]
# Action : [43.5176]
# Action : [47.7483]
# Action : [50.1269]
# Action : [51.6303]
# Action : [51.3939]
# Action : [48.5824]
# Action : [44.1015]
# Action : [38.6618]
# Action : [32.4652]
# ...
# Action : [27.5142]
# Action : [17.3057]
# Action : [8.66843]
# Action : [-2.88892]
# Action : [-15.3934]
# Action : [-21.9341]
# Action : [-19.8242]
# Action : [-7.4652]
# Action : [7.75622]
# Action : [17.7545]
# Action : [28.0993]
# Action : [38.5435]
# Action : [48.2876]
# Action : [54.1756]
# Action : [55.8725]
# Action : [54.0892]
# Action : [50.696]
# Action : [44.6446]
# Action : [38.3366]
# Action : [33.33]
# Action : [29.3633]
# Action : [31.6318]
# Action : [36.1255]
# Action : [41.7277]
# Action : [46.266]
# Action : [49.4348]
# Action : [51.1698]
# Action : [51.0258]
# Action : [49.5909]
# Action : [45.4562]
# Action : [40.9761]
# Action : [34.9617]
# Action : [28.5393]
# Action : [19.8219]
# Action : [10.839]
# Action : [0.109879]
# Action : [-10.8889]
# Action : [-19.8956]
# Action : [-22.0961]
# Action : [-12.3373]
# Action : [1.92411]
# Action : [11.6101]
# Action : [21.2614]
# Action : [31.5296]
# Action : [41.5002]
# Action : [49.8259]
# Action : [53.8795]
# Action : [54.1353]
# Action : [52.224]
# Action : [47.8446]
# Action : [41.8307]
# Action : [35.8272]
# Action : [31.3223]
# Action : [29.328]
# Action : [32.7998]
# Action : [38.3221]
# Action : [43.0988]
# Action : [46.6865]
# Action : [49.385]
# Action : [50.2952]
# Action : [50.1164]
# Action : [47.2231]
# Action : [43.2005]
# Action : [37.4965]
# Action : [31.5462]
# Action : [25.8744]
# Action : [16.9144]
# Action : [7.72272]
# Action : [-2.61389]
# Action : [-15.0567]
# Action : [-20.0662]
# Action : [-16.6143]
# Action : [-2.94507]
# Action : [12.2878]
# Action : [22.412]
# Action : [33.1182]
# Action : [42.6215]
# Action : [51.6549]
# Action : [55.0247]
# Action : [54.8606]
# Action : [52.4999]
# Action : [48.2897]
# Action : [41.7511]
# Action : [35.5448]
# Action : [31.1981]
# Action : [28.9639]
# Action : [33.8375]
# Action : [38.8631]
# Action : [43.4262]
# Action : [47.4282]
# Action : [50.2465]
# Action : [51.0606]
# Action : [49.8889]
# Action : [47.4472]
# Action : [43.6585]
# Action : [37.9254]
# Action : [31.8423]
# Action : [25.1765]
# Action : [15.7364]
# Action : [7.06819]
# Action : [-3.87973]
# Action : [-15.9693]
# Action : [-21.9066]
# Action : [-17.8315]
# Action : [-4.60939]
# Action : [10.8168]
# Action : [20.7535]
# Action : [31.5518]
# Action : [41.5676]
# Action : [50.7165]
# Action : [55.3724]
# Action : [56.5084]
# Action : [53.8937]
# Action : [49.6042]
# Action : [43.105]
# Action : [36.626]
# Action : [31.8706]
# Action : [29.3718]
# Action : [32.8852]
# Action : [38.2573]
# Action : [43.2387]
# Action : [47.3181]
# Action : [50.5275]
# Action : [51.388]
# Action : [51.489]
# Action : [48.831]
# Action : [44.5223]
# Action : [39.5695]
# Action : [33.0975]
# Action : [26.81]
# Action : [17.3457]
# Action : [8.177]
# Action : [-3.18223]
# Action : [-15.3505]
# Action : [-21.6996]
# Action : [-19.4524]
# Action : [-6.46644]
# Action : [8.4817]
# Action : [18.7278]
# Action : [28.8695]
# Action : [39.0849]
# Action : [49.6695]
# Action : [54.5894]
# Action : [56.2725]
# Action : [54.1]
# Action : [50.8686]
# Action : [44.1147]
# Action : [38.1117]
# Action : [32.5649]
# Action : [29.2637]
# Action : [32.0673]
# Action : [36.8459]
# Action : [41.5362]
# Action : [46.6398]
# Action : [49.9547]
# Action : [51.0264]
# Action : [51.5996]
# Action : [49.1333]
# Action : [45.4006]
# Action : [40.4736]
# Action : [34.009]
# Action : [28.1175]
# Action : [19.4118]
# Action : [9.88648]
# Action : [-0.813197]
# Action : [-12.9129]
# Action : [-20.6474]
# Action : [-21.3284]
# Action : [-9.83815]
# Action : [4.49115]
# Action : [14.4642]
# Action : [24.4181]
# Action : [34.6798]
# Action : [44.5793]
# Action : [51.988]
# Action : [54.7651]
# Action : [54.0542]
# Action : [51.1288]
# Action : [46.4034]
# Action : [39.831]
# Action : [33.9065]
# Action : [29.5385]
# Action : [29.5045]
# Action : [34.7443]
# Action : [39.8783]
# Action : [44.5194]
# Action : [47.7167]
# Action : [49.8042]
# Action : [50.4136]
# Action : [49.8132]
# Action : [46.6124]
# Action : [41.9243]
# Action : [36.6221]
# Action : [30.1245]
# Action : [23.8027]
# Action : [14.3145]
# Action : [4.52741]
# Action : [-5.6911]
# Action : [-16.6427]
# Action : [-21.5781]
# Action : [-16.3363]
# Action : [-2.41431]
# Action : [12.7453]
# Action : [22.7788]
# Action : [34.1228]
# Action : [44.3686]
# Action : [52.6134]
# Action : [56.3514]
# Action : [56.284]
# Action : [53.6223]
# Action : [48.4504]
# Action : [41.7737]
# Action : [35.9399]
# Action : [30.9272]
# Action : [29.1545]
# Action : [34.1043]
# Action : [39.7401]
# Action : [44.4904]
# Action : [48.7699]
# Action : [51.7613]
# Action : [52.3088]
# Action : [50.8352]
# Action : [48.1024]
# Action : [44.147]
# Action : [38.2153]
# Action : [32.0741]
# Action : [25.1944]
# Action : [15.3634]
# Action : [5.78272]
# Action : [-5.46532]
# Action : [-17.4332]
# Action : [-23.377]
# Action : [-19.831]
# Action : [-6.91145]
# Action : [8.50629]
# Action : [18.652]
# Action : [29.2974]
# Action : [39.8418]
# Action : [49.2986]
# Action : [55.815]
# Action : [56.8696]
# Action : [55.9183]
# Action : [51.1454]
# Action : [45.3951]
# Action : [38.8246]
# Action : [33.5439]
# Action : [29.4852]
# Action : [32.1045]
# Action : [37.1751]
# Action : [42.3752]
# Action : [46.8778]
# Action : [50.5689]
# Action : [52.7544]
# Action : [52.2209]
# Action : [49.9196]
# Action : [46.1576]
# Action : [41.07]
# Action : [35.0438]
# Action : [28.8205]
# Action : [19.3378]
# Action : [10.1389]
# Action : [-0.482294]
# Action : [-13.0301]
# Action : [-21.9009]
# Action : [-22.6578]
# Action : [-12.9985]
# Action : [1.49828]
# Action : [11.6212]
# Action : [21.7432]
# Action : [32.3404]
# Action : [42.7832]
# Action : [51.904]
# Action : [54.8658]
# Action : [54.9689]
# Action : [53.1317]
# Action : [48.4091]
# Action : [41.8263]
# Action : [35.9465]
# Action : [31.5215]
# Action : [29.0546]
# Action : [33.1501]
# Action : [38.8189]
# Action : [44.0964]
# Action : [47.8194]
# Action : [50.2445]
# Action : [51.4411]
# Action : [50.4525]
# Action : [48.0078]
# Action : [44.1674]
# Action : [38.4731]
# Action : [32.0649]
# Action : [25.7246]
# Action : [16.0746]
# Action : [7.50295]
# Action : [-3.88664]
# Action : [-16.0156]
# Action : [-21.7178]
# Action : [-18.3527]
# Action : [-4.94059]
# Action : [9.25726]
# Action : [19.6989]
# Action : [30.7338]
# Action : [40.813]
# Action : [49.8672]
# Action : [55.3004]
# Action : [55.3894]
# Action : [54.0862]
# Action : [50.0631]
# Action : [43.8183]
# Action : [37.3986]
# Action : [32.2214]
# Action : [29.264]
# Action : [32.4035]
# Action : [37.9629]
# Action : [42.9872]
# Action : [47.348]
# Action : [50.0927]
# Action : [52.013]
# Action : [51.3047]
# Action : [49.0258]
# Action : [44.9636]
# Action : [39.9965]
# Action : [33.8009]
# Action : [27.2163]
# Action : [18.1159]
# Action : [8.98167]
# Action : [-2.0603]
# Action : [-15.155]
# Action : [-21.3041]
# Action : [-19.5167]
# Action : [-6.91347]
# Action : [8.38916]
# Action : [18.0507]
# Action : [28.2521]
# Action : [39.2879]
# Action : [48.5183]
# Action : [54.2472]
# Action : [55.6036]
# Action : [53.171]
# Action : [50.1707]
# Action : [45.1331]
# Action : [38.0807]
# Action : [32.9243]
# Action : [29.0229]
# Action : [31.0536]
# Action : [36.831]
# Action : [42.0941]
# Action : [45.8009]
# Action : [49.5423]
# Action : [51.2536]
# Action : [50.8101]
# Action : [49.4467]
# Action : [45.5645]
# Action : [40.0268]
# Action : [34.3577]
# Action : [27.5375]
# Action : [19.5539]
# Action : [11.0116]
# Action : [0.32023]
# Action : [-11.1334]
# Action : [-20.0583]
# Action : [-22.252]
# Action : [-12.0397]
# Action : [2.18575]
# Action : [11.7596]
# Action : [21.4096]
# Action : [31.588]
# Action : [41.3073]
# Action : [50.3184]
# Action : [54.0654]
# Action : [53.8248]
# Action : [52.1705]
# Action : [47.4499]
# Action : [41.2503]
# Action : [35.7687]
# Action : [31.2367]
# Action : [29.2806]
# Action : [32.4615]
# Action : [38.1409]
# Action : [42.8806]
# Action : [46.168]
# Action : [49.4163]
# Action : [50.471]
# Action : [49.2886]
# Action : [47.5315]
# Action : [43.2946]
# Action : [37.7172]
# Action : [31.8092]
# Action : [25.5034]
# Action : [16.6408]
# Action : [7.98793]
# Action : [-2.27271]
# Action : [-15.0758]
# Action : [-19.7336]
# Action : [-15.5839]
# Action : [-3.07595]
# Action : [12.7403]
# Action : [22.6004]
# Action : [33.3292]
# Action : [43.026]
# Action : [51.7927]
# Action : [55.2212]
# Action : [54.9854]
# Action : [52.3723]
# Action : [47.7159]
# Action : [41.1504]
# Action : [35.3605]
# Action : [31.1335]
# Action : [29.5011]
# Action : [33.9759]
# Action : [39.1881]
# Action : [43.7561]
# Action : [47.7926]
# Action : [50.333]
# Action : [50.9234]
# Action : [49.7976]
# Action : [47.7966]
# Action : [43.4241]
# Action : [37.6931]
# Action : [31.8201]
# Action : [24.9214]
# Action : [16.0266]
# Action : [6.40454]
# Action : [-4.17116]
# Action : [-16.3872]
# Action : [-21.8588]
# Action : [-17.6266]
# Action : [-4.32136]
# Action : [11.0484]
# Action : [20.9188]
# Action : [31.4639]
# Action : [42.4362]
# Action : [51.2132]
# Action : [55.4607]
# Action : [56.3228]
# Action : [53.8386]
# Action : [49.7169]
# Action : [42.8466]
# Action : [36.3377]
# Action : [31.5091]
# Action : [29.2496]
# Action : [33.4688]
# Action : [38.7442]
# Action : [43.2455]
# Action : [47.6105]
# Action : [50.8467]
# Action : [52.0963]
# Action : [51.0869]
# Action : [48.8272]
# Action : [44.6447]
# Action : [39.2376]
# Action : [32.9196]
# Action : [27.3075]
# Action : [16.7198]
# Action : [8.32972]
# Action : [-2.81614]
# Action : [-15.7317]
# Action : [-22.1514]
# Action : [-19.0806]
# Action : [-6.90142]
# Action : [8.37455]
# Action : [18.1909]
# Action : [29.3216]
# Action : [39.2445]
# Action : [48.6404]
# Action : [54.6808]
# Action : [55.7704]
# Action : [54.2978]
# Action : [50.9148]
# Action : [44.5808]
# Action : [38.3552]
# Action : [32.9098]
# Action : [29.3298]
# Action : [31.6685]
# Action : [37.0907]
# Action : [42.2927]
# Action : [46.6398]
# Action : [49.9037]
# Action : [51.4405]
# Action : [51.239]
# Action : [49.0929]
# Action : [45.8191]
# Action : [40.7426]
# Action : [34.5386]
# Action : [28.1463]
# Action : [19.1025]
# Action : [10.4365]
# Action : [-0.683156]
# Action : [-12.5696]
# Action : [-20.8472]
# Action : [-21.3239]
# Action : [-10.1652]
# Action : [4.17882]
# Action : [13.8934]
# Action : [24.174]
# Action : [33.9905]
# Action : [43.7209]
# Action : [51.6718]
# Action : [54.6054]
# Action : [53.6343]
# Action : [51.7681]
# Action : [46.7912]
# Action : [39.8536]
# Action : [34.87]
# Action : [30.1743]
# Action : [29.7677]
# Action : [34.2866]
# Action : [39.6835]
# Action : [44.3965]
# Action : [47.7195]
# Action : [49.9614]
# Action : [50.7617]
# Action : [49.5154]
# Action : [46.4389]
# Action : [42.0981]
# Action : [36.9957]
# Action : [30.4979]
# Action : [23.6634]
# Action : [14.257]
# Action : [5.54656]
# Action : [-5.50892]
# Action : [-16.573]
# Action : [-21.1893]
# Action : [-16.5967]
# Action : [-3.05653]
# Action : [12.593]
# Action : [23.1115]
# Action : [33.248]
# Action : [43.7698]
# Action : [52.7625]
# Action : [55.6925]
# Action : [55.7974]
# Action : [53.7088]
# Action : [48.0661]
# Action : [41.4573]
# Action : [35.7167]
# Action : [31.0354]
# Action : [29.6854]
# Action : [33.668]
# Action : [39.6917]
# Action : [44.7617]
# Action : [48.0698]
# Action : [51.055]
# Action : [52.0957]
# Action : [50.583]
# Action : [48.1643]
# Action : [44.1848]
# Action : [38.6342]
# Action : [32.4805]
# Action : [25.2639]
# Action : [15.4897]
# Action : [6.3003]
# Action : [-5.23584]
# Action : [-17.2611]
# Action : [-22.9995]
# Action : [-19.6612]
# Action : [-6.45813]
# Action : [8.83944]
# Action : [18.7794]
# Action : [29.8805]
# Action : [40.3777]
# Action : [49.704]
# Action : [55.6024]
# Action : [56.5058]
# Action : [55.1509]
# Action : [51.1347]
# Action : [44.7576]
# Action : [38.4935]
# Action : [33.3527]
# Action : [29.0666]
# Action : [31.9689]
# Action : [37.8301]
# Action : [42.6861]
# Action : [46.803]
# Action : [50.2833]
# Action : [52.3391]
# Action : [52.2753]
# Action : [50.3502]
# Action : [46.0407]
# Action : [40.3931]
# Action : [34.6202]
# Action : [28.38]
# Action : [19.1265]
# Action : [9.73645]
# Action : [-0.898631]
# Action : [-13.2698]
# Action : [-22.1875]
# Action : [-22.7424]
# Action : [-11.4046]
# Action : [3.25622]
# Action : [12.9012]
# Action : [22.8441]
# Action : [33.1834]
# Action : [42.9445]
# Action : [51.7667]
# Action : [54.9568]
# Action : [54.5139]
# Action : [52.2479]
# Action : [47.4223]
# Action : [41.0064]
# Action : [35.2695]
# Action : [30.8106]
# Action : [29.4147]
# Action : [33.553]
# Action : [38.7701]
# Action : [44.3064]
# Action : [47.8522]
# Action : [50.1046]
# Action : [51.244]
# Action : [50.2568]
# Action : [47.4653]
# Action : [43.2955]
# Action : [37.571]
# Action : [31.5728]
# Action : [25.1319]
# Action : [14.9498]
# Action : [6.48094]
# Action : [-4.59158]
# Action : [-16.7217]
# Action : [-21.625]
# Action : [-17.802]
# Action : [-4.45256]
# Action : [11.5144]
# Action : [21.5437]
# Action : [32.2029]
# Action : [42.3425]
# Action : [51.4899]
# Action : [55.9008]
# Action : [55.8978]
# Action : [53.5818]
# Action : [49.4637]
# Action : [43.053]
# Action : [36.4082]
# Action : [31.3987]
# Action : [29.516]
# Action : [33.217]
# Action : [39.011]
# Action : [43.8042]
# Action : [48.1535]
# Action : [50.8944]
# Action : [52.4868]
# Action : [51.3344]
# Action : [48.6866]
# Action : [44.2981]
# Action : [39.4963]
# Action : [32.845]
# Action : [26.3339]
# Action : [17.0015]
# Action : [7.57163]
# Action : [-3.78985]
# Action : [-16.0957]
# Action : [-22.2157]
# Action : [-19.4474]
# Action : [-6.57745]
# Action : [7.94612]
# Action : [17.6459]
# Action : [28.4626]
# Action : [39.3029]
# Action : [48.8402]
# Action : [54.7172]
# Action : [56.0375]
# Action : [54.309]
# Action : [50.8047]
# Action : [44.8627]
# Action : [37.6792]
# Action : [32.9854]
# Action : [29.2958]
# Action : [31.4817]
# Action : [37.2911]
# Action : [42.2895]
# Action : [46.3768]
# Action : [50.2041]
# Action : [51.8663]
# Action : [51.3259]
# Action : [50.0085]
# Action : [46.0135]
# Action : [40.7671]
# Action : [34.8749]
# Action : [28.0665]
# Action : [19.6317]
# Action : [10.4443]
# Action : [-0.165609]
# Action : [-11.9137]
# Action : [-21.0044]
# Action : [-22.275]
# Action : [-12.027]
# Action : [2.62921]
# Action : [11.3734]
# Action : [21.9721]
# Action : [31.73]
# Action : [41.3949]
# Action : [50.5828]
# Action : [54.3599]
# Action : [54.3375]
# Action : [52.3152]
# Action : [48.2755]
# Action : [41.0733]
# Action : [35.4538]
# Action : [31.1955]
# Action : [29.7222]
# Action : [32.9082]
# Action : [38.371]
# Action : [43.4419]
# Action : [47.1157]
# Action : [49.465]
# Action : [50.7837]
# Action : [49.8725]
# Action : [47.4916]
# Action : [43.4048]
# Action : [37.8513]
# Action : [31.9831]
# Action : [25.9821]
# Action : [16.5976]
# Action : [7.6547]
# Action : [-3.04321]
# Action : [-15.4598]
# Action : [-20.5193]
# Action : [-16.5948]
# Action : [-3.71299]
# Action : [11.9891]
# Action : [22.1455]
# Action : [32.1248]
# Action : [42.9686]
# Action : [51.3139]
# Action : [55.2933]
# Action : [54.9063]
# Action : [53.0913]
# Action : [48.2701]
# Action : [41.7272]
# Action : [35.8027]
# Action : [31.3276]
# Action : [29.6129]
# Action : [33.994]
# Action : [38.6983]
# Action : [43.5725]
# Action : [47.7731]
# Action : [50.4145]
# Action : [51.1402]
# Action : [50.4566]
# Action : [47.8127]
# Action : [43.8443]
# Action : [38.3573]
# Action : [32.1557]
# Action : [25.6731]
# Action : [16.7046]
# Action : [7.27093]
# Action : [-3.77122]
# Action : [-16.1169]
# Action : [-21.7718]
# Action : [-18.311]
# Action : [-4.98349]
# Action : [10.1342]
# Action : [20.1827]
# Action : [30.7518]
# Action : [40.9091]
# Action : [50.1901]
# Action : [54.8628]
# Action : [55.7666]
# Action : [53.4498]
# Action : [50.25]
# Action : [43.4395]
# Action : [36.8467]
# Action : [32.4488]
# Action : [29.4397]
# Action : [32.595]
# Action : [37.9524]
# Action : [43.4922]
# Action : [47.4857]
# Action : [50.0395]
# Action : [52.1483]
# Action : [51.4612]
# Action : [48.4739]
# Action : [45.3119]
# Action : [39.2931]
# Action : [33.4608]
# Action : [26.9012]
# Action : [17.8401]
# Action : [8.88395]
# Action : [-2.49124]
# Action : [-15.1064]
# Action : [-21.4581]
# Action : [-19.0677]
# Action : [-6.48463]
# Action : [8.51307]
# Action : [18.3599]
# Action : [28.9719]
# Action : [38.8947]
# Action : [48.7481]
# Action : [53.9081]
# Action : [55.7239]
# Action : [54.256]
# Action : [50.272]
# Action : [44.4176]
# Action : [37.9204]
# Action : [33.4122]
# Action : [29.2299]
# Action : [31.5743]
# Action : [37.4314]
# Action : [42.3033]
# Action : [46.4773]
# Action : [49.2669]
# Action : [50.7562]
# Action : [51.269]
# Action : [49.1421]
# Action : [45.1211]
# Action : [40.5358]
# Action : [34.7495]
# Action : [28.2013]
# Action : [19.7991]
# Action : [10.2395]
# Action : [0.14391]
# Action : [-11.9266]
# Action : [-20.7811]
# Action : [-21.744]
# Action : [-11.6982]
# Action : [2.96424]
# Action : [12.1391]
# Action : [21.8571]
# Action : [31.8872]
# Action : [42.2622]
# Action : [50.977]
# Action : [54.0655]
# Action : [54.1057]
# Action : [51.726]
# Action : [47.605]
# Action : [40.9536]
# Action : [35.3657]
# Action : [30.9767]
# Action : [29.0509]
# Action : [33.113]
# Action : [38.7499]
# Action : [43.5491]
# Action : [46.9617]
# Action : [49.2953]
# Action : [50.7843]
# Action : [49.7144]
# Action : [46.4932]
# Action : [43.0963]
# Action : [36.9527]
# -68786.79490950791

# %%
policy_base(Array(ro[1][1][1]))

# %%
function loss(a)
    r = exp.(a .- (ones(size(a)) |> gpu))
    s1 = r .* (rand(size(a)) |> gpu)
    s2 = clamp.(a,0.9,1.1)
    -1.0 * mean(min.(s1,s2))
end

# %%
gs = Tracker.gradient(() -> loss(out),params(m))

# %%
gs[m.layers[1].W]

# %%
using Flux,CuArrays
using Flux:Tracker
using Statistics

m = Chain(Conv((3,3),3=>64)) |> gpu
x = rand(256,256,3,1) |> gpu

# %%
function loss(x)
   out = m(x)
   mean(out)
end

# %%
function test()
    @time o = loss(x)
    @time gs = Tracker.gradient(() -> loss(x),params(m))
end

test()

# %%
using Flux,CuArrays
using Flux:Tracker
using Flux:@treelike
using Statistics

# %%
struct Net
    u
end

@treelike Net

function Net()
   Net(Chain(Conv((3,3),3=>64))) 
end

function (n::Net)(x)
   return n.u(x) 
end

# %%
m = Net() |> gpu
x = rand(256,256,3,1) |> gpu

function loss(x)
   out = m(x)
   mean(out)
end

function test()
    @time o = loss(x)
    @time gs = Tracker.gradient(() -> loss(x),params(m))
end

test()

# %%
a = param(ones(2)) * 1.0

# %%
policy_Σ

# %%
using Pkg
Pkg.add("Plots")

# %%
using JLD

# %%
reward_hist

# %%
mean(reward_hist[end-100-100:end-100])

# %%
using JLD
save("stats.jld","rewards",reward_hist)

# %%
rh = load("stats.jld")

# %%
using Pkg
Pkg.activate("~/envs/test")

# %%
using JLD
using Plots

# %%
rh
