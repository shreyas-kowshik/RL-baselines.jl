# %%
using Flux, CuArrays
using OpenAIGym
import Reinforce.action
import Flux.params
using Flux.Tracker: grad, update!
using Flux: onehot
using Statistics

#-------Define Custom Policy------------
mutable struct CartPolePolicy <: Reinforce.AbstractPolicy
  train::Bool

  function CartPolePolicy(train = true)
    new(train)
  end
end

#----------Setup Environment-------
env = GymEnv("CartPole-v0")

#----------Define Hyperparameters-------
STATE_SIZE = length(env.state)
ACTION_SIZE = length(env.actions)
γ = 1.00f0    # discount rate

η = 1e-4 # Learning rate

#---------_Define Model And Loss Function---------
policy = Chain(Dense(STATE_SIZE,30,relu),Dense(30,50,relu),Dense(50,ACTION_SIZE))

function loss(s,actions,A_t)
    pi_ = softmax(policy(s))
    logpi = log.(mean(pi_ .* actions) .+ 1f-10)
    return mean(-logpi .* A_t)
end

opt = ADAM(params(policy),η)

println("Model Setup")

#-------Overriden action Method--------
function action(pi::CartPolePolicy,reward,state,action)
    state= Array(state)
    action_probs = softmax(policy(state))
    action = sample(1:ACTION_SIZE,Weights(action_probs)) - 1
    return action
end

#-------Overriden episode Method--------
function episode!(env,pi = RandomPolicy())
    ep = Episode(env,pi)

    experience = []
    for (s,a,r,s_) in ep
    OpenAIGym.render(env)
        push!(experience,(s,a,r,s_))
    end
    
    return experience
end

function train(env)
    experience = episode!(env,CartPolePolicy())
    l = 0.0
    G_t = 0.0

    for (i,(s,a,r,s_)) in enumerate(reverse(experience))
        state = Array(s)
        act = zeros(ACTION_SIZE,1)
        act[a+1,1] = 1
         
        G_t = γ*G_t + r
    
        l = l + loss(state,act,G_t)   
        Flux.back!(loss(state,act,G_t))
        opt()
    end 
    l = l./(1.0*length(experience))
    return G_t,l
end

println("Setup Training")

NUM_EPISODES = 1000

for i in 1:NUM_EPISODES
    println("---")
    reset!(env)
    returns,loss_val = train(env)
    println("Returns : $returns")
    println("Loss : $loss_val")
end

# %%
"""
- Rollouts
- Define networks
- GAE
- Utils : Normal distributions and log probability of an action
- train
- logging utilities

Experiment with shared network for both policy and value function
"""

using Flux, CuArrays
using OpenAIGym
import Reinforce.action
import Reinforce:run_episode
import Flux.params
using Flux.Tracker: grad, update!
using Flux: onehot
using Statistics
using Distributed
using Distributions
using LinearAlgebra
using Base.Iterators

"""
A few intricacies : 
The policy is a Normal distribution and the `policy_net` outputs the `μ` and `logσ`.
Each action is assumed to be independent of the others.
Thus our covariance matrix is a diagonal matrix with each element representing the variance of
taking a particular action.
"""

"""
Utilities
"""
# weight initialization
function _random_normal(shape...)
    return map(Float32,rand(Normal(0,0.1),shape...))
end

function normal_log_prob(μ,log_std,a)
    """
    Returns the log probability of an action under a policy Gaussian policy π
    """
    σ = exp.(log_std)
    σ² = σ.^2
    -(((a .- μ).^2)./(2.0 * σ²)) .- log.(sqrt(2 * π)) .- log.(σ)
end

function normal_entropy(log_std)
    0.5 + 0.5 * log(2 * π) .+ log_std
end

function normalise(arr)
    (arr .- mean(arr))./(sqrt(var(arr) + 1e-10))
end

"""
HYPERPARAMETERS
"""
# Policy parameters #
η = 1e-3 # Learning rate
STD = 0.0 # Standard deviation
HIDDEN_SIZE = 30
# Environment Variables #
STATE_SIZE = 3
ACTION_SIZE = 1
EPISODE_LENGTH = 50
TEST_STEPS = 10000
# GAE parameters
γ = 0.99
λ = 0.95
# Optimization parameters
PPO_EPOCHS = 5
NUM_EPISODES = 5000
BATCH_SIZE = 32
c₀ = 1.0
c₁ = 0.5
c₂ = 0.001
# PPO parameters
ϵ = 0.2

mutable struct PendulumPolicy <: Reinforce.AbstractPolicy
  train::Bool

  function PendulumPolicy(train = true)
    new(train)
  end
end

"""
Define the networks
"""
policy_μ = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu;initW = _random_normal),
                 Dense(HIDDEN_SIZE,ACTION_SIZE;initW = _random_normal)) 
policy_Σ = Chain(Dense(STATE_SIZE,ACTION_SIZE;initW = zeros))

value = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu),
              Dense(HIDDEN_SIZE,1))

# Optimizer
opt = ADAM(η)

function action(state)
    # Acccounting for the element type
    state = reshape(Array(state),length(state),1)
#     println("Action me : State : $state")
#     println(size(state))
    
    # Our policy outputs the parameters of a Normal distribution
    μ = policy_μ(state)
    μ = reshape(μ,ACTION_SIZE)
    log_std = policy_Σ(state)
    
#     println("Action me : log_std : $log_std")
    σ² = reshape((exp.(log_std)).^2,ACTION_SIZE)
    Σ = diagm(0=>σ².data)
    
#     println("Σ : $Σ")
    dis = MvNormal(μ.data,Σ)
    
    a = rand(dis,ACTION_SIZE)
#     println(a)
    
    a
end

function run_episode(env)
    experience = []
    
    s = reset!(env)
    for i in 1:EPISODE_LENGTH
        a = action(s)
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        
        r,s_ = step!(env,a)
        push!(experience,(s,a,r,s_))
        s = s_
        if env.done
           break 
        end
    end
    experience
end


function test_run(env)
    ep_r = 0.0
    
    s = reset!(env)
    for i in 1:TEST_STEPS
        OpenAIGym.render(env)
        a = action(s)
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        
        r,s_ = step!(env,a)
        ep_r += r
        
        s = s_
        if env.done
           break 
        end
    end
    ep_r
end
# Out:
# ┌ Warning: Flux is only supported with CuArrays v0.9.
# │ Try running `] pin CuArrays@0.9`.
# └ @ Flux.CUDA /home/shreyas/.julia/packages/Flux/WSB7k/src/cuda/cuda.jl:12
# WARNING: using Distributions.params in module Main conflicts with an existing identifier.
# test_run (generic function with 1 method)

# %%
"""
Rollout collection
"""
num_processes = 9
addprocs(num_processes) 

@everywhere function collect(env)
    run_episode(env)
end

@everywhere function rollout()
  env = GymEnv(:Pendulum,:v0)
  return collect(env)
end

function get_rollouts()
    g = []
    for  w in workers()
      push!(g, rollout())
    end

    rollouts = fetch.(g)
end
# Out:
# get_rollouts (generic function with 1 method)

# %%
function gae(states,actions,rewards,next_states)
    """
    Returns a Generalized Advantage Estimate for an episode
    """
    Â = []
    A = 0.0
    for i in reverse(1:length(states))
        δ = rewards[i] + γ*value(next_states[i]).data[1] - value(states[i]).data[1]
        A = δ + (γ*λ*A)
        push!(Â,A)
    end
    
    Â = reverse(Â)
    return Â
end

function disconunted_returns(rewards)
    r = 0.0
    returns = []
    for i in reverse(1:length(rewards))
        r = rewards[i] + γ*r
        push!(returns,r)
    end
    returns
end

function log_prob_from_actions(states,actions)
    """
    Returns log probabilities of the actions taken
    
    states,actions : episode vairbles in the form of a list
    """
    log_probs = []
    
    for i in 1:length(states)
        μ = reshape(policy_μ(states[i]),ACTION_SIZE).data
        logΣ = reshape(policy_Σ(states[i]),ACTION_SIZE).data
        push!(log_probs,normal_log_prob(μ,logΣ,actions[i]))
    end
    
    log_probs
end

function process_rollouts(rollouts)
    """
    rollouts : variable returned by calling `get_rollouts`
    
    Returns : 
    states, actions, rewards for minibatch processing
    """
    # Process the variables
    states = []
    actions = []
    rewards = []
    next_states = []
    advantages = []
    returns = []
    log_probs = []
    
    for ro in rollouts
        episode_states = []
        episode_actions = []
        episode_rewards = []
        episode_next_states = []
        
        for i in 1:length(ro)
             push!(episode_states,Array(ro[i][1]))
             push!(episode_actions,ro[i][2])
             push!(episode_rewards,ro[i][3])
             push!(episode_next_states,ro[i][4])
        end
        
#         println("Ep Max A : $(maximum(episode_actions))")

        episode_advantages = gae(episode_states,episode_actions,episode_rewards,episode_next_states)
        episode_returns = disconunted_returns(episode_rewards)
        
        episode_advantages = normalise(episode_advantages)
        episode_returns = normalise(episode_returns)
        
        push!(states,episode_states)
        push!(actions,episode_actions)
        push!(rewards,episode_rewards)
        push!(advantages,episode_advantages)
        push!(returns,episode_returns)
        push!(log_probs,log_prob_from_actions(episode_states,episode_actions))
    end
    
    states = cat(states...,dims=1)
    actions = cat(actions...,dims=1)
    rewards = cat(rewards...,dims=1)
    advantages = cat(advantages...,dims=1)
    returns = cat(returns...,dims=1)
    log_probs = cat(log_probs...,dims=1)
    
    return hcat(states...),hcat(actions...),hcat(rewards...),hcat(advantages...),hcat(returns...),hcat(log_probs...)
end
# Out:
# process_rollouts (generic function with 1 method)

# %%
function loss(states,actions,advantages,returns,old_log_probs)
#     println("---")
#     println(size(states))
#     println("States : $states")
#     println("---")
#     println("Actions : $actions")
#     println("---")
    
    μ = policy_μ(states)
    logΣ = policy_Σ(states)
    
#     println("μ : $μ")
#     println("---")
#     println("logΣ : $logΣ")
#     println("---")
    
    new_log_probs = normal_log_prob(μ,logΣ,actions)
#     println("New Log Probs : $new_log_probs")
#     println("Old Log Probs : $old_log_probs")
    
    # Surrogate loss computation
    ratio = exp.(new_log_probs .- old_log_probs)
    surr1 = ratio .* advantages
    surr2 = clamp.(ratio,1.0 - ϵ,1.0 + ϵ)
    policy_loss = -1.0 * mean(min.(surr1,surr2))
    
#     println("Surr1 : $surr1")
#     println("Surr2 : $surr2")
#     println("Policy Loss : $policy_loss")
    
    value_predicted = value(states)
    value_loss = mean((value_predicted .- returns).^2)
#     println("Value Loss : $value_loss")
    
    entropy_loss = -1.0 * mean(normal_entropy(logΣ))
    
    c₀*policy_loss + c₁*value_loss + c₂*entropy_loss
end

function ppo_update(states,actions,advantages,returns,old_log_probs)
    # Define model parameters
    model_params = params(params(policy_μ)...,params(policy_Σ)...,params(value))
    
    # Calculate gradients
    gs = Tracker.gradient(() -> loss(states,actions,advantages,returns,old_log_probs),model_params)
#     println("Gradient Done")
    
    # Take a step of optimisation
    update!(opt,model_params,gs)
#     println("Update Done")
end

function train_step()
    routs = get_rollouts()
    states,actions,rewards,advantages,returns,log_probs = process_rollouts(routs)
    
    idxs = partition(1:size(states)[end],BATCH_SIZE)
    
    for epoch in 1:PPO_EPOCHS
        println("Epoch : $epoch")
        for i in idxs
#             println(i)
            mb_states = states[:,i] 
            mb_actions = actions[:,i] 
            mb_advantages = advantages[:,i] 
            mb_returns = returns[:,i] 
            mb_log_probs = log_probs[:,i]
            
            ppo_update(mb_states,mb_actions,mb_advantages,mb_returns,mb_log_probs)
        end
    end
end

function train()
    for i in 1:NUM_EPISODES
        println("EP : $i")
        train_step()
        println("Ep done")
    end
end
# Out:
# train (generic function with 1 method)

# %%
train()
# Out:
# EP : 1
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = #GymEnv#1(::Type, ::Type, ::Symbol, ::Symbol) at OpenAIGym.jl:49
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:49
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv(::Symbol, ::Symbol, ::PyCall.PyObject, ::Type) at OpenAIGym.jl:56
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:56
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actions(::GymEnv{PyCall.PyArray{Float64,1}}, ::Nothing) at OpenAIGym.jl:117
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:117
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:88
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:88
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:91
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:91
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:95
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:95
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 2
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 3
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 5
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 6
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 7
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 8
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 9
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 10
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 11
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 12
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 13
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 14
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 15
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 16
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 17
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 18
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 19
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 20
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 21
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 22
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 23
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 24
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 25
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 26
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 27
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 28
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 29
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 30
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 31
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 32
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 33
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 34
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 35
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 36
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 37
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 38
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 39
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 40
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 41
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 42
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 43
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 44
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 45
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 46
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 47
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 48
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 49
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 50
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 51
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 52
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 53
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 54
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 55
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 56
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 57
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 58
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 59
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 60
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 61
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 62
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 63
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 64
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 65
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 66
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 67
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 68
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 69
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 70
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 71
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 72
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 73
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 74
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 75
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 76
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 77
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 78
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 79
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 80
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 81
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 82
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 83
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 84
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 85
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 86
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 87
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 88
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 89
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 90
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 91
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 92
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 93
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 94
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 95
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 96
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 97
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 98
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 99
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 100
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP :
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4947
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4948
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4949
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4950
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4951
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4952
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4953
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4954
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4955
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4956
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4957
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4958
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4959
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4960
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4961
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4962
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4963
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4964
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4965
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4966
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4967
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4968
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4969
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4970
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4971
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4972
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4973
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4974
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4975
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4976
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4977
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4978
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4979
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4980
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4981
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4982
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4983
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4984
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4985
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4986
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4987
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4988
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4989
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4990
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4991
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4992
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4993
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4994
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4995
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4996
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4997
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4998
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 4999
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done
# EP : 5000
# Epoch : 1
# Epoch : 2
# Epoch : 3
# Epoch : 4
# Epoch : 5
# Ep done

# %%
# Test the policy #
env = GymEnv("Pendulum-v0")
env.pyenv._max_episode_steps = 1e8
TEST_STEPS = 1e8

r = test_run(env)
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] sigatomic_end at ./c.jl:425 [inlined]
#  [2] __pycall!(::PyCall.PyObject, ::Ptr{PyCall.PyObject_struct}, ::PyCall.PyObject, ::Ptr{Nothing}) at /home/shreyas/.julia/packages/PyCall/a5Jd3/src/pyfncall.jl:49
#  [3] _pycall!(::PyCall.PyObject, ::PyCall.PyObject, ::Tuple{}, ::Int64, ::Ptr{Nothing}) at /home/shreyas/.julia/packages/PyCall/a5Jd3/src/pyfncall.jl:29
#  [4] #pycall#110 at /home/shreyas/.julia/packages/PyCall/a5Jd3/src/pyfncall.jl:11 [inlined]
#  [5] pycall(::PyCall.PyObject, ::Type{PyCall.PyAny}) at /home/shreyas/.julia/packages/PyCall/a5Jd3/src/pyfncall.jl:86
#  [6] #render#3(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::GymEnv{PyCall.PyArray{Float64,1}}) at /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:81
#  [7] render at /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:81 [inlined]
#  [8] test_run(::GymEnv{PyCall.PyArray{Float64,1}}) at ./In[1]:153
#  [9] top-level scope at In[9]:5

# %%
policy_base(Array(ro[1][1][1]))

# %%
function loss(a)
    r = exp.(a .- (ones(size(a)) |> gpu))
    s1 = r .* (rand(size(a)) |> gpu)
    s2 = clamp.(a,0.9,1.1)
    -1.0 * mean(min.(s1,s2))
end

# %%
gs = Tracker.gradient(() -> loss(out),params(m))

# %%
gs[m.layers[1].W]

# %%
env = GymEnv("Pendulum-v0")

# %%
for i ϵ 1:20
   action = rand(1)
   
end

# %%
rand(1)

# %%
s = reset!(env)

# %%
for i in 1:1000
    step!(env,[0.8])
    println(env.done)
end

# %%
env.done

# %%
run_episode(env)

# %%
eltype(action(reset!(env)).data)

# %%
using Distributions

# %%
Σ = diagonal(2,2)

MvNormal([1.0,1.0],Σ)

# %%
using LinearAlgebra

# %%
env = GymEnv("Pendulum-v0")
s = reset!(env)

# %%
action(s)

# %%
get_rollouts()

# %%
Σ = ones(2,2)
Σ[1,2] = 0.0
Σ[2,1] = 0.0
MvNormal(rand(2),Σ).μ

# %%
get_rollouts()

# %%
get_rollouts()

# %%
env = GymEnv("Pendulum-v0")
s = reset!(env)

action(s)

# %%
Σ = rand(2,2)
Σ[1,2] = 0.0
Σ[2,1] = 0.0

dis = MvNormal(rand(2),Σ)

# %%
rand(dis,3)

# %%
ro[1][1][2]

# %%
for i in reverse(1:10)
    println(i)
end

# %%
println(r[1])
cat(r...,dims=1)

# %%
push!(a,1.0)

# %%
using Flux,CuArrays
using Flux:Tracker
using Statistics

m = Chain(Conv((3,3),3=>64)) |> gpu
x = rand(256,256,3,1) |> gpu

# %%
function loss(x)
   out = m(x)
   mean(out)
end

# %%
@time o = loss(x)
@time gs = Tracker.gradient(() -> loss(x),params(m))

# %%
reverse(a)

# %%
using Distributions:Normal

# %%
Normal(1.0,1.0)

# %%
a = [0.5,1.0,3.0]
b = [1.0,0.0,2.9]
(a .- b).^2

# %%
s

# %%
using Base.Iterators

BATCH_SIZE = 11
idxs = partition(1:length(r),BATCH_SIZE)

# %%
for i in idxs
    mbx_rewards = r[:,i]
    mbx_states = s[:,i]
    mbx_actions = a[:,i]
    mbx_advantages = ad[:,i]
end

# %%
t = cpu

# %%
ones(2,3) |> t

# %%
1 + log(2*1.0) .+ rand(3)

# %%
ro = get_rollouts()
# Out:
# Action me : State : [0.513113; 0.858321; -0.804359]
# (3, 1)
# Action me : log_std : Float32[-0.0073239] (tracked)
# Σ : Float32[0.985459]
# [0.988432]
# Action me : State : [0.513644; 0.858004; -0.0123533]
# (3, 1)
# Action me : log_std : Float32[0.00957381] (tracked)
# Σ : Float32[1.01933]
# [1.40494]
# Action me : State : [0.477082; 0.878859; 0.841891]
# (3, 1)
# Action me : log_std : Float32[0.0265221] (tracked)
# Σ : Float32[1.05448]
# [-0.867079]
# Action me : State : [0.415764; 0.909473; 1.37097]
# (3, 1)
# Action me : log_std : Float32[0.0404726] (tracked)
# Σ : Float32[1.08431]
# [0.15721]
# Action me : State : [0.319261; 0.947667; 2.07666]
# (3, 1)
# Action me : log_std : Float32[0.0475005] (tracked)
# Σ : Float32[1.09966]
# [0.772658]
# Action me : State : [0.178817; 0.983882; 2.90331]
# (3, 1)
# Action me : log_std : Float32[0.0515891] (tracked)
# Σ : Float32[1.10869]
# [-0.592199]
# Action me : State : [0.00216486; 0.999998; 3.55239]
# (3, 1)
# Action me : log_std : Float32[0.052753] (tracked)
# Σ : Float32[1.11127]
# [1.20061]
# Action me : State : [-0.220141; 0.975468; 4.48248]
# (3, 1)
# Action me : log_std : Float32[0.0506335] (tracked)
# Σ : Float32[1.10657]
# [-0.814735]
# Action me : State : [-0.458719; 0.888582; 5.09187]
# (3, 1)
# Action me : log_std : Float32[0.0435375] (tracked)
# Σ : Float32[1.09098]
# [-0.0246534]
# Action me : State : [-0.69202; 0.721879; 5.75461]
# (3, 1)
# Action me : log_std : Float32[0.0321742] (tracked)
# Σ : Float32[1.06646]
# [-0.65508]
# Action me : State : [-0.879195; 0.476461; 6.19776]
# (3, 1)
# Action me : log_std : Float32[0.0164484] (tracked)
# Σ : Float32[1.03344]
# [-0.903632]
# Action me : State : [-0.984614; 0.174746; 6.41956]
# (3, 1)
# Action me : log_std : Float32[-0.00127495] (tracked)
# Σ : Float32[0.997453]
# [-0.518201]
# Action me : State : [-0.989068; -0.147457; 6.47289]
# (3, 1)
# Action me : log_std : Float32[-0.0208069] (tracked)
# Σ : Float32[0.95924]
# [0.16893]
# Action me : State : [-0.892753; -0.450547; 6.38763]
# (3, 1)
# Action me : log_std : Float32[-0.0387115] (tracked)
# Σ : Float32[0.925498]
# [0.254586]
# Action me : State : [-0.716675; -0.697407; 6.08791]
# (3, 1)
# Action me : log_std : Float32[-0.0521149] (tracked)
# Σ : Float32[0.901018]
# [0.294847]
# Action me : State : [-0.495637; -0.86853; 5.60908]
# (3, 1)
# Action me : log_std : Float32[-0.0602141] (tracked)
# Σ : Float32[0.886541]
# [-0.964307]
# Action me : State : [-0.274353; -0.961629; 4.81304]
# (3, 1)
# Action me : log_std : Float32[-0.0634306] (tracked)
# Σ : Float32[0.880856]
# [0.164616]
# Action me : State : [-0.0720288; -0.997403; 4.11651]
# (3, 1)
# Action me : log_std : Float32[-0.0634963] (tracked)
# Σ : Float32[0.88074]
# [0.286185]
# Action me : State : [0.0983189; -0.995155; 3.41138]
# (3, 1)
# Action me : log_std : Float32[-0.0563974] (tracked)
# Σ : Float32[0.893334]
# [-1.03864]
# Action me : State : [0.222072; -0.97503; 2.50922]
# (3, 1)
# Action me : log_std : Float32[-0.0473098] (tracked)
# Σ : Float32[0.909719]
# [0.985863]
# Action me : State : [-0.60857; -0.7935; -0.957933]
# (3, 1)
# Action me : log_std : Float32[0.063235] (tracked)
# Σ : Float32[1.13482]
# [-0.184587]
# Action me : State : [-0.669321; -0.742973; -1.58075]
# (3, 1)
# Action me : log_std : Float32[0.0890885] (tracked)
# Σ : Float32[1.19504]
# [0.365818]
# Action me : State : [-0.742939; -0.66936; -2.0831]
# (3, 1)
# Action me : log_std : Float32[0.102758] (tracked)
# Σ : Float32[1.22816]
# [1.97096]
# Action me : State : [-0.814533; -0.580117; -2.28948]
# (3, 1)
# Action me : log_std : Float32[0.105286] (tracked)
# Σ : Float32[1.23438]
# [1.08041]
# Action me : State : [-0.881981; -0.471285; -2.56251]
# (3, 1)
# Action me : log_std : Float32[0.109153] (tracked)
# Σ : Float32[1.24397]
# [0.515233]
# Action me : State : [-0.939779; -0.341783; -2.83869]
# (3, 1)
# Action me : log_std : Float32[0.112113] (tracked)
# Σ : Float32[1.25135]
# [-1.50888]
# Action me : State : [-0.983348; -0.18173; -3.32135]
# (3, 1)
# Action me : log_std : Float32[0.119121] (tracked)
# Σ : Float32[1.26902]
# [1.11041]
# Action me : State : [-0.999835; -0.0181899; -3.29109]
# (3, 1)
# Action me : log_std : Float32[0.108399] (tracked)
# Σ : Float32[1.24209]
# [0.330776]
# Action me : State : [-0.989569; 0.144062; -3.25511]
# (3, 1)
# Action me : log_std : Float32[0.0977093] (tracked)
# Σ : Float32[1.21582]
# [-0.846468]
# Action me : State : [-0.952861; 0.303408; -3.27404]
# (3, 1)
# Action me : log_std : Float32[0.0892252] (tracked)
# Σ : Float32[1.19536]
# [-2.16007]
# Action me : State : [-0.889022; 0.457864; -3.34648]
# (3, 1)
# Action me : log_std : Float32[0.0830198] (tracked)
# Σ : Float32[1.18062]
# [0.632178]
# Action me : State : [-0.813295; 0.581852; -2.90826]
# (3, 1)
# Action me : log_std : Float32[0.0611321] (tracked)
# Σ : Float32[1.13005]
# [0.430229]
# Action me : State : [-0.737544; 0.675299; -2.40734]
# (3, 1)
# Action me : log_std : Float32[0.0459285] (tracked)
# Σ : Float32[1.09621]
# [-0.268972]
# Action me : State : [-0.66863; 0.743595; -1.94121]
# (3, 1)
# Action me : log_std : Float32[0.0330215] (tracked)
# Σ : Float32[1.06827]
# [-0.262307]
# Action me : State : [-0.614082; 0.789242; -1.42286]
# (3, 1)
# Action me : log_std : Float32[0.0188748] (tracked)
# Σ : Float32[1.03847]
# [0.105581]
# Action me : State : [-0.581416; 0.813606; -0.815088]
# (3, 1)
# Action me : log_std : Float32[0.00824961] (tracked)
# Σ : Float32[1.01664]
# [1.76403]
# Action me : State : [-0.583843; 0.811867; 0.0597213]
# (3, 1)
# Action me : log_std : Float32[0.0352442] (tracked)
# Σ : Float32[1.07303]
# [1.15833]
# Action me : State : [-0.61751; 0.786563; 0.84237]
# (3, 1)
# Action me : log_std : Float32[0.0426889] (tracked)
# Σ : Float32[1.08913]
# [-2.11284]
# Action me : State : [-0.661028; 0.750362; 1.13229]
# (3, 1)
# Action me : log_std : Float32[0.0390344] (tracked)
# Σ : Float32[1.0812]
# [1.83108]
# Action me : State : [-0.731605; 0.681728; 1.96973]
# (3, 1)
# Action me : log_std : Float32[0.0356006] (tracked)
# Σ : Float32[1.0738]
# [0.229345]
# Action me : State : [0.358663; 0.933467; -0.810979]
# (3, 1)
# Action me : log_std : Float32[-0.00509008] (tracked)
# Σ : Float32[0.989872]
# [-0.478331]
# Action me : State : [0.367172; 0.930153; -0.182628]
# (3, 1)
# Action me : log_std : Float32[0.00158968] (tracked)
# Σ : Float32[1.00318]
# [1.60763]
# Action me : State : [0.331752; 0.943367; 0.756131]
# (3, 1)
# Action me : log_std : Float32[0.0280699] (tracked)
# Σ : Float32[1.05775]
# [0.188619]
# Action me : State : [0.260522; 0.965468; 1.49195]
# (3, 1)
# Action me : log_std : Float32[0.047359] (tracked)
# Σ : Float32[1.09935]
# [-1.79799]
# Action me : State : [0.16548; 0.986213; 1.94635]
# (3, 1)
# Action me : log_std : Float32[0.0516195] (tracked)
# Σ : Float32[1.10876]
# [-1.11447]
# Action me : State : [0.0402919; 0.999188; 2.51884]
# (3, 1)
# Action me : log_std : Float32[0.0526713] (tracked)
# Σ : Float32[1.11109]
# [1.59516]
# Action me : State : [-0.134662; 0.990892; 3.50751]
# (3, 1)
# Action me : log_std : Float32[0.0521162] (tracked)
# Σ : Float32[1.10986]
# [-0.639091]
# Action me : State : [-0.336138; 0.941813; 4.15481]
# (3, 1)
# Action me : log_std : Float32[0.0474525] (tracked)
# Σ : Float32[1.09955]
# [-1.92099]
# Action me : State : [-0.540864; 0.84111; 4.57302]
# (3, 1)
# Action me : log_std : Float32[0.0399449] (tracked)
# Σ : Float32[1.08317]
# [-1.08931]
# Action me : State : [-0.73352; 0.679668; 5.04046]
# (3, 1)
# Action me : log_std : Float32[0.0289336] (tracked)
# Σ : Float32[1.05957]
# [-0.9149]
# Action me : State : [-0.888532; 0.458815; 5.41297]
# (3, 1)
# Action me : log_std : Float32[0.0149596] (tracked)
# Σ : Float32[1.03037]
# [-1.32456]
# Action me : State : [-0.980316; 0.197435; 5.5584]
# (3, 1)
# Action me : log_std : Float32[-0.000424769] (tracked)
# Σ : Float32[0.999151]
# [0.421722]
# Action me : State : [-0.995976; -0.0896257; 5.76974]
# (3, 1)
# Action me : log_std : Float32[-0.0173233] (tracked)
# Σ : Float32[0.965947]
# [-0.34605]
# Action me : State : [-0.931502; -0.363737; 5.65061]
# (3, 1)
# Action me : log_std : Float32[-0.0337993] (tracked)
# Σ : Float32[0.934636]
# [0.213717]
# Action me : State : [-0.800439; -0.599415; 5.40986]
# (3, 1)
# Action me : log_std : Float32[-0.0470473] (tracked)
# Σ : Float32[0.910197]
# [0.517833]
# Action me : State : [-0.625777; -0.780002; 5.03798]
# (3, 1)
# Action me : log_std : Float32[-0.056303] (tracked)
# Σ : Float32[0.893503]
# [-1.04799]
# Action me : State : [-0.445147; -0.895457; 4.29578]
# (3, 1)
# Action me : log_std : Float32[-0.0614225] (tracked)
# Σ : Float32[0.884401]
# [1.86254]
# Action me : State : [-0.263029; -0.964788; 3.90357]
# (3, 1)
# Action me : log_std : Float32[-0.0635821] (tracked)
# Σ : Float32[0.880589]
# [-0.292784]
# Action me : State : [-0.10914; -0.994026; 3.13606]
# (3, 1)
# Action me : log_std : Float32[-0.0550652] (tracked)
# Σ : Float32[0.895717]
# [-0.989389]
# Action me : State : [0.00274886; -0.999996; 2.24213]
# (3, 1)
# Action me : log_std : Float32[-0.0461991] (tracked)
# Σ : Float32[0.911742]
# [-1.58211]
# Action me : State : [0.534839; 0.844954; 0.797994]
# (3, 1)
# Action me : log_std : Float32[0.0244681] (tracked)
# Σ : Float32[1.05015]
# [0.415237]
# Action me : State : [0.470288; 0.882513; 1.494]
# (3, 1)
# Action me : log_std : Float32[0.0399995] (tracked)
# Σ : Float32[1.08329]
# [0.29613]
# Action me : State : [0.370551; 0.928812; 2.2003]
# (3, 1)
# Action me : log_std : Float32[0.045956] (tracked)
# Σ : Float32[1.09627]
# [0.40874]
# Action me : State : [0.229624; 0.973279; 2.95822]
# (3, 1)
# Action me : log_std : Float32[0.0509311] (tracked)
# Σ : Float32[1.10723]
# [0.798137]
# Action me : State : [0.0412846; 0.999147; 3.8079]
# (3, 1)
# Action me : log_std : Float32[0.0526263] (tracked)
# Σ : Float32[1.11099]
# [-2.01633]
# Action me : State : [-0.170726; 0.985319; 4.25726]
# (3, 1)
# Action me : log_std : Float32[0.0516414] (tracked)
# Σ : Float32[1.1088]
# [0.357413]
# Action me : State : [-0.411464; 0.911426; 5.04986]
# (3, 1)
# Action me : log_std : Float32[0.0452655] (tracked)
# Σ : Float32[1.09476]
# [-0.748141]
# Action me : State : [-0.648125; 0.761534; 5.62121]
# (3, 1)
# Action me : log_std : Float32[0.0348367] (tracked)
# Σ : Float32[1.07216]
# [0.718902]
# Action me : State : [-0.852176; 0.523255; 6.30019]
# (3, 1)
# Action me : log_std : Float32[0.0194189] (tracked)
# Σ : Float32[1.0396]
# [-0.318782]
# Action me : State : [-0.97624; 0.216693; 6.64482]
# (3, 1)
# Action me : log_std : Float32[0.00123036] (tracked)
# Σ : Float32[1.00246]
# [-1.19389]
# Action me : State : [-0.993624; -0.112747; 6.62826]
# (3, 1)
# Action me : log_std : Float32[-0.0186616] (tracked)
# Σ : Float32[0.963365]
# [-1.27079]
# Action me : State : [-0.908698; -0.417453; 6.35308]
# (3, 1)
# Action me : log_std : Float32[-0.036828] (tracked)
# Σ : Float32[0.928991]
# [-0.332165]
# Action me : State : [-0.745075; -0.666981; 5.99016]
# (3, 1)
# Action me : log_std : Float32[-0.0505593] (tracked)
# Σ : Float32[0.903826]
# [-0.771536]
# Action me : State : [-0.541262; -0.840854; 5.3742]
# (3, 1)
# Action me : log_std : Float32[-0.0590581] (tracked)
# Σ : Float32[0.888593]
# [1.48641]
# Action me : State : [-0.317993; -0.948093; 4.96652]
# (3, 1)
# Action me : log_std : Float32[-0.0631004] (tracked)
# Σ : Float32[0.881438]
# [0.192207]
# Action me : State : [-0.109179; -0.994022; 4.28428]
# (3, 1)
# Action me : log_std : Float32[-0.0634889] (tracked)
# Σ : Float32[0.880753]
# [-1.95794]
# Action me : State : [0.0528315; -0.998603; 3.24507]
# (3, 1)
# Action me : log_std : Float32[-0.0550916] (tracked)
# Σ : Float32[0.89567]
# [-1.34427]
# Action me : State : [0.166797; -0.985991; 2.29448]
# (3, 1)
# Action me : log_std : Float32[-0.04583] (tracked)
# Σ : Float32[0.912415]
# [0.287658]
# Action me : State : [0.244968; -0.969531; 1.59813]
# (3, 1)
# Action me : log_std : Float32[-0.0391352] (tracked)
# Σ : Float32[0.924714]
# [0.0668156]
# Action me : State : [0.287425; -0.957803; 0.881008]
# (3, 1)
# Action me : log_std : Float32[-0.0317396] (tracked)
# Σ : Float32[0.938494]
# [-1.22324]
# Action me : State : [0.199685; -0.97986; 0.921094]
# (3, 1)
# Action me : log_std : Float32[-0.0317803] (tracked)
# Σ : Float32[0.938417]
# [-0.500144]
# Action me : State : [0.205129; -0.978735; 0.111177]
# (3, 1)
# Action me : log_std : Float32[0.0119138] (tracked)
# Σ : Float32[1.02411]
# [2.31285]
# Action me : State : [0.189302; -0.981919; -0.322874]
# (3, 1)
# Action me : log_std : Float32[0.0466614] (tracked)
# Σ : Float32[1.09782]
# [-0.411739]
# Action me : State : [0.133993; -0.990982; -1.12107]
# (3, 1)
# Action me : log_std : Float32[0.0799484] (tracked)
# Σ : Float32[1.17339]
# [1.77026]
# Action me : State : [0.0544322; -0.998517; -1.59877]
# (3, 1)
# Action me : log_std : Float32[0.102212] (tracked)
# Σ : Float32[1.22682]
# [0.89329]
# Action me : State : [-0.0561945; -0.99842; -2.21367]
# (3, 1)
# Action me : log_std : Float32[0.125056] (tracked)
# Σ : Float32[1.28417]
# [0.97781]
# Action me : State : [-0.195743; -0.980655; -2.81581]
# (3, 1)
# Action me : log_std : Float32[0.145264] (tracked)
# Σ : Float32[1.33713]
# [1.11928]
# Action me : State : [-0.358056; -0.9337; -3.38341]
# (3, 1)
# Action me : log_std : Float32[0.162876] (tracked)
# Σ : Float32[1.38507]
# [-1.82051]
# Action me : State : [-0.551385; -0.834251; -4.35676]
# (3, 1)
# Action me : log_std : Float32[0.190888] (tracked)
# Σ : Float32[1.46488]
# [-1.64434]
# Action me : State : [-0.748288; -0.663374; -5.2291]
# (3, 1)
# Action me : log_std : Float32[0.211789] (tracked)
# Σ : Float32[1.52742]
# [1.01189]
# Action me : State : [-0.901931; -0.43188; -5.57485]
# (3, 1)
# Action me : log_std : Float32[0.211323] (tracked)
# Σ : Float32[1.52599]
# [2.2901]
# Action me : State : [-0.986148; -0.165868; -5.59876]
# (3, 1)
# Action me : log_std : Float32[0.195925] (tracked)
# Σ : Float32[1.47971]
# [-0.746682]
# Action me : State : [-0.992183; 0.124794; -5.83516]
# (3, 1)
# Action me : log_std : Float32[0.186956] (tracked)
# Σ : Float32[1.45341]
# [2.13722]
# Action me : State : [-0.922149; 0.386836; -5.44156]
# (3, 1)
# Action me : log_std : Float32[0.158474] (tracked)
# Σ : Float32[1.37293]
# [-0.0639129]
# Action me : State : [-0.792896; 0.609357; -5.16102]
# (3, 1)
# Action me : log_std : Float32[0.136629] (tracked)
# Σ : Float32[1.31424]
# [-0.837405]
# Action me : State : [-0.624168; 0.78129; -4.82962]
# (3, 1)
# Action me : log_std : Float32[0.115132] (tracked)
# Σ : Float32[1.25893]
# [-0.780193]
# Action me : State : [-0.440389; 0.897807; -4.36068]
# (3, 1)
# Action me : log_std : Float32[0.0915941] (tracked)
# Σ : Float32[1.20104]
# [-0.149041]
# Action me : State : [-0.26726; 0.963624; -3.70968]
# (3, 1)
# Action me : log_std : Float32[0.0689328] (tracked)
# Σ : Float32[1.14782]
# [-0.740988]
# Action me : State : [-0.115385; 0.993321; -3.09811]
# (3, 1)
# Action me : log_std : Float32[0.0521105] (tracked)
# Σ : Float32[1.10985]
# [-1.50753]
# Action me : State : [0.0133191; 0.999911; -2.57925]
# (3, 1)
# Action me : log_std : Float32[0.0378151] (tracked)
# Σ : Float32[1.07856]
# [0.476678]
# Action me : State : [0.895132; 0.445802; -0.895503]
# (3, 1)
# Action me : log_std : Float32[0.0018134] (tracked)
# Σ : Float32[1.00363]
# [0.600236]
# Action me : State : [0.905383; 0.424595; -0.471116]
# (3, 1)
# Action me : log_std : Float32[0.00524848] (tracked)
# Σ : Float32[1.01055]
# [1.27066]
# Action me : State : [0.904577; 0.426311; 0.0379292]
# (3, 1)
# Action me : log_std : Float32[0.020698] (tracked)
# Σ : Float32[1.04226]
# [0.156403]
# Action me : State : [0.896289; 0.44347; 0.381123]
# (3, 1)
# Action me : log_std : Float32[0.0221573] (tracked)
# Σ : Float32[1.04531]
# [1.0018]
# Action me : State : [0.876301; 0.481764; 0.863996]
# (3, 1)
# Action me : log_std : Float32[0.0187268] (tracked)
# Σ : Float32[1.03816]
# [-1.50307]
# Action me : State : [0.851131; 0.524953; 0.999858]
# (3, 1)
# Action me : log_std : Float32[0.0193689] (tracked)
# Σ : Float32[1.0395]
# [0.0376366]
# Action me : State : [0.812353; 0.583166; 1.39922]
# (3, 1)
# Action me : log_std : Float32[0.0211758] (tracked)
# Σ : Float32[1.04326]
# [-0.814138]
# Action me : State : [0.75944; 0.650577; 1.71447]
# (3, 1)
# Action me : log_std : Float32[0.0253805] (tracked)
# Σ : Float32[1.05207]
# [0.339035]
# Action me : State : [0.681484; 0.731833; 2.25326]
# (3, 1)
# Action me : log_std : Float32[0.0312678] (tracked)
# Σ : Float32[1.06453]
# [-0.111934]
# Action me : State : [0.573295; 0.819349; 2.78534]
# (3, 1)
# Action me : log_std : Float32[0.0382174] (tracked)
# Σ : Float32[1.07943]
# [0.438856]
# Action me : State : [0.423439; 0.905925; 3.46568]
# (3, 1)
# Action me : log_std : Float32[0.0461482] (tracked)
# Σ : Float32[1.09669]
# [-0.366236]
# Action me : State : [0.230633; 0.973041; 4.09019]
# (3, 1)
# Action me : log_std : Float32[0.0508806] (tracked)
# Σ : Float32[1.10712]
# [-2.29171]
# Action me : State : [0.00672949; 0.999977; 4.51997]
# (3, 1)
# Action me : log_std : Float32[0.0527126] (tracked)
# Σ : Float32[1.11118]
# [1.18997]
# Action me : State : [-0.262578; 0.964911; 5.44845]
# (3, 1)
# Action me : log_std : Float32[0.0498877] (tracked)
# Σ : Float32[1.10492]
# [-0.922816]
# Action me : State : [-0.537423; 0.843313; 6.03371]
# (3, 1)
# Action me : log_std : Float32[0.0405372] (tracked)
# Σ : Float32[1.08445]
# [1.3479]
# Action me : State : [-0.789993; 0.613116; 6.86838]
# (3, 1)
# Action me : log_std : Float32[0.0254593] (tracked)
# Σ : Float32[1.05224]
# [0.244233]
# Action me : State : [-0.95774; 0.287635; 7.36485]
# (3, 1)
# Action me : log_std : Float32[0.00570225] (tracked)
# Σ : Float32[1.01147]
# [-0.828643]
# Action me : State : [-0.996717; -0.0809693; 7.45628]
# (3, 1)
# Action me : log_std : Float32[-0.0166138] (tracked)
# Σ : Float32[0.967318]
# [-0.395865]
# Action me : State : [-0.901373; -0.433044; 7.33618]
# (3, 1)
# Action me : log_std : Float32[-0.037618] (tracked)
# Σ : Float32[0.927524]
# [0.0983592]
# Action me : State : [-0.697299; -0.71678; 7.02615]
# (3, 1)
# Action me : log_std : Float32[-0.0529993] (tracked)
# Σ : Float32[0.899426]
# [-0.622258]
# Action me : State : [-0.442829; 0.896606; 0.988482]
# (3, 1)
# Action me : log_std : Float32[0.0445966] (tracked)
# Σ : Float32[1.09329]
# [-1.92375]
# Action me : State : [-0.503262; 0.864134; 1.37237]
# (3, 1)
# Action me : log_std : Float32[0.0448202] (tracked)
# Σ : Float32[1.09378]
# [-2.32238]
# Action me : State : [-0.575646; 0.817699; 1.72048]
# (3, 1)
# Action me : log_std : Float32[0.0440868] (tracked)
# Σ : Float32[1.09218]
# [0.504836]
# Action me : State : [-0.669746; 0.74259; 2.40947]
# (3, 1)
# Action me : log_std : Float32[0.0360528] (tracked)
# Σ : Float32[1.07477]
# [0.618196]
# Action me : State : [-0.775069; 0.631876; 3.05915]
# (3, 1)
# Action me : log_std : Float32[0.0255246] (tracked)
# Σ : Float32[1.05237]
# [0.124766]
# Action me : State : [-0.874504; 0.485018; 3.55177]
# (3, 1)
# Action me : log_std : Float32[0.0156669] (tracked)
# Σ : Float32[1.03183]
# [-0.0769668]
# Action me : State : [-0.951972; 0.306186; 3.90399]
# (3, 1)
# Action me : log_std : Float32[0.00502264] (tracked)
# Σ : Float32[1.0101]
# [-0.686311]
# Action me : State : [-0.993994; 0.10943; 4.03068]
# (3, 1)
# Action me : log_std : Float32[-0.00616404] (tracked)
# Σ : Float32[0.987748]
# [0.0534517]
# Action me : State : [-0.995358; -0.0962394; 4.12077]
# (3, 1)
# Action me : log_std : Float32[-0.0179019] (tracked)
# Σ : Float32[0.96483]
# [-1.25868]
# Action me : State : [-0.958422; -0.285356; 3.85979]
# (3, 1)
# Action me : log_std : Float32[-0.0293805] (tracked)
# Σ : Float32[0.942932]
# [-1.48436]
# Action me : State : [-0.895815; -0.444426; 3.42312]
# (3, 1)
# Action me : log_std : Float32[-0.0386691] (tracked)
# Σ : Float32[0.925577]
# [-0.942117]
# Action me : State : [-0.820816; -0.571192; 2.94848]
# (3, 1)
# Action me : log_std : Float32[-0.045775] (tracked)
# Σ : Float32[0.912516]
# [1.02735]
# Action me : State : [-0.737343; -0.675518; 2.67419]
# (3, 1)
# Action me : log_std : Float32[-0.0513409] (tracked)
# Σ : Float32[0.902414]
# [-0.902794]
# Action me : State : [-0.665021; -0.746824; 2.03213]
# (3, 1)
# Action me : log_std : Float32[-0.0461602] (tracked)
# Σ : Float32[0.911813]
# [0.775977]
# Action me : State : [-0.603674; -0.797231; 1.58841]
# (3, 1)
# Action me : log_std : Float32[-0.0403128] (tracked)
# Σ : Float32[0.922539]
# [0.0965697]
# Action me : State : [-0.562869; -0.826546; 1.00497]
# (3, 1)
# Action me : log_std : Float32[-0.0329453] (tracked)
# Σ : Float32[0.936233]
# [-0.500633]
# Action me : State : [-0.549992; -0.83517; 0.309967]
# (3, 1)
# Action me : log_std : Float32[-0.00949415] (tracked)
# Σ : Float32[0.981191]
# [0.530107]
# Action me : State : [-0.559846; -0.828597; -0.236894]
# (3, 1)
# Action me : log_std : Float32[0.033848] (tracked)
# Σ : Float32[1.07004]
# [1.71391]
# Action me : State : [-0.584499; -0.811394; -0.601256]
# (3, 1)
# Action me : log_std : Float32[0.046712] (tracked)
# Σ : Float32[1.09793]
# [-0.0321199]
# Action me : State : [-0.632668; -0.774423; -1.21462]
# (3, 1)
# Action me : log_std : Float32[0.0745795] (tracked)
# Σ : Float32[1.16086]
# [0.400403]
# Action me : State : [0.982457; -0.186491; 0.51986]
# (3, 1)
# Action me : log_std : Float32[0.00180953] (tracked)
# Σ : Float32[1.00363]
# [0.16644]
# Action me : State : [0.986031; -0.166562; 0.404957]
# (3, 1)
# Action me : log_std : Float32[0.00575673] (tracked)
# Σ : Float32[1.01158]
# [0.883599]
# Action me : State : [0.989257; -0.146187; 0.412576]
# (3, 1)
# Action me : log_std : Float32[0.00604771] (tracked)
# Σ : Float32[1.01217]
# [-1.09778]
# Action me : State : [0.990244; -0.139345; 0.138269]
# (3, 1)
# Action me : log_std : Float32[0.0150594] (tracked)
# Σ : Float32[1.03058]
# [0.153151]
# Action me : State : [0.990635; -0.136535; 0.0567329]
# (3, 1)
# Action me : log_std : Float32[0.01944] (tracked)
# Σ : Float32[1.03965]
# [-0.682337]
# Action me : State : [0.989598; -0.143863; -0.148019]
# (3, 1)
# Action me : log_std : Float32[0.0234646] (tracked)
# Σ : Float32[1.04805]
# [-1.41874]
# Action me : State : [0.985955; -0.167014; -0.468727]
# (3, 1)
# Action me : log_std : Float32[0.0286811] (tracked)
# Σ : Float32[1.05904]
# [-0.406869]
# Action me : State : [0.979957; -0.199209; -0.655017]
# (3, 1)
# Action me : log_std : Float32[0.0316985] (tracked)
# Σ : Float32[1.06545]
# [0.627417]
# Action me : State : [0.972265; -0.23388; -0.710312]
# (3, 1)
# Action me : log_std : Float32[0.0334243] (tracked)
# Σ : Float32[1.06913]
# [0.558142]
# Action me : State : [0.962108; -0.27267; -0.802001]
# (3, 1)
# Action me : log_std : Float32[0.0359455] (tracked)
# Σ : Float32[1.07454]
# [-0.319801]
# Action me : State : [0.946401; -0.322993; -1.05447]
# (3, 1)
# Action me : log_std : Float32[0.0463063] (tracked)
# Σ : Float32[1.09704]
# [1.83534]
# Action me : State : [0.928679; -0.370884; -1.02142]
# (3, 1)
# Action me : log_std : Float32[0.047627] (tracked)
# Σ : Float32[1.09994]
# [-0.211147]
# Action me : State : [0.901954; -0.431833; -1.33125]
# (3, 1)
# Action me : log_std : Float32[0.0596] (tracked)
# Σ : Float32[1.1266]
# [-0.0062649]
# Action me : State : [0.863147; -0.504953; -1.65607]
# (3, 1)
# Action me : log_std : Float32[0.072826] (tracked)
# Σ : Float32[1.15679]
# [0.809627]
# Action me : State : [0.810967; -0.585092; -1.91334]
# (3, 1)
# Action me : log_std : Float32[0.0847291] (tracked)
# Σ : Float32[1.18466]
# [-0.464961]
# Action me : State : [0.734349; -0.678772; -2.4219]
# (3, 1)
# Action me : log_std : Float32[0.104195] (tracked)
# Σ : Float32[1.23169]
# [-0.571009]
# Action me : State : [0.624019; -0.781409; -3.01663]
# (3, 1)
# Action me : log_std : Float32[0.127639] (tracked)
# Σ : Float32[1.29082]
# [-0.280352]
# Action me : State : [0.472071; -0.88156; -3.64474]
# (3, 1)
# Action me : log_std : Float32[0.157282] (tracked)
# Σ : Float32[1.36966]
# [-1.73007]
# Action me : State : [0.260334; -0.965519; -4.56542]
# (3, 1)
# Action me : log_std : Float32[0.196955] (tracked)
# Σ : Float32[1.48277]
# [1.2182]
# Action me : State : [0.0080261; -0.999968; -5.10683]
# (3, 1)
# Action me : log_std : Float32[0.220481] (tracked)
# Σ : Float32[1.5542]
# [-1.18652]
# Action me : State : [-0.0830913; 0.996542; 0.228666]
# (3, 1)
# Action me : log_std : Float32[0.0362788] (tracked)
# Σ : Float32[1.07525]
# [0.434871]
# Action me : State : [-0.13484; 0.990867; 1.0413]
# (3, 1)
# Action me : log_std : Float32[0.0444444] (tracked)
# Σ : Float32[1.09296]
# [0.629776]
# Action me : State : [-0.227197; 0.973849; 1.87892]
# (3, 1)
# Action me : log_std : Float32[0.0500815] (tracked)
# Σ : Float32[1.10535]
# [-0.471605]
# Action me : State : [-0.348647; 0.937254; 2.53857]
# (3, 1)
# Action me : log_std : Float32[0.0467319] (tracked)
# Σ : Float32[1.09797]
# [-1.12182]
# Action me : State : [-0.487993; 0.872848; 3.07323]
# (3, 1)
# Action me : log_std : Float32[0.041792] (tracked)
# Σ : Float32[1.08718]
# [0.109827]
# Action me : State : [-0.641925; 0.766768; 3.74434]
# (3, 1)
# Action me : log_std : Float32[0.0342917] (tracked)
# Σ : Float32[1.07099]
# [0.1305]
# Action me : State : [-0.791925; 0.610618; 4.33899]
# (3, 1)
# Action me : log_std : Float32[0.0240057] (tracked)
# Σ : Float32[1.04918]
# [-0.466077]
# Action me : State : [-0.91289; 0.408207; 4.72705]
# (3, 1)
# Action me : log_std : Float32[0.0115227] (tracked)
# Σ : Float32[1.02331]
# [-1.24899]
# Action me : State : [-0.984165; 0.177254; 4.84585]
# (3, 1)
# Action me : log_std : Float32[-0.00193581] (tracked)
# Σ : Float32[0.996136]
# [-0.280453]
# Action me : State : [-0.997645; -0.0685865; 4.93673]
# (3, 1)
# Action me : log_std : Float32[-0.016105] (tracked)
# Σ : Float32[0.968303]
# [0.168607]
# Action me : State : [-0.951053; -0.309026; 4.91058]
# (3, 1)
# Action me : log_std : Float32[-0.0306718] (tracked)
# Σ : Float32[0.9405]
# [0.840991]
# Action me : State : [-0.850207; -0.526448; 4.80496]
# (3, 1)
# Action me : log_std : Float32[-0.0431289] (tracked)
# Σ : Float32[0.917358]
# [0.392267]
# Action me : State : [-0.712413; -0.70176; 4.46896]
# (3, 1)
# Action me : log_std : Float32[-0.0525031] (tracked)
# Σ : Float32[0.900319]
# [0.32009]
# Action me : State : [-0.559182; -0.829045; 3.99065]
# (3, 1)
# Action me : log_std : Float32[-0.0586779] (tracked)
# Σ : Float32[0.889269]
# [0.963695]
# Action me : State : [-0.405684; -0.914013; 3.51342]
# (3, 1)
# Action me : log_std : Float32[-0.0612382] (tracked)
# Σ : Float32[0.884727]
# [0.715112]
# Action me : State : [-0.267665; -0.963512; 2.93518]
# (3, 1)
# Action me : log_std : Float32[-0.0550809] (tracked)
# Σ : Float32[0.895689]
# [-0.565035]
# Action me : State : [-0.163837; -0.986487; 2.12779]
# (3, 1)
# Action me : log_std : Float32[-0.0469213] (tracked)
# Σ : Float32[0.910426]
, 4.93673], [0.168607], -11.8802, [-0.951053, -0.309026, 4.91058]), ([-0.951053, -0.309026, 4.91058], [0.840991], -10.4064, [-0.850207, -0.526448, 4.80496]), ([-0.850207, -0.526448, 4.80496], [0.392267], -9.00239, [-0.712413, -0.70176, 4.46896]), ([-0.712413, -0.70176, 4.46896], [0.32009], -7.58447, [-0.559182, -0.829045, 3.99065]), ([-0.559182, -0.829045, 3.99065], [0.963695], -6.2772, [-0.405684, -0.914013, 3.51342]), ([-0.405684, -0.914013, 3.51342], [0.715112], -5.18915, [-0.267665, -0.963512, 2.93518]), ([-0.267665, -0.963512, 2.93518], [-0.565035], -4.25395, [-0.163837, -0.986487, 2.12779]), ([-0.163837, -0.986487, 2.12779], [0.843838], -3.46499, [-0.0887368, -0.996055, 1.5145]), ([-0.0887368, -0.996055, 1.5145], [-0.799298], -2.98445, [-0.0564454, -0.998406, 0.647566]), ([-0.0564454, -0.998406, 0.647566], [0.345422], -2.69007, [-0.0589125, -0.998263, -0.0494253]), ([-0.0589125, -0.998263, -0.0494253], [-1.1828], -2.65771, [-0.107516, -0.994203, -0.975543])]

# %%
s,a,t_ = process_rollouts(ro)
# Out:
# Ep Max A : [1.40494]
# Ep Max A : [1.97096]
# Ep Max A : [1.86254]
# Ep Max A : [1.48641]
# Ep Max A : [2.31285]
# Ep Max A : [1.3479]
# Ep Max A : [1.71391]
# Ep Max A : [1.83534]
# Ep Max A : [0.963695]
# ([0.513113 0.513644 … -0.0564454 -0.0589125; 0.858321 0.858004 … -0.998406 -0.998263; -0.804359 -0.0123533 … 0.647566 -0.0494253], [0.988432 1.40494 … 0.345422 -1.1828], [-1.13068 -1.06571 … -2.69007 -2.65771], [-60.2743 -62.8661 … -4.80747 -2.50624], [-2.44462 -5.75272 … -108.586 -110.241], [-1.38049 -1.85754 … -0.959654 -1.64744])

# %%
a
# Out:
# 1×180 Array{Float64,2}:
#  0.988432  1.40494  -0.867079  0.15721  …  -0.799298  0.345422  -1.1828

# %%
env = GymEnv("Pendulum-v0")
# Out:
# GymEnv Pendulum-v0
#   TimeLimit
#   r  = 0.0
#   ∑r = 0.0
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = show(::IOContext{Base.GenericIOBuffer{Array{UInt8,1}}}, ::GymEnv{PyCall.PyArray{Float64,1}}) at OpenAIGym.jl:64
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:64
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = show(::IOContext{Base.GenericIOBuffer{Array{UInt8,1}}}, ::GymEnv{PyCall.PyArray{Float64,1}}) at OpenAIGym.jl:65
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:65

# %%
s = reset!(env)
println(s)
# Out:
# [-0.850248, -0.526382, 0.851249]

# %%
step!(env,[2.0])
# Out:
# (-6.770338020214972, [-0.829735, -0.558157, 0.756462])

# %%
s = [0.908581, 0.41771, -0.57363]
# Out:
# 3-element Array{Float64,1}:
#   0.908581
#   0.41771
#  -0.57363

# %%
using Statistics

# %%
a = [1.0,2.0,3.0]
# Out:
# 3-element Array{Float64,1}:
#  1.0
#  2.0
#  3.0

# %%
mean(a)
# Out:
# 2.0

# %%
√(9.81)
# Out:
# 3.132091952673165
