# %%
"""
- Rollouts
- Define networks
- GAE
- Utils : Normal distributions and log probability of an action
- train
- logging utilities

Experiment with shared network for both policy and value function
"""

using Flux, CuArrays
using OpenAIGym
import Reinforce.action
import Reinforce:run_episode
import Flux.params
using Flux.Tracker: grad, update!
using Flux: onehot
using Statistics
using Distributed
using Distributions
using LinearAlgebra
using Base.Iterators
using BSON:@save,@load
using JLD

"""
A few intricacies : 
The policy is a Normal distribution and the `policy_net` outputs the `μ` and `logσ`.
Each action is assumed to be independent of the others.
Thus our covariance matrix is a diagonal matrix with each element representing the variance of
taking a particular action.
"""

"""
Utilities
"""
# weight initialization
function _random_normal(shape...)
    return map(Float32,rand(Normal(0,0.1),shape...))
end

function constant_init(shape...)
    return map(Float32,ones(shape...) * 0.1)
end

function normal_log_prob(μ,log_std,a)
    """
    Returns the log probability of an action under a policy Gaussian policy π
    """
    σ = exp.(log_std)
    σ² = σ.^2
    -(((a .- μ).^2)./(2.0 * σ²)) .- 0.5*log.(sqrt(2 * π)) .- log.(σ)
end

function normal_entropy(log_std)
    0.5 + 0.5 * log(2 * π) .+ log_std
end

function normalise(arr)
    (arr .- mean(arr))./(sqrt(var(arr) + 1e-10))
end

# Logging #
"""
Create logging utility
"""
mutable struct Logger
    hist_dict
end

Logger() = Logger(Dict())

function register(l::Logger,name::String)
     l.hist_dict[name] = []
end

function add(l::Logger,name,value)
    """
    Add a variable for it's history to be logged
    """
    if !(name in l.hist_dict.keys)
        err("Error...")
    else
        push!(l.hist_dict[name],value)
    end
end

"""
HYPERPARAMETERS
"""
# Policy parameters #
η = 3e-4 # Learning rate
STD = 0.0 # Standard deviation
HIDDEN_SIZE = 256
# Environment Variables #
STATE_SIZE = 3
ACTION_SIZE = 1
MIN_RANGE = -2.0f0
MAX_RANGE = 2.0f0
EPISODE_LENGTH = 20
TEST_STEPS = 10000
# GAE parameters
γ = 0.99
λ = 0.95
# Optimization parameters
PPO_EPOCHS = 4
NUM_EPISODES = 2000
BATCH_SIZE = 5
c₀ = 1.0
c₁ = 0.5
c₂ = 0.001
# PPO parameters
ϵ = 0.2
# FREQUENCIES
SAVE_FREQUENCY = 50
VERBOSE_FREQUENCY = 50
global_step = 0
# policy_type = "gaussian"

reward_hist = []

mutable struct PendulumPolicy <: Reinforce.AbstractPolicy
  train::Bool

  function PendulumPolicy(train = true)
    new(train)
  end
end

"""
Define the networks
"""
# if policy_type == "gaussian"
policy_μ = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu;initW = _random_normal,initb=constant_init),
                 Dense(HIDDEN_SIZE,ACTION_SIZE;initW = _random_normal,initb=constant_init),
                 x->tanh.(x),
                 x->param(2.0) .* x) 
policy_Σ = param(ones(ACTION_SIZE) * STD)

value = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu),
                  Dense(HIDDEN_SIZE,1))

# elseif policy_type == "linear"
#     policy = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu;initW = _random_normal,initb=constant_init),
#                      Dense(HIDDEN_SIZE,ACTION_SIZE;initW = _random_normal,initb=constant_init),
#                      x->tanh.(x))
    
#     value = Chain(Dense(STATE_SIZE,HIDDEN_SIZE,relu),
#                   Dense(HIDDEN_SIZE,1))
# end

# Optimizer
opt = ADAM(η)

function action(state)
    # Acccounting for the element type
    state = reshape(Array(state),length(state),1)
    
    a = nothing
    # Our policy outputs the parameters of a Normal distribution
#     if policy_type == "gaussian"
    μ = policy_μ(state)
    μ = reshape(μ,ACTION_SIZE)
    log_std = policy_Σ
    
    σ² = (exp.(log_std)).^2
    Σ = diagm(0=>σ².data)
    
    dis = MvNormal(μ.data,Σ)
    
    a = rand(dis,ACTION_SIZE)
    
#     elseif policy_type == "linear"
#         out = policy(state)
#     end
    a
end

function run_episode(env)
    experience = []
    
    s = reset!(env)
    for i in 1:EPISODE_LENGTH
        a = action(s)
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        
        r,s_ = step!(env,a)
        push!(experience,(s,a,r,s_))
        s = s_
        if env.done
           break 
        end
    end
    experience
end


function test_run(env)
    ep_r = 0.0
    
    s = reset!(env)
    for i in 1:TEST_STEPS
        OpenAIGym.render(env)
        a = policy_μ(s).data
        a = convert.(Float64,a)
        a = reshape(a,ACTION_SIZE)
        println("Action : $a")
        
        r,s_ = step!(env,a)
        ep_r += r
        
        s = s_
        if env.done
           break 
        end
    end
    ep_r
end
# Out:
# test_run (generic function with 1 method)

# %%
"""
Rollout collection
"""
num_processes = 9
addprocs(num_processes) 

@everywhere function collect(env)
    run_episode(env)
end

@everywhere function rollout()
  env = GymEnv(:Pendulum,:v0)
  return collect(env)
end

function get_rollouts()
    g = []
    for  w in workers()
      push!(g, rollout())
    end

    rollouts = fetch.(g)
end
# Out:
# get_rollouts (generic function with 1 method)

# %%
function gae(states,actions,rewards,next_states)
    """
    Returns a Generalized Advantage Estimate for an episode
    """
    Â = []
    A = 0.0
    for i in reverse(1:length(states))
        δ = rewards[i] + γ*value(next_states[i]).data[1] - value(states[i]).data[1]
        A = δ + (γ*λ*A)
        push!(Â,A)
    end
    
    Â = reverse(Â)
    return Â
end

function disconunted_returns(rewards)
    r = 0.0
    returns = []
    for i in reverse(1:length(rewards))
        r = rewards[i] + γ*r
        push!(returns,r)
    end
    returns = reverse(returns)
    returns
end

function log_prob_from_actions(states,actions)
    """
    Returns log probabilities of the actions taken
    
    states,actions : episode vairbles in the form of a list
    """
    log_probs = []
    
    for i in 1:length(states)
        μ = reshape(policy_μ(states[i]),ACTION_SIZE).data
        logΣ = policy_Σ.data
        push!(log_probs,normal_log_prob(μ,logΣ,actions[i]))
    end
    
    log_probs
end

function process_rollouts(rollouts)
    """
    rollouts : variable returned by calling `get_rollouts`
    
    Returns : 
    states, actions, rewards for minibatch processing
    """
    # Process the variables
    states = []
    actions = []
    rewards = []
    next_states = []
    advantages = []
    returns = []
    log_probs = []
    
    # Logging statistics
    episode_mean_returns = []
    
    for ro in rollouts
        episode_states = []
        episode_actions = []
        episode_rewards = []
        episode_next_states = []
        
        for i in 1:length(ro)
             push!(episode_states,Array(ro[i][1]))
             push!(episode_actions,ro[i][2])
             push!(episode_rewards,ro[i][3])
             push!(episode_next_states,ro[i][4])
        end
        
#         println("Ep Max A : $(maximum(episode_actions))")
        
        episode_advantages = gae(episode_states,episode_actions,episode_rewards,episode_next_states)
        episode_returns = disconunted_returns(episode_rewards)
        
        push!(episode_mean_returns,mean(episode_returns))
        
        episode_advantages = normalise(episode_advantages)
        
        push!(states,episode_states)
        push!(actions,episode_actions)
        push!(rewards,episode_rewards)
        push!(advantages,episode_advantages)
        push!(returns,episode_returns)
        push!(log_probs,log_prob_from_actions(episode_states,episode_actions))
    end
    
    states = cat(states...,dims=1)
    actions = cat(actions...,dims=1)
    rewards = cat(rewards...,dims=1)
    advantages = cat(advantages...,dims=1)
    returns = cat(returns...,dims=1)
    log_probs = cat(log_probs...,dims=1)
    
    push!(reward_hist,mean(episode_mean_returns))
    
    if length(reward_hist) <= 100
        println("RETURNS : $(mean(episode_mean_returns))")
    else
        println("LAST 100 RETURNS : $(mean(reward_hist[end-100:end]))")
    end
    
    return hcat(states...),hcat(actions...),hcat(rewards...),hcat(advantages...),hcat(returns...),hcat(log_probs...)
end
# Out:
# process_rollouts (generic function with 1 method)

# %%
function print_losses(pl,vl,el) 
   println("------")
   println("Policy Loss : $pl")
   println("Value Loss : $vl")
   println("Entropy Loss : $el") 
   println("------")
end

function loss(states,actions,advantages,returns,old_log_probs)
#     println("---")
#     println(size(states))
#     println("States : $states")
#     println("---")
#     println("Actions : $actions")
#     println("---")
    global global_step
    global_step += 1
    
    μ = policy_μ(states)
    logΣ = policy_Σ
    
#     println("μ : $μ")
#     println("---")
#     println("logΣ : $logΣ")
#     println("---")
    
    new_log_probs = normal_log_prob(μ,logΣ,actions)
#     println("New Log Probs : $new_log_probs")
#     println("Old Log Probs : $old_log_probs")
    
    # Surrogate loss computation
    ratio = exp.(new_log_probs .- old_log_probs)
    surr1 = ratio .* advantages
    surr2 = clamp.(ratio,1.0 - ϵ,1.0 + ϵ)
    policy_loss = mean(min.(surr1,surr2))
    
#     println("Surr1 : $surr1")
#     println("Surr2 : $surr2")
#     println("Policy Loss : $policy_loss")
    
    value_predicted = value(states)
    value_loss = mean((value_predicted .- returns).^2)
#     println("Value Loss : $value_loss")
    
    entropy_loss = mean(normal_entropy(logΣ))
    
#     if global_step % VERBOSE_FREQUENCY == 0
#         print_losses(policy_loss.data,value_loss.data,entropy_loss.data)
#     end
    
    -c₀*policy_loss + c₁*value_loss # - c₂*entropy_loss
end

function ppo_update(states,actions,advantages,returns,old_log_probs)
    # Define model parameters
    model_params = params(params(policy_μ)...,params(policy_Σ)...,params(value)...)

    # Calculate gradients
    gs = Tracker.gradient(() -> loss(states,actions,advantages,returns,old_log_probs),model_params)
#     println("Gradient Done")
    
    g = gs[policy_μ.layers[1].W]
#     println("GRAD : $(mean(g))")
    # Take a step of optimisation
    update!(opt,model_params,gs)
#     println("Update Done")
end

function train_step()    
    routs = get_rollouts()
    states,actions,rewards,advantages,returns,log_probs = process_rollouts(routs)
    
    idxs = partition(1:size(states)[end],BATCH_SIZE)
    
    for epoch in 1:PPO_EPOCHS
#         println("Epoch : $epoch")
        for i in idxs
#             println(i)
            mb_states = states[:,i] 
            mb_actions = actions[:,i] 
            mb_advantages = advantages[:,i] 
            mb_returns = returns[:,i] 
            mb_log_probs = log_probs[:,i]
            
            ppo_update(mb_states,mb_actions,mb_advantages,mb_returns,mb_log_probs)
        end
    end
end

function train()
    for i in 1:NUM_EPISODES
        println("EP : $i")
        train_step()
        println("Ep done")
        
        if i%SAVE_FREQUENCY == 0
            @save "weights/policy_mu.bson" policy_μ
            @save "weights/policy_sigma.bson" policy_Σ
            @save "weights/value.bson" value
            
            save("stats.jld","rewards",reward_hist)
            println("\n\n\n----MAX REWRD SO FAR : $(maximum(reward_hist))---\n\n\n")
        end
    end
end
# Out:
# train (generic function with 1 method)

# %%
train()
# Out:
# EP : 1
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = #GymEnv#1(::Type, ::Type, ::Symbol, ::Symbol) at OpenAIGym.jl:49
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:49
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv(::Symbol, ::Symbol, ::PyCall.PyObject, ::Type) at OpenAIGym.jl:56
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:56
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = GymEnv{PyCall.PyArray{Float64,1}}(::Symbol, ::Symbol, ::PyCall.PyObject, ::PyCall.PyObject, ::PyCall.PyArray{Float64,1}) at OpenAIGym.jl:34
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:34
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actions(::GymEnv{PyCall.PyArray{Float64,1}}, ::Nothing) at OpenAIGym.jl:117
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:117
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:88
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:88
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:91
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:91
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:95
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:95
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = actionset(::PyCall.PyObject) at OpenAIGym.jl:97
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:97
# RETURNS : -66.00464906199679
# Ep done
# EP : 2
# RETURNS : -60.828709201813844
# Ep done
# EP : 3
# RETURNS : -57.1118626688542
# Ep done
# EP : 4
# RETURNS : -66.91570343846391
# Ep done
# EP : 5
# RETURNS : -67.03777485796535
# Ep done
# EP : 6
# RETURNS : -51.236294703649676
# Ep done
# EP : 7
# RETURNS : -72.27709944958444
# Ep done
# EP : 8
# RETURNS : -66.82793205969216
# Ep done
# EP : 9
# RETURNS : -66.03147814761293
# Ep done
# EP : 10
# RETURNS : -71.97654893416939
# Ep done
# EP : 11
# RETURNS : -68.03935338051677
# Ep done
# EP : 12
# RETURNS : -70.48327752896024
# Ep done
# EP : 13
# RETURNS : -66.15414226963698
# Ep done
# EP : 14
# RETURNS : -62.60670216483017
# Ep done
# EP : 15
# RETURNS : -71.13771082882575
# Ep done
# EP : 16
# RETURNS : -60.84374520416228
# Ep done
# EP : 17
# RETURNS : -61.565031032573316
# Ep done
# EP : 18
# RETURNS : -64.76381695486268
# Ep done
# EP : 19
# RETURNS : -64.24812487235162
# Ep done
# EP : 20
# RETURNS : -64.14245531604512
# Ep done
# EP : 21
# RETURNS : -72.89172176439018
# Ep done
# EP : 22
# RETURNS : -55.89434810008264
# Ep done
# EP : 23
# RETURNS : -65.43121316577688
# Ep done
# EP : 24
# RETURNS : -59.52656292065751
# Ep done
# EP : 25
# RETURNS : -64.48454144847204
# Ep done
# EP : 26
# RETURNS : -60.50914884881578
# Ep done
# EP : 27
# RETURNS : -70.56468734467715
# Ep done
# EP : 28
# RETURNS : -58.600988648663915
# Ep done
# EP : 29
# RETURNS : -65.09169981560723
# Ep done
# EP : 30
# RETURNS : -47.67092997568548
# Ep done
# EP : 31
# RETURNS : -71.35995446960013
# Ep done
# EP : 32
# RETURNS : -63.877409798439594
# Ep done
# EP : 33
# RETURNS : -56.43327517361415
# Ep done
# EP : 34
# RETURNS : -65.08620444445447
# Ep done
# EP : 35
# RETURNS : -68.5917827825266
# Ep done
# EP : 36
# RETURNS : -70.26095922735479
# Ep done
# EP : 37
# RETURNS : -65.9777643979188
# Ep done
# EP : 38
# RETURNS : -71.80975290863084
# Ep done
# EP : 39
# RETURNS : -77.85284230620357
# Ep done
# EP : 40
# RETURNS : -65.18512859845805
# Ep done
# EP : 41
# RETURNS : -64.22523616917292
# Ep done
# EP : 42
# RETURNS : -72.90055595133705
# Ep done
# EP : 43
# RETURNS : -71.74875667583676
# Ep done
# EP : 44
# RETURNS : -70.17974845896688
# Ep done
# EP : 45
# RETURNS : -63.85287834971137
# Ep done
# EP : 46
# RETURNS : -72.19639864852162
# Ep done
# EP : 47
# RETURNS : -70.46683101715591
# Ep done
# EP : 48
# RETURNS : -68.32330688352522
# Ep done
# EP : 49
# RETURNS : -67.2365576329696
# Ep done
# EP : 50
# RETURNS : -69.67372314136915
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -47.67092997568548---
#
#
#
# EP : 51
# RETURNS : -48.471444138587756
# Ep done
# EP : 52
# RETURNS : -66.03623352256828
# Ep done
# EP : 53
# RETURNS : -72.07881700896257
# Ep done
# EP : 54
# RETURNS : -65.78473490452585
# Ep done
# EP : 55
# RETURNS : -64.63063350040187
# Ep done
# EP : 56
# RETURNS : -65.26642516252608
# Ep done
# EP : 57
# RETURNS : -63.51385889162451
# Ep done
# EP : 58
# RETURNS : -68.61945335167478
# Ep done
# EP : 59
# RETURNS : -64.77021552652427
# Ep done
# EP : 60
# RETURNS : -65.41029383578824
# Ep done
# EP : 61
# RETURNS : -70.64484721081106
# Ep done
# EP : 62
# RETURNS : -64.49923060120983
# Ep done
# EP : 63
# RETURNS : -59.23185245277395
# Ep done
# EP : 64
# RETURNS : -73.46168163448135
# Ep done
# EP : 65
# RETURNS : -53.41763987181548
# Ep done
# EP : 66
# RETURNS : -39.88275536414078
# Ep done
# EP : 67
# RETURNS : -71.51150621733959
# Ep done
# EP : 68
# RETURNS : -72.89597688852297
# Ep done
# EP : 69
# RETURNS : -60.38420481486758
# Ep done
# EP : 70
# RETURNS : -46.54148347034303
# Ep done
# EP : 71
# RETURNS : -69.96301885967485
# Ep done
# EP : 72
# RETURNS : -62.04132139704817
# Ep done
# EP : 73
# RETURNS : -65.06754679689871
# Ep done
# EP : 74
# RETURNS : -54.465499843325404
# Ep done
# EP : 75
# RETURNS : -66.9305682415523
# Ep done
# EP : 76
# RETURNS : -60.86519508614065
# Ep done
# EP : 77
# RETURNS : -62.88488519931039
# Ep done
# EP : 78
# RETURNS : -54.40895217819249
# Ep done
# EP : 79
# RETURNS : -73.98242322358176
# Ep done
# EP : 80
# RETURNS : -53.936884614254076
# Ep done
# EP : 81
# RETURNS : -59.8381471889562
# Ep done
# EP : 82
# RETURNS : -48.9867621885045
# Ep done
# EP : 83
# RETURNS : -62.2617609415679
# Ep done
# EP : 84
# RETURNS : -61.550630007643605
# Ep done
# EP : 85
# RETURNS : -65.05013674359174
# Ep done
# EP : 86
# RETURNS : -68.91672644472561
# Ep done
# EP : 87
# RETURNS : -68.95960841241202
# Ep done
# EP : 88
# RETURNS : -68.1809874466553
# Ep done
# EP : 89
# RETURNS : -58.771660958044386
# Ep done
# EP : 90
# RETURNS : -66.6420539995673
# Ep done
# EP : 91
# RETURNS : -63.65802380406046
# Ep done
# EP : 92
# RETURNS : -50.64423345153549
# Ep done
# EP : 93
# RETURNS : -70.86036649947833
# Ep done
# EP : 94
# RETURNS : -58.60357219896085
# Ep done
# EP : 95
# RETURNS : -49.072599030376956
# Ep done
# EP : 96
# RETURNS : -61.09492865467582
# Ep done
# EP : 97
# RETURNS : -65.4791600144951
# Ep done
# EP : 98
# RETURNS : -66.89152581085358
# Ep done
# EP : 99
# RETURNS : -57.95684684928892
# Ep done
# EP : 100
# RETURNS : -62.773126728596054
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -39.88275536414078---
#
#
#
# EP : 101
# LAST 100 RETURNS : -63.97970805054558
# Ep done
# EP : 102
# LAST 100 RETURNS : -63.99703964043939
# Ep done
# EP : 103
# LAST 100 RETURNS : -63.99500953418915
# Ep done
# EP : 104
# LAST 100 RETURNS : -64.0996166824405
# Ep done
# EP : 105
# LAST 100 RETURNS : -64.06628270557692
# Ep done
# EP : 106
# LAST 100 RETURNS : -64.04000138796596
# Ep done
# EP : 107
# LAST 100 RETURNS : -64.1584399250275
# Ep done
# EP : 108
# LAST 100 RETURNS : -64.08998942322484
# Ep done
# EP : 109
# LAST 100 RETURNS : -64.02381331980477
# Ep done
# EP : 110
# LAST 100 RETURNS : -64.09786134621388
# Ep done
# EP : 111
# LAST 100 RETURNS : -63.91474792617114
# Ep done
# EP : 112
# LAST 100 RETURNS : -63.93660213176388
# Ep done
# EP : 113
# LAST 100 RETURNS : -63.92163029733711
# Ep done
# EP : 114
# LAST 100 RETURNS : -63.83944836540946
# Ep done
# EP : 115
# LAST 100 RETURNS : -63.76623509242813
# Ep done
# EP : 116
# LAST 100 RETURNS : -63.718471657467646
# Ep done
# EP : 117
# LAST 100 RETURNS : -63.780308640390665
# Ep done
# EP : 118
# LAST 100 RETURNS : -63.75381068752177
# Ep done
# EP : 119
# LAST 100 RETURNS : -63.66110298178574
# Ep done
# EP : 120
# LAST 100 RETURNS : -63.42178143648511
# Ep done
# EP : 121
# LAST 100 RETURNS : -63.22730272697981
# Ep done
# EP : 122
# LAST 100 RETURNS : -63.105541080233095
# Ep done
# EP : 123
# LAST 100 RETURNS : -63.15254341931038
# Ep done
# EP : 124
# LAST 100 RETURNS : -63.099967952263874
# Ep done
# EP : 125
# LAST 100 RETURNS : -63.072105672098715
# Ep done
# EP : 126
# LAST 100 RETURNS : -63.08661327926276
# Ep done
# EP : 127
# LAST 100 RETURNS : -63.015275820017344
# Ep done
# EP : 128
# LAST 100 RETURNS : -62.813135033231205
# Ep done
# EP : 129
# LAST 100 RETURNS : -62.90208707465878
# Ep done
# EP : 130
# LAST 100 RETURNS : -62.86921429769393
# Ep done
# EP : 131
# LAST 100 RETURNS : -63.06534323060715
# Ep done
# EP : 132
# LAST 100 RETURNS : -62.9647718404082
# Ep done
# EP : 133
# LAST 100 RETURNS : -62.94848759532647
# Ep done
# EP : 134
# LAST 100 RETURNS : -62.91582722845112
# Ep done
# EP : 135
# LAST 100 RETURNS : -62.856272728334666
# Ep done
# EP : 136
# LAST 100 RETURNS : -62.78692593199866
# Ep done
# EP : 137
# LAST 100 RETURNS : -62.64651229615211
# Ep done
# EP : 138
# LAST 100 RETURNS : -62.57168449416394
# Ep done
# EP : 139
# LAST 100 RETURNS : -62.35603226288327
# Ep done
# EP : 140
# LAST 100 RETURNS : -62.25940885168597
# Ep done
# EP : 141
# LAST 100 RETURNS : -62.29556082884536
# Ep done
# EP : 142
# LAST 100 RETURNS : -62.23556811784221
# Ep done
# EP : 143
# LAST 100 RETURNS : -62.0582154976349
# Ep done
# EP : 144
# LAST 100 RETURNS : -61.70044328177923
# Ep done
# EP : 145
# LAST 100 RETURNS : -61.58392254506386
# Ep done
# EP : 146
# LAST 100 RETURNS : -61.49984088511339
# Ep done
# EP : 147
# LAST 100 RETURNS : -61.21291782317911
# Ep done
# EP : 148
# LAST 100 RETURNS : -61.09200050123521
# Ep done
# EP : 149
# LAST 100 RETURNS : -60.9095206078366
# Ep done
# EP : 150
# LAST 100 RETURNS : -60.786834529374445
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 151
# LAST 100 RETURNS : -60.559728539901386
# Ep done
# EP : 152
# LAST 100 RETURNS : -60.682947165007704
# Ep done
# EP : 153
# LAST 100 RETURNS : -60.507621250370505
# Ep done
# EP : 154
# LAST 100 RETURNS : -60.41039401884864
# Ep done
# EP : 155
# LAST 100 RETURNS : -60.30303107204727
# Ep done
# EP : 156
# LAST 100 RETURNS : -60.190458039738566
# Ep done
# EP : 157
# LAST 100 RETURNS : -60.04633792664328
# Ep done
# EP : 158
# LAST 100 RETURNS : -60.03899045640828
# Ep done
# EP : 159
# LAST 100 RETURNS : -59.92704995593955
# Ep done
# EP : 160
# LAST 100 RETURNS : -59.80230523101667
# Ep done
# EP : 161
# LAST 100 RETURNS : -59.763108735120646
# Ep done
# EP : 162
# LAST 100 RETURNS : -59.696244329594286
# Ep done
# EP : 163
# LAST 100 RETURNS : -59.681781036532605
# Ep done
# EP : 164
# LAST 100 RETURNS : -59.72784251786296
# Ep done
# EP : 165
# LAST 100 RETURNS : -59.50558666416136
# Ep done
# EP : 166
# LAST 100 RETURNS : -59.530977459617645
# Ep done
# EP : 167
# LAST 100 RETURNS : -59.77231549746605
# Ep done
# EP : 168
# LAST 100 RETURNS : -59.656715766947414
# Ep done
# EP : 169
# LAST 100 RETURNS : -59.64484988989452
# Ep done
# EP : 170
# LAST 100 RETURNS : -59.767777526827146
# Ep done
# EP : 171
# LAST 100 RETURNS : -59.91332550202707
# Ep done
# EP : 172
# LAST 100 RETURNS : -59.797620678982476
# Ep done
# EP : 173
# LAST 100 RETURNS : -59.741178337026
# Ep done
# EP : 174
# LAST 100 RETURNS : -59.61504400486295
# Ep done
# EP : 175
# LAST 100 RETURNS : -59.669749012844676
# Ep done
# EP : 176
# LAST 100 RETURNS : -59.595128950837875
# Ep done
# EP : 177
# LAST 100 RETURNS : -59.57613673453536
# Ep done
# EP : 178
# LAST 100 RETURNS : -59.51126378915249
# Ep done
# EP : 179
# LAST 100 RETURNS : -59.59598684376885
# Ep done
# EP : 180
# LAST 100 RETURNS : -59.548778041992385
# Ep done
# EP : 181
# LAST 100 RETURNS : -59.59243234149027
# Ep done
# EP : 182
# LAST 100 RETURNS : -59.617965854788885
# Ep done
# EP : 183
# LAST 100 RETURNS : -59.82313472229839
# Ep done
# EP : 184
# LAST 100 RETURNS : -59.70568146270318
# Ep done
# EP : 185
# LAST 100 RETURNS : -59.649736513201745
# Ep done
# EP : 186
# LAST 100 RETURNS : -59.6664227589387
# Ep done
# EP : 187
# LAST 100 RETURNS : -59.50110510287736
# Ep done
# EP : 188
# LAST 100 RETURNS : -59.493649613234695
# Ep done
# EP : 189
# LAST 100 RETURNS : -59.42464771071732
# Ep done
# EP : 190
# LAST 100 RETURNS : -59.40361163898988
# Ep done
# EP : 191
# LAST 100 RETURNS : -59.39953794074168
# Ep done
# EP : 192
# LAST 100 RETURNS : -59.27625092962912
# Ep done
# EP : 193
# LAST 100 RETURNS : -59.40208642136362
# Ep done
# EP : 194
# LAST 100 RETURNS : -59.37255772844262
# Ep done
# EP : 195
# LAST 100 RETURNS : -59.44327920693471
# Ep done
# EP : 196
# LAST 100 RETURNS : -59.52394777858414
# Ep done
# EP : 197
# LAST 100 RETURNS : -59.58165226313468
# Ep done
# EP : 198
# LAST 100 RETURNS : -59.67766306963866
# Ep done
# EP : 199
# LAST 100 RETURNS : -59.63374512515477
# Ep done
# EP : 200
# LAST 100 RETURNS : -59.59096747408902
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 201
# LAST 100 RETURNS : -59.62485027172299
# Ep done
# EP : 202
# LAST 100 RETURNS : -59.71760170827519
# Ep done
# EP : 203
# LAST 100 RETURNS : -59.565065292421664
# Ep done
# EP : 204
# LAST 100 RETURNS : -59.52724260905177
# Ep done
# EP : 205
# LAST 100 RETURNS : -59.46388819404012
# Ep done
# EP : 206
# LAST 100 RETURNS : -59.32479222767217
# Ep done
# EP : 207
# LAST 100 RETURNS : -59.35988823458831
# Ep done
# EP : 208
# LAST 100 RETURNS : -59.39012730397001
# Ep done
# EP : 209
# LAST 100 RETURNS : -59.37599559115766
# Ep done
# EP : 210
# LAST 100 RETURNS : -59.35470355433875
# Ep done
# EP : 211
# LAST 100 RETURNS : -59.20439680799731
# Ep done
# EP : 212
# LAST 100 RETURNS : -59.1847059707649
# Ep done
# EP : 213
# LAST 100 RETURNS : -59.01285564697957
# Ep done
# EP : 214
# LAST 100 RETURNS : -58.69792424781939
# Ep done
# EP : 215
# LAST 100 RETURNS : -58.66731220592923
# Ep done
# EP : 216
# LAST 100 RETURNS : -58.59465506200515
# Ep done
# EP : 217
# LAST 100 RETURNS : -58.57440752096198
# Ep done
# EP : 218
# LAST 100 RETURNS : -58.42928075400737
# Ep done
# EP : 219
# LAST 100 RETURNS : -58.446428227884496
# Ep done
# EP : 220
# LAST 100 RETURNS : -58.4646667264857
# Ep done
# EP : 221
# LAST 100 RETURNS : -58.62965333097755
# Ep done
# EP : 222
# LAST 100 RETURNS : -58.76202280229494
# Ep done
# EP : 223
# LAST 100 RETURNS : -58.839532185692214
# Ep done
# EP : 224
# LAST 100 RETURNS : -58.838970526112504
# Ep done
# EP : 225
# LAST 100 RETURNS : -58.86528129674765
# Ep done
# EP : 226
# LAST 100 RETURNS : -58.91709071756325
# Ep done
# EP : 227
# LAST 100 RETURNS : -58.90218568633638
# Ep done
# EP : 228
# LAST 100 RETURNS : -59.00629913778907
# Ep done
# EP : 229
# LAST 100 RETURNS : -59.08729362145608
# Ep done
# EP : 230
# LAST 100 RETURNS : -59.02692413295707
# Ep done
# EP : 231
# LAST 100 RETURNS : -59.09727064351421
# Ep done
# EP : 232
# LAST 100 RETURNS : -59.04511283548031
# Ep done
# EP : 233
# LAST 100 RETURNS : -59.02110877263106
# Ep done
# EP : 234
# LAST 100 RETURNS : -59.05787001897254
# Ep done
# EP : 235
# LAST 100 RETURNS : -59.15444654604743
# Ep done
# EP : 236
# LAST 100 RETURNS : -59.17485413306436
# Ep done
# EP : 237
# LAST 100 RETURNS : -59.21370677854609
# Ep done
# EP : 238
# LAST 100 RETURNS : -59.32325918610165
# Ep done
# EP : 239
# LAST 100 RETURNS : -59.295950811836846
# Ep done
# EP : 240
# LAST 100 RETURNS : -59.506722141565895
# Ep done
# EP : 241
# LAST 100 RETURNS : -59.550320104426824
# Ep done
# EP : 242
# LAST 100 RETURNS : -59.4990363996271
# Ep done
# EP : 243
# LAST 100 RETURNS : -59.53870467412868
# Ep done
# EP : 244
# LAST 100 RETURNS : -59.628873214564116
# Ep done
# EP : 245
# LAST 100 RETURNS : -59.8554901745898
# Ep done
# EP : 246
# LAST 100 RETURNS : -59.93296976340072
# Ep done
# EP : 247
# LAST 100 RETURNS : -60.02098428614123
# Ep done
# EP : 248
# LAST 100 RETURNS : -60.31198408955597
# Ep done
# EP : 249
# LAST 100 RETURNS : -60.34451352600008
# Ep done
# EP : 250
# LAST 100 RETURNS : -60.46459668209957
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 251
# LAST 100 RETURNS : -60.653480887041674
# Ep done
# EP : 252
# LAST 100 RETURNS : -60.828241952695414
# Ep done
# EP : 253
# LAST 100 RETURNS : -60.90463884098597
# Ep done
# EP : 254
# LAST 100 RETURNS : -61.06710598162456
# Ep done
# EP : 255
# LAST 100 RETURNS : -60.98501125918711
# Ep done
# EP : 256
# LAST 100 RETURNS : -61.01358704996954
# Ep done
# EP : 257
# LAST 100 RETURNS : -61.16121997294613
# Ep done
# EP : 258
# LAST 100 RETURNS : -61.324837674349936
# Ep done
# EP : 259
# LAST 100 RETURNS : -61.18997646714746
# Ep done
# EP : 260
# LAST 100 RETURNS : -61.31898545590212
# Ep done
# EP : 261
# LAST 100 RETURNS : -61.42213833912684
# Ep done
# EP : 262
# LAST 100 RETURNS : -61.501600664660714
# Ep done
# EP : 263
# LAST 100 RETURNS : -61.45005450460583
# Ep done
# EP : 264
# LAST 100 RETURNS : -61.42686845582475
# Ep done
# EP : 265
# LAST 100 RETURNS : -61.41774610703461
# Ep done
# EP : 266
# LAST 100 RETURNS : -61.48964850343783
# Ep done
# EP : 267
# LAST 100 RETURNS : -61.605109803834125
# Ep done
# EP : 268
# LAST 100 RETURNS : -61.609649457944045
# Ep done
# EP : 269
# LAST 100 RETURNS : -61.5796265474078
# Ep done
# EP : 270
# LAST 100 RETURNS : -61.51925983598631
# Ep done
# EP : 271
# LAST 100 RETURNS : -61.36824990279824
# Ep done
# EP : 272
# LAST 100 RETURNS : -61.457142105492686
# Ep done
# EP : 273
# LAST 100 RETURNS : -61.5359331413719
# Ep done
# EP : 274
# LAST 100 RETURNS : -61.61884177258202
# Ep done
# EP : 275
# LAST 100 RETURNS : -61.6202046243373
# Ep done
# EP : 276
# LAST 100 RETURNS : -61.71496966880449
# Ep done
# EP : 277
# LAST 100 RETURNS : -61.72156729613443
# Ep done
# EP : 278
# LAST 100 RETURNS : -61.76567818669408
# Ep done
# EP : 279
# LAST 100 RETURNS : -61.86576346785935
# Ep done
# EP : 280
# LAST 100 RETURNS : -61.89321025554923
# Ep done
# EP : 281
# LAST 100 RETURNS : -61.78888198547157
# Ep done
# EP : 282
# LAST 100 RETURNS : -61.70374305557278
# Ep done
# EP : 283
# LAST 100 RETURNS : -61.661497703359665
# Ep done
# EP : 284
# LAST 100 RETURNS : -61.58789892836112
# Ep done
# EP : 285
# LAST 100 RETURNS : -61.516281448917525
# Ep done
# EP : 286
# LAST 100 RETURNS : -61.6484351536262
# Ep done
# EP : 287
# LAST 100 RETURNS : -61.62698175722403
# Ep done
# EP : 288
# LAST 100 RETURNS : -61.82249659855244
# Ep done
# EP : 289
# LAST 100 RETURNS : -61.77282002297085
# Ep done
# EP : 290
# LAST 100 RETURNS : -61.818459604096844
# Ep done
# EP : 291
# LAST 100 RETURNS : -61.776626322209296
# Ep done
# EP : 292
# LAST 100 RETURNS : -61.61602367351997
# Ep done
# EP : 293
# LAST 100 RETURNS : -61.67606722547306
# Ep done
# EP : 294
# LAST 100 RETURNS : -61.6206016320725
# Ep done
# EP : 295
# LAST 100 RETURNS : -61.59109467338873
# Ep done
# EP : 296
# LAST 100 RETURNS : -61.48580632650019
# Ep done
# EP : 297
# LAST 100 RETURNS : -61.601368603183204
# Ep done
# EP : 298
# LAST 100 RETURNS : -61.44931013715925
# Ep done
# EP : 299
# LAST 100 RETURNS : -61.328680866336164
# Ep done
# EP : 300
# LAST 100 RETURNS : -61.29006556357419
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 301
# LAST 100 RETURNS : -61.325581510738054
# Ep done
# EP : 302
# LAST 100 RETURNS : -61.23945531245573
# Ep done
# EP : 303
# LAST 100 RETURNS : -61.19916847992052
# Ep done
# EP : 304
# LAST 100 RETURNS : -61.333681100932175
# Ep done
# EP : 305
# LAST 100 RETURNS : -61.48441335274068
# Ep done
# EP : 306
# LAST 100 RETURNS : -61.51767534071374
# Ep done
# EP : 307
# LAST 100 RETURNS : -61.717813797531065
# Ep done
# EP : 308
# LAST 100 RETURNS : -61.58977466621261
# Ep done
# EP : 309
# LAST 100 RETURNS : -61.53003731811004
# Ep done
# EP : 310
# LAST 100 RETURNS : -61.49894880556341
# Ep done
# EP : 311
# LAST 100 RETURNS : -61.531520945438636
# Ep done
# EP : 312
# LAST 100 RETURNS : -61.37048405712367
# Ep done
# EP : 313
# LAST 100 RETURNS : -61.51757872999305
# Ep done
# EP : 314
# LAST 100 RETURNS : -61.56296049630587
# Ep done
# EP : 315
# LAST 100 RETURNS : -61.74333510461918
# Ep done
# EP : 316
# LAST 100 RETURNS : -61.835247706468856
# Ep done
# EP : 317
# LAST 100 RETURNS : -61.97934162858311
# Ep done
# EP : 318
# LAST 100 RETURNS : -61.84956949715615
# Ep done
# EP : 319
# LAST 100 RETURNS : -61.88274733966528
# Ep done
# EP : 320
# LAST 100 RETURNS : -61.8941804173273
# Ep done
# EP : 321
# LAST 100 RETURNS : -61.9581113659169
# Ep done
# EP : 322
# LAST 100 RETURNS : -62.083078133318516
# Ep done
# EP : 323
# LAST 100 RETURNS : -62.19221662584962
# Ep done
# EP : 324
# LAST 100 RETURNS : -62.15917974627676
# Ep done
# EP : 325
# LAST 100 RETURNS : -62.23285360240853
# Ep done
# EP : 326
# LAST 100 RETURNS : -62.30572692545622
# Ep done
# EP : 327
# LAST 100 RETURNS : -62.33115645165028
# Ep done
# EP : 328
# LAST 100 RETURNS : -62.33638549228592
# Ep done
# EP : 329
# LAST 100 RETURNS : -62.33533534502625
# Ep done
# EP : 330
# LAST 100 RETURNS : -62.42496661372179
# Ep done
# EP : 331
# LAST 100 RETURNS : -62.45153333727417
# Ep done
# EP : 332
# LAST 100 RETURNS : -62.403288558984265
# Ep done
# EP : 333
# LAST 100 RETURNS : -62.403672900983814
# Ep done
# EP : 334
# LAST 100 RETURNS : -62.4235230999315
# Ep done
# EP : 335
# LAST 100 RETURNS : -62.408162503062805
# Ep done
# EP : 336
# LAST 100 RETURNS : -62.38673395627774
# Ep done
# EP : 337
# LAST 100 RETURNS : -62.32362698167438
# Ep done
# EP : 338
# LAST 100 RETURNS : -62.322870537309356
# Ep done
# EP : 339
# LAST 100 RETURNS : -62.252448697313994
# Ep done
# EP : 340
# LAST 100 RETURNS : -62.3013826554896
# Ep done
# EP : 341
# LAST 100 RETURNS : -62.25149925544399
# Ep done
# EP : 342
# LAST 100 RETURNS : -62.2005995772907
# Ep done
# EP : 343
# LAST 100 RETURNS : -62.27195331162134
# Ep done
# EP : 344
# LAST 100 RETURNS : -62.32401590289595
# Ep done
# EP : 345
# LAST 100 RETURNS : -62.21490664317497
# Ep done
# EP : 346
# LAST 100 RETURNS : -62.21711713550481
# Ep done
# EP : 347
# LAST 100 RETURNS : -62.08702399745061
# Ep done
# EP : 348
# LAST 100 RETURNS : -62.10336571579709
# Ep done
# EP : 349
# LAST 100 RETURNS : -61.908187298776106
# Ep done
# EP : 350
# LAST 100 RETURNS : -62.00542765894932
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 351
# LAST 100 RETURNS : -62.0179169940737
# Ep done
# EP : 352
# LAST 100 RETURNS : -61.971481634007276
# Ep done
# EP : 353
# LAST 100 RETURNS : -62.03099681768956
# Ep done
# EP : 354
# LAST 100 RETURNS : -62.00474037052385
# Ep done
# EP : 355
# LAST 100 RETURNS : -62.01352995320092
# Ep done
# EP : 356
# LAST 100 RETURNS : -62.09471295419456
# Ep done
# EP : 357
# LAST 100 RETURNS : -62.07944367586088
# Ep done
# EP : 358
# LAST 100 RETURNS : -62.047438867067314
# Ep done
# EP : 359
# LAST 100 RETURNS : -61.9674897410101
# Ep done
# EP : 360
# LAST 100 RETURNS : -62.14986317257007
# Ep done
# EP : 361
# LAST 100 RETURNS : -62.12612604535099
# Ep done
# EP : 362
# LAST 100 RETURNS : -62.038347191990844
# Ep done
# EP : 363
# LAST 100 RETURNS : -61.94001510950417
# Ep done
# EP : 364
# LAST 100 RETURNS : -61.94082552603366
# Ep done
# EP : 365
# LAST 100 RETURNS : -61.96289995265354
# Ep done
# EP : 366
# LAST 100 RETURNS : -62.00692412944568
# Ep done
# EP : 367
# LAST 100 RETURNS : -62.113879467668546
# Ep done
# EP : 368
# LAST 100 RETURNS : -61.97584679621984
# Ep done
# EP : 369
# LAST 100 RETURNS : -61.94216566960333
# Ep done
# EP : 370
# LAST 100 RETURNS : -61.968838272575184
# Ep done
# EP : 371
# LAST 100 RETURNS : -61.99263615253904
# Ep done
# EP : 372
# LAST 100 RETURNS : -62.01215901079886
# Ep done
# EP : 373
# LAST 100 RETURNS : -61.9595341533662
# Ep done
# EP : 374
# LAST 100 RETURNS : -61.90745795102278
# Ep done
# EP : 375
# LAST 100 RETURNS : -61.951605797042824
# Ep done
# EP : 376
# LAST 100 RETURNS : -62.025162522179635
# Ep done
# EP : 377
# LAST 100 RETURNS : -61.915960567263866
# Ep done
# EP : 378
# LAST 100 RETURNS : -61.92675913749711
# Ep done
# EP : 379
# LAST 100 RETURNS : -61.92880558722604
# Ep done
# EP : 380
# LAST 100 RETURNS : -61.91251773474078
# Ep done
# EP : 381
# LAST 100 RETURNS : -61.92208405900647
# Ep done
# EP : 382
# LAST 100 RETURNS : -61.835927479203235
# Ep done
# EP : 383
# LAST 100 RETURNS : -61.95497554039345
# Ep done
# EP : 384
# LAST 100 RETURNS : -62.01503880665138
# Ep done
# EP : 385
# LAST 100 RETURNS : -62.039330271640964
# Ep done
# EP : 386
# LAST 100 RETURNS : -62.28603068248051
# Ep done
# EP : 387
# LAST 100 RETURNS : -62.12177564755931
# Ep done
# EP : 388
# LAST 100 RETURNS : -62.06572956905351
# Ep done
# EP : 389
# LAST 100 RETURNS : -61.99397050778279
# Ep done
# EP : 390
# LAST 100 RETURNS : -61.98479844367119
# Ep done
# EP : 391
# LAST 100 RETURNS : -61.952407733995194
# Ep done
# EP : 392
# LAST 100 RETURNS : -62.1105671776886
# Ep done
# EP : 393
# LAST 100 RETURNS : -62.309835854659056
# Ep done
# EP : 394
# LAST 100 RETURNS : -62.42441411281959
# Ep done
# EP : 395
# LAST 100 RETURNS : -62.59715588658649
# Ep done
# EP : 396
# LAST 100 RETURNS : -62.64030531203469
# Ep done
# EP : 397
# LAST 100 RETURNS : -62.69180578064775
# Ep done
# EP : 398
# LAST 100 RETURNS : -62.63977114045413
# Ep done
# EP : 399
# LAST 100 RETURNS : -62.778200193352966
# Ep done
# EP : 400
# LAST 100 RETURNS : -62.83600104648896
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 401
# LAST 100 RETURNS : -62.92451465089467
# Ep done
# EP : 402
# LAST 100 RETURNS : -63.01692177786864
# Ep done
# EP : 403
# LAST 100 RETURNS : -63.12355438798345
# Ep done
# EP : 404
# LAST 100 RETURNS : -63.16938157805371
# Ep done
# EP : 405
# LAST 100 RETURNS : -63.11244769810979
# Ep done
# EP : 406
# LAST 100 RETURNS : -63.0282877329531
# Ep done
# EP : 407
# LAST 100 RETURNS : -63.05194798517757
# Ep done
# EP : 408
# LAST 100 RETURNS : -62.91778144187838
# Ep done
# EP : 409
# LAST 100 RETURNS : -63.00093948721454
# Ep done
# EP : 410
# LAST 100 RETURNS : -63.04736571642324
# Ep done
# EP : 411
# LAST 100 RETURNS : -63.058628475437466
# Ep done
# EP : 412
# LAST 100 RETURNS : -63.17311334543172
# Ep done
# EP : 413
# LAST 100 RETURNS : -63.45224778412171
# Ep done
# EP : 414
# LAST 100 RETURNS : -63.47109843455228
# Ep done
# EP : 415
# LAST 100 RETURNS : -63.49291265075849
# Ep done
# EP : 416
# LAST 100 RETURNS : -63.56200585159274
# Ep done
# EP : 417
# LAST 100 RETURNS : -63.533910194593716
# Ep done
# EP : 418
# LAST 100 RETURNS : -63.52504778583503
# Ep done
# EP : 419
# LAST 100 RETURNS : -63.68306531885999
# Ep done
# EP : 420
# LAST 100 RETURNS : -63.74093431226525
# Ep done
# EP : 421
# LAST 100 RETURNS : -63.80459593972403
# Ep done
# EP : 422
# LAST 100 RETURNS : -63.76170413978075
# Ep done
# EP : 423
# LAST 100 RETURNS : -63.75757061882721
# Ep done
# EP : 424
# LAST 100 RETURNS : -63.71944354033843
# Ep done
# EP : 425
# LAST 100 RETURNS : -63.62531412119308
# Ep done
# EP : 426
# LAST 100 RETURNS : -63.58652646235013
# Ep done
# EP : 427
# LAST 100 RETURNS : -63.53710059626612
# Ep done
# EP : 428
# LAST 100 RETURNS : -63.442189120057726
# Ep done
# EP : 429
# LAST 100 RETURNS : -63.3518325849897
# Ep done
# EP : 430
# LAST 100 RETURNS : -63.3313026356913
# Ep done
# EP : 431
# LAST 100 RETURNS : -63.25624166230477
# Ep done
# EP : 432
# LAST 100 RETURNS : -63.19496310396587
# Ep done
# EP : 433
# LAST 100 RETURNS : -63.22038944823582
# Ep done
# EP : 434
# LAST 100 RETURNS : -63.22905852321664
# Ep done
# EP : 435
# LAST 100 RETURNS : -63.26362220701987
# Ep done
# EP : 436
# LAST 100 RETURNS : -63.201248971341045
# Ep done
# EP : 437
# LAST 100 RETURNS : -63.16183455277744
# Ep done
# EP : 438
# LAST 100 RETURNS : -63.16394163260507
# Ep done
# EP : 439
# LAST 100 RETURNS : -63.08386422557355
# Ep done
# EP : 440
# LAST 100 RETURNS : -62.95381759802081
# Ep done
# EP : 441
# LAST 100 RETURNS : -62.75924843003044
# Ep done
# EP : 442
# LAST 100 RETURNS : -62.64767427819974
# Ep done
# EP : 443
# LAST 100 RETURNS : -62.38276428649358
# Ep done
# EP : 444
# LAST 100 RETURNS : -62.23532162463158
# Ep done
# EP : 445
# LAST 100 RETURNS : -62.154034235500866
# Ep done
# EP : 446
# LAST 100 RETURNS : -62.141735392375026
# Ep done
# EP : 447
# LAST 100 RETURNS : -62.1483240956586
# Ep done
# EP : 448
# LAST 100 RETURNS : -62.1723398004459
# Ep done
# EP : 449
# LAST 100 RETURNS : -62.15863853082185
# Ep done
# EP : 450
# LAST 100 RETURNS : -62.17258277229984
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 451
# LAST 100 RETURNS : -62.04894554618473
# Ep done
# EP : 452
# LAST 100 RETURNS : -61.82023362017874
# Ep done
# EP : 453
# LAST 100 RETURNS : -61.69093137416253
# Ep done
# EP : 454
# LAST 100 RETURNS : -61.641465786167494
# Ep done
# EP : 455
# LAST 100 RETURNS : -61.58760585645584
# Ep done
# EP : 456
# LAST 100 RETURNS : -61.38541410896546
# Ep done
# EP : 457
# LAST 100 RETURNS : -61.43917557417013
# Ep done
# EP : 458
# LAST 100 RETURNS : -61.61515672409891
# Ep done
# EP : 459
# LAST 100 RETURNS : -61.580891411015365
# Ep done
# EP : 460
# LAST 100 RETURNS : -61.61973010669915
# Ep done
# EP : 461
# LAST 100 RETURNS : -61.48453017875212
# Ep done
# EP : 462
# LAST 100 RETURNS : -61.34396784689967
# Ep done
# EP : 463
# LAST 100 RETURNS : -61.42322604987527
# Ep done
# EP : 464
# LAST 100 RETURNS : -61.27410813366755
# Ep done
# EP : 465
# LAST 100 RETURNS : -61.25313919988316
# Ep done
# EP : 466
# LAST 100 RETURNS : -61.17552514506918
# Ep done
# EP : 467
# LAST 100 RETURNS : -61.06987231384808
# Ep done
# EP : 468
# LAST 100 RETURNS : -61.06499275295687
# Ep done
# EP : 469
# LAST 100 RETURNS : -61.06836986747331
# Ep done
# EP : 470
# LAST 100 RETURNS : -61.055549728957004
# Ep done
# EP : 471
# LAST 100 RETURNS : -60.9537376590339
# Ep done
# EP : 472
# LAST 100 RETURNS : -60.808462152295824
# Ep done
# EP : 473
# LAST 100 RETURNS : -60.74849770774949
# Ep done
# EP : 474
# LAST 100 RETURNS : -60.609594778262256
# Ep done
# EP : 475
# LAST 100 RETURNS : -60.55383938702073
# Ep done
# EP : 476
# LAST 100 RETURNS : -60.444890588805244
# Ep done
# EP : 477
# LAST 100 RETURNS : -60.39960401701895
# Ep done
# EP : 478
# LAST 100 RETURNS : -60.2565261408482
# Ep done
# EP : 479
# LAST 100 RETURNS : -60.20420108904002
# Ep done
# EP : 480
# LAST 100 RETURNS : -60.146695142600144
# Ep done
# EP : 481
# LAST 100 RETURNS : -60.09281623587106
# Ep done
# EP : 482
# LAST 100 RETURNS : -59.92417500082707
# Ep done
# EP : 483
# LAST 100 RETURNS : -59.92176853484785
# Ep done
# EP : 484
# LAST 100 RETURNS : -59.733721941138924
# Ep done
# EP : 485
# LAST 100 RETURNS : -59.7318520968121
# Ep done
# EP : 486
# LAST 100 RETURNS : -59.61265899194395
# Ep done
# EP : 487
# LAST 100 RETURNS : -59.41839758012604
# Ep done
# EP : 488
# LAST 100 RETURNS : -59.44049879130189
# Ep done
# EP : 489
# LAST 100 RETURNS : -59.27422020626575
# Ep done
# EP : 490
# LAST 100 RETURNS : -59.29329220507756
# Ep done
# EP : 491
# LAST 100 RETURNS : -59.152970121625664
# Ep done
# EP : 492
# LAST 100 RETURNS : -59.156708246341275
# Ep done
# EP : 493
# LAST 100 RETURNS : -59.09295497963619
# Ep done
# EP : 494
# LAST 100 RETURNS : -58.8127763827245
# Ep done
# EP : 495
# LAST 100 RETURNS : -58.800270750667146
# Ep done
# EP : 496
# LAST 100 RETURNS : -58.73766768710293
# Ep done
# EP : 497
# LAST 100 RETURNS : -58.556863089760206
# Ep done
# EP : 498
# LAST 100 RETURNS : -58.59880163997647
# Ep done
# EP : 499
# LAST 100 RETURNS : -58.55979506235889
# Ep done
# EP : 500
# LAST 100 RETURNS : -58.464088900401286
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 501
# LAST 100 RETURNS : -58.29460900506761
# Ep done
# EP : 502
# LAST 100 RETURNS : -58.20402745705434
# Ep done
# EP : 503
# LAST 100 RETURNS : -57.99485033215274
# Ep done
# EP : 504
# LAST 100 RETURNS : -57.87689205380754
# Ep done
# EP : 505
# LAST 100 RETURNS : -57.65589030520992
# Ep done
# EP : 506
# LAST 100 RETURNS : -57.6266386726458
# Ep done
# EP : 507
# LAST 100 RETURNS : -57.45027482783661
# Ep done
# EP : 508
# LAST 100 RETURNS : -57.18512810738535
# Ep done
# EP : 509
# LAST 100 RETURNS : -57.19851390714234
# Ep done
# EP : 510
# LAST 100 RETURNS : -57.19611667117322
# Ep done
# EP : 511
# LAST 100 RETURNS : -57.224603301904224
# Ep done
# EP : 512
# LAST 100 RETURNS : -57.211904076184915
# Ep done
# EP : 513
# LAST 100 RETURNS : -57.00814005825745
# Ep done
# EP : 514
# LAST 100 RETURNS : -57.01350104934305
# Ep done
# EP : 515
# LAST 100 RETURNS : -56.93354435688339
# Ep done
# EP : 516
# LAST 100 RETURNS : -56.90129318844896
# Ep done
# EP : 517
# LAST 100 RETURNS : -57.00197223596381
# Ep done
# EP : 518
# LAST 100 RETURNS : -56.98785187249376
# Ep done
# EP : 519
# LAST 100 RETURNS : -56.82783713248212
# Ep done
# EP : 520
# LAST 100 RETURNS : -56.768758529952855
# Ep done
# EP : 521
# LAST 100 RETURNS : -56.75264903923342
# Ep done
# EP : 522
# LAST 100 RETURNS : -56.68930451777729
# Ep done
# EP : 523
# LAST 100 RETURNS : -56.710189130217934
# Ep done
# EP : 524
# LAST 100 RETURNS : -56.562706120830555
# Ep done
# EP : 525
# LAST 100 RETURNS : -56.51909884459069
# Ep done
# EP : 526
# LAST 100 RETURNS : -56.56947722417092
# Ep done
# EP : 527
# LAST 100 RETURNS : -56.52739520141962
# Ep done
# EP : 528
# LAST 100 RETURNS : -56.59897164010622
# Ep done
# EP : 529
# LAST 100 RETURNS : -56.631398989686915
# Ep done
# EP : 530
# LAST 100 RETURNS : -56.7106242716046
# Ep done
# EP : 531
# LAST 100 RETURNS : -56.634946219828166
# Ep done
# EP : 532
# LAST 100 RETURNS : -56.649450376397056
# Ep done
# EP : 533
# LAST 100 RETURNS : -56.630606235845676
# Ep done
# EP : 534
# LAST 100 RETURNS : -56.40151731744872
# Ep done
# EP : 535
# LAST 100 RETURNS : -56.249749116142084
# Ep done
# EP : 536
# LAST 100 RETURNS : -56.13701891015904
# Ep done
# EP : 537
# LAST 100 RETURNS : -56.223304251966184
# Ep done
# EP : 538
# LAST 100 RETURNS : -56.28119830657686
# Ep done
# EP : 539
# LAST 100 RETURNS : -56.39166396178707
# Ep done
# EP : 540
# LAST 100 RETURNS : -56.30400768667839
# Ep done
# EP : 541
# LAST 100 RETURNS : -56.523125056044556
# Ep done
# EP : 542
# LAST 100 RETURNS : -56.70609891525739
# Ep done
# EP : 543
# LAST 100 RETURNS : -56.73402133291528
# Ep done
# EP : 544
# LAST 100 RETURNS : -56.94547521938012
# Ep done
# EP : 545
# LAST 100 RETURNS : -56.93443299966932
# Ep done
# EP : 546
# LAST 100 RETURNS : -56.921704479775656
# Ep done
# EP : 547
# LAST 100 RETURNS : -56.95020741831198
# Ep done
# EP : 548
# LAST 100 RETURNS : -56.85908465132067
# Ep done
# EP : 549
# LAST 100 RETURNS : -56.885723839242715
# Ep done
# EP : 550
# LAST 100 RETURNS : -56.90373503520186
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.61376287441367---
#
#
#
# EP : 551
# LAST 100 RETURNS : -56.808325881740856
# Ep done
# EP : 552
# LAST 100 RETURNS : -56.87531551826762
# Ep done
# EP : 553
# LAST 100 RETURNS : -57.04125258018889
# Ep done
# EP : 554
# LAST 100 RETURNS : -57.15664759676418
# Ep done
# EP : 555
# LAST 100 RETURNS : -56.949247871984234
# Ep done
# EP : 556
# LAST 100 RETURNS : -56.78278771419917
# Ep done
# EP : 557
# LAST 100 RETURNS : -57.03164763329501
# Ep done
# EP : 558
# LAST 100 RETURNS : -57.06273717319336
# Ep done
# EP : 559
# LAST 100 RETURNS : -56.946053310095515
# Ep done
# EP : 560
# LAST 100 RETURNS : -56.91830719153616
# Ep done
# EP : 561
# LAST 100 RETURNS : -56.84242488056602
# Ep done
# EP : 562
# LAST 100 RETURNS : -56.82154610746552
# Ep done
# EP : 563
# LAST 100 RETURNS : -56.939654219832555
# Ep done
# EP : 564
# LAST 100 RETURNS : -56.889584013464976
# Ep done
# EP : 565
# LAST 100 RETURNS : -56.800336253846744
# Ep done
# EP : 566
# LAST 100 RETURNS : -56.906184749040726
# Ep done
# EP : 567
# LAST 100 RETURNS : -56.92306588225598
# Ep done
# EP : 568
# LAST 100 RETURNS : -56.88127542993264
# Ep done
# EP : 569
# LAST 100 RETURNS : -56.80201921348907
# Ep done
# EP : 570
# LAST 100 RETURNS : -56.87369961554782
# Ep done
# EP : 571
# LAST 100 RETURNS : -56.68155793015193
# Ep done
# EP : 572
# LAST 100 RETURNS : -56.59823067637424
# Ep done
# EP : 573
# LAST 100 RETURNS : -56.67506531985827
# Ep done
# EP : 574
# LAST 100 RETURNS : -56.76342623990904
# Ep done
# EP : 575
# LAST 100 RETURNS : -56.62880051090781
# Ep done
# EP : 576
# LAST 100 RETURNS : -56.755913457166294
# Ep done
# EP : 577
# LAST 100 RETURNS : -56.54337519202906
# Ep done
# EP : 578
# LAST 100 RETURNS : -56.53061845120639
# Ep done
# EP : 579
# LAST 100 RETURNS : -56.690870231080254
# Ep done
# EP : 580
# LAST 100 RETURNS : -56.60581483494817
# Ep done
# EP : 581
# LAST 100 RETURNS : -56.60997884482261
# Ep done
# EP : 582
# LAST 100 RETURNS : -56.399952062896105
# Ep done
# EP : 583
# LAST 100 RETURNS : -56.36852234357168
# Ep done
# EP : 584
# LAST 100 RETURNS : -56.4244945513761
# Ep done
# EP : 585
# LAST 100 RETURNS : -56.7449599974299
# Ep done
# EP : 586
# LAST 100 RETURNS : -56.57947030320972
# Ep done
# EP : 587
# LAST 100 RETURNS : -56.73660422429877
# Ep done
# EP : 588
# LAST 100 RETURNS : -56.83945337116515
# Ep done
# EP : 589
# LAST 100 RETURNS : -56.98717960929026
# Ep done
# EP : 590
# LAST 100 RETURNS : -57.07684981502364
# Ep done
# EP : 591
# LAST 100 RETURNS : -56.88822177337533
# Ep done
# EP : 592
# LAST 100 RETURNS : -56.90610588167466
# Ep done
# EP : 593
# LAST 100 RETURNS : -56.71525269130362
# Ep done
# EP : 594
# LAST 100 RETURNS : -56.66803409532768
# Ep done
# EP : 595
# LAST 100 RETURNS : -56.72077390634364
# Ep done
# EP : 596
# LAST 100 RETURNS : -56.74910313485568
# Ep done
# EP : 597
# LAST 100 RETURNS : -56.595855687547925
# Ep done
# EP : 598
# LAST 100 RETURNS : -56.6810859459298
# Ep done
# EP : 599
# LAST 100 RETURNS : -56.57120800234459
# Ep done
# EP : 600
# LAST 100 RETURNS : -56.440168725576406
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -35.47066903963386---
#
#
#
# EP : 601
# LAST 100 RETURNS : -56.53825445974525
# Ep done
# EP : 602
# LAST 100 RETURNS : -56.6475632019774
# Ep done
# EP : 603
# LAST 100 RETURNS : -56.768376949153655
# Ep done
# EP : 604
# LAST 100 RETURNS : -56.882190718739594
# Ep done
# EP : 605
# LAST 100 RETURNS : -56.83804287725083
# Ep done
# EP : 606
# LAST 100 RETURNS : -57.077834765782015
# Ep done
# EP : 607
# LAST 100 RETURNS : -57.061216312216665
# Ep done
# EP : 608
# LAST 100 RETURNS : -57.31299787999038
# Ep done
# EP : 609
# LAST 100 RETURNS : -57.4958099286556
# Ep done
# EP : 610
# LAST 100 RETURNS : -57.40221682331022
# Ep done
# EP : 611
# LAST 100 RETURNS : -57.324968721877674
# Ep done
# EP : 612
# LAST 100 RETURNS : -57.20449075758443
# Ep done
# EP : 613
# LAST 100 RETURNS : -57.21289566397633
# Ep done
# EP : 614
# LAST 100 RETURNS : -57.2815802639924
# Ep done
# EP : 615
# LAST 100 RETURNS : -57.25321068610032
# Ep done
# EP : 616
# LAST 100 RETURNS : -57.19591850696057
# Ep done
# EP : 617
# LAST 100 RETURNS : -56.94449769047363
# Ep done
# EP : 618
# LAST 100 RETURNS : -56.79643625572396
# Ep done
# EP : 619
# LAST 100 RETURNS : -56.78865155914278
# Ep done
# EP : 620
# LAST 100 RETURNS : -56.851437474047316
# Ep done
# EP : 621
# LAST 100 RETURNS : -56.732622223235595
# Ep done
# EP : 622
# LAST 100 RETURNS : -56.7099369964783
# Ep done
# EP : 623
# LAST 100 RETURNS : -56.68083574084074
# Ep done
# EP : 624
# LAST 100 RETURNS : -56.65907560925439
# Ep done
# EP : 625
# LAST 100 RETURNS : -56.69817357596692
# Ep done
# EP : 626
# LAST 100 RETURNS : -56.73383507556012
# Ep done
# EP : 627
# LAST 100 RETURNS : -56.73110524322678
# Ep done
# EP : 628
# LAST 100 RETURNS : -56.55597789206786
# Ep done
# EP : 629
# LAST 100 RETURNS : -56.45931065468024
# Ep done
# EP : 630
# LAST 100 RETURNS : -56.41131256670405
# Ep done
# EP : 631
# LAST 100 RETURNS : -56.484651996685514
# Ep done
# EP : 632
# LAST 100 RETURNS : -56.639219424798895
# Ep done
# EP : 633
# LAST 100 RETURNS : -56.512985949922545
# Ep done
# EP : 634
# LAST 100 RETURNS : -56.45879193189177
# Ep done
# EP : 635
# LAST 100 RETURNS : -56.62990379178103
# Ep done
# EP : 636
# LAST 100 RETURNS : -56.711938483041656
# Ep done
# EP : 637
# LAST 100 RETURNS : -56.899886439476234
# Ep done
# EP : 638
# LAST 100 RETURNS : -56.7823718977346
# Ep done
# EP : 639
# LAST 100 RETURNS : -56.61832688157927
# Ep done
# EP : 640
# LAST 100 RETURNS : -56.576492908707365
# Ep done
# EP : 641
# LAST 100 RETURNS : -56.60078850138746
# Ep done
# EP : 642
# LAST 100 RETURNS : -56.551598524204294
# Ep done
# EP : 643
# LAST 100 RETURNS : -56.58309664576725
# Ep done
# EP : 644
# LAST 100 RETURNS : -56.52400844917835
# Ep done
# EP : 645
# LAST 100 RETURNS : -56.6588142818336
# Ep done
# EP : 646
# LAST 100 RETURNS : -56.70427233706938
# Ep done
# EP : 647
# LAST 100 RETURNS : -56.62365724684028
# Ep done
# EP : 648
# LAST 100 RETURNS : -56.67016067993576
# Ep done
# EP : 649
# LAST 100 RETURNS : -56.872393664465434
# Ep done
# EP : 650
# LAST 100 RETURNS : -56.922102592088564
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -31.025669200428485---
#
#
#
# EP : 651
# LAST 100 RETURNS : -56.89672804389301
# Ep done
# EP : 652
# LAST 100 RETURNS : -57.12372046116037
# Ep done
# EP : 653
# LAST 100 RETURNS : -57.044277084633826
# Ep done
# EP : 654
# LAST 100 RETURNS : -57.01904235864314
# Ep done
# EP : 655
# LAST 100 RETURNS : -56.891981716710355
# Ep done
# EP : 656
# LAST 100 RETURNS : -57.06195454433975
# Ep done
# EP : 657
# LAST 100 RETURNS : -57.1727599713973
# Ep done
# EP : 658
# LAST 100 RETURNS : -57.04007627048834
# Ep done
# EP : 659
# LAST 100 RETURNS : -56.951227418790566
# Ep done
# EP : 660
# LAST 100 RETURNS : -56.89291099615254
# Ep done
# EP : 661
# LAST 100 RETURNS : -56.84529287956098
# Ep done
# EP : 662
# LAST 100 RETURNS : -56.68150773209771
# Ep done
# EP : 663
# LAST 100 RETURNS : -56.75654593142113
# Ep done
# EP : 664
# LAST 100 RETURNS : -56.620754073861264
# Ep done
# EP : 665
# LAST 100 RETURNS : -56.612640005506336
# Ep done
# EP : 666
# LAST 100 RETURNS : -56.792154114356855
# Ep done
# EP : 667
# LAST 100 RETURNS : -56.62943036198578
# Ep done
# EP : 668
# LAST 100 RETURNS : -56.66339340999303
# Ep done
# EP : 669
# LAST 100 RETURNS : -56.69178494084847
# Ep done
# EP : 670
# LAST 100 RETURNS : -56.766598697222506
# Ep done
# EP : 671
# LAST 100 RETURNS : -56.62293049058938
# Ep done
# EP : 672
# LAST 100 RETURNS : -56.76701288331721
# Ep done
# EP : 673
# LAST 100 RETURNS : -56.88663743785034
# Ep done
# EP : 674
# LAST 100 RETURNS : -56.87403790784922
# Ep done
# EP : 675
# LAST 100 RETURNS : -56.74701494895337
# Ep done
# EP : 676
# LAST 100 RETURNS : -56.95536220638381
# Ep done
# EP : 677
# LAST 100 RETURNS : -56.76579897987994
# Ep done
# EP : 678
# LAST 100 RETURNS : -57.014834104104885
# Ep done
# EP : 679
# LAST 100 RETURNS : -56.96909174438295
# Ep done
# EP : 680
# LAST 100 RETURNS : -56.82260623168462
# Ep done
# EP : 681
# LAST 100 RETURNS : -56.83733037837485
# Ep done
# EP : 682
# LAST 100 RETURNS : -56.83573485801277
# Ep done
# EP : 683
# LAST 100 RETURNS : -57.07334674384311
# Ep done
# EP : 684
# LAST 100 RETURNS : -57.17905370752902
# Ep done
# EP : 685
# LAST 100 RETURNS : -57.221329074847716
# Ep done
# EP : 686
# LAST 100 RETURNS : -57.12530682343116
# Ep done
# EP : 687
# LAST 100 RETURNS : -57.219511177546494
# Ep done
# EP : 688
# LAST 100 RETURNS : -57.17934795345909
# Ep done
# EP : 689
# LAST 100 RETURNS : -57.18991522348498
# Ep done
# EP : 690
# LAST 100 RETURNS : -57.141473703687126
# Ep done
# EP : 691
# LAST 100 RETURNS : -57.30385692810379
# Ep done
# EP : 692
# LAST 100 RETURNS : -57.38388701583051
# Ep done
# EP : 693
# LAST 100 RETURNS : -57.44901354604998
# Ep done
# EP : 694
# LAST 100 RETURNS : -57.519671957410914
# Ep done
# EP : 695
# LAST 100 RETURNS : -57.58253499377818
# Ep done
# EP : 696
# LAST 100 RETURNS : -57.594615061902815
# Ep done
# EP : 697
# LAST 100 RETURNS : -57.58629262115462
# Ep done
# EP : 698
# LAST 100 RETURNS : -57.658164223299885
# Ep done
# EP : 699
# LAST 100 RETURNS : -57.49845735506299
# Ep done
# EP : 700
# LAST 100 RETURNS : -57.641433540192985
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -31.025669200428485---
#
#
#
# EP : 701
# LAST 100 RETURNS : -57.77927983744901
# Ep done
# EP : 702
# LAST 100 RETURNS : -57.78367243794091
# Ep done
# EP : 703
# LAST 100 RETURNS : -57.75138020180037
# Ep done
# EP : 704
# LAST 100 RETURNS : -57.53015762210441
# Ep done
# EP : 705
# LAST 100 RETURNS : -57.529494689303434
# Ep done
# EP : 706
# LAST 100 RETURNS : -57.59253507206863
# Ep done
# EP : 707
# LAST 100 RETURNS : -57.544200618923114
# Ep done
# EP : 708
# LAST 100 RETURNS : -57.59602221458554
# Ep done
# EP : 709
# LAST 100 RETURNS : -57.513640489381324
# Ep done
# EP : 710
# LAST 100 RETURNS : -57.44315789269765
# Ep done
# EP : 711
# LAST 100 RETURNS : -57.65671564352426
# Ep done
# EP : 712
# LAST 100 RETURNS : -57.720191846149675
# Ep done
# EP : 713
# LAST 100 RETURNS : -57.73428855111635
# Ep done
# EP : 714
# LAST 100 RETURNS : -57.69226000476327
# Ep done
# EP : 715
# LAST 100 RETURNS : -57.6531455469127
# Ep done
# EP : 716
# LAST 100 RETURNS : -57.47976495295198
# Ep done
# EP : 717
# LAST 100 RETURNS : -57.424969139176106
# Ep done
# EP : 718
# LAST 100 RETURNS : -57.73129791992353
# Ep done
# EP : 719
# LAST 100 RETURNS : -57.771130950150166
# Ep done
# EP : 720
# LAST 100 RETURNS : -57.66453722342827
# Ep done
# EP : 721
# LAST 100 RETURNS : -57.67535007352537
# Ep done
# EP : 722
# LAST 100 RETURNS : -57.703075008506566
# Ep done
# EP : 723
# LAST 100 RETURNS : -57.61713409962193
# Ep done
# EP : 724
# LAST 100 RETURNS : -57.686868052354534
# Ep done
# EP : 725
# LAST 100 RETURNS : -57.67518637425082
# Ep done
# EP : 726
# LAST 100 RETURNS : -57.72355778313592
# Ep done
# EP : 727
# LAST 100 RETURNS : -57.48273691466894
# Ep done
# EP : 728
# LAST 100 RETURNS : -57.24216146072719
# Ep done
# EP : 729
# LAST 100 RETURNS : -57.47003936298377
# Ep done
# EP : 730
# LAST 100 RETURNS : -57.439723732486485
# Ep done
# EP : 731
# LAST 100 RETURNS : -57.518269274132656
# Ep done
# EP : 732
# LAST 100 RETURNS : -57.2689659977035
# Ep done
# EP : 733
# LAST 100 RETURNS : -56.88156495621993
# Ep done
# EP : 734
# LAST 100 RETURNS : -56.9846881775733
# Ep done
# EP : 735
# LAST 100 RETURNS : -57.14843641216736
# Ep done
# EP : 736
# LAST 100 RETURNS : -57.19796239758047
# Ep done
# EP : 737
# LAST 100 RETURNS : -57.20923283458169
# Ep done
# EP : 738
# LAST 100 RETURNS : -57.12987405202629
# Ep done
# EP : 739
# LAST 100 RETURNS : -57.03773950729394
# Ep done
# EP : 740
# LAST 100 RETURNS : -57.2438361220697
# Ep done
# EP : 741
# LAST 100 RETURNS : -57.190570633560974
# Ep done
# EP : 742
# LAST 100 RETURNS : -57.379056286166744
# Ep done
# EP : 743
# LAST 100 RETURNS : -57.184424018251
# Ep done
# EP : 744
# LAST 100 RETURNS : -56.95129905710693
# Ep done
# EP : 745
# LAST 100 RETURNS : -57.0809051497658
# Ep done
# EP : 746
# LAST 100 RETURNS : -56.76807565121356
# Ep done
# EP : 747
# LAST 100 RETURNS : -56.712793744262584
# Ep done
# EP : 748
# LAST 100 RETURNS : -56.86112046129518
# Ep done
# EP : 749
# LAST 100 RETURNS : -56.806085679598816
# Ep done
# EP : 750
# LAST 100 RETURNS : -56.69233541737665
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -30.480256129577597---
#
#
#
# EP : 751
# LAST 100 RETURNS : -56.55737775089401
# Ep done
# EP : 752
# LAST 100 RETURNS : -56.62685314686318
# Ep done
# EP : 753
# LAST 100 RETURNS : -56.54547030214488
# Ep done
# EP : 754
# LAST 100 RETURNS : -56.56924262582453
# Ep done
# EP : 755
# LAST 100 RETURNS : -56.60348064447818
# Ep done
# EP : 756
# LAST 100 RETURNS : -56.49221194342424
# Ep done
# EP : 757
# LAST 100 RETURNS : -56.44467214049979
# Ep done
# EP : 758
# LAST 100 RETURNS : -56.491753287466146
# Ep done
# EP : 759
# LAST 100 RETURNS : -56.50660710530338
# Ep done
# EP : 760
# LAST 100 RETURNS : -56.37586323273913
# Ep done
# EP : 761
# LAST 100 RETURNS : -56.45424075264099
# Ep done
# EP : 762
# LAST 100 RETURNS : -56.399256348483746
# Ep done
# EP : 763
# LAST 100 RETURNS : -56.584462253203654
# Ep done
# EP : 764
# LAST 100 RETURNS : -56.42965943697618
# Ep done
# EP : 765
# LAST 100 RETURNS : -56.35457283220631
# Ep done
# EP : 766
# LAST 100 RETURNS : -56.382183432170436
# Ep done
# EP : 767
# LAST 100 RETURNS : -56.4693794646393
# Ep done
# EP : 768
# LAST 100 RETURNS : -56.42491289513967
# Ep done
# EP : 769
# LAST 100 RETURNS : -56.39281467867148
# Ep done
# EP : 770
# LAST 100 RETURNS : -56.36043694824009
# Ep done
# EP : 771
# LAST 100 RETURNS : -56.29764538450999
# Ep done
# EP : 772
# LAST 100 RETURNS : -56.44876877334012
# Ep done
# EP : 773
# LAST 100 RETURNS : -56.43309728047351
# Ep done
# EP : 774
# LAST 100 RETURNS : -56.49447376284445
# Ep done
# EP : 775
# LAST 100 RETURNS : -56.306646907538656
# Ep done
# EP : 776
# LAST 100 RETURNS : -56.31704844748703
# Ep done
# EP : 777
# LAST 100 RETURNS : -56.41475105072793
# Ep done
# EP : 778
# LAST 100 RETURNS : -56.43044143298353
# Ep done
# EP : 779
# LAST 100 RETURNS : -56.20947661003285
# Ep done
# EP : 780
# LAST 100 RETURNS : -56.38159595751342
# Ep done
# EP : 781
# LAST 100 RETURNS : -56.52814694414693
# Ep done
# EP : 782
# LAST 100 RETURNS : -56.80305187484478
# Ep done
# EP : 783
# LAST 100 RETURNS : -56.834065099506205
# Ep done
# EP : 784
# LAST 100 RETURNS : -56.72550764192174
# Ep done
# EP : 785
# LAST 100 RETURNS : -56.82863970333485
# Ep done
# EP : 786
# LAST 100 RETURNS : -56.80116512170595
# Ep done
# EP : 787
# LAST 100 RETURNS : -56.7814828445524
# Ep done
# EP : 788
# LAST 100 RETURNS : -56.70574947242542
# Ep done
# EP : 789
# LAST 100 RETURNS : -56.62630807273406
# Ep done
# EP : 790
# LAST 100 RETURNS : -56.671240317357785
# Ep done
# EP : 791
# LAST 100 RETURNS : -56.673889964442886
# Ep done
# EP : 792
# LAST 100 RETURNS : -56.63860280619648
# Ep done
# EP : 793
# LAST 100 RETURNS : -56.57313104428986
# Ep done
# EP : 794
# LAST 100 RETURNS : -56.664657361931546
# Ep done
# EP : 795
# LAST 100 RETURNS : -56.69315046083057
# Ep done
# EP : 796
# LAST 100 RETURNS : -56.745331637470706
# Ep done
# EP : 797
# LAST 100 RETURNS : -56.73875231128486
# Ep done
# EP : 798
# LAST 100 RETURNS : -56.59958375255239
# Ep done
# EP : 799
# LAST 100 RETURNS : -56.63342368137475
# Ep done
# EP : 800
# LAST 100 RETURNS : -56.78009359206385
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -30.480256129577597---
#
#
#
# EP : 801
# LAST 100 RETURNS : -56.657569979225286
# Ep done
# EP : 802
# LAST 100 RETURNS : -56.577744203301464
# Ep done
# EP : 803
# LAST 100 RETURNS : -56.330417826916964
# Ep done
# EP : 804
# LAST 100 RETURNS : -56.34698606289542
# Ep done
# EP : 805
# LAST 100 RETURNS : -56.33495621337932
# Ep done
# EP : 806
# LAST 100 RETURNS : -56.153972202045296
# Ep done
# EP : 807
# LAST 100 RETURNS : -56.0542077026466
# Ep done
# EP : 808
# LAST 100 RETURNS : -56.02229907506933
# Ep done
# EP : 809
# LAST 100 RETURNS : -56.00886467917697
# Ep done
# EP : 810
# LAST 100 RETURNS : -55.83470245532856
# Ep done
# EP : 811
# LAST 100 RETURNS : -55.98910339430634
# Ep done
# EP : 812
# LAST 100 RETURNS : -55.960434354991165
# Ep done
# EP : 813
# LAST 100 RETURNS : -55.86457857378573
# Ep done
# EP : 814
# LAST 100 RETURNS : -55.587217385453634
# Ep done
# EP : 815
# ...
# Ep done
# EP : 1722
# LAST 100 RETURNS : -53.24105246346487
# Ep done
# EP : 1723
# LAST 100 RETURNS : -53.21961029229011
# Ep done
# EP : 1724
# LAST 100 RETURNS : -53.16740629296647
# Ep done
# EP : 1725
# LAST 100 RETURNS : -53.03180207836086
# Ep done
# EP : 1726
# LAST 100 RETURNS : -53.2434097616425
# Ep done
# EP : 1727
# LAST 100 RETURNS : -53.18339782090849
# Ep done
# EP : 1728
# LAST 100 RETURNS : -53.141182628706
# Ep done
# EP : 1729
# LAST 100 RETURNS : -53.22483867063621
# Ep done
# EP : 1730
# LAST 100 RETURNS : -53.019962735338865
# Ep done
# EP : 1731
# LAST 100 RETURNS : -52.81052566824306
# Ep done
# EP : 1732
# LAST 100 RETURNS : -52.8449884266927
# Ep done
# EP : 1733
# LAST 100 RETURNS : -52.7502576039028
# Ep done
# EP : 1734
# LAST 100 RETURNS : -52.681428802469604
# Ep done
# EP : 1735
# LAST 100 RETURNS : -52.61530943336256
# Ep done
# EP : 1736
# LAST 100 RETURNS : -52.53863471659177
# Ep done
# EP : 1737
# LAST 100 RETURNS : -52.50683686917206
# Ep done
# EP : 1738
# LAST 100 RETURNS : -52.61009861464252
# Ep done
# EP : 1739
# LAST 100 RETURNS : -52.51050072642618
# Ep done
# EP : 1740
# LAST 100 RETURNS : -52.63267011983355
# Ep done
# EP : 1741
# LAST 100 RETURNS : -52.523662359269245
# Ep done
# EP : 1742
# LAST 100 RETURNS : -52.55795595659148
# Ep done
# EP : 1743
# LAST 100 RETURNS : -52.48903894159499
# Ep done
# EP : 1744
# LAST 100 RETURNS : -52.424034007486796
# Ep done
# EP : 1745
# LAST 100 RETURNS : -52.465005193465814
# Ep done
# EP : 1746
# LAST 100 RETURNS : -52.31054435214226
# Ep done
# EP : 1747
# LAST 100 RETURNS : -52.36492015379674
# Ep done
# EP : 1748
# LAST 100 RETURNS : -52.2230602409964
# Ep done
# EP : 1749
# LAST 100 RETURNS : -52.11867557718259
# Ep done
# EP : 1750
# LAST 100 RETURNS : -52.218631191910525
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---
#
#
#
# EP : 1751
# LAST 100 RETURNS : -52.29146730692877
# Ep done
# EP : 1752
# LAST 100 RETURNS : -52.40023801947451
# Ep done
# EP : 1753
# LAST 100 RETURNS : -52.49757816924468
# Ep done
# EP : 1754
# LAST 100 RETURNS : -52.5848164111593
# Ep done
# EP : 1755
# LAST 100 RETURNS : -52.1791385476385
# Ep done
# EP : 1756
# LAST 100 RETURNS : -52.21968541315093
# Ep done
# EP : 1757
# LAST 100 RETURNS : -52.12513709221737
# Ep done
# EP : 1758
# LAST 100 RETURNS : -52.09911983998093
# Ep done
# EP : 1759
# LAST 100 RETURNS : -52.109014173721974
# Ep done
# EP : 1760
# LAST 100 RETURNS : -51.9682080040753
# Ep done
# EP : 1761
# LAST 100 RETURNS : -51.636191731840945
# Ep done
# EP : 1762
# LAST 100 RETURNS : -51.85866367021753
# Ep done
# EP : 1763
# LAST 100 RETURNS : -51.75550554544604
# Ep done
# EP : 1764
# LAST 100 RETURNS : -51.62018425924078
# Ep done
# EP : 1765
# LAST 100 RETURNS : -51.60195941716847
# Ep done
# EP : 1766
# LAST 100 RETURNS : -51.59532843662116
# Ep done
# EP : 1767
# LAST 100 RETURNS : -51.36107785711511
# Ep done
# EP : 1768
# LAST 100 RETURNS : -51.46168158461151
# Ep done
# EP : 1769
# LAST 100 RETURNS : -51.31250812545547
# Ep done
# EP : 1770
# LAST 100 RETURNS : -51.228962262773294
# Ep done
# EP : 1771
# LAST 100 RETURNS : -51.20613993349179
# Ep done
# EP : 1772
# LAST 100 RETURNS : -51.25086001739423
# Ep done
# EP : 1773
# LAST 100 RETURNS : -51.10423665796817
# Ep done
# EP : 1774
# LAST 100 RETURNS : -51.075198636972885
# Ep done
# EP : 1775
# LAST 100 RETURNS : -51.29283721995675
# Ep done
# EP : 1776
# LAST 100 RETURNS : -51.28752122874235
# Ep done
# EP : 1777
# LAST 100 RETURNS : -51.66938029708504
# Ep done
# EP : 1778
# LAST 100 RETURNS : -51.745153568172334
# Ep done
# EP : 1779
# LAST 100 RETURNS : -51.791842359753126
# Ep done
# EP : 1780
# LAST 100 RETURNS : -51.85032124419107
# Ep done
# EP : 1781
# LAST 100 RETURNS : -51.95099056524318
# Ep done
# EP : 1782
# LAST 100 RETURNS : -51.86446680620268
# Ep done
# EP : 1783
# LAST 100 RETURNS : -52.09865135725337
# Ep done
# EP : 1784
# LAST 100 RETURNS : -52.0730624501939
# Ep done
# EP : 1785
# LAST 100 RETURNS : -51.968285687189265
# Ep done
# EP : 1786
# LAST 100 RETURNS : -52.12007490346838
# Ep done
# EP : 1787
# LAST 100 RETURNS : -52.12502342807131
# Ep done
# EP : 1788
# LAST 100 RETURNS : -52.10363744302906
# Ep done
# EP : 1789
# LAST 100 RETURNS : -52.26224153481802
# Ep done
# EP : 1790
# LAST 100 RETURNS : -52.31452898164096
# Ep done
# EP : 1791
# LAST 100 RETURNS : -52.233600270284384
# Ep done
# EP : 1792
# LAST 100 RETURNS : -52.14686987108835
# Ep done
# EP : 1793
# LAST 100 RETURNS : -52.126405934991254
# Ep done
# EP : 1794
# LAST 100 RETURNS : -52.11091638233898
# Ep done
# EP : 1795
# LAST 100 RETURNS : -52.07819220797464
# Ep done
# EP : 1796
# LAST 100 RETURNS : -51.92473388326975
# Ep done
# EP : 1797
# LAST 100 RETURNS : -52.17736976314427
# Ep done
# EP : 1798
# LAST 100 RETURNS : -52.10649532366443
# Ep done
# EP : 1799
# LAST 100 RETURNS : -52.34405658234314
# Ep done
# EP : 1800
# LAST 100 RETURNS : -52.35330194393419
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---
#
#
#
# EP : 1801
# LAST 100 RETURNS : -52.39185623212677
# Ep done
# EP : 1802
# LAST 100 RETURNS : -52.399261049803386
# Ep done
# EP : 1803
# LAST 100 RETURNS : -52.493049802882354
# Ep done
# EP : 1804
# LAST 100 RETURNS : -52.606717793128325
# Ep done
# EP : 1805
# LAST 100 RETURNS : -52.801830456128165
# Ep done
# EP : 1806
# LAST 100 RETURNS : -52.827009486621215
# Ep done
# EP : 1807
# LAST 100 RETURNS : -52.89817225012285
# Ep done
# EP : 1808
# LAST 100 RETURNS : -52.99450010575858
# Ep done
# EP : 1809
# LAST 100 RETURNS : -53.028705956492594
# Ep done
# EP : 1810
# LAST 100 RETURNS : -52.87368439533616
# Ep done
# EP : 1811
# LAST 100 RETURNS : -52.96113215133064
# Ep done
# EP : 1812
# LAST 100 RETURNS : -52.84621362357962
# Ep done
# EP : 1813
# LAST 100 RETURNS : -52.941737025093275
# Ep done
# EP : 1814
# LAST 100 RETURNS : -53.086263248525945
# Ep done
# EP : 1815
# LAST 100 RETURNS : -53.18110626604762
# Ep done
# EP : 1816
# LAST 100 RETURNS : -53.18451787748965
# Ep done
# EP : 1817
# LAST 100 RETURNS : -53.44039805546655
# Ep done
# EP : 1818
# LAST 100 RETURNS : -53.40988165748893
# Ep done
# EP : 1819
# LAST 100 RETURNS : -53.42908424843105
# Ep done
# EP : 1820
# LAST 100 RETURNS : -53.56661235094588
# Ep done
# EP : 1821
# LAST 100 RETURNS : -53.565391677531075
# Ep done
# EP : 1822
# LAST 100 RETURNS : -53.671384571137054
# Ep done
# EP : 1823
# LAST 100 RETURNS : -53.64953369825148
# Ep done
# EP : 1824
# LAST 100 RETURNS : -53.59500598337376
# Ep done
# EP : 1825
# LAST 100 RETURNS : -53.4637073230386
# Ep done
# EP : 1826
# LAST 100 RETURNS : -53.62692421306801
# Ep done
# EP : 1827
# LAST 100 RETURNS : -53.57857346755763
# Ep done
# EP : 1828
# LAST 100 RETURNS : -53.61475216488145
# Ep done
# EP : 1829
# LAST 100 RETURNS : -53.587314311458314
# Ep done
# EP : 1830
# LAST 100 RETURNS : -53.469914295291744
# Ep done
# EP : 1831
# LAST 100 RETURNS : -53.70137273384734
# Ep done
# EP : 1832
# LAST 100 RETURNS : -53.932163533005024
# Ep done
# EP : 1833
# LAST 100 RETURNS : -54.00091106427348
# Ep done
# EP : 1834
# LAST 100 RETURNS : -54.201618959798374
# Ep done
# EP : 1835
# LAST 100 RETURNS : -54.222398083748374
# Ep done
# EP : 1836
# LAST 100 RETURNS : -54.229491667667084
# Ep done
# EP : 1837
# LAST 100 RETURNS : -54.04777745385234
# Ep done
# EP : 1838
# LAST 100 RETURNS : -53.8860770845838
# Ep done
# EP : 1839
# LAST 100 RETURNS : -53.881847059755515
# Ep done
# EP : 1840
# LAST 100 RETURNS : -54.098772604130026
# Ep done
# EP : 1841
# LAST 100 RETURNS : -54.085269495085036
# Ep done
# EP : 1842
# LAST 100 RETURNS : -54.12222596397132
# Ep done
# EP : 1843
# LAST 100 RETURNS : -54.180263882182906
# Ep done
# EP : 1844
# LAST 100 RETURNS : -54.218449800558396
# Ep done
# EP : 1845
# LAST 100 RETURNS : -54.41551874245903
# Ep done
# EP : 1846
# LAST 100 RETURNS : -54.564640293686175
# Ep done
# EP : 1847
# LAST 100 RETURNS : -54.540229153543066
# Ep done
# EP : 1848
# LAST 100 RETURNS : -54.54134542349304
# Ep done
# EP : 1849
# LAST 100 RETURNS : -54.61618450321859
# Ep done
# EP : 1850
# LAST 100 RETURNS : -54.83132544457052
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---
#
#
#
# EP : 1851
# LAST 100 RETURNS : -54.654204983315175
# Ep done
# EP : 1852
# LAST 100 RETURNS : -54.59812899107375
# Ep done
# EP : 1853
# LAST 100 RETURNS : -54.599965491218114
# Ep done
# EP : 1854
# LAST 100 RETURNS : -54.51488749181257
# Ep done
# EP : 1855
# LAST 100 RETURNS : -54.511467056985474
# Ep done
# EP : 1856
# LAST 100 RETURNS : -54.78009739425939
# Ep done
# EP : 1857
# LAST 100 RETURNS : -54.68632764185208
# Ep done
# EP : 1858
# LAST 100 RETURNS : -54.682563891021
# Ep done
# EP : 1859
# LAST 100 RETURNS : -54.74175106656651
# Ep done
# EP : 1860
# LAST 100 RETURNS : -54.864916152283456
# Ep done
# EP : 1861
# LAST 100 RETURNS : -54.810371167207
# Ep done
# EP : 1862
# LAST 100 RETURNS : -55.03535784222611
# Ep done
# EP : 1863
# LAST 100 RETURNS : -54.93431801627721
# Ep done
# EP : 1864
# LAST 100 RETURNS : -55.13575016693526
# Ep done
# EP : 1865
# LAST 100 RETURNS : -55.17595040873265
# Ep done
# EP : 1866
# LAST 100 RETURNS : -55.36413541426373
# Ep done
# EP : 1867
# LAST 100 RETURNS : -55.51705759131975
# Ep done
# EP : 1868
# LAST 100 RETURNS : -55.744146049218394
# Ep done
# EP : 1869
# LAST 100 RETURNS : -55.87864877990405
# Ep done
# EP : 1870
# LAST 100 RETURNS : -55.82181212584943
# Ep done
# EP : 1871
# LAST 100 RETURNS : -55.80557604487802
# Ep done
# EP : 1872
# LAST 100 RETURNS : -55.85299323362703
# Ep done
# EP : 1873
# LAST 100 RETURNS : -55.92902171585118
# Ep done
# EP : 1874
# LAST 100 RETURNS : -56.023306935406076
# Ep done
# EP : 1875
# LAST 100 RETURNS : -56.017543022320574
# Ep done
# EP : 1876
# LAST 100 RETURNS : -55.95534792048342
# Ep done
# EP : 1877
# LAST 100 RETURNS : -56.13545137916211
# Ep done
# EP : 1878
# LAST 100 RETURNS : -55.925140442020904
# Ep done
# EP : 1879
# LAST 100 RETURNS : -55.9447711184509
# Ep done
# EP : 1880
# LAST 100 RETURNS : -55.702573442644976
# Ep done
# EP : 1881
# LAST 100 RETURNS : -55.7224591889835
# Ep done
# EP : 1882
# LAST 100 RETURNS : -55.529572631497146
# Ep done
# EP : 1883
# LAST 100 RETURNS : -55.56489152190183
# Ep done
# EP : 1884
# LAST 100 RETURNS : -55.51553181759705
# Ep done
# EP : 1885
# LAST 100 RETURNS : -55.63781368787326
# Ep done
# EP : 1886
# LAST 100 RETURNS : -55.67714302163756
# Ep done
# EP : 1887
# LAST 100 RETURNS : -55.719530810571456
# Ep done
# EP : 1888
# LAST 100 RETURNS : -55.63816754273728
# Ep done
# EP : 1889
# LAST 100 RETURNS : -55.64827304609931
# Ep done
# EP : 1890
# LAST 100 RETURNS : -55.38153032140437
# Ep done
# EP : 1891
# LAST 100 RETURNS : -55.520634517195155
# Ep done
# EP : 1892
# LAST 100 RETURNS : -55.46988886777016
# Ep done
# EP : 1893
# LAST 100 RETURNS : -55.58744580573185
# Ep done
# EP : 1894
# LAST 100 RETURNS : -55.56436164626434
# Ep done
# EP : 1895
# LAST 100 RETURNS : -55.44114652686999
# Ep done
# EP : 1896
# LAST 100 RETURNS : -55.45451180590067
# Ep done
# EP : 1897
# LAST 100 RETURNS : -55.41129029088027
# Ep done
# EP : 1898
# LAST 100 RETURNS : -55.40872867775973
# Ep done
# EP : 1899
# LAST 100 RETURNS : -55.436790883462244
# Ep done
# EP : 1900
# LAST 100 RETURNS : -55.443833926139945
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---
#
#
#
# EP : 1901
# LAST 100 RETURNS : -55.55793350826901
# Ep done
# EP : 1902
# LAST 100 RETURNS : -55.483483338659696
# Ep done
# EP : 1903
# LAST 100 RETURNS : -55.61594628549319
# Ep done
# EP : 1904
# LAST 100 RETURNS : -55.633971241038225
# Ep done
# EP : 1905
# LAST 100 RETURNS : -55.7349668475996
# Ep done
# EP : 1906
# LAST 100 RETURNS : -55.9311748281624
# Ep done
# EP : 1907
# LAST 100 RETURNS : -55.87617337386036
# Ep done
# EP : 1908
# LAST 100 RETURNS : -55.85104111765458
# Ep done
# EP : 1909
# LAST 100 RETURNS : -55.784550230420564
# Ep done
# EP : 1910
# LAST 100 RETURNS : -55.864038600731
# Ep done
# EP : 1911
# LAST 100 RETURNS : -55.854853695829526
# Ep done
# EP : 1912
# LAST 100 RETURNS : -55.94747986384444
# Ep done
# EP : 1913
# LAST 100 RETURNS : -55.96253638729337
# Ep done
# EP : 1914
# LAST 100 RETURNS : -56.012407713459886
# Ep done
# EP : 1915
# LAST 100 RETURNS : -55.97559449458571
# Ep done
# EP : 1916
# LAST 100 RETURNS : -55.99839786802544
# Ep done
# EP : 1917
# LAST 100 RETURNS : -55.99683793806681
# Ep done
# EP : 1918
# LAST 100 RETURNS : -55.85662960484118
# Ep done
# EP : 1919
# LAST 100 RETURNS : -55.82623638121209
# Ep done
# EP : 1920
# LAST 100 RETURNS : -55.91810147609837
# Ep done
# EP : 1921
# LAST 100 RETURNS : -55.86016700776858
# Ep done
# EP : 1922
# LAST 100 RETURNS : -55.75516858470348
# Ep done
# EP : 1923
# LAST 100 RETURNS : -55.5891363570629
# Ep done
# EP : 1924
# LAST 100 RETURNS : -55.68113350402749
# Ep done
# EP : 1925
# LAST 100 RETURNS : -55.64042504154037
# Ep done
# EP : 1926
# LAST 100 RETURNS : -55.888848833674196
# Ep done
# EP : 1927
# LAST 100 RETURNS : -55.814825795828256
# Ep done
# EP : 1928
# LAST 100 RETURNS : -55.84838940219414
# Ep done
# EP : 1929
# LAST 100 RETURNS : -55.79977260115443
# Ep done
# EP : 1930
# LAST 100 RETURNS : -55.68652073284077
# Ep done
# EP : 1931
# LAST 100 RETURNS : -55.76488458262978
# Ep done
# EP : 1932
# LAST 100 RETURNS : -55.72224674307464
# Ep done
# EP : 1933
# LAST 100 RETURNS : -55.714636630039855
# Ep done
# EP : 1934
# LAST 100 RETURNS : -55.59583824059272
# Ep done
# EP : 1935
# LAST 100 RETURNS : -55.374983104300696
# Ep done
# EP : 1936
# LAST 100 RETURNS : -55.29165783209302
# Ep done
# EP : 1937
# LAST 100 RETURNS : -55.28575234454363
# Ep done
# EP : 1938
# LAST 100 RETURNS : -55.27041492124328
# Ep done
# EP : 1939
# LAST 100 RETURNS : -55.41196477370647
# Ep done
# EP : 1940
# LAST 100 RETURNS : -55.350863068765506
# Ep done
# EP : 1941
# LAST 100 RETURNS : -55.35246309423962
# Ep done
# EP : 1942
# LAST 100 RETURNS : -55.30625876157514
# Ep done
# EP : 1943
# LAST 100 RETURNS : -55.19632743231025
# Ep done
# EP : 1944
# LAST 100 RETURNS : -54.98690350988815
# Ep done
# EP : 1945
# LAST 100 RETURNS : -55.03409458706142
# Ep done
# EP : 1946
# LAST 100 RETURNS : -54.86903908014984
# Ep done
# EP : 1947
# LAST 100 RETURNS : -54.89338106501382
# Ep done
# EP : 1948
# LAST 100 RETURNS : -54.86861355070973
# Ep done
# EP : 1949
# LAST 100 RETURNS : -54.90524408875208
# Ep done
# EP : 1950
# LAST 100 RETURNS : -54.96987286326243
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---
#
#
#
# EP : 1951
# LAST 100 RETURNS : -54.88324427194737
# Ep done
# EP : 1952
# LAST 100 RETURNS : -54.8702988722121
# Ep done
# EP : 1953
# LAST 100 RETURNS : -54.87425059634838
# Ep done
# EP : 1954
# LAST 100 RETURNS : -54.87134731466029
# Ep done
# EP : 1955
# LAST 100 RETURNS : -54.98689388415061
# Ep done
# EP : 1956
# LAST 100 RETURNS : -55.10087235655151
# Ep done
# EP : 1957
# LAST 100 RETURNS : -54.91571878470147
# Ep done
# EP : 1958
# LAST 100 RETURNS : -54.8134949551165
# Ep done
# EP : 1959
# LAST 100 RETURNS : -55.00902981430488
# Ep done
# EP : 1960
# LAST 100 RETURNS : -54.776331425554694
# Ep done
# EP : 1961
# LAST 100 RETURNS : -54.732308161810884
# Ep done
# EP : 1962
# LAST 100 RETURNS : -54.94940706498383
# Ep done
# EP : 1963
# LAST 100 RETURNS : -54.97452426777292
# Ep done
# EP : 1964
# LAST 100 RETURNS : -54.953036698870264
# Ep done
# EP : 1965
# LAST 100 RETURNS : -54.925004060390535
# Ep done
# EP : 1966
# LAST 100 RETURNS : -54.86277778510668
# Ep done
# EP : 1967
# LAST 100 RETURNS : -54.746150885206454
# Ep done
# EP : 1968
# LAST 100 RETURNS : -54.7137874153393
# Ep done
# EP : 1969
# LAST 100 RETURNS : -54.73070619245083
# Ep done
# EP : 1970
# LAST 100 RETURNS : -54.579262589860434
# Ep done
# EP : 1971
# LAST 100 RETURNS : -54.74341626968004
# Ep done
# EP : 1972
# LAST 100 RETURNS : -54.8642839187301
# Ep done
# EP : 1973
# LAST 100 RETURNS : -54.80374671213586
# Ep done
# EP : 1974
# LAST 100 RETURNS : -54.76635238963998
# Ep done
# EP : 1975
# LAST 100 RETURNS : -54.753926157522415
# Ep done
# EP : 1976
# LAST 100 RETURNS : -54.68813115723608
# Ep done
# EP : 1977
# LAST 100 RETURNS : -54.66327923982889
# Ep done
# EP : 1978
# LAST 100 RETURNS : -54.55828787609223
# Ep done
# EP : 1979
# LAST 100 RETURNS : -54.7258300651773
# Ep done
# EP : 1980
# LAST 100 RETURNS : -54.621898556481405
# Ep done
# EP : 1981
# LAST 100 RETURNS : -54.81512057261762
# Ep done
# EP : 1982
# LAST 100 RETURNS : -54.661296092759855
# Ep done
# EP : 1983
# LAST 100 RETURNS : -54.86696074418166
# Ep done
# EP : 1984
# LAST 100 RETURNS : -54.78946913720957
# Ep done
# EP : 1985
# LAST 100 RETURNS : -54.57034319623804
# Ep done
# EP : 1986
# LAST 100 RETURNS : -54.51910300839288
# Ep done
# EP : 1987
# LAST 100 RETURNS : -54.62359007247115
# Ep done
# EP : 1988
# LAST 100 RETURNS : -54.51660249530806
# Ep done
# EP : 1989
# LAST 100 RETURNS : -54.477684852389274
# Ep done
# EP : 1990
# LAST 100 RETURNS : -54.354576036737946
# Ep done
# EP : 1991
# LAST 100 RETURNS : -54.534790354241146
# Ep done
# EP : 1992
# LAST 100 RETURNS : -54.39861291283896
# Ep done
# EP : 1993
# LAST 100 RETURNS : -54.44240277012887
# Ep done
# EP : 1994
# LAST 100 RETURNS : -54.42997587206627
# Ep done
# EP : 1995
# LAST 100 RETURNS : -54.43349307984276
# Ep done
# EP : 1996
# LAST 100 RETURNS : -54.67334621354258
# Ep done
# EP : 1997
# LAST 100 RETURNS : -54.810229566461935
# Ep done
# EP : 1998
# LAST 100 RETURNS : -54.915241640446
# Ep done
# EP : 1999
# LAST 100 RETURNS : -54.939038508835516
# Ep done
# EP : 2000
# LAST 100 RETURNS : -54.96294726036703
# Ep done
#
#
#
# ----MAX REWRD SO FAR : -25.112662512601453---

# %%
# Test the policy #
env = GymEnv("Pendulum-v0")
env.pyenv._max_episode_steps = 50000
TEST_STEPS = 50000

r = test_run(env)
# Out:
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-1.99986]
# Action : [-0.467727]
# Action : [1.9996]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [2.0]
# Action : [1.99999]
# Action : [1.99969]
# Action : [1.99078]
# Action : [1.72303]
# Action : [-1.22844]
# Action : [-1.99976]
# Action : [-1.99995]
# Action : [-1.99999]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-2.0]
# Action : [-1.99999]
# Action : [-1.99728]
# Action : [-1.65396]
# Action : [1.15847]
# Action : [1.29891]
# Action : [1.06539]
# Action : [0.400123]
# Action : [1.15889]
# Action : [1.48758]
# Action : [1.59316]
# Action : [1.56347]
# Action : [1.42931]
# Action : [1.22326]
# Action : [0.996614]
# Action : [0.910676]
# Action : [0.812455]
# Action : [0.865503]
# Action : [1.09143]
# Action : [1.45461]
# Action : [1.54188]
# Action : [1.31565]
# Action : [0.55544]
# Action : [-0.78713]
# Action : [-1.63723]
# Action : [-1.87876]
# Action : [-1.93566]
# Action : [-1.94104]
# Action : [-1.9002]
# Action : [-1.50536]
# Action : [0.181362]
# Action : [0.716522]
# Action : [0.989618]
# Action : [1.31242]
# Action : [1.53571]
# Action : [1.41112]
# Action : [0.871374]
# Action : [-0.338672]
# Action : [-1.43803]
# Action : [-1.82467]
# Action : [-1.9199]
# Action : [-1.93664]
# Action : [-1.91326]
# Action : [-1.66742]
# Action : [-0.327834]
# Action : [0.704721]
# Action : [0.94935]
# Action : [1.22384]
# Action : [1.52578]
# Action : [1.46581]
# Action : [1.05051]
# Action : [-0.0257576]
# Action : [-1.26367]
# Action : [-1.77926]
# Action : [-1.90965]
# Action : [-1.93718]
# Action : [-1.9253]
# Action : [-1.77287]
# Action : [-0.800479]
# Action : [0.663622]
# Action : [0.886151]
# Action : [1.13156]
# Action : [1.49087]
# Action : [1.50563]
# Action : [1.20162]
# Action : [0.296346]
# Action : [-1.02503]
# Action : [-1.70995]
# Action : [-1.8931]
# Action : [-1.93516]
# Action : [-1.9324]
# Action : [-1.84921]
# Action : [-1.20479]
# Action : [0.522108]
# Action : [0.803464]
# Action : [1.05136]
# Action : [1.42072]
# Action : [1.52618]
# Action : [1.3123]
# Action : [0.582626]
# Action : [-0.733124]
# Action : [-1.60824]
# Action : [-1.86728]
# Action : [-1.9292]
# Action : [-1.93484]
# Action : [-1.88904]
# Action : [-1.45733]
# Action : [0.238609]
# Action : [0.729958]
# Action : [0.999896]
# Action : [1.33846]
# Action : [1.53378]
# Action : [1.38848]
# Action : [0.805547]
# Action : [-0.436959]
# Action : [-1.48376]
# Action : [-1.8357]
# Action : [-1.92198]
# Action : [-1.93573]
# Action : [-1.9074]
# Action : [-1.62029]
# Action : [-0.163164]
# Action : [0.706509]
# Action : [0.966345]
# Action : [1.25715]
# Action : [1.53124]
# Action : [1.44764]
# Action : [0.988291]
# Action : [-0.141164]
# Action : [-1.33311]
# Action : [-1.79769]
# Action : [-1.91379]
# Action : [-1.93712]
# Action : [-1.92159]
# Action : [-1.73807]
# Action : [-0.628634]
# Action : [0.682871]
# Action : [0.91113]
# Action : [1.16502]
# Action : [1.50781]
# Action : [1.49335]
# Action : [1.15309]
# Action : [0.184274]
# Action : [-1.11754]
# Action : [-1.73839]
# Action : [-1.90017]
# Action : [-1.9365]
# Action : [-1.9307]
# Action : [-1.82795]
# Action : [-1.08454]
# Action : [0.591186]
# Action : [0.834536]
# Action : [1.07413]
# Action : [1.44778]
# Action : [1.52128]
# Action : [1.2788]
# Action : [0.491105]
# Action : [-0.836375]
# Action : [-1.64648]
# Action : [-1.87705]
# Action : [-1.93155]
# Action : [-1.93433]
# Action : [-1.87836]
# Action : [-1.38423]
# Action : [0.351676]
# Action : [0.750497]
# Action : [1.01503]
# Action : [1.36648]
# Action : [1.53098]
# Action : [1.36359]
# Action : [0.732586]
# Action : [-0.53968]
# Action : [-1.52902]
# Action : [-1.84686]
# Action : [-1.92421]
# Action : [-1.93505]
# Action : [-1.90102]
# Action : [-1.56582]
# Action : [-0.0051128]
# Action : [0.705535]
# Action : [0.980739]
# Action : [1.28742]
# Action : [1.53503]
# Action : [1.42904]
# Action : [0.926547]
# Action : [-0.249326]
# Action : [-1.39286]
# Action : [-1.81332]
# Action : [-1.91741]
# Action : [-1.93706]
# Action : [-1.91747]
# Action : [-1.70241]
# Action : [-0.469119]
# Action : [0.697749]
# Action : [0.932815]
# Action : [1.19564]
# Action : [1.51844]
# Action : [1.47979]
# Action : [1.10076]
# Action : [0.0736748]
# Action : [-1.19808]
# Action : [-1.76135]
# Action : [-1.90557]
# Action : [-1.93702]
# Action : [-1.92806]
# Action : [-1.80109]
# Action : [-0.940518]
# Action : [0.637104]
# Action : [0.863292]
# Action : [1.10327]
# Action : [1.47242]
# Action : [1.51381]
# Action : [1.23926]
# Action : [0.38937]
# Action : [-0.939303]
# Action : [-1.68194]
# Action : [-1.88599]
# Action : [-1.93356]
# Action : [-1.93336]
# Action : [-1.86402]
# Action : [-1.29283]
# Action : [0.44962]
# Action : [0.77788]
# Action : [1.035]
# Action : [1.39653]
# Action : [1.52856]
# Action : [1.33668]
# Action : [0.65288]
# Action : [-0.645916]
# Action : [-1.57365]
# Action : [-1.85831]
# Action : [-1.92694]
# Action : [-1.93489]
# Action : [-1.89505]
# Action : [-1.5085]
# Action : [0.134929]
# Action : [0.716565]
# Action : [0.990145]
# Action : [1.31591]
# Action : [1.53528]
# Action : [1.40773]
# Action : [0.861929]
# Action : [-0.352861]
# Action : [-1.44467]
# Action : [-1.82621]
# Action : [-1.92015]
# Action : [-1.93644]
# Action : [-1.91233]
# Action : [-1.66042]
# Action : [-0.301991]
# Action : [0.705409]
# Action : [0.952211]
# Action : [1.22911]
# Action : [1.52679]
# Action : [1.46299]
# Action : [1.04074]
# Action : [-0.0443885]
# Action : [-1.27532]
# Action : [-1.78238]
# Action : [-1.91035]
# Action : [-1.93718]
# Action : [-1.92474]
# Action : [-1.7674]
# Action : [-0.773176]
# Action : [0.667597]
# Action : [0.890193]
# Action : [1.13705]
# Action : [1.49386]
# Action : [1.50385]
# Action : [1.19414]
# Action : [0.278487]
# Action : [-1.04054]
# Action : [-1.71485]
# Action : [-1.89433]
# Action : [-1.93542]
# Action : [-1.93217]
# Action : [-1.84607]
# Action : [-1.18688]
# Action : [0.534488]
# Action : [0.808562]
# Action : [1.05455]
# Action : [1.42516]
# Action : [1.52555]
# Action : [1.30731]
# Action : [0.568643]
# Action : [-0.749613]
# Action : [-1.61454]
# Action : [-1.86889]
# Action : [-1.92959]
# Action : [-1.93479]
# Action : [-1.8876]
# Action : [-1.4468]
# Action : [0.257913]
# Action : [0.732811]
# Action : [1.00178]
# Action : [1.34278]
# Action : [1.53338]
# Action : [1.38462]
# Action : [0.794319]
# Action : [-0.453149]
# Action : [-1.49104]
# Action : [-1.83747]
# Action : [-1.92231]
# Action : [-1.93559]
# Action : [-1.90636]
# Action : [-1.6119]
# Action : [-0.137058]
# Action : [0.706197]
# Action : [0.968875]
# Action : [1.26224]
# Action : [1.53198]
# Action : [1.44471]
# Action : [0.978317]
# Action : [-0.159049]
# Action : [-1.34334]
# Action : [-1.80038]
# Action : [-1.91441]
# Action : [-1.93712]
# Action : [-1.92098]
# Action : [-1.73245]
# Action : [-0.60231]
# Action : [0.685533]
# Action : [0.915009]
# Action : [1.17039]
# Action : [1.50995]
# Action : [1.49126]
# Action : [1.14464]
# Action : [0.165839]
# Action : [-1.13161]
# Action : [-1.74251]
# Action : [-1.90115]
# Action : [-1.93662]
# Action : [-1.93031]
# Action : [-1.82389]
# Action : [-1.06218]
# Action : [0.600724]
# Action : [0.839646]
# Action : [1.07868]
# Action : [1.45204]
# Action : [1.52024]
# Action : [1.2726]
# Action : [0.474676]
# Action : [-0.853822]
# Action : [-1.65268]
# Action : [-1.87863]
# Action : [-1.93192]
# Action : [-1.93421]
# Action : [-1.8763]
# Action : [-1.37009]
# Action : [0.36871]
# Action : [0.754737]
# Action : [1.01835]
# Action : [1.37147]
# Action : [1.53061]
# Action : [1.3593]
# Action : [0.719753]
# Action : [-0.557246]
# Action : [-1.53659]
# Action : [-1.84879]
# Action : [-1.92465]
# Action : [-1.93501]
# Action : [-1.90004]
# Action : [-1.55659]
# Action : [0.0196311]
# Action : [0.70658]
# Action : [0.98229]
# Action : [1.29192]
# Action : [1.53514]
# Action : [1.4255]
# Action : [0.915881]
# Action : [-0.266798]
# Action : [-1.40183]
# Action : [-1.81555]
# Action : [-1.91786]
# Action : [-1.93694]
# Action : [-1.91659]
# Action : [-1.69549]
# Action : [-0.440529]
# Action : [0.699696]
# Action : [0.936421]
# Action : [1.20147]
# Action : [1.52011]
# Action : [1.47701]
# Action : [1.09054]
# Action : [0.0529903]
# Action : [-1.2122]
# Action : [-1.76525]
# Action : [-1.90647]
# Action : [-1.93707]
# Action : [-1.92751]
# Action : [-1.79536]
# Action : [-0.912092]
# Action : [0.64362]
# Action : [0.868279]
# Action : [1.10896]
# Action : [1.47646]
# Action : [1.51225]
# Action : [1.23157]
# Action : [0.370172]
# Action : [-0.957554]
# Action : [-1.68801]
# Action : [-1.88752]
# Action : [-1.9339]
# Action : [-1.93317]
# Action : [-1.86108]
# Action : [-1.27504]
# Action : [0.465878]
# Action : [0.782942]
# Action : [1.03857]
# Action : [1.40182]
# Action : [1.5282]
# Action : [1.33178]
# Action : [0.638428]
# Action : [-0.664503]
# Action : [-1.58123]
# Action : [-1.86029]
# Action : [-1.92745]
# Action : [-1.9349]
# Action : [-1.89397]
# Action : [-1.4983]
# Action : [0.157055]
# Action : [0.719217]
# Action : [0.991709]
# Action : [1.32061]
# Action : [1.53515]
# Action : [1.40403]
# Action : [0.850863]
# Action : [-0.369871]
# Action : [-1.45281]
# Action : [-1.82821]
# Action : [-1.92058]
# Action : [-1.93632]
# Action : [-1.91145]
# Action : [-1.65298]
# Action : [-0.27438]
# Action : [0.706098]
# Action : [0.955142]
# Action : [1.23482]
# Action : [1.52781]
# Action : [1.45999]
# Action : [1.03043]
# Action : [-0.0638304]
# Action : [-1.28729]
# Action : [-1.78557]
# Action : [-1.91106]
# Action : [-1.93717]
# Action : [-1.92416]
# Action : [-1.76165]
# Action : [-0.744402]
# Action : [0.671355]
# Action : [0.89431]
# Action : [1.14269]
# Action : [1.49691]
# Action : [1.50198]
# Action : [1.18633]
# Action : [0.259959]
# Action : [-1.05637]
# Action : [-1.71982]
# Action : [-1.89559]
# Action : [-1.93568]
# Action : [-1.93195]
# Action : [-1.8428]
# Action : [-1.16789]
# Action : [0.546369]
# Action : [0.813648]
# Action : [1.05781]
# Action : [1.42958]
# Action : [1.52489]
# Action : [1.3022]
# Action : [0.554437]
# Action : [-0.766124]
# Action : [-1.62078]
# Action : [-1.8705]
# Action : [-1.92999]
# Action : [-1.93474]
# Action : [-1.88605]
# Action : [-1.43589]
# Action : [0.276637]
# Action : [0.735653]
# Action : [1.00365]
# Action : [1.34705]
# Action : [1.53293]
# Action : [1.38081]
# Action : [0.783224]
# Action : [-0.468997]
# Action : [-1.49811]
# Action : [-1.83919]
# Action : [-1.92264]
# Action : [-1.93547]
# Action : [-1.90535]
# Action : [-1.60355]
# Action : [-0.111889]
# Action : [0.705853]
# Action : [0.971304]
# Action : [1.26713]
# Action : [1.53269]
# Action : [1.44187]
# Action : [0.968709]
# Action : [-0.176258]
# Action : [-1.35308]
# Action : [-1.80295]
# Action : [-1.91501]
# Action : [-1.93713]
# Action : [-1.92035]
# Action : [-1.72705]
# Action : [-0.577332]
# Action : [0.687951]
# Action : [0.918634]
# Action : [1.17537]
# Action : [1.51173]
# Action : [1.48926]
# Action : [1.13664]
# Action : [0.148573]
# Action : [-1.14455]
# Action : [-1.74627]
# Action : [-1.90204]
# Action : [-1.93673]
# Action : [-1.92993]
# Action : [-1.81999]
# Action : [-1.04029]
# Action : [0.608533]
# Action : [0.844232]
# Action : [1.08298]
# Action : [1.45589]
# Action : [1.51918]
# Action : [1.26671]
# Action : [0.45927]
# Action : [-0.869868]
# Action : [-1.6583]
# Action : [-1.88005]
# Action : [-1.93225]
# Action : [-1.93408]
# Action : [-1.87426]
# Action : [-1.35656]
# Action : [0.384316]
# Action : [0.758711]
# Action : [1.02147]
# Action : [1.37613]
# Action : [1.53027]
# Action : [1.35528]
# Action : [0.707675]
# Action : [-0.573603]
# Action : [-1.54357]
# Action : [-1.85057]
# Action : [-1.92507]
# Action : [-1.93497]
# Action : [-1.89913]
# Action : [-1.54794]
# Action : [0.0415653]
# Action : [0.708387]
# Action : [0.983779]
# Action : [1.29618]
# Action : [1.53528]
# Action : [1.42224]
# Action : [0.905963]
# Action : [-0.28296]
# Action : [-1.41006]
# Action : [-1.81762]
# Action : [-1.91829]
# Action : [-1.93684]
# Action : [-1.9158]
# Action : [-1.68911]
# Action : [-0.414575]
# Action : [0.70131]
# Action : [0.939619]
# Action : [1.20686]
# Action : [1.52159]
# Action : [1.47444]
# Action : [1.08117]
# Action : [0.0342295]
# Action : [-1.22479]
# Action : [-1.7687]
# Action : [-1.90726]
# Action : [-1.9371]
# Action : [-1.927]
# Action : [-1.79013]
# Action : [-0.885982]
# Action : [0.649071]
# Action : [0.872695]
# Action : [1.11438]
# Action : [1.48004]
# Action : [1.51073]
# Action : [1.22453]
# Action : [0.352552]
# Action : [-0.974084]
# Action : [-1.69346]
# Action : [-1.8889]
# Action : [-1.93421]
# Action : [-1.93298]
# Action : [-1.85835]
# Action : [-1.25857]
# Action : [0.48027]
# Action : [0.787928]
# Action : [1.04163]
# Action : [1.40651]
# Action : [1.52775]
# Action : [1.32712]
# Action : [0.624979]
# Action : [-0.681417]
# Action : [-1.588]
# Action : [-1.86204]
# Action : [-1.92788]
# Action : [-1.93489]
# Action : [-1.89285]
# Action : [-1.48847]
# Action : [0.177523]
# Action : [0.721741]
# Action : [0.993759]
# Action : [1.32506]
# Action : [1.53489]
# Action : [1.40023]
# Action : [0.839753]
# Action : [-0.386599]
# Action : [-1.46065]
# Action : [-1.83011]
# Action : [-1.92097]
# Action : [-1.93618]
# Action : [-1.91047]
# Action : [-1.64521]
# Action : [-0.246446]
# Action : [0.706667]
# Action : [0.958097]
# Action : [1.2406]
# Action : [1.52882]
# Action : [1.45691]
# Action : [1.01983]
# Action : [-0.0836283]
# Action : [-1.29929]
# Action : [-1.78876]
# Action : [-1.91178]
# Action : [-1.93716]
# Action : [-1.92355]
# Action : [-1.75578]
# Action : [-0.71497]
# Action : [0.674778]
# Action : [0.898373]
# Action : [1.14841]
# Action : [1.49994]
# Action : [1.50005]
# Action : [1.17834]
# Action : [0.241199]
# Action : [-1.07211]
# Action : [-1.72471]
# Action : [-1.89683]
# Action : [-1.93595]
# Action : [-1.93171]
# Action : [-1.83943]
# Action : [-1.1485]
# Action : [0.557881]
# Action : [0.818698]
# Action : [1.0614]
# Action : [1.43398]
# Action : [1.52414]
# Action : [1.29689]
# Action : [0.53983]
# Action : [-0.782788]
# Action : [-1.62699]
# Action : [-1.87209]
# Action : [-1.93038]
# Action : [-1.93466]
# Action : [-1.88433]
# Action : [-1.42444]
# Action : [0.295389]
# Action : [0.738695]
# Action : [1.00586]
# Action : [1.35147]
# Action : [1.53241]
# Action : [1.37679]
# Action : [0.771562]
# Action : [-0.485459]
# Action : [-1.50537]
# Action : [-1.84096]
# Action : [-1.92297]
# Action : [-1.93534]
# Action : [-1.90429]
# Action : [-1.59468]
# Action : [-0.0859051]
# Action : [0.705459]
# Action : [0.973809]
# Action : [1.27217]
# Action : [1.53342]
# Action : [1.43891]
# Action : [0.958703]
# Action : [-0.194026]
# Action : [-1.36302]
# Action : [-1.80558]
# Action : [-1.91563]
# Action : [-1.93714]
# Action : [-1.9197]
# Action : [-1.7214]
# Action : [-0.551703]
# Action : [0.690619]
# Action : [0.922099]
# Action : [1.18027]
# Action : [1.51337]
# Action : [1.48705]
# Action : [1.12823]
# Action : [0.130769]
# Action : [-1.15759]
# Action : [-1.74997]
# Action : [-1.90291]
# Action : [-1.9368]
# Action : [-1.92949]
# Action : [-1.81572]
# Action : [-1.01672]
# Action : [0.616132]
# Action : [0.848976]
# Action : [1.08757]
# Action : [1.45991]
# Action : [1.51801]
# Action : [1.26036]
# Action : [0.442818]
# Action : [-0.886708]
# Action : [-1.66414]
# Action : [-1.88153]
# Action : [-1.93259]
# Action : [-1.93393]
# Action : [-1.872]
# Action : [-1.34195]
# Action : [0.400475]
# Action : [0.763198]
# Action : [1.02466]
# Action : [1.38099]
# Action : [1.52983]
# Action : [1.35087]
# Action : [0.694644]
# Action : [-0.590952]
# Action : [-1.55086]
# Action : [-1.85242]
# Action : [-1.9255]
# Action : [-1.93492]
# Action : [-1.89812]
# Action : [-1.53841]
# Action : [0.0649868]
# Action : [0.710346]
# Action : [0.985367]
# Action : [1.30099]
# Action : [1.53537]
# Action : [1.41866]
# Action : [0.895069]
# Action : [-0.300527]
# Action : [-1.41891]
# Action : [-1.81982]
# Action : [-1.91876]
# Action : [-1.93673]
# Action : [-1.91493]
# Action : [-1.68206]
# Action : [-0.38619]
# Action : [0.70267]
# Action : [0.942954]
# Action : [1.21262]
# Action : [1.52312]
# Action : [1.4716]
# Action : [1.07095]
# Action : [0.0139968]
# Action : [-1.23812]
# Action : [-1.77234]
# Action : [-1.9081]
# Action : [-1.93714]
# Action : [-1.92643]
# Action : [-1.78442]
# Action : [-0.857336]
# Action : [0.654413]
# Action : [0.877347]
# Action : [1.12018]
# Action : [1.48382]
# Action : [1.50907]
# Action : [1.21689]
# Action : [0.333607]
# Action : [-0.991598]
# Action : [-1.69919]
# Action : [-1.89036]
# Action : [-1.93455]
# Action : [-1.9328]
# Action : [-1.8554]
# Action : [-1.24081]
# Action : [0.495093]
# Action : [0.793159]
# Action : [1.04484]
# Action : [1.41141]
# Action : [1.5273]
# Action : [1.32223]
# Action : [0.610839]
# Action : [-0.698994]
# Action : [-1.59498]
# Action : [-1.86385]
# Action : [-1.92834]
# Action : [-1.93489]
# Action : [-1.89171]
# Action : [-1.47824]
# Action : [0.198318]
# Action : [0.724321]
# Action : [0.995865]
# Action : [1.32958]
# Action : [1.53463]
# Action : [1.39637]
# Action : [0.828429]
# Action : [-0.403497]
# Action : [-1.46851]
# Action : [-1.83201]
# Action : [-1.92132]
# Action : [-1.93604]
# Action : [-1.90949]
# Action : [-1.63732]
# Action : [-0.218253]
# Action : [0.706779]
# Action : [0.960885]
# Action : [1.2462]
# Action : [1.52963]
# Action : [1.45381]
# Action : [1.00929]
# Action : [-0.103041]
# Action : [-1.31085]
# Action : [-1.79181]
# Action : [-1.91246]
# Action : [-1.93714]
# Action : [-1.92288]
# Action : [-1.74985]
# Action : [-0.685776]
# Action : [0.677748]
# Action : [0.902357]
# Action : [1.15409]
# Action : [1.50284]
# Action : [1.49806]
# Action : [1.17028]
# Action : [0.222523]
# Action : [-1.08748]
# Action : [-1.72944]
# Action : [-1.89802]
# Action : [-1.93619]
# Action : [-1.93146]
# Action : [-1.83598]
# Action : [-1.12885]
# Action : [0.568925]
# Action : [0.823687]
# Action : [1.06534]
# Action : [1.43833]
# Action : [1.52328]
# Action : [1.29136]
# Action : [0.524826]
# Action : [-0.79957]
# Action : [-1.63316]
# Action : [-1.87366]
# Action : [-1.93075]
# Action : [-1.93456]
# Action : [-1.8825]
# Action : [-1.41228]
# Action : [0.313856]
# Action : [0.742137]
# Action : [1.00858]
# Action : [1.35613]
# Action : [1.53188]
# Action : [1.37257]
# Action : [0.759266]
# Action : [-0.502661]
# Action : [-1.51291]
# Action : [-1.84281]
# Action : [-1.92334]
# Action : [-1.93521]
# Action : [-1.9032]
# Action : [-1.58536]
# Action : [-0.0592915]
# Action : [0.705028]
# Action : [0.976362]
# Action : [1.2773]
# Action : [1.53417]
# Action : [1.43587]
# Action : [0.948415]
# Action : [-0.212131]
# Action : [-1.37302]
# Action : [-1.80822]
# Action : [-1.91626]
# Action : [-1.93716]
# Action : [-1.91905]
# Action : [-1.71555]
# Action : [-0.525808]
# Action : [0.693105]
# Action : [0.925515]
# Action : [1.18513]
# Action : [1.51499]
# Action : [1.48482]
# Action : [1.11975]
# Action : [0.112959]
# Action : [-1.17044]
# Action : [-1.7536]
# Action : [-1.90376]
# Action : [-1.93687]
# Action : [-1.92905]
# Action : [-1.81132]
# Action : [-0.993077]
# Action : [0.623208]
# Action : [0.853579]
# Action : [1.09227]
# Action : [1.46396]
# Action : [1.51678]
# Action : [1.2539]
# Action : [0.426248]
# Action : [-0.903358]
# Action : [-1.66985]
# Action : [-1.88296]
# Action : [-1.93291]
# Action : [-1.93377]
# Action : [-1.86962]
# Action : [-1.32702]
# Action : [0.416181]
# Action : [0.767775]
# Action : [1.02788]
# Action : [1.38586]
# Action : [1.52941]
# Action : [1.34647]
# Action : [0.681669]
# Action : [-0.608197]
# Action : [-1.55808]
# Action : [-1.85427]
# Action : [-1.92594]
# Action : [-1.9349]
# Action : [-1.89716]
# Action : [-1.52903]
# Action : [0.0875445]
# Action : [0.712238]
# Action : [0.986897]
# Action : [1.30589]
# Action : [1.53536]
# Action : [1.41513]
# Action : [0.884397]
# Action : [-0.317535]
# Action : [-1.42737]
# Action : [-1.82191]
# Action : [-1.91921]
# Action : [-1.93663]
# Action : [-1.91408]
# Action : [-1.67509]
# Action : [-0.358537]
# Action : [0.703661]
# Action : [0.946072]
# Action : [1.21808]
# Action : [1.52447]
# Action : [1.4688]
# Action : [1.06104]
# Action : [-0.00536534]
# Action : [-1.25066]
# Action : [-1.77574]
# Action : [-1.90886]
# Action : [-1.93716]
# Action : [-1.92588]
# Action : [-1.77881]
# Action : [-0.829619]
# Action : [0.659]
# Action : [0.881674]
# Action : [1.1256]
# Action : [1.48736]
# Action : [1.50747]
# Action : [1.20959]
# Action : [0.315615]
# Action : [-1.00795]
# Action : [-1.70449]
# Action : [-1.89172]
# Action : [-1.93486]
# Action : [-1.93263]
# Action : [-1.8525]
# Action : [-1.22375]
# Action : [0.508275]
# Action : [0.797937]
# Action : [1.04789]
# Action : [1.4159]
# Action : [1.52686]
# Action : [1.31767]
# Action : [0.59769]
# Action : [-0.715118]
# Action : [-1.60131]
# Action : [-1.8655]
# Action : [-1.92877]
# Action : [-1.93489]
# Action : [-1.89057]
# Action : [-1.46876]
# Action : [0.217053]
# Action : [0.726826]
# Action : [0.997728]
# Action : [1.33365]
# Action : [1.53426]
# Action : [1.3928]
# Action : [0.818055]
# Action : [-0.418772]
# Action : [-1.47552]
# Action : [-1.83371]
# Action : [-1.92162]
# Action : [-1.9359]
# Action : [-1.90858]
# Action : [-1.62969]
# Action : [-0.193038]
# Action : [0.70676]
# Action : [0.963402]
# Action : [1.25123]
# Action : [1.53038]
# Action : [1.451]
# Action : [0.999711]
# Action : [-0.120522]
# Action : [-1.32113]
# Action : [-1.79453]
# Action : [-1.91307]
# Action : [-1.93713]
# Action : [-1.92229]
# Action : [-1.74448]
# Action : [-0.659586]
# Action : [0.680103]
# Action : [0.90652]
# Action : [1.15897]
# Action : [1.50524]
# Action : [1.496]
# Action : [1.16259]
# Action : [0.205193]
# Action : [-1.1013]
# Action : [-1.7336]
# Action : [-1.89904]
# Action : [-1.93636]
# Action : [-1.93115]
# Action : [-1.83247]
# Action : [-1.10929]
# Action : [0.579149]
# Action : [0.828547]
# Action : [1.06919]
# Action : [1.44259]
# Action : [1.52242]
# Action : [1.28583]
# Action : [0.50992]
# Action : [-0.816001]
# Action : [-1.63914]
# Action : [-1.87518]
# Action : [-1.93111]
# Action : [-1.93446]
# Action : [-1.88068]
# Action : [-1.39996]
# Action : [0.331152]
# Action : [0.745663]
# Action : [1.01132]
# Action : [1.36069]
# Action : [1.53142]
# Action : [1.36852]
# Action : [0.747361]
# Action : [-0.519216]
# Action : [-1.52012]
# Action : [-1.84461]
# Action : [-1.92371]
# Action : [-1.93512]
# Action : [-1.90219]
# Action : [-1.57649]
# Action : [-0.0344774]
# Action : [0.705049]
# Action : [0.978519]
# Action : [1.28194]
# Action : [1.53467]
# Action : [1.43289]
# Action : [0.938572]
# Action : [-0.229104]
# Action : [-1.3822]
# Action : [-1.81061]
# Action : [-1.91681]
# Action : [-1.93714]
# Action : [-1.91838]
# Action : [-1.70979]
# Action : [-0.500618]
# Action : [0.695303]
# Action : [0.928785]
# Action : [1.18981]
# Action : [1.51653]
# Action : [1.48262]
# Action : [1.11139]
# Action : [0.0955744]
# Action : [-1.18279]
# Action : [-1.75707]
# Action : [-1.90458]
# Action : [-1.93694]
# Action : [-1.92861]
# Action : [-1.80691]
# Action : [-0.969849]
# Action : [0.629651]
# Action : [0.857955]
# Action : [1.09721]
# Action : [1.46782]
# Action : [1.51545]
# Action : [1.24737]
# Action : [0.409744]
# Action : [-0.919592]
# Action : [-1.67534]
# Action : [-1.88433]
# Action : [-1.9332]
# Action : [-1.93358]
# Action : [-1.86714]
# Action : [-1.31171]
# Action : [0.431526]
# Action : [0.772364]
# Action : [1.03111]
# Action : [1.39072]
# Action : [1.529]
# Action : [1.34203]
# Action : [0.668613]
# Action : [-0.625414]
# Action : [-1.56522]
# Action : [-1.85612]
# Action : [-1.92639]
# Action : [-1.93488]
# Action : [-1.8962]
# Action : [-1.51966]
# Action : [0.109554]
# Action : [0.714101]
# Action : [0.988397]
# Action : [1.31055]
# Action : [1.53532]
# Action : [1.41172]
# Action : [0.874043]
# Action : [-0.333899]
# Action : [-1.43543]
# Action : [-1.82391]
# Action : [-1.91964]
# Action : [-1.93654]
# Action : [-1.91327]
# Action : [-1.66833]
# Action : [-0.332215]
# Action : [0.704506]
# Action : [0.948973]
# Action : [1.2232]
# Action : [1.52564]
# Action : [1.46612]
# Action : [1.05164]
# Action : [-0.0235641]
# Action : [-1.26227]
# Action : [-1.77888]
# Action : [-1.90957]
# Action : [-1.93717]
# Action : [-1.92536]
# Action : [-1.77349]
# Action : [-0.803531]
# Action : [0.663143]
# Action : [0.885693]
# Action : [1.13094]
# Action : [1.49054]
# Action : [1.50582]
# Action : [1.20245]
# Action : [0.298335]
# Action : [-1.02328]
# Action : [-1.7094]
# Action : [-1.89296]
# Action : [-1.93513]
# Action : [-1.93243]
# Action : [-1.84955]
# Action : [-1.20678]
# Action : [0.520696]
# Action : [0.80289]
# Action : [1.051]
# Action : [1.42022]
# Action : [1.52625]
# Action : [1.31286]
# Action : [0.584194]
# Action : [-0.731262]
# Action : [-1.60753]
# Action : [-1.86709]
# Action : [-1.92915]
# Action : [-1.93484]
# Action : [-1.88921]
# Action : [-1.45852]
# Action : [0.236403]
# Action : [0.729636]
# Action : [0.999672]
# Action : [1.33797]
# Action : [1.53383]
# Action : [1.38892]
# Action : [0.806833]
# Action : [-0.435097]
# Action : [-1.48292]
# Action : [-1.83549]
# Action : [-1.92194]
# Action : [-1.93575]
# Action : [-1.90752]
# Action : [-1.62126]
# Action : [-0.166206]
# Action : [0.706543]
# Action : [0.966048]
# Action : [1.25655]
# Action : [1.53115]
# Action : [1.44799]
# Action : [0.989454]
# Action : [-0.139071]
# Action : [-1.3319]
# Action : [-1.79737]
# Action : [-1.91372]
# Action : [-1.93712]
# Action : [-1.92166]
# Action : [-1.73872]
# Action : [-0.631772]
# Action : [0.682585]
# Action : [0.910681]
# Action : [1.16439]
# Action : [1.50756]
# Action : [1.49361]
# Action : [1.15408]
# Action : [0.18644]
# Action : [-1.11588]
# Action : [-1.7379]
# Action : [-1.90006]
# Action : [-1.93649]
# Action : [-1.93075]
# Action : [-1.82843]
# Action : [-1.08716]
# Action : [0.589958]
# Action : [0.833913]
# Action : [1.07358]
# Action : [1.44726]
# Action : [1.52141]
# Action : [1.27956]
# Action : [0.493106]
# Action : [-0.834234]
# Action : [-1.64571]
# Action : [-1.87686]
# Action : [-1.93151]
# Action : [-1.93435]
# Action : [-1.87861]
# Action : [-1.38596]
# Action : [0.349545]
# Action : [0.749971]
# Action : [1.01462]
# Action : [1.36586]
# Action : [1.53103]
# Action : [1.36412]
# Action : [0.734179]
# Action : [-0.537487]
# Action : [-1.52807]
# Action : [-1.84662]
# Action : [-1.92416]
# Action : [-1.93506]
# Action : [-1.90115]
# Action : [-1.56696]
# Action : [-0.00824007]
# Action : [0.705415]
# Action : [0.980542]
# Action : [1.28684]
# Action : [1.53501]
# Action : [1.42948]
# Action : [0.927885]
# Action : [-0.247122]
# Action : [-1.39172]
# Action : [-1.81304]
# Action : [-1.91735]
# Action : [-1.93708]
# Action : [-1.91758]
# Action : [-1.70327]
# Action : [-0.472727]
# Action : [0.697489]
# Action : [0.932353]
# Action : [1.19497]
# Action : [1.51822]
# Action : [1.48012]
# Action : [1.102]
# Action : [0.076216]
# Action : [-1.19632]
# Action : [-1.76086]
# Action : [-1.90546]
# Action : [-1.93701]
# Action : [-1.92813]
# Action : [-1.80177]
# Action : [-0.943939]
# Action : [0.636272]
# Action : [0.86268]
# Action : [1.10257]
# Action : [1.47193]
# Action : [1.514]
# Action : [1.24019]
# Action : [0.391697]
# Action : [-0.93707]
# Action : [-1.6812]
# Action : [-1.8858]
# Action : [-1.93352]
# Action : [-1.93339]
# Action : [-1.86438]
# Action : [-1.29498]
# Action : [0.447601]
# Action : [0.777259]
# Action : [1.03457]
# Action : [1.39588]
# Action : [1.52861]
# Action : [1.33728]
# Action : [0.654652]
# Action : [-0.64362]
# Action : [-1.57271]
# Action : [-1.85806]
# Action : [-1.92688]
# Action : [-1.93488]
# Action : [-1.89518]
# Action : [-1.50975]
# Action : [0.132144]
# Action : [0.716235]
# Action : [0.989965]
# Action : [1.31532]
# Action : [1.53529]
# Action : [1.40819]
# Action : [0.863297]
# Action : [-0.350741]
# Action : [-1.44365]
# Action : [-1.82595]
# Action : [-1.9201]
# Action : [-1.93645]
# Action : [-1.91244]
# Action : [-1.66133]
# Action : [-0.305422]
# Action : [0.705315]
# Action : [0.951845]
# Action : [1.2284]
# Action : [1.52666]
# Action : [1.46336]
# Action : [1.04202]
# Action : [-0.041969]
# Action : [-1.27382]
# Action : [-1.78198]
# Action : [-1.91026]
# Action : [-1.93718]
# Action : [-1.92482]
# Action : [-1.76812]
# Action : [-0.776755]
# Action : [0.6671]
# Action : [0.889671]
# Action : [1.13634]
# Action : [1.49347]
# Action : [1.50408]
# Action : [1.19512]
# Action : [0.280814]
# Action : [-1.03853]
# Action : [-1.71422]
# Action : [-1.89417]
# Action : [-1.93538]
# Action : [-1.9322]
# Action : [-1.84648]
# Action : [-1.18923]
# Action : [0.532917]
# Action : [0.807907]
# Action : [1.05414]
# Action : [1.42459]
# Action : [1.52563]
# Action : [1.30795]
# Action : [0.570447]
# Action : [-0.747497]
# Action : [-1.61373]
# Action : [-1.86869]
# Action : [-1.92954]
# Action : [-1.9348]
# Action : [-1.88778]
# Action : [-1.44815]
# Action : [0.255459]
# Action : [0.732446]
# Action : [1.00154]
# Action : [1.34223]
# Action : [1.53343]
# Action : [1.38511]
# Action : [0.795749]
# Action : [-0.451094]
# Action : [-1.49012]
# Action : [-1.83724]
# Action : [-1.92227]
# Action : [-1.93561]
# Action : [-1.90649]
# Action : [-1.61296]
# Action : [-0.140348]
# Action : [0.706239]
# Action : [0.968558]
# Action : [1.2616]
# Action : [1.53188]
# Action : [1.44508]
# Action : [0.979567]
# Action : [-0.1568]
# Action : [-1.34206]
# Action : [-1.80004]
# Action : [-1.91433]
# Action : [-1.93712]
# Action : [-1.92106]
# Action : [-1.73316]
# Action : [-0.605588]
# Action : [0.68521]
# Action : [0.914531]
# Action : [1.16973]
# Action : [1.50969]
# Action : [1.49152]
# Action : [1.14569]
# Action : [0.168122]
# Action : [-1.12988]
# Action : [-1.742]
# Action : [-1.90103]
# Action : [-1.93661]
# Action : [-1.93036]
# Action : [-1.82439]
# Action : [-1.06499]
# Action : [0.599614]
# Action : [0.839027]
# Action : [1.07812]
# Action : [1.45152]
# Action : [1.52036]
# Action : [1.27336]
# Action : [0.476683]
# Action : [-0.851705]
# Action : [-1.65193]
# Action : [-1.87844]
# Action : [-1.93188]
# Action : [-1.93423]
# Action : [-1.87656]
# Action : [-1.37182]
# Action : [0.366666]
# Action : [0.754224]
# Action : [1.01795]
# Action : [1.37087]
# Action : [1.53066]
# Action : [1.35982]
# Action : [0.721305]
# Action : [-0.555132]
# Action : [-1.53568]
# Action : [-1.84855]
# Action : [-1.9246]
# Action : [-1.93501]
# Action : [-1.90016]
# Action : [-1.5577]
# Action : [0.0167155]
# Action : [0.706387]
# Action : [0.98211]
# Action : [1.29139]
# Action : [1.53513]
# Action : [1.42593]
# Action : [0.917179]
# Action : [-0.264687]
# Action : [-1.40075]
# Action : [-1.81529]
# Action : [-1.91781]
# Action : [-1.93695]
# Action : [-1.9167]
# Action : [-1.69634]
# Action : [-0.444006]
# Action : [0.699471]
# Action : [0.935986]
# Action : [1.20076]
# Action : [1.51991]
# Action : [1.47735]
# Action : [1.09179]
# Action : [0.0555101]
# Action : [-1.21049]
# Action : [-1.76478]
# Action : [-1.90636]
# Action : [-1.93706]
# Action : [-1.92758]
# Action : [-1.79606]
# Action : [-0.915573]
# Action : [0.642856]
# Action : [0.867678]
# Action : [1.10828]
# Action : [1.47597]
# Action : [1.51244]
# Action : [1.23251]
# Action : [0.372502]
# Action : [-0.955356]
# Action : [-1.68728]
# Action : [-1.88734]
# Action : [-1.93386]
# Action : [-1.93319]
# Action : [-1.86144]
# Action : [-1.2772]
# Action : [0.463944]
# Action : [0.782327]
# Action : [1.03814]
# Action : [1.40119]
# Action : [1.52825]
# Action : [1.33237]
# Action : [0.64017]
# Action : [-0.662278]
# Action : [-1.58033]
# Action : [-1.86005]
# Action : [-1.92739]
# Action : [-1.9349]
# Action : [-1.89411]
# Action : [-1.49953]
# Action : [0.154428]
# Action : [0.718899]
# Action : [0.99148]
# Action : [1.32005]
# Action : [1.53517]
# Action : [1.4045]
# Action : [0.852228]
# Action : [-0.367796]
# Action : [-1.45183]
# Action : [-1.82797]
# Action : [-1.92053]
# Action : [-1.93634]
# Action : [-1.91156]
# Action : [-1.65392]
# Action : [-0.277811]
# Action : [0.70602]
# Action : [0.954778]
# Action : [1.23411]
# Action : [1.52768]
# Action : [1.46037]
# Action : [1.03173]
# Action : [-0.0614005]
# Action : [-1.2858]
# Action : [-1.78517]
# Action : [-1.91097]
# Action : [-1.93717]
# Action : [-1.92423]
# Action : [-1.76237]
# Action : [-0.748004]
# Action : [0.670908]
# Action : [0.893802]
# Action : [1.14199]
# Action : [1.49654]
# Action : [1.50221]
# Action : [1.1873]
# Action : [0.262263]
# Action : [-1.05442]
# Action : [-1.7192]
# Action : [-1.89543]
# Action : [-1.93565]
# Action : [-1.93197]
# Action : [-1.8432]
# Action : [-1.17025]
# Action : [0.544922]
# Action : [0.813022]
# Action : [1.05738]
# Action : [1.42904]
# Action : [1.52498]
# Action : [1.30285]
# Action : [0.556213]
# Action : [-0.764078]
# Action : [-1.62001]
# Action : [-1.8703]
# Action : [-1.92994]
# Action : [-1.93475]
# Action : [-1.88625]
# Action : [-1.43727]
# Action : [0.274319]
# Action : [0.735296]
# Action : [1.00341]
# Action : [1.34652]
# Action : [1.53299]
# Action : [1.38128]
# Action : [0.784612]
# Action : [-0.467025]
# Action : [-1.49723]
# Action : [-1.83898]
# Action : [-1.9226]
# Action : [-1.93548]
# Action : [-1.90547]
# Action : [-1.60459]
# Action : [-0.115006]
# Action : [0.705897]
# Action : [0.971003]
# Action : [1.26653]
# Action : [1.5326]
# Action : [1.44222]
# Action : [0.969903]
# Action : [-0.174129]
# Action : [-1.35188]
# Action : [-1.80264]
# Action : [-1.91494]
# Action : [-1.93712]
# Action : [-1.92043]
# Action : [-1.72772]
# Action : [-0.580417]
# Action : [0.687616]
# Action : [0.918211]
# Action : [1.17477]
# Action : [1.51153]
# Action : [1.48952]
# Action : [1.13766]
# Action : [0.150728]
# Action : [-1.14296]
# Action : [-1.74581]
# Action : [-1.90194]
# Action : [-1.93672]
# Action : [-1.92998]
# Action : [-1.8205]
# Action : [-1.04313]
# Action : [0.607578]
# Action : [0.843648]
# Action : [1.08241]
# Action : [1.4554]
# Action : [1.51933]
# Action : [1.26748]
# Action : [0.461276]
# Action : [-0.867797]
# Action : [-1.65758]
# Action : [-1.87987]
# Action : [-1.93221]
# Action : [-1.9341]
# Action : [-1.87453]
# Action : [-1.35834]
# Action : [0.382296]
# Action : [0.758192]
# Action : [1.02106]
# Action : [1.37552]
# Action : [1.53031]
# Action : [1.3558]
# Action : [0.709258]
# Action : [-0.571469]
# Action : [-1.54266]
# Action : [-1.85034]
# Action : [-1.92502]
# Action : [-1.93498]
# Action : [-1.89925]
# Action : [-1.54907]
# Action : [0.0387248]
# Action : [0.708153]
# Action : [0.983588]
# Action : [1.2956]
# Action : [1.53527]
# Action : [1.42267]
# Action : [0.907265]
# Action : [-0.280849]
# Action : [-1.40899]
# Action : [-1.81735]
# Action : [-1.91824]
# Action : [-1.93685]
# Action : [-1.9159]
# Action : [-1.68995]
# Action : [-0.41797]
# Action : [0.701108]
# Action : [0.939204]
# Action : [1.20615]
# Action : [1.52139]
# Action : [1.47477]
# Action : [1.0824]
# Action : [0.0366851]
# Action : [-1.22315]
# Action : [-1.76826]
# Action : [-1.90716]
# Action : [-1.9371]
# Action : [-1.92707]
# Action : [-1.79081]
# Action : [-0.88942]
# Action : [0.64838]
# Action : [0.872123]
# Action : [1.11367]
# Action : [1.47957]
# Action : [1.51093]
# Action : [1.22545]
# Action : [0.354854]
# Action : [-0.971935]
# Action : [-1.69275]
# Action : [-1.88872]
# Action : [-1.93417]
# Action : [-1.93301]
# Action : [-1.8587]
# Action : [-1.26072]
# Action : [0.478423]
# Action : [0.787284]
# Action : [1.04123]
# Action : [1.40591]
# Action : [1.52781]
# Action : [1.32773]
# Action : [0.626718]
# Action : [-0.679241]
# Action : [-1.58713]
# Action : [-1.86181]
# Action : [-1.92783]
# Action : [-1.93489]
# Action : [-1.893]
# Action : [-1.48974]
# Action : [0.174916]
# Action : [0.721418]
# Action : [0.993498]
# Action : [1.32449]
# Action : [1.53492]
# Action : [1.40072]
# Action : [0.841171]
# Action : [-0.384473]
# Action : [-1.45966]
# Action : [-1.82986]
# Action : [-1.92092]
# Action : [-1.93619]
# Action : [-1.9106]
# Action : [-1.6462]
# Action : [-0.249978]
# Action : [0.7066]
# Action : [0.957726]
# Action : [1.23987]
# Action : [1.5287]
# Action : [1.4573]
# Action : [1.02117]
# Action : [-0.0811446]
# Action : [-1.2978]
# Action : [-1.78836]
# Action : [-1.91169]
# Action : [-1.93716]
# Action : [-1.92363]
# Action : [-1.75652]
# Action : [-0.718664]
# Action : [0.674372]
# Action : [0.897871]
# Action : [1.14768]
# Action : [1.49956]
# Action : [1.5003]
# Action : [1.17935]
# Action : [0.243561]
# Action : [-1.07015]
# Action : [-1.72411]
# Action : [-1.89668]
# Action : [-1.93592]
# Action : [-1.93174]
# Action : [-1.83986]
# Action : [-1.15096]
# Action : [0.556454]
# Action : [0.818064]
# Action : [1.0609]
# Action : [1.43343]
# Action : [1.52425]
# Action : [1.29759]
# Action : [0.541726]
# Action : [-0.780649]
# Action : [-1.6262]
# Action : [-1.87189]
# Action : [-1.93033]
# Action : [-1.93467]
# Action : [-1.88456]
# Action : [-1.42597]
# Action : [0.292992]
# Action : [0.738254]
# Action : [1.00551]
# Action : [1.35087]
# Action : [1.53247]
# Action : [1.37733]
# Action : [0.773141]
# Action : [-0.483237]
# Action : [-1.5044]
# Action : [-1.84072]
# Action : [-1.92293]
# Action : [-1.93535]
# Action : [-1.90443]
# Action : [-1.59587]
# Action : [-0.089375]
# Action : [0.705513]
# Action : [0.973475]
# Action : [1.2715]
# Action : [1.53332]
# Action : [1.4393]
# Action : [0.96004]
# Action : [-0.191662]
# Action : [-1.3617]
# Action : [-1.80523]
# Action : [-1.91555]
# Action : [-1.93714]
# Action : [-1.91979]
# Action : [-1.72216]
# Action : [-0.555098]
# Action : [0.690277]
# Action : [0.921645]
# Action : [1.17963]
# Action : [1.51315]
# Action : [1.48735]
# Action : [1.12934]
# Action : [0.133119]
# Action : [-1.15588]
# Action : [-1.74948]
# Action : [-1.9028]
# Action : [-1.93679]
# Action : [-1.92954]
# Action : [-1.8163]
# Action : [-1.01984]
# Action : [0.61516]
# Action : [0.848357]
# Action : [1.08697]
# Action : [1.45937]
# Action : [1.51817]
# Action : [1.2612]
# Action : [0.444982]
# Action : [-0.884509]
# Action : [-1.66338]
# Action : [-1.88133]
# Action : [-1.93254]
# Action : [-1.93395]
# Action : [-1.8723]
# Action : [-1.34387]
# Action : [0.398398]
# Action : [0.762606]
# Action : [1.02424]
# Action : [1.38036]
# Action : [1.52988]
# Action : [1.35145]
# Action : [0.696341]
# Action : [-0.588703]
# Action : [-1.54992]
# Action : [-1.85218]
# Action : [-1.92544]
# Action : [-1.93493]
# Action : [-1.89825]
# Action : [-1.53964]
# Action : [0.0619854]
# Action : [0.710094]
# Action : [0.985164]
# Action : [1.30035]
# Action : [1.53537]
# Action : [1.41913]
# Action : [0.896488]
# Action : [-0.298254]
# Action : [-1.41777]
# Action : [-1.81954]
# Action : [-1.9187]
# Action : [-1.93675]
# Action : [-1.91504]
# Action : [-1.68298]
# Action : [-0.389897]
# Action : [0.702526]
# Action : [0.942531]
# Action : [1.21188]
# Action : [1.52292]
# Action : [1.47197]
# Action : [1.07228]
# Action : [0.0166139]
# Action : [-1.23641]
# Action : [-1.77188]
# Action : [-1.90799]
# Action : [-1.93713]
# Action : [-1.92651]
# Action : [-1.78516]
# Action : [-0.861097]
# Action : [0.653779]
# Action : [0.876757]
# Action : [1.11943]
# Action : [1.48334]
# Action : [1.50929]
# Action : [1.21788]
# Action : [0.336053]
# Action : [-0.989356]
# Action : [-1.69845]
# Action : [-1.89018]
# Action : [-1.9345]
# Action : [-1.93282]
# Action : [-1.85578]
# Action : [-1.24313]
# Action : [0.493228]
# Action : [0.792493]
# Action : [1.04443]
# Action : [1.41078]
# Action : [1.52735]
# Action : [1.32286]
# Action : [0.61265]
# Action : [-0.696756]
# Action : [-1.59409]
# Action : [-1.86362]
# Action : [-1.92828]
# Action : [-1.93489]
# Action : [-1.89185]
# Action : [-1.47954]
# Action : [0.195697]
# Action : [0.723994]
# Action : [0.995599]
# Action : [1.32901]
# Action : [1.53467]
# Action : [1.39685]
# Action : [0.829854]
# Action : [-0.401381]
# Action : [-1.46753]
# Action : [-1.83177]
# Action : [-1.92128]
# Action : [-1.93605]
# Action : [-1.90961]
# Action : [-1.63831]
# Action : [-0.221765]
# Action : [0.70677]
# Action : [0.96054]
# Action : [1.24551]
# Action : [1.52953]
# Action : [1.45419]
# Action : [1.0106]
# Action : [-0.100628]
# Action : [-1.30942]
# Action : [-1.79144]
# Action : [-1.91238]
# Action : [-1.93715]
# Action : [-1.92297]
# Action : [-1.7506]
# Action : [-0.689405]
# Action : [0.6774]
# Action : [0.901833]
# Action : [1.1534]
# Action : [1.50249]
# Action : [1.49832]
# Action : [1.17131]
# Action : [0.224872]
# Action : [-1.08557]
# Action : [-1.72886]
# Action : [-1.89788]
# Action : [-1.93617]
# Action : [-1.9315]
# Action : [-1.83643]
# Action : [-1.13139]
# Action : [0.567541]
# Action : [0.823049]
# Action : [1.06483]
# Action : [1.43777]
# Action : [1.5234]
# Action : [1.29207]
# Action : [0.526762]
# Action : [-0.797418]
# Action : [-1.63237]
# Action : [-1.87346]
# Action : [-1.9307]
# Action : [-1.93457]
# Action : [-1.88273]
# Action : [-1.41388]
# Action : [0.311536]
# Action : [0.741698]
# Action : [1.00824]
# Action : [1.35554]
# Action : [1.53194]
# Action : [1.37311]
# Action : [0.760835]
# Action : [-0.500478]
# Action : [-1.51195]
# Action : [-1.84258]
# Action : [-1.92329]
# Action : [-1.93523]
# Action : [-1.90333]
# Action : [-1.58655]
# Action : [-0.0626487]
# Action : [0.705083]
# Action : [0.97604]
# Action : [1.27665]
# Action : [1.53407]
# Action : [1.43626]
# Action : [0.949717]
# Action : [-0.20985]
# Action : [-1.37177]
# Action : [-1.80789]
# Action : [-1.91618]
# Action : [-1.93715]
# Action : [-1.91913]
# Action : [-1.71629]
# Action : [-0.529061]
# Action : [0.692804]
# Action : [0.925091]
# Action : [1.18452]
# Action : [1.51479]
# Action : [1.4851]
# Action : [1.12081]
# Action : [0.115186]
# Action : [-1.16884]
# Action : [-1.75315]
# Action : [-1.90365]
# Action : [-1.93686]
# Action : [-1.9291]
# Action : [-1.81187]
# Action : [-0.99604]
# Action : [0.62235]
# Action : [0.85301]
# Action : [1.09165]
# Action : [1.46345]
# Action : [1.51694]
# Action : [1.25473]
# Action : [0.428357]
# Action : [-0.901262]
# Action : [-1.66914]
# Action : [-1.88279]
# Action : [-1.93287]
# Action : [-1.9338]
# Action : [-1.86993]
# Action : [-1.32896]
# Action : [0.414184]
# Action : [0.767186]
# Action : [1.02746]
# Action : [1.38523]
# Action : [1.52947]
# Action : [1.34704]
# Action : [0.683343]
# Action : [-0.605975]
# Action : [-1.55715]
# Action : [-1.85403]
# Action : [-1.92588]
# Action : [-1.9349]
# Action : [-1.89728]
# Action : [-1.53024]
# Action : [0.0846695]
# Action : [0.711996]
# Action : [0.986701]
# Action : [1.30527]
# Action : [1.53537]
# Action : [1.41558]
# Action : [0.885757]
# Action : [-0.315378]
# Action : [-1.4263]
# Action : [-1.82165]
# Action : [-1.91915]
# Action : [-1.93664]
# Action : [-1.91419]
# Action : [-1.67598]
# Action : [-0.362037]
# Action : [0.703544]
# Action : [0.945681]
# Action : [1.2174]
# Action : [1.52431]
# Action : [1.46916]
# Action : [1.0623]
# Action : [-0.00292651]
# Action : [-1.24909]
# Action : [-1.77532]
# Action : [-1.90877]
# Action : [-1.93716]
# Action : [-1.92595]
# Action : [-1.77952]
# Action : [-0.833096]
# Action : [0.65843]
# Action : [0.881132]
# Action : [1.12493]
# Action : [1.48692]
# Action : [1.50767]
# Action : [1.21051]
# Action : [0.317871]
# Action : [-1.00591]
# Action : [-1.70383]
# Action : [-1.89155]
# Action : [-1.93482]
# Action : [-1.93265]
# Action : [-1.85286]
# Action : [-1.22588]
# Action : [0.506658]
# Action : [0.797347]
# Action : [1.04748]
# Action : [1.41534]
# Action : [1.52692]
# Action : [1.31825]
# Action : [0.599351]
# Action : [-0.713099]
# Action : [-1.60053]
# Action : [-1.8653]
# Action : [-1.92872]
# Action : [-1.93489]
# Action : [-1.89072]
# Action : [-1.46997]
# Action : [0.214687]
# Action : [0.726491]
# Action : [0.997497]
# Action : [1.33313]
# Action : [1.53431]
# Action : [1.39326]
# Action : [0.819394]
# Action : [-0.416815]
# Action : [-1.47462]
# Action : [-1.83349]
# Action : [-1.92159]
# Action : [-1.93592]
# Action : [-1.9087]
# Action : [-1.63069]
# Action : [-0.196273]
# Action : [0.70677]
# Action : [0.963077]
# Action : [1.25059]
# Action : [1.53028]
# Action : [1.45136]
# Action : [1.00095]
# Action : [-0.118272]
# Action : [-1.31982]
# Action : [-1.79418]
# Action : [-1.91299]
# Action : [-1.93713]
# Action : [-1.92237]
# Action : [-1.74517]
# Action : [-0.662952]
# Action : [0.679816]
# Action : [0.905991]
# Action : [1.15835]
# Action : [1.50493]
# Action : [1.49626]
# Action : [1.16357]
# Action : [0.207406]
# Action : [-1.09954]
# Action : [-1.73307]
# Action : [-1.89891]
# Action : [-1.93633]
# Action : [-1.93119]
# Action : [-1.83292]
# Action : [-1.11179]
# Action : [0.577871]
# Action : [0.827934]
# Action : [1.06871]
# Action : [1.44205]
# Action : [1.52253]
# Action : [1.28653]
# Action : [0.511808]
# Action : [-0.813932]
# Action : [-1.63839]
# Action : [-1.87499]
# Action : [-1.93106]
# Action : [-1.93447]
# Action : [-1.88091]
# Action : [-1.40152]
# Action : [0.329055]
# Action : [0.745179]
# Action : [1.01096]
# Action : [1.36011]
# Action : [1.53147]
# Action : [1.36902]
# Action : [0.748839]
# Action : [-0.517154]
# Action : [-1.51922]
# Action : [-1.84438]
# Action : [-1.92366]
# Action : [-1.93512]
# Action : [-1.9023]
# Action : [-1.57756]
# Action : [-0.0374546]
# Action : [0.705012]
# Action : [0.978279]
# Action : [1.2814]
# Action : [1.53463]
# Action : [1.43325]
# Action : [0.939761]
# Action : [-0.227077]
# Action : [-1.38112]
# Action : [-1.81033]
# Action : [-1.91675]
# Action : [-1.93714]
# Action : [-1.91846]
# Action : [-1.7105]
# Action : [-0.503701]
# Action : [0.695046]
# Action : [0.928387]
# Action : [1.18924]
# Action : [1.51635]
# Action : [1.48289]
# Action : [1.11242]
# Action : [0.0977113]
# Action : [-1.18128]
# Action : [-1.75665]
# Action : [-1.90448]
# Action : [-1.93693]
# Action : [-1.92867]
# Action : [-1.80747]
# Action : [-0.972704]
# Action : [0.628886]
# Action : [0.857425]
# Action : [1.09661]
# Action : [1.46735]
# Action : [1.51562]
# Action : [1.24817]
# Action : [0.411758]
# Action : [-0.917624]
# Action : [-1.67467]
# Action : [-1.88417]
# Action : [-1.93316]
# Action : [-1.93361]
# Action : [-1.86745]
# Action : [-1.31358]
# Action : [0.429688]
# Action : [0.77181]
# Action : [1.03072]
# Action : [1.39014]
# Action : [1.52905]
# Action : [1.34257]
# Action : [0.670189]
# Action : [-0.623345]
# Action : [-1.56437]
# Action : [-1.8559]
# Action : [-1.92633]
# Action : [-1.93488]
# Action : [-1.89632]
# Action : [-1.52078]
# Action : [0.106937]
# Action : [0.713879]
# Action : [0.988218]
# Action : [1.31]
# Action : [1.53532]
# Action : [1.41212]
# Action : [0.875274]
# Action : [-0.33196]
# Action : [-1.43448]
# Action : [-1.82367]
# Action : [-1.91959]
# Action : [-1.93655]
# Action : [-1.91336]
# Action : [-1.66914]
# Action : [-0.335318]
# Action : [0.704406]
# Action : [0.948637]
# Action : [1.2226]
# Action : [1.52551]
# Action : [1.46644]
# Action : [1.05275]
# Action : [-0.0214329]
# Action : [-1.26092]
# Action : [-1.77851]
# Action : [-1.90948]
# Action : [-1.93717]
# Action : [-1.92542]
# Action : [-1.77412]
# Action : [-0.806609]
# Action : [0.662664]
# Action : [0.885227]
# Action : [1.13031]
# Action : [1.49019]
# Action : [1.50602]
# Action : [1.2033]
# Action : [0.300371]
# Action : [-1.0215]
# Action : [-1.70883]
# Action : [-1.89282]
# Action : [-1.9351]
# Action : [-1.93245]
# Action : [-1.84991]
# Action : [-1.20882]
# Action : [0.519241]
# Action : [0.802299]
# Action : [1.05063]
# Action : [1.41971]
# Action : [1.52632]
# Action : [1.31344]
# Action : [0.58581]
# Action : [-0.72934]
# Action : [-1.60679]
# Action : [-1.8669]
# Action : [-1.92911]
# Action : [-1.93485]
# Action : [-1.88938]
# Action : [-1.45974]
# Action : [0.234118]
# Action : [0.729301]
# Action : [0.999441]
# Action : [1.33745]
# Action : [1.53388]
# Action : [1.38938]
# Action : [0.808167]
# Action : [-0.433165]
# Action : [-1.48205]
# Action : [-1.83528]
# Action : [-1.92191]
# Action : [-1.93576]
# Action : [-1.90764]
# Action : [-1.62226]
# Action : [-0.169369]
# Action : [0.706576]
# Action : [0.965739]
# Action : [1.25593]
# Action : [1.53106]
# Action : [1.44834]
# Action : [0.990664]
# Action : [-0.136894]
# Action : [-1.33064]
# Action : [-1.79704]
# Action : [-1.91364]
# Action : [-1.93713]
# Action : [-1.92173]
# Action : [-1.7394]
# Action : [-0.635038]
# Action : [0.682284]
# Action : [0.91021]
# Action : [1.16373]
# Action : [1.5073]
# Action : [1.49391]
# Action : [1.15511]
# Action : [0.188684]
# Action : [-1.11416]
# Action : [-1.7374]
# Action : [-1.89994]
# Action : [-1.93647]
# Action : [-1.9308]
# Action : [-1.82893]
# Action : [-1.08988]
# Action : [0.588672]
# Action : [0.833258]
# Action : [1.073]
# Action : [1.44671]
# Action : [1.52155]
# Action : [1.28035]
# Action : [0.495204]
# Action : [-0.831984]
# Action : [-1.64491]
# Action : [-1.87665]
# Action : [-1.93146]
# Action : [-1.93436]
# Action : [-1.87888]
# Action : [-1.38774]
# Action : [0.347265]
# Action : [0.749416]
# Action : [1.01418]
# Action : [1.3652]
# Action : [1.53108]
# Action : [1.36468]
# Action : [0.735863]
# Action : [-0.535165]
# Action : [-1.52707]
# Action : [-1.84636]
# Action : [-1.9241]
# Action : [-1.93506]
# Action : [-1.90128]
# Action : [-1.56818]
# Action : [-0.0115642]
# Action : [0.70531]
# Action : [0.980321]
# Action : [1.28623]
# Action : [1.53499]
# Action : [1.42995]
# Action : [0.929291]
# Action : [-0.244793]
# Action : [-1.39051]
# Action : [-1.81274]
# Action : [-1.91729]
# Action : [-1.93709]
# Action : [-1.9177]
# Action : [-1.70417]
# Action : [-0.476497]
# Action : [0.697211]
# Action : [0.931872]
# Action : [1.19427]
# Action : [1.51799]
# Action : [1.48046]
# Action : [1.10329]
# Action : [0.0788634]
# Action : [-1.19448]
# Action : [-1.76034]
# Action : [-1.90534]
# Action : [-1.937]
# Action : [-1.9282]
# Action : [-1.80249]
# Action : [-0.94749]
# Action : [0.635399]
# Action : [0.862042]
# Action : [1.10185]
# Action : [1.4714]
# Action : [1.51419]
# Action : [1.24116]
# Action : [0.394128]
# Action : [-0.934731]
# Action : [-1.68041]
# Action : [-1.88561]
# Action : [-1.93348]
# Action : [-1.93341]
# Action : [-1.86475]
# Action : [-1.29723]
# Action : [0.445478]
# Action : [0.776608]
# Action : [1.03411]
# Action : [1.3952]
# Action : [1.52865]
# Action : [1.33792]
# Action : [0.656511]
# Action : [-0.641207]
# Action : [-1.57172]
# Action : [-1.8578]
# Action : [-1.92681]
# Action : [-1.93488]
# Action : [-1.89532]
# Action : [-1.51106]
# Action : [0.129203]
# Action : [0.715886]
# Action : [0.989776]
# Action : [1.3147]
# Action : [1.5353]
# Action : [1.40867]
# Action : [0.864741]
# Action : [-0.348502]
# Action : [-1.44256]
# Action : [-1.82569]
# Action : [-1.92004]
# Action : [-1.93647]
# Action : [-1.91256]
# Action : [-1.66229]
# Action : [-0.309052]
# Action : [0.705214]
# Action : [0.951455]
# Action : [1.22764]
# Action : [1.52653]
# Action : [1.46375]
# Action : [1.04337]
# Action : [-0.0394087]
# Action : [-1.27222]
# Action : [-1.78155]
# Action : [-1.91017]
# Action : [-1.93718]
# Action : [-1.9249]
# Action : [-1.76887]
# Action : [-0.780541]
# Action : [0.666566]
# Action : [0.889116]
# Action : [1.13558]
# Action : [1.49306]
# Action : [1.50433]
# Action : [1.19615]
# Action : [0.28328]
# Action : [-1.0364]
# Action : [-1.71354]
# Action : [-1.894]
# Action : [-1.93535]
# Action : [-1.93223]
# Action : [-1.84691]
# Action : [-1.1917]
# Action : [0.531228]
# Action : [0.807207]
# Action : [1.0537]
# Action : [1.42398]
# Action : [1.52572]
# Action : [1.30864]
# Action : [0.572369]
# Action : [-0.745241]
# Action : [-1.61287]
# Action : [-1.86847]
# Action : [-1.92949]
# Action : [-1.93481]
# Action : [-1.88798]
# Action : [-1.4496]
# Action : [0.252833]
# Action : [0.732056]
# Action : [1.00129]
# Action : [1.34164]
# Action : [1.53348]
# Action : [1.38563]
# Action : [0.797277]
# Action : [-0.448897]
# Action : [-1.48913]
# Action : [-1.837]
# Action : [-1.92222]
# Action : [-1.93563]
# Action : [-1.90663]
# ...
# Action : [-1.88997]
# Action : [-1.46407]
# Action : [0.225991]
# Action : [0.728117]
# Action : [0.998622]
# Action : [1.33564]
# Action : [1.53406]
# Action : [1.39102]
# Action : [0.812896]
# Action : [-0.426296]
# Action : [-1.47894]
# Action : [-1.83453]
# Action : [-1.92177]
# Action : [-1.93583]
# Action : [-1.90809]
# Action : [-1.62582]
# Action : [-0.180654]
# Action : [0.706691]
# Action : [0.964635]
# Action : [1.2537]
# Action : [1.53074]
# Action : [1.44961]
# Action : [0.994974]
# Action : [-0.129116]
# Action : [-1.32614]
# Action : [-1.79585]
# Action : [-1.91337]
# Action : [-1.93713]
# Action : [-1.922]
# Action : [-1.74183]
# Action : [-0.646717]
# Action : [0.681176]
# Action : [0.908516]
# Action : [1.16137]
# Action : [1.50636]
# Action : [1.49497]
# Action : [1.1588]
# Action : [0.196734]
# Action : [-1.10796]
# Action : [-1.73559]
# Action : [-1.89952]
# Action : [-1.93643]
# Action : [-1.93099]
# Action : [-1.83073]
# Action : [-1.09966]
# Action : [0.583984]
# Action : [0.830896]
# Action : [1.07106]
# Action : [1.44464]
# Action : [1.522]
# Action : [1.28314]
# Action : [0.502669]
# Action : [-0.823915]
# Action : [-1.64201]
# Action : [-1.87591]
# Action : [-1.93128]
# Action : [-1.93442]
# Action : [-1.8798]
# Action : [-1.39398]
# Action : [0.33912]
# Action : [0.747509]
# Action : [1.01271]
# Action : [1.36291]
# Action : [1.53126]
# Action : [1.36664]
# Action : [0.741726]
# Action : [-0.527056]
# Action : [-1.52354]
# Action : [-1.84547]
# Action : [-1.9239]
# Action : [-1.93509]
# Action : [-1.90174]
# Action : [-1.57242]
# Action : [-0.0232238]
# Action : [0.705184]
# Action : [0.979423]
# Action : [1.28404]
# Action : [1.53484]
# Action : [1.43146]
# Action : [0.934047]
# Action : [-0.236786]
# Action : [-1.38629]
# Action : [-1.81166]
# Action : [-1.91705]
# Action : [-1.93712]
# Action : [-1.91805]
# Action : [-1.70707]
# Action : [-0.488886]
# Action : [0.696254]
# Action : [0.930292]
# Action : [1.19199]
# Action : [1.51725]
# Action : [1.48157]
# Action : [1.10746]
# Action : [0.0874517]
# Action : [-1.18849]
# Action : [-1.75867]
# Action : [-1.90495]
# Action : [-1.93697]
# Action : [-1.92841]
# Action : [-1.80478]
# Action : [-0.958986]
# Action : [0.632498]
# Action : [0.859956]
# Action : [1.09948]
# Action : [1.46959]
# Action : [1.51484]
# Action : [1.24434]
# Action : [0.402112]
# Action : [-0.927017]
# Action : [-1.67783]
# Action : [-1.88496]
# Action : [-1.93333]
# Action : [-1.9335]
# Action : [-1.86597]
# Action : [-1.30463]
# Action : [0.438412]
# Action : [0.77445]
# Action : [1.03258]
# Action : [1.39292]
# Action : [1.52881]
# Action : [1.34001]
# Action : [0.662671]
# Action : [-0.633187]
# Action : [-1.56843]
# Action : [-1.85695]
# Action : [-1.92659]
# Action : [-1.93488]
# Action : [-1.89576]
# Action : [-1.51542]
# Action : [0.119329]
# Action : [0.714936]
# Action : [0.989067]
# Action : [1.31259]
# Action : [1.5353]
# Action : [1.41021]
# Action : [0.86944]
# Action : [-0.34113]
# Action : [-1.43896]
# Action : [-1.82479]
# Action : [-1.91984]
# Action : [-1.9365]
# Action : [-1.91291]
# Action : [-1.66533]
# Action : [-0.320671]
# Action : [0.704868]
# Action : [0.950216]
# Action : [1.22542]
# Action : [1.52608]
# Action : [1.46494]
# Action : [1.04752]
# Action : [-0.0314777]
# Action : [-1.26726]
# Action : [-1.78022]
# Action : [-1.90987]
# Action : [-1.93718]
# Action : [-1.92513]
# Action : [-1.77117]
# Action : [-0.792075]
# Action : [0.664885]
# Action : [0.887412]
# Action : [1.13327]
# Action : [1.4918]
# Action : [1.50508]
# Action : [1.19931]
# Action : [0.290803]
# Action : [-1.02987]
# Action : [-1.71148]
# Action : [-1.89349]
# Action : [-1.93524]
# Action : [-1.93233]
# Action : [-1.84823]
# Action : [-1.19924]
# Action : [0.526015]
# Action : [0.805061]
# Action : [1.05236]
# Action : [1.42211]
# Action : [1.52598]
# Action : [1.31074]
# Action : [0.578253]
# Action : [-0.738304]
# Action : [-1.61023]
# Action : [-1.86778]
# Action : [-1.92932]
# Action : [-1.93482]
# Action : [-1.88859]
# Action : [-1.45403]
# Action : [0.244717]
# Action : [0.730857]
# Action : [1.0005]
# Action : [1.33983]
# Action : [1.53365]
# Action : [1.38725]
# Action : [0.80199]
# Action : [-0.4421]
# Action : [-1.48608]
# Action : [-1.83626]
# Action : [-1.92208]
# Action : [-1.93569]
# Action : [-1.90706]
# Action : [-1.61763]
# Action : [-0.154812]
# Action : [0.706414]
# Action : [0.967157]
# Action : [1.25878]
# Action : [1.53148]
# Action : [1.4467]
# Action : [0.985095]
# Action : [-0.1469]
# Action : [-1.3364]
# Action : [-1.79855]
# Action : [-1.91399]
# Action : [-1.93712]
# Action : [-1.92139]
# Action : [-1.73627]
# Action : [-0.620142]
# Action : [0.68373]
# Action : [0.912383]
# Action : [1.16675]
# Action : [1.5085]
# Action : [1.49268]
# Action : [1.15037]
# Action : [0.178321]
# Action : [-1.12211]
# Action : [-1.73973]
# Action : [-1.90049]
# Action : [-1.93654]
# Action : [-1.93057]
# Action : [-1.82664]
# Action : [-1.07742]
# Action : [0.594457]
# Action : [0.836215]
# Action : [1.07563]
# Action : [1.44918]
# Action : [1.52094]
# Action : [1.27677]
# Action : [0.485722]
# Action : [-0.84212]
# Action : [-1.64852]
# Action : [-1.87757]
# Action : [-1.93167]
# Action : [-1.93429]
# Action : [-1.87769]
# Action : [-1.37959]
# Action : [0.357337]
# Action : [0.751898]
# Action : [1.01613]
# Action : [1.36814]
# Action : [1.53086]
# Action : [1.36217]
# Action : [0.728341]
# Action : [-0.545513]
# Action : [-1.53154]
# Action : [-1.8475]
# Action : [-1.92436]
# Action : [-1.93503]
# Action : [-1.90069]
# Action : [-1.56276]
# Action : [0.00317277]
# Action : [0.705853]
# Action : [0.981262]
# Action : [1.28893]
# Action : [1.53507]
# Action : [1.42787]
# Action : [0.922999]
# Action : [-0.255161]
# Action : [-1.39587]
# Action : [-1.81407]
# Action : [-1.91756]
# Action : [-1.93702]
# Action : [-1.91718]
# Action : [-1.70012]
# Action : [-0.459577]
# Action : [0.698423]
# Action : [0.934027]
# Action : [1.19756]
# Action : [1.519]
# Action : [1.47887]
# Action : [1.09737]
# Action : [0.0667919]
# Action : [-1.20281]
# Action : [-1.76266]
# Action : [-1.90587]
# Action : [-1.93703]
# Action : [-1.92788]
# Action : [-1.7992]
# Action : [-0.931104]
# Action : [0.639334]
# Action : [0.864964]
# Action : [1.10517]
# Action : [1.47378]
# Action : [1.51329]
# Action : [1.2367]
# Action : [0.382973]
# Action : [-0.945421]
# Action : [-1.68398]
# Action : [-1.8865]
# Action : [-1.93367]
# Action : [-1.9333]
# Action : [-1.86304]
# Action : [-1.2869]
# Action : [0.455118]
# Action : [0.779578]
# Action : [1.0362]
# Action : [1.39831]
# Action : [1.52844]
# Action : [1.33504]
# Action : [0.64803]
# Action : [-0.652182]
# Action : [-1.57622]
# Action : [-1.85898]
# Action : [-1.92711]
# Action : [-1.93489]
# Action : [-1.89469]
# Action : [-1.50507]
# Action : [0.142453]
# Action : [0.717463]
# Action : [0.990633]
# Action : [1.31751]
# Action : [1.53524]
# Action : [1.4065]
# Action : [0.858219]
# Action : [-0.358595]
# Action : [-1.44743]
# Action : [-1.82689]
# Action : [-1.9203]
# Action : [-1.9364]
# Action : [-1.91204]
# Action : [-1.65794]
# Action : [-0.292729]
# Action : [0.705654]
# Action : [0.953197]
# Action : [1.23103]
# Action : [1.52713]
# Action : [1.46199]
# Action : [1.0373]
# Action : [-0.0509057]
# Action : [-1.27935]
# Action : [-1.78345]
# Action : [-1.91059]
# Action : [-1.93717]
# Action : [-1.92455]
# Action : [-1.76549]
# Action : [-0.763537]
# Action : [0.668904]
# Action : [0.891589]
# Action : [1.13896]
# Action : [1.49489]
# Action : [1.50322]
# Action : [1.19151]
# Action : [0.272246]
# Action : [-1.0459]
# Action : [-1.71653]
# Action : [-1.89476]
# Action : [-1.93551]
# Action : [-1.9321]
# Action : [-1.84497]
# Action : [-1.18049]
# Action : [0.538554]
# Action : [0.81029]
# Action : [1.05564]
# Action : [1.42666]
# Action : [1.52533]
# Action : [1.30559]
# Action : [0.563848]
# Action : [-0.755215]
# Action : [-1.61666]
# Action : [-1.86944]
# Action : [-1.92973]
# Action : [-1.93477]
# Action : [-1.88709]
# Action : [-1.44312]
# Action : [0.264309]
# Action : [0.733774]
# Action : [1.00242]
# Action : [1.34423]
# Action : [1.53325]
# Action : [1.38332]
# Action : [0.790543]
# Action : [-0.458562]
# Action : [-1.49346]
# Action : [-1.83806]
# Action : [-1.92242]
# Action : [-1.93555]
# Action : [-1.90601]
# Action : [-1.60907]
# Action : [-0.128426]
# Action : [0.706084]
# Action : [0.969709]
# Action : [1.26392]
# Action : [1.53222]
# Action : [1.44374]
# Action : [0.975032]
# Action : [-0.164952]
# Action : [-1.34669]
# Action : [-1.80127]
# Action : [-1.91462]
# Action : [-1.93712]
# Action : [-1.92076]
# Action : [-1.7306]
# Action : [-0.59373]
# Action : [0.686362]
# Action : [0.916258]
# Action : [1.17212]
# Action : [1.5106]
# Action : [1.49059]
# Action : [1.14191]
# Action : [0.159912]
# Action : [-1.13609]
# Action : [-1.74382]
# Action : [-1.90146]
# Action : [-1.93666]
# Action : [-1.93018]
# Action : [-1.82257]
# Action : [-1.05482]
# Action : [0.603497]
# Action : [0.841228]
# Action : [1.08009]
# Action : [1.45336]
# Action : [1.5199]
# Action : [1.27064]
# Action : [0.469497]
# Action : [-0.859262]
# Action : [-1.6546]
# Action : [-1.87912]
# Action : [-1.93204]
# Action : [-1.93417]
# Action : [-1.87563]
# Action : [-1.36562]
# Action : [0.373952]
# Action : [0.756058]
# Action : [1.01939]
# Action : [1.37302]
# Action : [1.5305]
# Action : [1.35797]
# Action : [0.715752]
# Action : [-0.562684]
# Action : [-1.53891]
# Action : [-1.84938]
# Action : [-1.92479]
# Action : [-1.93499]
# Action : [-1.89974]
# Action : [-1.55372]
# Action : [0.0269581]
# Action : [0.707183]
# Action : [0.982796]
# Action : [1.29334]
# Action : [1.53518]
# Action : [1.42441]
# Action : [0.912573]
# Action : [-0.272202]
# Action : [-1.40459]
# Action : [-1.81624]
# Action : [-1.918]
# Action : [-1.9369]
# Action : [-1.91632]
# Action : [-1.69336]
# Action : [-0.431823]
# Action : [0.700254]
# Action : [0.937502]
# Action : [1.20325]
# Action : [1.52061]
# Action : [1.47615]
# Action : [1.08742]
# Action : [0.0467161]
# Action : [-1.21643]
# Action : [-1.76641]
# Action : [-1.90674]
# Action : [-1.93708]
# Action : [-1.92734]
# Action : [-1.79361]
# Action : [-0.903413]
# Action : [0.645488]
# Action : [0.869764]
# Action : [1.11075]
# Action : [1.47766]
# Action : [1.51175]
# Action : [1.22923]
# Action : [0.364288]
# Action : [-0.963078]
# Action : [-1.68983]
# Action : [-1.88798]
# Action : [-1.934]
# Action : [-1.9331]
# Action : [-1.86017]
# Action : [-1.26954]
# Action : [0.470745]
# Action : [0.784621]
# Action : [1.0396]
# Action : [1.4034]
# Action : [1.52805]
# Action : [1.33021]
# Action : [0.633899]
# Action : [-0.67022]
# Action : [-1.58352]
# Action : [-1.86088]
# Action : [-1.92759]
# Action : [-1.9349]
# Action : [-1.89359]
# Action : [-1.49498]
# Action : [0.164025]
# Action : [0.720073]
# Action : [0.992405]
# Action : [1.32212]
# Action : [1.53506]
# Action : [1.40274]
# Action : [0.847085]
# Action : [-0.375576]
# Action : [-1.45549]
# Action : [-1.82886]
# Action : [-1.92071]
# Action : [-1.93627]
# Action : [-1.91112]
# Action : [-1.65034]
# Action : [-0.264813]
# Action : [0.706304]
# Action : [0.956159]
# Action : [1.23681]
# Action : [1.52816]
# Action : [1.45894]
# Action : [1.0268]
# Action : [-0.07063]
# Action : [-1.29143]
# Action : [-1.78667]
# Action : [-1.91131]
# Action : [-1.93717]
# Action : [-1.92395]
# Action : [-1.75965]
# Action : [-0.734295]
# Action : [0.672578]
# Action : [0.895722]
# Action : [1.14463]
# Action : [1.49796]
# Action : [1.50133]
# Action : [1.1836]
# Action : [0.253529]
# Action : [-1.0618]
# Action : [-1.72151]
# Action : [-1.89602]
# Action : [-1.93578]
# Action : [-1.93187]
# Action : [-1.84165]
# Action : [-1.16128]
# Action : [0.550362]
# Action : [0.815382]
# Action : [1.05897]
# Action : [1.43109]
# Action : [1.52465]
# Action : [1.30042]
# Action : [0.549508]
# Action : [-0.771789]
# Action : [-1.62291]
# Action : [-1.87105]
# Action : [-1.93013]
# Action : [-1.93471]
# Action : [-1.88548]
# Action : [-1.43208]
# Action : [0.283016]
# Action : [0.736637]
# Action : [1.0043]
# Action : [1.34852]
# Action : [1.53277]
# Action : [1.37949]
# Action : [0.779389]
# Action : [-0.474437]
# Action : [-1.50052]
# Action : [-1.83978]
# Action : [-1.92275]
# Action : [-1.93543]
# Action : [-1.905]
# Action : [-1.60065]
# Action : [-0.103315]
# Action : [0.705727]
# Action : [0.972129]
# Action : [1.2688]
# Action : [1.53293]
# Action : [1.44089]
# Action : [0.965422]
# Action : [-0.182113]
# Action : [-1.35637]
# Action : [-1.80382]
# Action : [-1.91522]
# Action : [-1.93713]
# Action : [-1.92013]
# Action : [-1.7252]
# Action : [-0.568863]
# Action : [0.688856]
# Action : [0.919789]
# Action : [1.177]
# Action : [1.51228]
# Action : [1.48853]
# Action : [1.13386]
# Action : [0.142669]
# Action : [-1.1489]
# Action : [-1.7475]
# Action : [-1.90233]
# Action : [-1.93675]
# Action : [-1.92978]
# Action : [-1.81859]
# Action : [-1.03249]
# Action : [0.611111]
# Action : [0.84582]
# Action : [1.08451]
# Action : [1.45723]
# Action : [1.51879]
# Action : [1.2646]
# Action : [0.453788]
# Action : [-0.875507]
# Action : [-1.66026]
# Action : [-1.88055]
# Action : [-1.93236]
# Action : [-1.93403]
# Action : [-1.87352]
# Action : [-1.35168]
# Action : [0.389786]
# Action : [0.760204]
# Action : [1.02254]
# Action : [1.37777]
# Action : [1.53012]
# Action : [1.3538]
# Action : [0.703305]
# Action : [-0.579447]
# Action : [-1.54603]
# Action : [-1.8512]
# Action : [-1.92521]
# Action : [-1.93496]
# Action : [-1.89879]
# Action : [-1.54475]
# Action : [0.049481]
# Action : [0.709047]
# Action : [0.984314]
# Action : [1.29779]
# Action : [1.53534]
# Action : [1.42104]
# Action : [0.902293]
# Action : [-0.288901]
# Action : [-1.41307]
# Action : [-1.81837]
# Action : [-1.91845]
# Action : [-1.9368]
# Action : [-1.9155]
# Action : [-1.68674]
# Action : [-0.405049]
# Action : [0.701864]
# Action : [0.940778]
# Action : [1.20884]
# Action : [1.52212]
# Action : [1.47349]
# Action : [1.07772]
# Action : [0.0273522]
# Action : [-1.22935]
# Action : [-1.76995]
# Action : [-1.90755]
# Action : [-1.93712]
# Action : [-1.92681]
# Action : [-1.78821]
# Action : [-0.876345]
# Action : [0.650962]
# Action : [0.874286]
# Action : [1.11636]
# Action : [1.48133]
# Action : [1.51017]
# Action : [1.22195]
# Action : [0.346133]
# Action : [-0.980055]
# Action : [-1.69541]
# Action : [-1.8894]
# Action : [-1.93433]
# Action : [-1.93292]
# Action : [-1.85735]
# Action : [-1.25257]
# Action : [0.485368]
# Action : [0.789715]
# Action : [1.04273]
# Action : [1.40819]
# Action : [1.5276]
# Action : [1.32546]
# Action : [0.620157]
# Action : [-0.687436]
# Action : [-1.59039]
# Action : [-1.86266]
# Action : [-1.92804]
# Action : [-1.93489]
# Action : [-1.89246]
# Action : [-1.48497]
# Action : [0.184698]
# Action : [0.722632]
# Action : [0.994483]
# Action : [1.32662]
# Action : [1.5348]
# Action : [1.3989]
# Action : [0.835846]
# Action : [-0.392445]
# Action : [-1.46338]
# Action : [-1.83077]
# Action : [-1.92109]
# Action : [-1.93613]
# Action : [-1.91013]
# Action : [-1.64248]
# Action : [-0.236639]
# Action : [0.706715]
# Action : [0.959071]
# Action : [1.24256]
# Action : [1.5291]
# Action : [1.45583]
# Action : [1.01616]
# Action : [-0.0903981]
# Action : [-1.30334]
# Action : [-1.78983]
# Action : [-1.91202]
# Action : [-1.93716]
# Action : [-1.92332]
# Action : [-1.75373]
# Action : [-0.704787]
# Action : [0.675858]
# Action : [0.899751]
# Action : [1.15041]
# Action : [1.50096]
# Action : [1.49936]
# Action : [1.17554]
# Action : [0.234684]
# Action : [-1.07751]
# Action : [-1.72638]
# Action : [-1.89725]
# Action : [-1.93604]
# Action : [-1.93163]
# Action : [-1.83824]
# Action : [-1.14169]
# Action : [0.561777]
# Action : [0.820441]
# Action : [1.06277]
# Action : [1.4355]
# Action : [1.52384]
# Action : [1.29497]
# Action : [0.534608]
# Excessive output truncated after 524293 bytes.
# Action : [-0.788654]
# Action : [-1.62915]
# Action : [-1.87264]
# Action : [-1.93051]
# Action : [-1.93462]
# Action : [-1.88369]
# Action : [-1.42024]
# Action : [0.301932]
# Action : [0.739905]
# Action : [1.00682]
# Action : [1.35311]
# Action : [1.53222]
# Action : [1.3753]
# Action : [0.767241]
# Action : [-0.491525]
# Action : [-1.50804]
# Action : [-1.84162]
# Action : [-1.9231]
# Action : [-1.93529]
# Action : [-1.9039]
# Action : [-1.5914]
# Action : [-0.0764724]
# Action : [0.705309]
# Action : [0.974715]
# Action : [1.27399]
# Action : [1.53368]
# Action : [1.43783]
# Action : [0.955063]
# Action : [-0.200451]
# Action : [-1.36658]
# Action : [-1.80652]
# Action : [-1.91586]
# Action : [-1.93714]
# Action : [-1.91947]
# Action : [-1.71933]
# Action : [-0.542493]
# Action : [0.691525]
# Action : [0.923324]
# Action : [1.18201]
# Action : [1.51395]
# Action : [1.48626]
# Action : [1.12521]
# Action : [0.124412]
# Action : [-1.1622]
# Action : [-1.75127]
# Action : [-1.90321]
# Action : [-1.93682]
# Action : [-1.92933]
# Action : [-1.81416]
# Action : [-1.0083]
# Action : [0.618713]
# Action : [0.850633]
# Action : [1.08918]
# Action : [1.46136]
# Action : [1.51759]
# Action : [1.2581]
# Action : [0.436968]
# Action : [-0.892633]
# Action : [-1.66619]
# Action : [-1.88204]
# Action : [-1.93271]
# Action : [-1.93388]
# Action : [-1.87118]
# Action : [-1.33675]
# Action : [0.406033]
# Action : [0.764802]
# Action : [1.02579]
# Action : [1.3827]
# Action : [1.52968]
# Action : [1.34934]
# Action : [0.690082]
# Action : [-0.596996]
# -1390.819616030872

# %%
policy_base(Array(ro[1][1][1]))

# %%
function loss(a)
    r = exp.(a .- (ones(size(a)) |> gpu))
    s1 = r .* (rand(size(a)) |> gpu)
    s2 = clamp.(a,0.9,1.1)
    -1.0 * mean(min.(s1,s2))
end

# %%
gs = Tracker.gradient(() -> loss(out),params(m))

# %%
gs[m.layers[1].W]

# %%
using Flux,CuArrays
using Flux:Tracker
using Statistics

m = Chain(Conv((3,3),3=>64)) |> gpu
x = rand(256,256,3,1) |> gpu

# %%
function loss(x)
   out = m(x)
   mean(out)
end

# %%
function test()
    @time o = loss(x)
    @time gs = Tracker.gradient(() -> loss(x),params(m))
end

test()

# %%
using Flux,CuArrays
using Flux:Tracker
using Flux:@treelike
using Statistics

# %%
struct Net
    u
end

@treelike Net

function Net()
   Net(Chain(Conv((3,3),3=>64))) 
end

function (n::Net)(x)
   return n.u(x) 
end

# %%
m = Net() |> gpu
x = rand(256,256,3,1) |> gpu

function loss(x)
   out = m(x)
   mean(out)
end

function test()
    @time o = loss(x)
    @time gs = Tracker.gradient(() -> loss(x),params(m))
end

test()

# %%
a = param(ones(2)) * 1.0

# %%
policy_Σ

# %%
using Pkg
Pkg.add("Plots")

# %%
using JLD

# %%
reward_hist

# %%
mean(reward_hist[end-100-100:end-100])

# %%
using JLD
save("stats.jld","rewards",reward_hist)

# %%
rh = load("stats.jld")

# %%
using Pkg
Pkg.activate("~/envs/test")

# %%
using JLD
using Plots

# %%
rh

# %%
policy_Σ

# %%
i = 1
if i == 1
    a = 3
else
    b = 5
end

# %%
using OpenAIGym
env = GymEnv(:Pendulum, :v0)
for i ∈ 1:20
  T = 0
  R = run_episode(env, RandomPolicy()) do (s, a, r, s′)
    render(env)
    T += 1
  end
  @info("Episode $i finished after $T steps. Total reward: $R")
end
