# %%
#----------------__CHECKING__------------------- #
using Flux, CuArrays
using OpenAIGym
import Reinforce.action
import Reinforce:run_episode
import Flux.params
using Flux.Tracker: grad, update!
using Flux: onehot
using Statistics
using Distributed
using Distributions
using LinearAlgebra
using Base.Iterators
using BSON:@save,@load
using JLD

include("policy.jl")
# Out:
# ┌ Warning: Flux is only supported with CuArrays v0.9.
# │ Try running `] pin CuArrays@0.9`.
# └ @ Flux.CUDA /home/shreyas/.julia/packages/Flux/WSB7k/src/cuda/cuda.jl:12
# WARNING: using Distributions.params in module Main conflicts with an existing identifier.
# WARNING: using JLD.@load in module Main conflicts with an existing identifier.
# WARNING: using JLD.@save in module Main conflicts with an existing identifier.
# value_fn (generic function with 2 methods)

# %%
"""
HYPERPARAMETERS
"""
# Environment Creation #
env_name = "CartPole-v0"
MODE = "CAT" # Can be either "CON" (Continuous) or "CON" (Categorical)

# Environment Variables #
STATE_SIZE = 4
ACTION_SIZE = 2
MIN_RANGE = -2.0f0
MAX_RANGE = 2.0f0
EPISODE_LENGTH = 100
TEST_STEPS = 10000
# Policy parameters #
η = 3e-4 # Learning rate
STD = 0.0 # Standard deviation
HIDDEN_SIZE = 256
# GAE parameters
γ = 0.99
λ = 0.95
# Optimization parameters
PPO_EPOCHS = 10
NUM_EPISODES = 15000
BATCH_SIZE = 5
c₀ = 1.0
c₁ = 0.5
c₂ = 0.001
# PPO parameters
ϵ = 0.2
# FREQUENCIES
SAVE_FREQUENCY = 50
VERBOSE_FREQUENCY = 5
global_step = 0

# Global variable to monitor losses
reward_hist = []
policy_l = 0.0
entropy_l = 0.0
value_l = 0.0
# Out:
# 0.0

# %%
function scale_rewards(rewards)
    return rewards # ./ 16.2736044
end
# Out:
# scale_rewards (generic function with 1 method)

# %%
"""
Define the networks
"""

if MODE == "CON"
	policy_μ,policy_Σ = gaussian_policy(STATE_SIZE,HIDDEN_SIZE,ACTION_SIZE)
	value = value_fn(STATE_SIZE,HIDDEN_SIZE,ACTION_SIZE,tanh)
elseif MODE == "CAT"
	policy = categorical_policy(STATE_SIZE,HIDDEN_SIZE,ACTION_SIZE)
	value = value_fn(STATE_SIZE,HIDDEN_SIZE,ACTION_SIZE,relu)
else 
	error("MODE can only be (CON) or (CAT)...")
end

opt = ADAM(η)
# Out:
# ADAM(0.0003, (0.9, 0.999), IdDict{Any,Any}())

# %%
"""
Functions to get rollouts
"""

function action(state)
    # Acccounting for the element type
    state = reshape(Array(state),length(state),1) 

    a = nothing
    if MODE == "CON"
	    # Our policy outputs the parameters of a Normal distribution
	    μ = policy_μ(state)
	    μ = reshape(μ,ACTION_SIZE)
	    log_std = policy_Σ
	    
	    σ² = (exp.(log_std)).^2
	    Σ = diagm(0=>σ².data)
	    
	    dis = MvNormal(μ.data,Σ)
	    
	    a = rand(dis,ACTION_SIZE)
	else
		action_probs = policy(state).data
        action_probs = reshape(action_probs,ACTION_SIZE)
    	a = sample(1:ACTION_SIZE,Weights(action_probs)) - 1
    end
    a
end

function run_episode(env)
    experience = []
    
    s = reset!(env)
    for i in 1:EPISODE_LENGTH
        a = action(s)
        # a = convert.(Float64,a)
        
        if MODE == "CON"
            a = reshape(a,ACTION_SIZE)
        end

        r,s_ = step!(env,a)
        push!(experience,(s,a,r,s_))
        s = s_
        if env.done
           break 
        end
    end
    experience
end
# Out:
# run_episode (generic function with 2 methods)

# %%
"""
Multi-threaded parallel rollout collection
"""

num_processes = 9
addprocs(num_processes) 

@everywhere function collect(env)
    run_episode(env)
end

@everywhere function rollout()
  env = GymEnv(env_name)
  return collect(env)
end

function get_rollouts()
    g = []
    for  w in workers()
      push!(g, rollout())
    end

    fetch.(g)
end
# Out:
# get_rollouts (generic function with 1 method)

# %%
"""
Generalized Adavantage Estimation
"""

function gae(states,actions,rewards,next_states)
    """
    Returns a Generalized Advantage Estimate for an episode
    """
    Â = []
    A = 0.0
    for i in reverse(1:length(states))
        δ = rewards[i] + γ*cpu.(value(next_states[i]).data[1]) - cpu.(value(states[i]).data[1])
        A = δ + (γ*λ*A)
        push!(Â,A)
    end
    
    Â = reverse(Â)
    return Â
end

function disconunted_returns(rewards)
    r = 0.0
    returns = []
    for i in reverse(1:length(rewards))
        r = rewards[i] + γ*r
        push!(returns,r)
    end
    returns = reverse(returns)
    returns
end

"""
Calculate Log Probabilities
"""
function log_prob_from_actions(states,actions)
    """
    Returns log probabilities of the actions taken
    
    states,actions : episode vairbles in the form of a list
    """
    log_probs = []
    
    for i in 1:length(states)
    	if MODE == "CON"
	        μ = reshape(policy_μ(states[i]),ACTION_SIZE).data
	        logΣ = policy_Σ.data |> cpu
        	push!(log_probs,normal_log_prob(μ,logΣ,actions[i]))
        else
        	action_probs = policy(states[i])
        	prob = action_probs[actions[i],:].data
        	push!(log_probs,log.(prob))
        end
    end
    
    log_probs
end
# Out:
# log_prob_from_actions

# %%
"""
Process and extraction information from rollouts
"""

function process_rollouts(rollouts)
    """
    rollouts : variable returned by calling `get_rollouts`
    
    Returns : 
    states, actions, rewards for minibatch processing
    """
    # Process the variables
    states = []
    actions = []
    rewards = []
    next_states = []
    advantages = []
    returns = []
    log_probs = []
    
    # Logging statistics
    episode_mean_returns = []
    
    for ro in rollouts
        episode_states = []
        episode_actions = []
        episode_rewards = []
        episode_next_states = []
        
        for i in 1:length(ro)
             push!(episode_states,Array(ro[i][1]))
             
             if MODE == "CON"
                 push!(episode_actions,ro[i][2])
             else
                 push!(episode_actions,ro[i][2] + 1)
             end
             
             push!(episode_rewards,ro[i][3])
             push!(episode_next_states,ro[i][4])
        end
        
        episode_rewards = scale_rewards(episode_rewards)
        episode_advantages = gae(episode_states,episode_actions,episode_rewards,episode_next_states)
        # episode_rewards = normalise(episode_rewards)
        
        episode_returns = disconunted_returns(episode_rewards)
        
        push!(episode_mean_returns,mean(episode_returns))
        
        push!(states,episode_states)
        push!(actions,episode_actions)
        push!(rewards,episode_rewards)
        push!(advantages,episode_advantages)
        push!(returns,episode_returns)
        push!(log_probs,log_prob_from_actions(episode_states,episode_actions))
    end
    
    states = cat(states...,dims=1)
    actions = cat(actions...,dims=1)
    rewards = cat(rewards...,dims=1)
    advantages = cat(advantages...,dims=1)
    returns = cat(returns...,dims=1)
    log_probs = cat(log_probs...,dims=1)
    
    push!(reward_hist,mean(episode_mean_returns))
    
    if length(reward_hist) <= 100
        println("RETURNS : $(mean(episode_mean_returns))")
    else
        println("MEAN RETURNS : $(mean(reward_hist))")
        println("LAST 100 RETURNS : $(mean(reward_hist[end-100:end]))")
    end
    
    return hcat(states...),hcat(actions...),hcat(rewards...),hcat(advantages...),hcat(returns...),hcat(log_probs...)
end

"""
Loss function definition
"""
function loss(states,actions,advantages,returns,old_log_probs)
    global global_step,policy_l,entropy_l,value_l
    global_step += 1
    
    if MODE == "CON"
	    μ = policy_μ(states)
	    logΣ = policy_Σ 
        
	    new_log_probs = normal_log_prob(μ,logΣ,actions)
	else
		action_probs = policy(states) # ACTION_SIZE x BATCH_SIZE
		actions_one_hot = zeros(ACTION_SIZE,size(action_probs)[end])
        
		for i in 1:size(action_probs)[end]
			actions_one_hot[actions[:,i][1],i] = 1.0				
		end
        
		new_log_probs = log.(sum((action_probs .+ 1f-5) .* actions_one_hot,dims=1))
    end
    
    # Surrogate loss computations
    ratio = exp.(new_log_probs .- old_log_probs)
    surr1 = ratio .* advantages
    surr2 = clamp.(ratio,(1.0 - ϵ),(1.0 + ϵ)) .* advantages
    policy_loss = mean(min.(surr1,surr2))
    
    value_predicted = value(states)
    value_loss = mean((value_predicted .- returns).^2)
    
    if MODE == "CON"
        entropy_loss = mean(normal_entropy(logΣ))
    else
        entropy_loss = mean(categorical_entropy(action_probs))
    end
    
    policy_l = policy_loss.data
    entropy_l = entropy_loss.data
    value_l = value_loss.data
    
    -c₀*policy_loss + c₁*value_loss - c₂*entropy_loss
end

"""
Optimization Function
"""
function ppo_update(states,actions,advantages,returns,old_log_probs)
    # Define model parameters
    if MODE == "CON"
        model_params = params(params(policy_μ)...,params(policy_Σ)...,params(value)...)
    else
        model_params = params(params(policy)...,params(value)...)
    end

    # Calculate gradients
    gs = Tracker.gradient(() -> loss(states,actions,advantages,returns,old_log_probs),model_params)

    # Take a step of optimisation
    update!(opt,model_params,gs)
end
# Out:
# ppo_update

# %%
"""
Train
"""

function train_step()    
    routs = get_rollouts()
    states,actions,rewards,advantages,returns,log_probs = process_rollouts(routs)
    
    idxs = partition(1:size(states)[end],BATCH_SIZE)
    
    for epoch in 1:PPO_EPOCHS
        for i in idxs
            mb_states = states[:,i] 
            mb_actions = actions[:,i] 
            mb_advantages = advantages[:,i] 
            mb_returns = returns[:,i] 
            mb_log_probs = log_probs[:,i]
            
            ppo_update(mb_states,mb_actions,mb_advantages,mb_returns,mb_log_probs)
        end
    end
end

function train()
    for i in 1:NUM_EPISODES
        println("EP : $i")
        train_step()
        println("Ep done")
        
        # Anneal learning rate
        if i%300 == 0
            if opt.eta > 1e-6
                opt.eta = opt.eta / 3.0
            end
        end
        
        if i % VERBOSE_FREQUENCY == 0
            # Show important statistics
            println("-----___Stats___-----")
            
            if MODE == "CON"
                println("Entropy : $(normal_entropy(policy_Σ))")
            end
            
            println("Policy Loss : $(policy_l)")
            println("Entropy Loss : $(entropy_l)")
            println("Value Loss : $(value_l)")
        end
        
        if i%SAVE_FREQUENCY == 0
        	if MODE == "CON"
	            @save "weights/policy_mu.bson" policy_μ
	            @save "weights/policy_sigma.bson" policy_Σ
	            @save "weights/value.bson" value
	        else
	        	@save "weights/policy_cat.bson" policy
	        	@save "weights/value.bson" value
            end
            
            save("stats.jld","rewards",reward_hist)
            println("\n\n\n----MAX REWRD SO FAR : $(maximum(reward_hist))---\n\n\n")
        end
    end
end
# Out:
# train (generic function with 1 method)

# %%
train()
# Out:
# EP : 1
# Float32[2.19058e-5, 0.999978] (tracked)
# Float32[0.999978]
# Float32[6.79824e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[2.00836e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.08198e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.14919e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.5061e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.27061e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06539e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.05703e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.75426e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.70566e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.96306e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.36759e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.12165e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.56257e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.33271e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.60118e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.86987e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[8.66897e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.35475e-5, 0.999976] (tracked)
# Float32[0.999976]
# Float32[6.79867e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.89012e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.50791e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[9.46406e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.91775e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.73608e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.99194e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.24826e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.16933e-5, 0.999978] (tracked)
# Float32[0.999978]
# Float32[6.55052e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.87416e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.58311e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.00988e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.13914e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.35001e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.48468e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.57552e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.65203e-5, 0.999974] (tracked)
# Float32[0.999974]
# Float32[8.34449e-6, 0.999992] (tracked)
# Float32[0.999992]
# Float32[2.53947e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[6.87725e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.60099e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.5628e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.66121e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.58243e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.126e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.85318e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.0291e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.09208e-5, 0.999979] (tracked)
# Float32[0.999979]
# Float32[6.11586e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.71814e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.10379e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.70212e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.78486e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.51993e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.6642e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20351e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.59248e-5, 0.999974] (tracked)
# Float32[0.999974]
# Float32[7.62634e-6, 0.999992] (tracked)
# Float32[0.999992]
# Float32[2.15592e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.26056e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.12813e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.33363e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.64419e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.87604e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.6201e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.88841e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.64654e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.61899e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.94366e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.54465e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.79378e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.62131e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[7.0174e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.29822e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.94417e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.79573e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.64396e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.94105e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.51413e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.78078e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.57615e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.88969e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.26513e-10, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.41571282277778
# LAST 100 RETURNS : 5.963633527188951
# Ep done
# EP : 2
# Float32[1.91421e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.92049e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.74522e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.42263e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[9.95756e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.16222e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.52986e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.12279e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.75428e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.19488e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.76008e-5, 0.999982] (tracked)
# Float32[0.999982]
# Float32[5.40221e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.5668e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.87957e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.63468e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.85873e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.84911e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[7.64681e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.44995e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.59434e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.2529e-5, 0.999977] (tracked)
# Float32[0.999977]
# Float32[6.67789e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.89897e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.67093e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.01232e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.11005e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.22365e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.11417e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.48715e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.22962e-5, 0.999978] (tracked)
# Float32[0.999978]
# Float32[6.70251e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.94029e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.84421e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06133e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.24048e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.57447e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.97779e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.68339e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.99049e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.07948e-5, 0.999979] (tracked)
# Float32[0.999979]
# Float32[5.92748e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.61731e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.73426e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.72787e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.54159e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.95381e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.43358e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.8993e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.84142e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.72061e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.35317e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[9.74561e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.10593e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.39026e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.80118e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.68484e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.0554e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.13305e-5, 0.999979] (tracked)
# Float32[0.999979]
# Float32[6.61861e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.96231e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.04177e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.14704e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.50523e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.27399e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06512e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.05466e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.74733e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.91908e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.57003e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.55497e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.67551e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.6895e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.56538e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.07045e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.78143e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04109e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.34603e-5, 0.999977] (tracked)
# Float32[0.999977]
# Float32[7.12349e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[2.08807e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.35295e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19154e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.54654e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.26378e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04505e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.98308e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.56637e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.4049930208943175
# LAST 100 RETURNS : 5.916606311767312
# Ep done
# EP : 3
# Float32[1.72827e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[5.2029e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.48992e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.67456e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.07718e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.70869e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.46622e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.7442e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.2514e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.18807e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.63989e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.85753e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.36778e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.25777e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.96155e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.44462e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.88579e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.53159e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.0124e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.75048e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74351e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.91491e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.32895e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.01747e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.12773e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20885e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.29307e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.17564e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.86874e-5, 0.999981] (tracked)
# Float32[0.999981]
# Float32[5.47828e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.53977e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.70538e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.9064e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.62838e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.2194e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.10749e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.10608e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.63289e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.74841e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.31829e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.08707e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.48601e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.32229e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.58857e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.86017e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[8.71413e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.22158e-5, 0.999978] (tracked)
# Float32[0.999978]
# Float32[6.6037e-6, 0.999993] (tracked)
# Float32[0.999993]
# Float32[1.89698e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[4.81158e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04851e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.19881e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.43934e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.60468e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.59375e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.79396e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.99371e-5, 0.99998] (tracked)
# Float32[0.99998]
# Float32[5.67479e-6, 0.999994] (tracked)
# Float32[0.999994]
# Float32[1.56119e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.72279e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.74062e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.54587e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.96691e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.46862e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[9.61961e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.57351e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.72392e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.34138e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.23309e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.01253e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.47471e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.98279e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.78683e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07141e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.87258e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.71579e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.83895e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.30581e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.95102e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.01474e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.18606e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.24627e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.08309e-10, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.393154742888747
# LAST 100 RETURNS : 5.848285860152673
# Ep done
# EP : 4
# Float32[1.47239e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.193e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.13657e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.58302e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.31239e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.05751e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.02027e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.7e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.46508e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.62228e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.8809e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.4168e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.54529e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.77987e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.64555e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.35578e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.58592e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.23424e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.19633e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.54687e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.45908e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.21903e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.83147e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.93908e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19664e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.31071e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.27635e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.53055e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.5919e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.66072e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.31713e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.2009e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.80552e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.40069e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.77187e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.26862e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[9.56498e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.64418e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.71419e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[5.03814e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.42746e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.50851e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.52873e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.55829e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.09298e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.89264e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07129e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.84052e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74292e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[5.28424e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.54829e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[3.95773e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.80008e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.87983e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.87285e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[7.66146e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.44761e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.59626e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.45129e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.26937e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.20004e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.86279e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.07568e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25194e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.48411e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.73004e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[8.59701e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.47858e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.72398e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[5.18445e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.48668e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.66569e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[8.04259e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.69668e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.45134e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.72988e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25262e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.20646e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.79159e-5, 0.999982] (tracked)
# Float32[0.999982]
# Float32[4.98975e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.33512e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.04644e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.16464e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20157e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.24773e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.03658e-10, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.3827955777565615
# LAST 100 RETURNS : 5.808990687165139
# Ep done
# EP : 5
# Float32[1.52529e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.54441e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.29898e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.21223e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.97782e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.4621e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.94642e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.69087e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04896e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.83064e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.27155e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.62692e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.80177e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.22204e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.57275e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.10802e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.73923e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.18192e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.55192e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.53449e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.22869e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.11822e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.49031e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.94879e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.53213e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.76358e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.13129e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.43082e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[3.95968e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.05226e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.37466e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.7776e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.21162e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.70664e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.03252e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.36881e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[3.92982e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.07071e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.45979e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.10828e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.02557e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.97457e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.64328e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.41359e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.2809e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.59183e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.60717e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.17762e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.43575e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.64486e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.61941e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.90689e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.96628e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.68133e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.67822e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.25293e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.88331e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.83633e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.13728e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.12607e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.81415e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.53024e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.38641e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[4.12365e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.17813e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.90499e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.29132e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.31514e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.64047e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.0875e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[9.35161e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.62747e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.38271e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[3.91053e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.06306e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.44429e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.98244e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.85898e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.87647e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.42559e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.97432e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.370482414420294
# LAST 100 RETURNS : 5.733369295407601
# Ep done
# -----___Stats___-----
# Policy Loss : 0.4594273473633217
# Entropy Loss : -1.1553716e-9
# Value Loss : 0.011913968078772541
# EP : 6
# Float32[1.69129e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.77535e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.2977e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.0599e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.2949e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.24638e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.37147e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.32468e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.53041e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.10415e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.18958e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.76112e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.03849e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.2413e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.55058e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.65505e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.07031e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.4313e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[9.08337e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.61544e-5, 0.999984] (tracked)
# Float32[0.999984]
# Float32[4.54875e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.23209e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.88511e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.91367e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.16818e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.21234e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.01812e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.96625e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.50984e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.14161e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.0871e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.42853e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.84407e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.2712e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.69998e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.98968e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.27137e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.5355e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.41513e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.10222e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.2051e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.17011e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.52333e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.72261e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.64726e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.46972e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.04627e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.068e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.38946e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.76601e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.16847e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.69139e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.99258e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.05517e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.65602e-5, 0.999983] (tracked)
# Float32[0.999983]
# Float32[4.91618e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.40668e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.49029e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.60116e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.58164e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.18327e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.16345e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.13928e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.00094e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.29772e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.51361e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.23685e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.13025e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.57243e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.24434e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.0252e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.91946e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.44407e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.88475e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.21465e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.47998e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.47638e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.1889e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.53818e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.09261e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74461e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.20707e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.61974e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.359208878675096
# LAST 100 RETURNS : 5.683093728548421
# Ep done
# EP : 7
# Float32[1.54443e-5, 0.999985] (tracked)
# Float32[0.999985]
# Float32[4.55727e-6, 0.999995] (tracked)
# Float32[0.999995]
# Float32[1.29287e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[3.23209e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[7.01923e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.45522e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.90729e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[5.55311e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.01178e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74803e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.12587e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.2437e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.95299e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.12278e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.43905e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.96126e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.73399e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.21644e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.68666e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[9.52047e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.23493e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.39734e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.9491e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.00525e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.01024e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.69331e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.41407e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.4907e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.18086e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.15496e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.34113e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.28767e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.2222e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.66987e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.47281e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.84402e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.44259e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.12788e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.03426e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.05719e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[2.93818e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.76402e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.72687e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.46716e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.71335e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.24557e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.21306e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.74847e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.13398e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.30869e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.28475e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.24243e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.74981e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.72017e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.90967e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.60306e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.48229e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.10678e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.16516e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.29413e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.8961e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.0423e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.17535e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.26055e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.56597e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.84439e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.9271e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.40978e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[4.0948e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.14469e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.7694e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.87242e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19446e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.34746e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.42248e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.94791e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.35661e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.27096e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.58252e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.62698e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.20137e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.50227e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.86698e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.67609e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.0334e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.23608e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.34937268339823
# LAST 100 RETURNS : 5.637444534917115
# Ep done
# EP : 8
# Float32[1.25769e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.4682e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.13093e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.04631e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.09641e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.88393e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.45518e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.57116e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.333e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.03725e-5, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.95787e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.01325e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.84465e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.78992e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.54553e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.44276e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.64317e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.61526e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.64162e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[8.6891e-6, 0.999991] (tracked)
# Float32[0.999991]
# Float32[2.3344e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.95415e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.25526e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.4218e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.50883e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.05412e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37807e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37385e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[3.98125e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.11639e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.77357e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.90622e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20446e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.36348e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.44098e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.9615e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.35481e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.23781e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.55335e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.85664e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.37593e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.97475e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.00243e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.94417e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.61484e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.41101e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07944e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.38238e-5, 0.999986] (tracked)
# Float32[0.999986]
# Float32[3.75946e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.81466e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.19006e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.31225e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.18683e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.49643e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.6185e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.37771e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07459e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.00738e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.04789e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.84955e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.77005e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.36507e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37748e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.46753e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.20969e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.17746e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.21763e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.48629e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.92333e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.82171e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.29851e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.33683e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.34759e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.93324e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.00266e-5, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.74824e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.22301e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.59631e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.1445e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.00504e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.10175e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.9372e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.25067e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.3384483704706645
# LAST 100 RETURNS : 5.606678442687435
# Ep done
# EP : 9
# Float32[1.22114e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.31418e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.63943e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.92351e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.76707e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.13499e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.30188e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.27474e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.79434e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25064e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.50339e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.4221e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.19328e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.47972e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.77184e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.65458e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.98358e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.13089e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[8.36402e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[9.78854e-6, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.80754e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.70784e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.82361e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.7973e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.62843e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.4695e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.71194e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.76907e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.95206e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[9.88597e-6, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.80667e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.62572e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.79659e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.72519e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.40107e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.4057e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.55776e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.42893e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.25677e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04746e-5, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.83128e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.28287e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.57083e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.06017e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.75624e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.03848e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.79361e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.95619e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.31144e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.63593e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[9.71481e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.26672e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.58324e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.8953e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.66197e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.97065e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.06659e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[8.19651e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.1596e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.28943e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.99988e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.14366e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.43625e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.82929e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.68787e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.0901e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.39409e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[8.93426e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.31836e-5, 0.999987] (tracked)
# Float32[0.999987]
# Float32[3.80769e-6, 0.999996] (tracked)
# Float32[0.999996]
# Float32[1.06183e-6, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.61374e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.55412e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.12554e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.20319e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[4.1269e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.37495e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25076e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19927e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.43696e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.51414e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.29509e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.81406e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.66261e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.87415e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.48141e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[6.16726e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.03701e-11, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.329751685379492
# LAST 100 RETURNS : 5.586309321759782
# Ep done
# EP : 10
# Float32[1.13618e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.06955e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.95722e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.76835e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.46475e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.52727e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.18453e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.05508e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.40309e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.00169e-5, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.71851e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.0474e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.54709e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.0352e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.73776e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.04265e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.81188e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.00338e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[9.80538e-6, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.7192e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.27269e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.68522e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.40649e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.62367e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.23173e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.19497e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.72654e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[5.99724e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.18125e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.26522e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.71053e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.02001e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.07092e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.86626e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.46864e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.62515e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.47555e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.24853e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.24129e-5, 0.999988] (tracked)
# Float32[0.999988]
# Float32[3.43702e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[9.17335e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.13257e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.31253e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.34244e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.56047e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.79444e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.77287e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.74456e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07091e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[2.99158e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.98798e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.8491e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.77272e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.36064e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37938e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.47003e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.21303e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[6.80255e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[9.86464e-6, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.75477e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.43491e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.74404e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.54891e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.95185e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.30515e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.34914e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.03052e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[6.56233e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[8.99248e-6, 0.999991] (tracked)
# Float32[0.999991]
# Float32[2.47919e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[6.58292e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.49897e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.99417e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.77172e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06662e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.8888e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.18872e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[5.10815e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.01139e-5, 0.99999] (tracked)
# Float32[0.99999]
# Float32[2.81879e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.51159e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.71284e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.45881e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.72514e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25969e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.25681e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.85334e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[6.24399e-12, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.321190885992868
# LAST 100 RETURNS : 5.573233023549719
# Ep done
# -----___Stats___-----
# Policy Loss : 0.6104554409827614
# Entropy Loss : -1.6358014e-9
# Value Loss : 0.0021674645517537317
# EP : 11
# Float32[1.07866e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[2.80916e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[7.05052e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.53386e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.9055e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.28043e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.1974e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.53457e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.44375e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.09941e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.11085e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.50199e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.06611e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.30909e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.5551e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.63946e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[3.00144e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[5.24057e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[8.67873e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[7.73521e-6, 0.999992] (tracked)
# Float32[0.999992]
# Float32[2.14506e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.64218e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.26441e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.52903e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.8844e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.0579e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.60621e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.71243e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[4.34281e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[8.96213e-6, 0.999991] (tracked)
# Float32[0.999991]
# Float32[2.31374e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.71976e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.1886e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.20434e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.95776e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.81678e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.12528e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[7.73531e-6, 0.999992] (tracked)
# Float32[0.999992]
# Float32[2.03431e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.09073e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[1.08022e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.06117e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[3.75608e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[6.55152e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.09344e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.73815e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[8.87901e-6, 0.999991] (tracked)
# Float32[0.999991]
# Float32[2.30826e-6, 0.999998] (tracked)
# Float32[0.999998]
# Float32[5.79588e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[1.24963e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.36143e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[4.27482e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[7.41618e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.23316e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.10974e-5, 0.999989] (tracked)
# Float32[0.999989]
# Float32[3.09516e-6, 0.999997] (tracked)
# Float32[0.999997]
# Float32[8.3503e-7, 0.999999] (tracked)
# Float32[0.999999]
# Float32[2.00566e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.11402e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.0501e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.51969e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.74098e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[4.71473e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[7.69524e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[9.84321e-6, 0.99999] (tracked)
# Float32[0.99999]
# ...
# Float32[1.0]
# Float32[1.2897e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.54716e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.76688e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.90462e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.26922e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.52431e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.69236e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.47951e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.13909e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.89178e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.7406e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[4.55434e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[5.2281e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[5.63119e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.09072e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.72911e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.39179e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.43157e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20106e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.43874e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.63644e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.75968e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.20977e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.42133e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.48517e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.43391e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.07361e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.8038e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.63264e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[4.43335e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[5.09422e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[5.49081e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[3.23281e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[6.29089e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19631e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[2.07305e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.98481e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.97528e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[5.06071e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[6.07482e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[6.88634e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[7.33732e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.5127e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.51885e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.85909e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.21106e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.57194e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.90494e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.19147e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.38337e-13, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.0054431543186295
# LAST 100 RETURNS : 5.02431588132488
# Ep done
# EP : 52
# Float32[2.24383e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.38521e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.25696e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37472e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.94656e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.57532e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.26745e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[3.90988e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[4.4052e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[4.66013e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.86323e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.42392e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.02379e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.09333e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.19238e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.47295e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.73294e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.92142e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.01152e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[1.84051e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.68394e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.09623e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.20619e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74884e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.36819e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.06673e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[3.74237e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[4.30438e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[4.64313e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.75955e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.49255e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06167e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.86632e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.73782e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.72552e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[4.83413e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[5.9169e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[6.81866e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[7.37239e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.86958e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.49282e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.27546e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.84691e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.32363e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.66371e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.98694e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.23856e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.37993e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.60543e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.13791e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[9.85101e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.71117e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.48023e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.33753e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[4.28803e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[5.19227e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[5.92642e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[6.34864e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.91171e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.64441e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.70383e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.07863e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.48239e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.91214e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.35039e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.72586e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.98312e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[3.0674e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[3.06776e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[5.92074e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.11217e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[1.8971e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.69605e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[3.55168e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[4.4773e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[5.33327e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[5.98382e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[6.3096e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.66529e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.2531e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.09375e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.9273e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.39297e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.8347e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.30312e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.72695e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[3.04336e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[3.18716e-15, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 6.000905073198471
# LAST 100 RETURNS : 5.025351849316261
# Ep done
# EP : 53
# Float32[1.85081e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.50361e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.38389e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.02046e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.39222e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.78005e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.16648e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.48267e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.68336e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.72321e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.93488e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.44957e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.96335e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.98542e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.15588e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.39223e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.59252e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.72472e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[1.76647e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.28153e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.48994e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.5482e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.46843e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.11239e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.83051e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.61163e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[4.33951e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[4.91057e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[5.21122e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.21524e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.25929e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.88892e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.30373e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.81611e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.3688e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.94175e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[3.43763e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[3.78456e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[3.90985e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74792e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.15223e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.47664e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.37238e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.08415e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.31094e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.50193e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.62775e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[1.66599e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[1.58011e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.95971e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.31842e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.28039e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.11104e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.39889e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.67356e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.88922e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.01141e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.21938e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.98133e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.91342e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06722e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.38438e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.67613e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.92697e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.09089e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.14414e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.39668e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.51068e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.22679e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.34283e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.83786e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.34983e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.86656e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[3.29121e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[3.56613e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[3.63093e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.36569e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.56985e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.58398e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.45176e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.05308e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.70145e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.39679e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[4.02436e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[4.49603e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[4.71661e-15, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 5.995810215864368
# LAST 100 RETURNS : 5.026387817307643
# Ep done
# EP : 54
# Float32[1.82182e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.29089e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.72198e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.69302e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.12744e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.37191e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.58914e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.73325e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[1.78505e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[1.65525e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.17306e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.85823e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[9.50395e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.31463e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.70266e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.10814e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.45616e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.69826e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.78195e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.30676e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.52626e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[8.6606e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.50858e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[2.19666e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[2.94655e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[3.76892e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[4.54445e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[5.16247e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[5.50154e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[2.052e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.81822e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.86275e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.09766e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.47743e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.86219e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.23669e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.52615e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.69174e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[1.88675e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.55546e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.49742e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.05984e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.45306e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.85712e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.257e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.5849e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.79277e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.8332e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.95086e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.65466e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[6.66635e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.08674e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.48525e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.8909e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.29283e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.62347e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.83363e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[2.87615e-15, 1.0] (tracked)
# Float32[1.0]
# Float32[1.54128e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[2.83634e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.02801e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[7.79798e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.03244e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.27748e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.50042e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.66362e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[1.74038e-14, 1.0] (tracked)
# Float32[1.0]
# Float32[1.92005e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[3.35362e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[5.68116e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[8.47981e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.06922e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.25874e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[1.40603e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[1.48481e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.24511e-7, 1.0] (tracked)
# Float32[1.0]
# Float32[4.08019e-8, 1.0] (tracked)
# Float32[1.0]
# Float32[7.22091e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.14677e-9, 1.0] (tracked)
# Float32[1.0]
# Float32[1.51986e-10, 1.0] (tracked)
# Float32[1.0]
# Float32[1.87599e-11, 1.0] (tracked)
# Float32[1.0]
# Float32[2.2035e-12, 1.0] (tracked)
# Float32[1.0]
# Float32[2.43989e-13, 1.0] (tracked)
# Float32[1.0]
# Float32[2.55297e-14, 1.0] (tracked)
# Float32[1.0]
# MEAN RETURNS : 5.990166271015956
# LAST 100 RETURNS : 5.026391261587888
# InterruptException:
#
# Stacktrace:
#  [1] apply!(::ADAM, ::TrackedArray{…,Array{Float32,2}}, ::Array{Float32,2}) at /home/shreyas/.julia/packages/Flux/WSB7k/src/optimise/optimisers.jl:107
#  [2] update!(::ADAM, ::TrackedArray{…,Array{Float32,2}}, ::TrackedArray{…,Array{Float32,2}}) at /home/shreyas/.julia/packages/Flux/WSB7k/src/optimise/train.jl:6
#  [3] update!(::ADAM, ::Tracker.Params, ::Tracker.Grads) at /home/shreyas/.julia/packages/Flux/WSB7k/src/optimise/train.jl:11
#  [4] ppo_update(::Array{Float64,2}, ::Array{Int64,2}, ::Array{Float64,2}, ::Array{Float64,2}, ::Array{Float32,2}) at ./In[132]:142
#  [5] train_step() at ./In[133]:19
#  [6] train() at ./In[133]:27
#  [7] top-level scope at In[134]:1

# %%
policy(ones(4,1))

# %%
env = GymEnv(env_name)
# Out:
# GymEnv CartPole-v0
#   TimeLimit
#   r  = 0.0
#   ∑r = 0.0
# ┌ Warning: `haskey(o::PyObject, s::Union{Symbol, AbstractString})` is deprecated, use `hasproperty(o, s)` instead.
# │   caller = show(::IOContext{Base.GenericIOBuffer{Array{UInt8,1}}}, ::GymEnv{PyCall.PyArray{Float64,1}}) at OpenAIGym.jl:64
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:64
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = show(::IOContext{Base.GenericIOBuffer{Array{UInt8,1}}}, ::GymEnv{PyCall.PyArray{Float64,1}}) at OpenAIGym.jl:65
# └ @ OpenAIGym /home/shreyas/.julia/packages/OpenAIGym/wZkkM/src/OpenAIGym.jl:65

# %%
s = reset!(env)
# Out:
# 4-element PyCall.PyArray{Float64,1}:
#  -0.04849816918922241
#   0.013628561471056858
#   0.006237321324826253
#   0.04166733079767969

# %%
function loss(x)
    action_probs = policy(x)
    mean(action_probs)
end

gs = Tracker.gradient(() -> loss(s),params(policy))
# Out:
# Grads(...)

# %%
policy.layers[1].W
# Out:
# Tracked 256×4 Array{Float32,2}:
#   0.0463625    -0.0288894    0.0691652    -0.0266886
#   0.124687      0.0818793   -0.129135      0.204254
#  -0.106862      0.193595    -0.0882367    -0.0241373
#  -0.0685683     0.0427704    0.0284292     0.0874056
#  -0.176015      0.104862     0.0349711    -0.124782
#   0.0458958    -0.0517615    0.0304131     0.00226418
#   0.0698005     0.0420365   -0.162521     -0.0820992
#  -0.0710014    -0.0629289    0.0741035     0.173773
#   0.036564      0.0159403    0.0240178    -0.0337437
#  -0.0883487    -0.074553     0.121145     -0.183758
#  -0.0945337    -0.00958645  -0.00795938   -0.0662095
#   0.0517599    -0.0620799   -0.000125911  -0.0471872
#  -0.0486801     0.006256     0.178224      0.092455
#   ⋮
#   0.0060984     0.0074       0.149015      0.0837609
#  -0.12016      -0.0510779    0.182024      0.0255303
#  -0.142491     -0.138318    -0.078126     -0.124178
#   0.179972      0.124144    -0.0903058    -0.0722095
#  -0.00565518   -0.0069747   -0.255583      0.053678
#   0.148183     -0.08695     -0.0568453    -0.0385866
#  -0.0178394     0.00701577  -0.0264899    -0.0312972
#  -0.000947906  -0.0182501   -0.079818      0.114955
#  -0.0132274    -0.145377     0.107797      0.0581217
#  -0.0112895    -0.0326152    0.0914327     0.0422812
#   0.0581694    -0.154598    -0.106047     -0.179227
#  -0.0671879     0.203426     0.160432      0.0620347
